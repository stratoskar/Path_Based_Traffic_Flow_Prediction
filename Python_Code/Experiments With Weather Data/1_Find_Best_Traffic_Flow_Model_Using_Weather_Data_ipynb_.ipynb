# %% [markdown]
# <a href="https://colab.research.google.com/github/stratoskar/Path_Based_Traffic_Flow_Prediction/blob/main/Python_Code%20/Experiments%20With%20Weather%20Data/1_Find_Best_Traffic_Flow_Model_Using_Weather_Data_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In this section of the code, we train two discrete Machine Learning models with the purpose of forecasting traffic flow along every path. We use additional weather data to compare the results with the model trained when their use was absent.**
#
# The models that we use are: Long Short-Term Memory (LSTM) Recurent Neural Network (RNN) and an XGBoost regressor.

# %%
# Disable warnings
import warnings
warnings.filterwarnings('ignore')

# Standard library imports
import pandas as pd
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Handle timestamp data types
from datetime import datetime, timedelta

# %%
# Access google drive location
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the path with the data that we are interested in
PATH = '/content/drive/MyDrive/Paper/Timeseries/traffic_flow_SPQ.csv'

# %% [markdown]
# **Prepare the dataset**

# %%
# Read the time series dataset
traffic_flow = pd.read_csv(PATH)

# This list contains the column names
columns = ["Taxi ID", "Traj ID", "Path", "Length"]

# Generate the columns for the dataset
i = 4

while(True):
    # If it is the first iteration, append the initial timestamp
    if i == 4:
        columns.append(pd.to_datetime('2008-05-17 10:00:04'))
    else:
        # Append the next timestamp by adding 30 minutes (1800 seconds) to the previous timestamp
        columns.append(columns[i-1] + timedelta(seconds=1800))

    # Check if the current timestamp is greater than or equal to a specific end timestamp
    if (columns[i] >= pd.to_datetime('2008-06-10 09:30:04')):

        # Break out of the loop if the condition is met
        break

    # Increment the counter
    i += 1

# Delete the last timestamp
columns.pop()

# Assign new column names to the dataframe
traffic_flow.columns = columns

# %%
# Print first 2 rows of dataframe
traffic_flow.head(2)
# Out:
#    Taxi ID  Traj ID                                               Path  \
# 0      304     1291  [734004334, 734004334, 734004334, 734004334, 7...
# 1      344      433  [514685521, 514685521, 306338109, 306338109, 3...
#
#    Length  2008-05-17 10:00:04  2008-05-17 10:30:04  2008-05-17 11:00:04  \
# 0      17                    0                    0                    0
# 1       7                   11                    7                    6
#
#    2008-05-17 11:30:04  2008-05-17 12:00:04  2008-05-17 12:30:04  ...  \
# 0                    0                    0                    0  ...
# 1                    3                    0                    1  ...
#
#    2008-06-10 04:30:04  2008-06-10 05:00:04  2008-06-10 05:30:04  \
# 0                    0                    0                    1
# 1                    0                    0                    0
#
#    2008-06-10 06:00:04  2008-06-10 06:30:04  2008-06-10 07:00:04  \
# 0                    0                    0                    0
# 1                    0                    0                    0
#
#    2008-06-10 07:30:04  2008-06-10 08:00:04  2008-06-10 08:30:04  \
# 0                    0                    0                    0
# 1                    2                    2                    0
#
#    2008-06-10 09:00:04
# 0                    0
# 1                    0
#
# [2 rows x 1155 columns]

# %%
# Reshape the data from wide format to long format
id_cols = ['Taxi ID','Traj ID', 'Path', 'Length']
time_cols = traffic_flow.iloc[:,2:].columns
traffic_flow = traffic_flow.melt(id_vars=id_cols, value_vars=time_cols, var_name='Time Column', value_name='Traffic Flow')
traffic_flow['Time Column'] = pd.to_datetime(traffic_flow['Time Column'])

# Sort rows by Path and Time
traffic_flow.sort_values(by=['Path','Time Column'],inplace=True)

# %%
# Convert 'Path' column to numerical
# Use label encoder
from sklearn.preprocessing import LabelEncoder

# Create an instance of LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder on the 'Path' column
traffic_flow['Path'] = label_encoder.fit_transform(traffic_flow['Path'])

# Sort the data based in Path column
traffic_flow = traffic_flow.sort_values(by=['Path','Time Column'])

# %%
# Select only data of May, as we have only weather data from 2008-05-01 to 2008-05-31 time period
traffic_flow = traffic_flow[traffic_flow['Time Column']<'2008-06-01']

# %%
# Print dataframe
traffic_flow = traffic_flow.reset_index(drop=True)

# %%
traffic_flow
# Out:
#        Taxi ID  Traj ID  Path  Length         Time Column  Traffic Flow
# 0          108        5     0      20 2008-05-17 10:00:04             0
# 1          108        5     0      20 2008-05-17 10:30:04             0
# 2          108        5     0      20 2008-05-17 11:00:04             0
# 3          108        5     0      20 2008-05-17 11:30:04             1
# 4          108        5     0      20 2008-05-17 12:00:04             0
# ...        ...      ...   ...     ...                 ...           ...
# 69995      168      547    99       2 2008-05-31 21:30:04             0
# 69996      168      547    99       2 2008-05-31 22:00:04             0
# 69997      168      547    99       2 2008-05-31 22:30:04             0
# 69998      168      547    99       2 2008-05-31 23:00:04             0
# 69999      168      547    99       2 2008-05-31 23:30:04             1
#
# [70000 rows x 6 columns]

# %% [markdown]
# **Read and preprocess the weather data**
# In the weather dataset of San Francisco area, there are many columns that are useless for our research. We just drop them and preprocess the dataset with weather information.

# %%
# Define the path of weather data
path2 = '/content/drive/MyDrive/Paper/Dataset/Weather/weather_data.csv'

# Read weather data
weather_data = pd.read_csv(path2,sep=',')

# %%
# Drop unecessary columns

# Columns kept: temperature, humidity, windspeed and dew
weather_data = weather_data.drop(['name','conditions','visibility','feelslike','sealevelpressure','precip','precipprob','preciptype',
                                  'snow','snowdepth','windgust','winddir','cloudcover',
                                  'solarradiation','solarenergy','uvindex','severerisk','stations','icon'],axis=1)

# %%
# Convert datetime column to appropriate format
weather_data['datetime'] = pd.to_datetime(weather_data['datetime'])

# %%
# Connect two dataframes, "traffic_flow" and "weather data"
traffic_flow.set_index('Time Column', inplace=True)
weather_data.set_index('datetime', inplace=True)

# Resample the 'weather_data' dataset to 30-minute intervals and forward-fill the missing values
weather_data = weather_data.resample('30T').ffill()
weather_data.index= weather_data.index  + timedelta(seconds=4)

# Merge the time_series and weather_data_resampled datasets based on their indexes
traffic_flow = traffic_flow.merge(weather_data, left_index=True, right_index=True)

# %%
# Reset index in dataframe
traffic_flow = traffic_flow.reset_index()
traffic_flow.rename(columns={'index': 'Time Column'}, inplace=True)

# %% [markdown]
# **Feature Creation From Time Information**
#
# In this step we define some features based on time series timestamps.
# - Day, day of week, hour and minute features derive directly from the timestamp column of the dataset.
# - Hour_sin and Hour_cos columns transform the hour values into a cyclic representation, where the values range from -1 to 1. This transformation is used in time series analysis to capture the periodic patterns or cyclical nature of time-related data.
# - Use also the 3_hour_interval to describe, in which interval of the day data refer to.

# %%
### Extract timestamp information to different columns ###
traffic_flow['hour'] = traffic_flow['Time Column'].dt.hour
traffic_flow['dayofweek'] = traffic_flow['Time Column'].dt.dayofweek
traffic_flow['day'] = traffic_flow['Time Column'].dt.day
traffic_flow['minute'] = traffic_flow['Time Column'].dt.minute

### Circular Encoding for cyclic time features ###
traffic_flow['hour_sin'] = np.sin(2 * np.pi * traffic_flow['hour'] / 24)
traffic_flow['hour_cos'] = np.cos(2 * np.pi * traffic_flow['hour'] / 24)

traffic_flow['day_of_week_sin'] = np.sin(2 * np.pi * traffic_flow['dayofweek'] / 7)
traffic_flow['day_of_week_cos'] = np.cos(2 * np.pi * traffic_flow['dayofweek'] / 7)

traffic_flow['day_sin'] = np.sin(2 * np.pi * traffic_flow['day'] / 31)
traffic_flow['day_cos'] = np.cos(2 * np.pi * traffic_flow['day'] / 31)

traffic_flow['minute_sin'] = np.sin(2 * np.pi * traffic_flow['minute'] / 60)
traffic_flow['minute_cos'] = np.cos(2 * np.pi * traffic_flow['minute'] / 60)

# %%
# Define a custom function to determine the three-hour interval, based in timestamp hour information
def get_3hour_interval(hour):
    if hour in [0, 1, 2]:
        return 1
    elif hour in [3, 4, 5]:
        return 2
    elif hour in [6, 7, 8]:
        return 3
    elif hour in [9, 10, 11]:
        return 4
    elif hour in [12, 13, 14]:
        return 5
    elif hour in [15, 16, 17]:
        return 6
    elif hour in [18, 19, 20]:
        return 7
    elif hour in [21, 22, 23]:
        return 8
    else:
        return None

# Apply the custom function on the data to create the '3hour_interval' column
traffic_flow['3hour_interval'] = traffic_flow['hour'].apply(get_3hour_interval)

# %%
traffic_flow.head(5)
# Out:
#           Time Column  Taxi ID  Traj ID  Path  Length  Traffic Flow  temp  \
# 0 2008-05-17 10:00:04      108        5     0      20             0  21.4
# 1 2008-05-17 10:00:04      176      259     1      15             0  21.4
# 2 2008-05-17 10:00:04      331      515     2      16             1  21.4
# 3 2008-05-17 10:00:04       47      361     3      20            13  21.4
# 4 2008-05-17 10:00:04      176       99     4       6            26  21.4
#
#     dew  humidity  windspeed  ...  minute  hour_sin  hour_cos  \
# 0  11.8     54.07       12.1  ...       0       0.5 -0.866025
# 1  11.8     54.07       12.1  ...       0       0.5 -0.866025
# 2  11.8     54.07       12.1  ...       0       0.5 -0.866025
# 3  11.8     54.07       12.1  ...       0       0.5 -0.866025
# 4  11.8     54.07       12.1  ...       0       0.5 -0.866025
#
#    day_of_week_sin  day_of_week_cos   day_sin   day_cos  minute_sin  \
# 0        -0.974928        -0.222521 -0.299363 -0.954139         0.0
# 1        -0.974928        -0.222521 -0.299363 -0.954139         0.0
# 2        -0.974928        -0.222521 -0.299363 -0.954139         0.0
# 3        -0.974928        -0.222521 -0.299363 -0.954139         0.0
# 4        -0.974928        -0.222521 -0.299363 -0.954139         0.0
#
#    minute_cos  3hour_interval
# 0         1.0               4
# 1         1.0               4
# 2         1.0               4
# 3         1.0               4
# 4         1.0               4
#
# [5 rows x 23 columns]

# %%
print(f"Earlier timestamp in traffic_flow dataframe is: {traffic_flow['Time Column'].min()}")
print(f"Latest timestamp in traffic_flow dataframe is: {traffic_flow['Time Column'].max()}")
# Out:
# Earlier timestamp in traffic_flow dataframe is: 2008-05-17 10:00:04
# Latest timestamp in traffic_flow dataframe is: 2008-05-31 23:00:04

# %%
# Use a correlation matrix to show correlations among attributes in the dataset
sns.heatmap(traffic_flow.corr(),cmap='viridis')
# Out:
# <Axes: >

# %%
# Define a list with the items to be removed
removable_items = ['Record 1(t)', 'Time Column', 'Taxi ID', 'Traj ID', 'Length', 'Traffic Flow', 'hour', 'hour_sin','day_of_week_cos', 'dayofweek', 'day', 'minute', 'minute_cos']

# %% [markdown]
# #### **Find the Optimum Sliding Window Length**

# %%
# Sort the time series data
traffic_flow.sort_values(by=['Path','Time Column'], inplace=True)

# %%
# Import libraries to use XGBoost model
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# Import libraries to use the LSTM Neural Network algorithm
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
import tensorflow as tf

# Min Max Scaler
from sklearn.preprocessing import MinMaxScaler

# %%
# Use Regression Evaluation Metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# **Create function that converts the data into a supervised problem**
#
# Consider for each path n_in timesteps of observations in the past, in order to predict the n_out timesteps in the future.

# %%
def series_to_supervised(data, n_in=1, n_out=1):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # Input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('Record %d(t-%d)' % (j+1, i)) for j in range(n_vars)]

    # Generate sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('Record %d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('Record %d(t+%d)' % (j+1, i)) for j in range(n_vars)]

    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    return agg

def generate_X_y_pairs(data, n_in=1, n_out=1):
    """
    Convert the training data into a supervised dataset. Create X,y pairs of the traffic column information.
    Then, concatenate the rest of the columns.
    """
    new_data = pd.DataFrame()

    # Iterate over unique values in the 'Path' column
    for item in data['Path'].unique():
        # Call function only for the 'Traffic Flow' column
        supervised_traffic_flow = series_to_supervised(pd.DataFrame(data[data['Path'] == item]['Traffic Flow']), n_in, n_out)

        # Concatenate the rest of the columns
        supervised_traffic_flow = pd.concat([supervised_traffic_flow, traffic_flow[traffic_flow['Path'] == item]], axis=1)

        new_data = pd.concat([new_data, supervised_traffic_flow])

    # Drop rows with NaN values
    new_data.dropna(inplace=True)
    return new_data

# %% [markdown]
# ##### Sliding Window Length Equals to 2

# %%
# Define Window Length
optimum_lookback = 2

# %%
# Define train data
train= traffic_flow.loc[traffic_flow['Time Column'] < '2008-05-29']

# Define test data
test = traffic_flow.loc[traffic_flow['Time Column'] >= '2008-05-29']

# %%
# Convert train and test data to supervised problem based in the optimum lookback step we defined above.
train = generate_X_y_pairs(train, optimum_lookback)
test = generate_X_y_pairs(test, optimum_lookback)

# %%
# Add rolling mean information
train['rolling_mean'] = 0
test['rolling_mean'] = 0

# Add rolling var information
train['rolling_var'] = 0
test['rolling_var'] = 0

# Calculate rolling mean of window
train['rolling_mean'] = train.iloc[:,0:2].mean(axis=1)
test['rolling_mean'] = test.iloc[:,0:optimum_lookback].mean(axis=1)

# Calculate rolling variance of window
train['rolling_var'] = train.iloc[:, 0:optimum_lookback].var(axis=1)
test['rolling_var'] = test.iloc[:, 0:optimum_lookback].var(axis=1)

# %%
# Define features
features = train.drop(removable_items,axis=1).columns

# Define labels
labels = ['Record 1(t)']

# Create X_train and y_train data sets
X_train = train[features]
y_train = train[labels]

# Create X_test and y_test data sets
X_test = test[features]
y_test = test[labels]

# %% [markdown]
# **Apply GridSearchCV**
#
# Use a 3-fold K-fold cross-validation was used for learning the optimum hyperparameters for the XGBoost algorithm.

# %%
# Import Grid Search library
from sklearn.model_selection import GridSearchCV

# %%
# Tune hyperparameters using XGboost
xgb_params = {
    "n_estimators": [100],
    "learning_rate": [0.1],
    "max_depth": [3,6,9],
    "objective":['reg:squarederror'],
    "gamma": [0,0.1],
    "reg_lambda": [0,1],
    'reg_alpha': [0, 0.1]
}

# Define GridSearchCV object
xgb_grid = GridSearchCV(xgb.XGBRegressor(),
                        xgb_params,cv=3,
                        scoring= "neg_mean_squared_error")

# Train on train data using 3 fold Cross Validation
xgb_grid.fit(X_train,y_train,
             early_stopping_rounds=5,
             eval_set=[(X_train, y_train), (X_test,y_test)],
             eval_metric='rmse')

# print the best hyperparameters and corresponding score
print("Best Hyperparameters: ", xgb_grid.best_params_)
print("Best Score: ", xgb_grid.best_score_)
# Out:
# [0]	validation_0-rmse:4.58107	validation_1-rmse:4.50583
# [1]	validation_0-rmse:4.26298	validation_1-rmse:4.18637
# [2]	validation_0-rmse:3.98530	validation_1-rmse:3.91207
# [3]	validation_0-rmse:3.74203	validation_1-rmse:3.67107
# [4]	validation_0-rmse:3.53157	validation_1-rmse:3.46369
# [5]	validation_0-rmse:3.34920	validation_1-rmse:3.28516
# [6]	validation_0-rmse:3.19368	validation_1-rmse:3.13353
# [7]	validation_0-rmse:3.06015	validation_1-rmse:3.00343
# [8]	validation_0-rmse:2.94598	validation_1-rmse:2.89404
# [9]	validation_0-rmse:2.85013	validation_1-rmse:2.80179
# [10]	validation_0-rmse:2.76855	validation_1-rmse:2.72474
# [11]	validation_0-rmse:2.69993	validation_1-rmse:2.66064
# [12]	validation_0-rmse:2.64002	validation_1-rmse:2.60367
# [13]	validation_0-rmse:2.59059	validation_1-rmse:2.55649
# [14]	validation_0-rmse:2.54989	validation_1-rmse:2.51956
# [15]	validation_0-rmse:2.51699	validation_1-rmse:2.49056
# [16]	validation_0-rmse:2.48797	validation_1-rmse:2.46363
# [17]	validation_0-rmse:2.46440	validation_1-rmse:2.44330
# [18]	validation_0-rmse:2.44487	validation_1-rmse:2.42636
# [19]	validation_0-rmse:2.42812	validation_1-rmse:2.41131
# [20]	validation_0-rmse:2.41425	validation_1-rmse:2.39937
# [21]	validation_0-rmse:2.40427	validation_1-rmse:2.39048
# [22]	validation_0-rmse:2.39386	validation_1-rmse:2.38192
# [23]	validation_0-rmse:2.38543	validation_1-rmse:2.37513
# [24]	validation_0-rmse:2.37718	validation_1-rmse:2.36777
# [25]	validation_0-rmse:2.36961	validation_1-rmse:2.36165
# [26]	validation_0-rmse:2.36497	validation_1-rmse:2.35803
# [27]	validation_0-rmse:2.36075	validation_1-rmse:2.35440
# [28]	validation_0-rmse:2.35667	validation_1-rmse:2.35095
# [29]	validation_0-rmse:2.35263	validation_1-rmse:2.34867
# [30]	validation_0-rmse:2.34893	validation_1-rmse:2.34524
# [31]	validation_0-rmse:2.34600	validation_1-rmse:2.34358
# [32]	validation_0-rmse:2.34335	validation_1-rmse:2.34136
# [33]	validation_0-rmse:2.34116	validation_1-rmse:2.34015
# [34]	validation_0-rmse:2.33894	validation_1-rmse:2.33853
# [35]	validation_0-rmse:2.33737	validation_1-rmse:2.33804
# [36]	validation_0-rmse:2.33413	validation_1-rmse:2.33597
# [37]	validation_0-rmse:2.34040	validation_1-rmse:2.33939
# [38]	validation_0-rmse:2.34002	validation_1-rmse:2.33919
# [39]	validation_0-rmse:2.33748	validation_1-rmse:2.33767
# [40]	validation_0-rmse:2.33563	validation_1-rmse:2.33707
# [0]	validation_0-rmse:4.58089	validation_1-rmse:4.50377
# [1]	validation_0-rmse:4.26406	validation_1-rmse:4.18730
# [2]	validation_0-rmse:3.98993	validation_1-rmse:3.91694
# [3]	validation_0-rmse:3.74533	validation_1-rmse:3.67594
# [4]	validation_0-rmse:3.53709	validation_1-rmse:3.47069
# [5]	validation_0-rmse:3.35749	validation_1-rmse:3.29337
# [6]	validation_0-rmse:3.20398	validation_1-rmse:3.14386
# [7]	validation_0-rmse:3.06908	validation_1-rmse:3.01291
# [8]	validation_0-rmse:2.95389	validation_1-rmse:2.90193
# [9]	validation_0-rmse:2.86361	validation_1-rmse:2.81249
# [10]	validation_0-rmse:2.78013	validation_1-rmse:2.73346
# [11]	validation_0-rmse:2.71643	validation_1-rmse:2.67118
# [12]	validation_0-rmse:2.65757	validation_1-rmse:2.61757
# [13]	validation_0-rmse:2.60725	validation_1-rmse:2.57140
# [14]	validation_0-rmse:2.56994	validation_1-rmse:2.53649
# [15]	validation_0-rmse:2.53805	validation_1-rmse:2.50612
# [16]	validation_0-rmse:2.51091	validation_1-rmse:2.47994
# [17]	validation_0-rmse:2.48756	validation_1-rmse:2.45849
# [18]	validation_0-rmse:2.46825	validation_1-rmse:2.43919
# [19]	validation_0-rmse:2.45226	validation_1-rmse:2.42466
# [20]	validation_0-rmse:2.43757	validation_1-rmse:2.41141
# [21]	validation_0-rmse:2.42479	validation_1-rmse:2.40129
# [22]	validation_0-rmse:2.41395	validation_1-rmse:2.39108
# [23]	validation_0-rmse:2.40415	validation_1-rmse:2.38186
# [24]	validation_0-rmse:2.39963	validation_1-rmse:2.37774
# [25]	validation_0-rmse:2.39408	validation_1-rmse:2.37329
# [26]	validation_0-rmse:2.38791	validation_1-rmse:2.36938
# [27]	validation_0-rmse:2.38580	validation_1-rmse:2.36804
# [28]	validation_0-rmse:2.38136	validation_1-rmse:2.36395
# [29]	validation_0-rmse:2.37694	validation_1-rmse:2.36136
# [30]	validation_0-rmse:2.37386	validation_1-rmse:2.35938
# [31]	validation_0-rmse:2.36900	validation_1-rmse:2.35602
# [32]	validation_0-rmse:2.36567	validation_1-rmse:2.35311
# [33]	validation_0-rmse:2.36195	validation_1-rmse:2.35101
# [34]	validation_0-rmse:2.35789	validation_1-rmse:2.34754
# [35]	validation_0-rmse:2.35583	validation_1-rmse:2.34667
# [36]	validation_0-rmse:2.35295	validation_1-rmse:2.34554
# [37]	validation_0-rmse:2.35110	validation_1-rmse:2.34521
# [38]	validation_0-rmse:2.34887	validation_1-rmse:2.34385
# [39]	validation_0-rmse:2.34753	validation_1-rmse:2.34227
# [40]	validation_0-rmse:2.34495	validation_1-rmse:2.34112
# [41]	validation_0-rmse:2.34289	validation_1-rmse:2.34006
# [42]	validation_0-rmse:2.34149	validation_1-rmse:2.34015
# [43]	validation_0-rmse:2.34009	validation_1-rmse:2.33922
# [44]	validation_0-rmse:2.33806	validation_1-rmse:2.33816
# [45]	validation_0-rmse:2.33780	validation_1-rmse:2.33791
# [46]	validation_0-rmse:2.33766	validation_1-rmse:2.33804
# [47]	validation_0-rmse:2.33556	validation_1-rmse:2.33813
# [48]	validation_0-rmse:2.33635	validation_1-rmse:2.33782
# [49]	validation_0-rmse:2.33480	validation_1-rmse:2.33868
# [50]	validation_0-rmse:2.33459	validation_1-rmse:2.33865
# [51]	validation_0-rmse:2.33296	validation_1-rmse:2.33778
# [52]	validation_0-rmse:2.33297	validation_1-rmse:2.33796
# [53]	validation_0-rmse:2.33369	validation_1-rmse:2.33775
# [54]	validation_0-rmse:2.33274	validation_1-rmse:2.33687
# [55]	validation_0-rmse:2.33158	validation_1-rmse:2.33578
# [56]	validation_0-rmse:2.33114	validation_1-rmse:2.33525
# [57]	validation_0-rmse:2.33034	validation_1-rmse:2.33468
# [58]	validation_0-rmse:2.32895	validation_1-rmse:2.33467
# [59]	validation_0-rmse:2.32771	validation_1-rmse:2.33612
# [60]	validation_0-rmse:2.32791	validation_1-rmse:2.33659
# [61]	validation_0-rmse:2.32688	validation_1-rmse:2.33539
# [62]	validation_0-rmse:2.32579	validation_1-rmse:2.33578
# [63]	validation_0-rmse:2.32453	validation_1-rmse:2.33454
# [64]	validation_0-rmse:2.32360	validation_1-rmse:2.33418
# [65]	validation_0-rmse:2.32256	validation_1-rmse:2.33418
# [66]	validation_0-rmse:2.32281	validation_1-rmse:2.33419
# [67]	validation_0-rmse:2.32356	validation_1-rmse:2.33386
# [68]	validation_0-rmse:2.32210	validation_1-rmse:2.33455
# [69]	validation_0-rmse:2.32176	validation_1-rmse:2.33476
# [70]	validation_0-rmse:2.32114	validation_1-rmse:2.33417
# [71]	validation_0-rmse:2.32057	validation_1-rmse:2.33398
# [72]	validation_0-rmse:2.31924	validation_1-rmse:2.33326
# [73]	validation_0-rmse:2.31902	validation_1-rmse:2.33367
# [74]	validation_0-rmse:2.32020	validation_1-rmse:2.33402
# [75]	validation_0-rmse:2.31921	validation_1-rmse:2.33339
# [76]	validation_0-rmse:2.31868	validation_1-rmse:2.33300
# [77]	validation_0-rmse:2.31743	validation_1-rmse:2.33264
# [78]	validation_0-rmse:2.31681	validation_1-rmse:2.33194
# [79]	validation_0-rmse:2.31662	validation_1-rmse:2.33172
# [80]	validation_0-rmse:2.31565	validation_1-rmse:2.33142
# [81]	validation_0-rmse:2.31475	validation_1-rmse:2.33297
# [82]	validation_0-rmse:2.31402	validation_1-rmse:2.33294
# [83]	validation_0-rmse:2.31357	validation_1-rmse:2.33264
# [84]	validation_0-rmse:2.31258	validation_1-rmse:2.33237
# [85]	validation_0-rmse:2.31205	validation_1-rmse:2.33169
# [0]	validation_0-rmse:4.56905	validation_1-rmse:4.49279
# [1]	validation_0-rmse:4.24283	validation_1-rmse:4.16699
# [2]	validation_0-rmse:3.95932	validation_1-rmse:3.88647
# [3]	validation_0-rmse:3.71127	validation_1-rmse:3.64249
# [4]	validation_0-rmse:3.49778	validation_1-rmse:3.43093
# [5]	validation_0-rmse:3.31503	validation_1-rmse:3.25299
# [6]	validation_0-rmse:3.15762	validation_1-rmse:3.09973
# [7]	validation_0-rmse:3.02365	validation_1-rmse:2.97230
# [8]	validation_0-rmse:2.91063	validation_1-rmse:2.86301
# [9]	validation_0-rmse:2.81526	validation_1-rmse:2.77178
# [10]	validation_0-rmse:2.73466	validation_1-rmse:2.69597
# [11]	validation_0-rmse:2.66696	validation_1-rmse:2.63255
# [12]	validation_0-rmse:2.61105	validation_1-rmse:2.58156
# [13]	validation_0-rmse:2.56475	validation_1-rmse:2.53851
# [14]	validation_0-rmse:2.52248	validation_1-rmse:2.49831
# [15]	validation_0-rmse:2.49029	validation_1-rmse:2.46775
# [16]	validation_0-rmse:2.46254	validation_1-rmse:2.44189
# [17]	validation_0-rmse:2.44112	validation_1-rmse:2.42189
# [18]	validation_0-rmse:2.42397	validation_1-rmse:2.40627
# [19]	validation_0-rmse:2.40925	validation_1-rmse:2.39413
# [20]	validation_0-rmse:2.39606	validation_1-rmse:2.38317
# [21]	validation_0-rmse:2.38458	validation_1-rmse:2.37316
# [22]	validation_0-rmse:2.37668	validation_1-rmse:2.36736
# [23]	validation_0-rmse:2.36947	validation_1-rmse:2.36278
# [24]	validation_0-rmse:2.36401	validation_1-rmse:2.35966
# [25]	validation_0-rmse:2.35794	validation_1-rmse:2.35458
# [26]	validation_0-rmse:2.35310	validation_1-rmse:2.35064
# [27]	validation_0-rmse:2.34945	validation_1-rmse:2.34980
# [28]	validation_0-rmse:2.34670	validation_1-rmse:2.34896
# [29]	validation_0-rmse:2.34448	validation_1-rmse:2.34697
# [30]	validation_0-rmse:2.34166	validation_1-rmse:2.34460
# [31]	validation_0-rmse:2.34120	validation_1-rmse:2.34480
# [32]	validation_0-rmse:2.33976	validation_1-rmse:2.34537
# [33]	validation_0-rmse:2.34063	validation_1-rmse:2.34772
# [34]	validation_0-rmse:2.33945	validation_1-rmse:2.34765
# [35]	validation_0-rmse:2.33789	validation_1-rmse:2.34683
# [0]	validation_0-rmse:4.58169	validation_1-rmse:4.50636
# [1]	validation_0-rmse:4.26410	validation_1-rmse:4.18735
# [2]	validation_0-rmse:3.98671	validation_1-rmse:3.91329
# [3]	validation_0-rmse:3.74376	validation_1-rmse:3.67254
# [4]	validation_0-rmse:3.53336	validation_1-rmse:3.46519
# [5]	validation_0-rmse:3.35114	validation_1-rmse:3.28677
# [6]	validation_0-rmse:3.19567	validation_1-rmse:3.13514
# [7]	validation_0-rmse:3.06221	validation_1-rmse:3.00506
# [8]	validation_0-rmse:2.94809	validation_1-rmse:2.89563
# [9]	validation_0-rmse:2.85211	validation_1-rmse:2.80326
# [10]	validation_0-rmse:2.77054	validation_1-rmse:2.72627
# [11]	validation_0-rmse:2.70174	validation_1-rmse:2.66235
# [12]	validation_0-rmse:2.64168	validation_1-rmse:2.60524
# [13]	validation_0-rmse:2.59211	validation_1-rmse:2.55794
# [14]	validation_0-rmse:2.55127	validation_1-rmse:2.52092
# [15]	validation_0-rmse:2.51830	validation_1-rmse:2.49166
# [16]	validation_0-rmse:2.48915	validation_1-rmse:2.46455
# [17]	validation_0-rmse:2.46552	validation_1-rmse:2.44391
# [18]	validation_0-rmse:2.44575	validation_1-rmse:2.42678
# [19]	validation_0-rmse:2.43040	validation_1-rmse:2.41378
# [20]	validation_0-rmse:2.41847	validation_1-rmse:2.40311
# [21]	validation_0-rmse:2.40677	validation_1-rmse:2.39258
# [22]	validation_0-rmse:2.39653	validation_1-rmse:2.38405
# [23]	validation_0-rmse:2.38782	validation_1-rmse:2.37703
# [24]	validation_0-rmse:2.38048	validation_1-rmse:2.37113
# [25]	validation_0-rmse:2.37408	validation_1-rmse:2.36539
# [26]	validation_0-rmse:2.36766	validation_1-rmse:2.36023
# [27]	validation_0-rmse:2.36256	validation_1-rmse:2.35633
# [28]	validation_0-rmse:2.35732	validation_1-rmse:2.35231
# [29]	validation_0-rmse:2.35327	validation_1-rmse:2.34911
# [30]	validation_0-rmse:2.34996	validation_1-rmse:2.34722
# [31]	validation_0-rmse:2.34608	validation_1-rmse:2.34430
# [32]	validation_0-rmse:2.34316	validation_1-rmse:2.34201
# [33]	validation_0-rmse:2.34065	validation_1-rmse:2.34060
# [34]	validation_0-rmse:2.34116	validation_1-rmse:2.34093
# [35]	validation_0-rmse:2.33838	validation_1-rmse:2.33911
# [36]	validation_0-rmse:2.33741	validation_1-rmse:2.33843
# [37]	validation_0-rmse:2.33436	validation_1-rmse:2.33645
# [38]	validation_0-rmse:2.33283	validation_1-rmse:2.33587
# [39]	validation_0-rmse:2.33144	validation_1-rmse:2.33556
# [40]	validation_0-rmse:2.33007	validation_1-rmse:2.33510
# [41]	validation_0-rmse:2.32824	validation_1-rmse:2.33412
# [42]	validation_0-rmse:2.32717	validation_1-rmse:2.33401
# [43]	validation_0-rmse:2.32579	validation_1-rmse:2.33420
# [44]	validation_0-rmse:2.32517	validation_1-rmse:2.33390
# [45]	validation_0-rmse:2.32470	validation_1-rmse:2.33373
# [46]	validation_0-rmse:2.32391	validation_1-rmse:2.33369
# [47]	validation_0-rmse:2.32327	validation_1-rmse:2.33360
# [48]	validation_0-rmse:2.32208	validation_1-rmse:2.33328
# [49]	validation_0-rmse:2.32009	validation_1-rmse:2.33201
# [50]	validation_0-rmse:2.31958	validation_1-rmse:2.33203
# [51]	validation_0-rmse:2.31919	validation_1-rmse:2.33192
# [52]	validation_0-rmse:2.31877	validation_1-rmse:2.33157
# [53]	validation_0-rmse:2.31756	validation_1-rmse:2.33101
# [54]	validation_0-rmse:2.31653	validation_1-rmse:2.32998
# [55]	validation_0-rmse:2.31629	validation_1-rmse:2.33077
# [56]	validation_0-rmse:2.31595	validation_1-rmse:2.33056
# [57]	validation_0-rmse:2.31404	validation_1-rmse:2.32918
# [58]	validation_0-rmse:2.31218	validation_1-rmse:2.32982
# [59]	validation_0-rmse:2.31165	validation_1-rmse:2.32997
# [60]	validation_0-rmse:2.31102	validation_1-rmse:2.32972
# [61]	validation_0-rmse:2.30944	validation_1-rmse:2.32833
# [62]	validation_0-rmse:2.30891	validation_1-rmse:2.32798
# [63]	validation_0-rmse:2.30811	validation_1-rmse:2.32805
# [64]	validation_0-rmse:2.30747	validation_1-rmse:2.32820
# [65]	validation_0-rmse:2.30688	validation_1-rmse:2.32824
# [66]	validation_0-rmse:2.30688	validation_1-rmse:2.32820
# [67]	validation_0-rmse:2.30644	validation_1-rmse:2.32784
# [68]	validation_0-rmse:2.30590	validation_1-rmse:2.32775
# [69]	validation_0-rmse:2.30417	validation_1-rmse:2.32637
# [70]	validation_0-rmse:2.30270	validation_1-rmse:2.32556
# [71]	validation_0-rmse:2.30196	validation_1-rmse:2.32538
# [72]	validation_0-rmse:2.30485	validation_1-rmse:2.32751
# [73]	validation_0-rmse:2.30483	validation_1-rmse:2.32859
# [74]	validation_0-rmse:2.30421	validation_1-rmse:2.32870
# [75]	validation_0-rmse:2.30354	validation_1-rmse:2.32879
# [76]	validation_0-rmse:2.30298	validation_1-rmse:2.32884
# [0]	validation_0-rmse:4.58147	validation_1-rmse:4.50426
# [1]	validation_0-rmse:4.26521	validation_1-rmse:4.18827
# [2]	validation_0-rmse:3.99135	validation_1-rmse:3.91813
# [3]	validation_0-rmse:3.74727	validation_1-rmse:3.67751
# [4]	validation_0-rmse:3.53919	validation_1-rmse:3.47238
# [5]	validation_0-rmse:3.35960	validation_1-rmse:3.29505
# [6]	validation_0-rmse:3.20603	validation_1-rmse:3.14547
# [7]	validation_0-rmse:3.07124	validation_1-rmse:3.01457
# [8]	validation_0-rmse:2.95606	validation_1-rmse:2.90354
# [9]	validation_0-rmse:2.86572	validation_1-rmse:2.81402
# [10]	validation_0-rmse:2.78215	validation_1-rmse:2.73488
# [11]	validation_0-rmse:2.71836	validation_1-rmse:2.67250
# [12]	validation_0-rmse:2.66407	validation_1-rmse:2.61978
# [13]	validation_0-rmse:2.61312	validation_1-rmse:2.57316
# [14]	validation_0-rmse:2.57138	validation_1-rmse:2.53660
# [15]	validation_0-rmse:2.53943	validation_1-rmse:2.50623
# [16]	validation_0-rmse:2.51252	validation_1-rmse:2.48005
# [17]	validation_0-rmse:2.48907	validation_1-rmse:2.45847
# [18]	validation_0-rmse:2.46971	validation_1-rmse:2.43908
# [19]	validation_0-rmse:2.45358	validation_1-rmse:2.42442
# [20]	validation_0-rmse:2.43880	validation_1-rmse:2.41106
# [21]	validation_0-rmse:2.42615	validation_1-rmse:2.40099
# [22]	validation_0-rmse:2.41484	validation_1-rmse:2.39010
# [23]	validation_0-rmse:2.40549	validation_1-rmse:2.38143
# [24]	validation_0-rmse:2.40095	validation_1-rmse:2.37728
# [25]	validation_0-rmse:2.39535	validation_1-rmse:2.37278
# [26]	validation_0-rmse:2.38918	validation_1-rmse:2.36888
# [27]	validation_0-rmse:2.38341	validation_1-rmse:2.36565
# [28]	validation_0-rmse:2.37892	validation_1-rmse:2.36161
# [29]	validation_0-rmse:2.37279	validation_1-rmse:2.35760
# [30]	validation_0-rmse:2.36918	validation_1-rmse:2.35467
# [31]	validation_0-rmse:2.36560	validation_1-rmse:2.35117
# [32]	validation_0-rmse:2.36234	validation_1-rmse:2.34962
# [33]	validation_0-rmse:2.35926	validation_1-rmse:2.34796
# [34]	validation_0-rmse:2.35710	validation_1-rmse:2.34688
# [35]	validation_0-rmse:2.35315	validation_1-rmse:2.34345
# [36]	validation_0-rmse:2.35092	validation_1-rmse:2.34242
# [37]	validation_0-rmse:2.34852	validation_1-rmse:2.34157
# [38]	validation_0-rmse:2.34689	validation_1-rmse:2.34147
# [39]	validation_0-rmse:2.34565	validation_1-rmse:2.34030
# [40]	validation_0-rmse:2.34384	validation_1-rmse:2.33925
# [41]	validation_0-rmse:2.34306	validation_1-rmse:2.33821
# [42]	validation_0-rmse:2.34139	validation_1-rmse:2.33785
# [43]	validation_0-rmse:2.34047	validation_1-rmse:2.33842
# [44]	validation_0-rmse:2.34101	validation_1-rmse:2.33760
# [45]	validation_0-rmse:2.33957	validation_1-rmse:2.33760
# [46]	validation_0-rmse:2.34033	validation_1-rmse:2.33728
# [47]	validation_0-rmse:2.33925	validation_1-rmse:2.33647
# [48]	validation_0-rmse:2.33747	validation_1-rmse:2.33660
# [49]	validation_0-rmse:2.33644	validation_1-rmse:2.33637
# [50]	validation_0-rmse:2.33626	validation_1-rmse:2.33605
# [51]	validation_0-rmse:2.33510	validation_1-rmse:2.33509
# [52]	validation_0-rmse:2.33375	validation_1-rmse:2.33587
# [53]	validation_0-rmse:2.33273	validation_1-rmse:2.33606
# [54]	validation_0-rmse:2.33182	validation_1-rmse:2.33523
# [55]	validation_0-rmse:2.33056	validation_1-rmse:2.33400
# [56]	validation_0-rmse:2.33047	validation_1-rmse:2.33434
# [57]	validation_0-rmse:2.33025	validation_1-rmse:2.33436
# [58]	validation_0-rmse:2.32948	validation_1-rmse:2.33382
# [59]	validation_0-rmse:2.32903	validation_1-rmse:2.33395
# [60]	validation_0-rmse:2.32781	validation_1-rmse:2.33570
# [61]	validation_0-rmse:2.32700	validation_1-rmse:2.33527
# [62]	validation_0-rmse:2.32534	validation_1-rmse:2.33528
# [63]	validation_0-rmse:2.32561	validation_1-rmse:2.33455
# [0]	validation_0-rmse:4.56955	validation_1-rmse:4.49325
# [1]	validation_0-rmse:4.24366	validation_1-rmse:4.16773
# [2]	validation_0-rmse:3.96045	validation_1-rmse:3.88747
# [3]	validation_0-rmse:3.71251	validation_1-rmse:3.64358
# [4]	validation_0-rmse:3.49909	validation_1-rmse:3.43207
# [5]	validation_0-rmse:3.31643	validation_1-rmse:3.25418
# [6]	validation_0-rmse:3.15900	validation_1-rmse:3.10089
# [7]	validation_0-rmse:3.02507	validation_1-rmse:2.97345
# [8]	validation_0-rmse:2.91244	validation_1-rmse:2.86476
# [9]	validation_0-rmse:2.81687	validation_1-rmse:2.77266
# [10]	validation_0-rmse:2.73628	validation_1-rmse:2.69690
# [11]	validation_0-rmse:2.66854	validation_1-rmse:2.63352
# [12]	validation_0-rmse:2.61246	validation_1-rmse:2.58241
# [13]	validation_0-rmse:2.56603	validation_1-rmse:2.53930
# [14]	validation_0-rmse:2.52367	validation_1-rmse:2.49914
# [15]	validation_0-rmse:2.49144	validation_1-rmse:2.46862
# [16]	validation_0-rmse:2.46357	validation_1-rmse:2.44276
# [17]	validation_0-rmse:2.44195	validation_1-rmse:2.42284
# [18]	validation_0-rmse:2.42452	validation_1-rmse:2.40695
# [19]	validation_0-rmse:2.41005	validation_1-rmse:2.39385
# [20]	validation_0-rmse:2.39703	validation_1-rmse:2.38368
# [21]	validation_0-rmse:2.38702	validation_1-rmse:2.37633
# [22]	validation_0-rmse:2.37721	validation_1-rmse:2.36785
# [23]	validation_0-rmse:2.37002	validation_1-rmse:2.36250
# [24]	validation_0-rmse:2.36392	validation_1-rmse:2.35875
# [25]	validation_0-rmse:2.35910	validation_1-rmse:2.35640
# [26]	validation_0-rmse:2.35399	validation_1-rmse:2.35190
# [27]	validation_0-rmse:2.35059	validation_1-rmse:2.35048
# [28]	validation_0-rmse:2.34869	validation_1-rmse:2.34973
# [29]	validation_0-rmse:2.34617	validation_1-rmse:2.34910
# [30]	validation_0-rmse:2.34268	validation_1-rmse:2.34579
# [31]	validation_0-rmse:2.34039	validation_1-rmse:2.34465
# [32]	validation_0-rmse:2.33807	validation_1-rmse:2.34274
# [33]	validation_0-rmse:2.33689	validation_1-rmse:2.34304
# [34]	validation_0-rmse:2.33691	validation_1-rmse:2.34362
# [35]	validation_0-rmse:2.33786	validation_1-rmse:2.34552
# [36]	validation_0-rmse:2.33633	validation_1-rmse:2.34506
# [0]	validation_0-rmse:4.58108	validation_1-rmse:4.50583
# [1]	validation_0-rmse:4.26299	validation_1-rmse:4.18637
# [2]	validation_0-rmse:3.98531	validation_1-rmse:3.91208
# [3]	validation_0-rmse:3.74204	validation_1-rmse:3.67108
# [4]	validation_0-rmse:3.53158	validation_1-rmse:3.46370
# [5]	validation_0-rmse:3.34921	validation_1-rmse:3.28517
# [6]	validation_0-rmse:3.19370	validation_1-rmse:3.13355
# [7]	validation_0-rmse:3.06016	validation_1-rmse:3.00345
# [8]	validation_0-rmse:2.94599	validation_1-rmse:2.89406
# [9]	validation_0-rmse:2.85015	validation_1-rmse:2.80181
# [10]	validation_0-rmse:2.76857	validation_1-rmse:2.72476
# [11]	validation_0-rmse:2.69995	validation_1-rmse:2.66066
# [12]	validation_0-rmse:2.64004	validation_1-rmse:2.60368
# [13]	validation_0-rmse:2.59061	validation_1-rmse:2.55650
# [14]	validation_0-rmse:2.54991	validation_1-rmse:2.51957
# [15]	validation_0-rmse:2.51701	validation_1-rmse:2.49057
# [16]	validation_0-rmse:2.48798	validation_1-rmse:2.46364
# [17]	validation_0-rmse:2.46442	validation_1-rmse:2.44331
# [18]	validation_0-rmse:2.44489	validation_1-rmse:2.42636
# [19]	validation_0-rmse:2.42813	validation_1-rmse:2.41132
# [20]	validation_0-rmse:2.41427	validation_1-rmse:2.39938
# [21]	validation_0-rmse:2.40428	validation_1-rmse:2.39049
# [22]	validation_0-rmse:2.39388	validation_1-rmse:2.38193
# [23]	validation_0-rmse:2.38544	validation_1-rmse:2.37514
# [24]	validation_0-rmse:2.37719	validation_1-rmse:2.36778
# [25]	validation_0-rmse:2.36962	validation_1-rmse:2.36165
# [26]	validation_0-rmse:2.36498	validation_1-rmse:2.35803
# [27]	validation_0-rmse:2.36076	validation_1-rmse:2.35441
# [28]	validation_0-rmse:2.35668	validation_1-rmse:2.35095
# [29]	validation_0-rmse:2.35264	validation_1-rmse:2.34867
# [30]	validation_0-rmse:2.34894	validation_1-rmse:2.34525
# [31]	validation_0-rmse:2.34601	validation_1-rmse:2.34359
# [32]	validation_0-rmse:2.34336	validation_1-rmse:2.34136
# [33]	validation_0-rmse:2.34117	validation_1-rmse:2.34015
# [34]	validation_0-rmse:2.33895	validation_1-rmse:2.33853
# [35]	validation_0-rmse:2.33725	validation_1-rmse:2.33781
# [36]	validation_0-rmse:2.33403	validation_1-rmse:2.33577
# [37]	validation_0-rmse:2.33321	validation_1-rmse:2.33539
# [38]	validation_0-rmse:2.33952	validation_1-rmse:2.33885
# [39]	validation_0-rmse:2.33915	validation_1-rmse:2.33864
# [40]	validation_0-rmse:2.33770	validation_1-rmse:2.33807
# [41]	validation_0-rmse:2.33637	validation_1-rmse:2.33720
# [42]	validation_0-rmse:2.33620	validation_1-rmse:2.33707
# [0]	validation_0-rmse:4.58090	validation_1-rmse:4.50377
# [1]	validation_0-rmse:4.26407	validation_1-rmse:4.18731
# [2]	validation_0-rmse:3.98994	validation_1-rmse:3.91695
# [3]	validation_0-rmse:3.74535	validation_1-rmse:3.67595
# [4]	validation_0-rmse:3.53710	validation_1-rmse:3.47070
# [5]	validation_0-rmse:3.35750	validation_1-rmse:3.29338
# [6]	validation_0-rmse:3.20400	validation_1-rmse:3.14387
# [7]	validation_0-rmse:3.06909	validation_1-rmse:3.01293
# [8]	validation_0-rmse:2.95391	validation_1-rmse:2.90194
# [9]	validation_0-rmse:2.86363	validation_1-rmse:2.81251
# [10]	validation_0-rmse:2.78015	validation_1-rmse:2.73347
# [11]	validation_0-rmse:2.71645	validation_1-rmse:2.67119
# [12]	validation_0-rmse:2.65759	validation_1-rmse:2.61759
# [13]	validation_0-rmse:2.60726	validation_1-rmse:2.57141
# [14]	validation_0-rmse:2.56996	validation_1-rmse:2.53650
# [15]	validation_0-rmse:2.53807	validation_1-rmse:2.50613
# [16]	validation_0-rmse:2.51092	validation_1-rmse:2.47995
# [17]	validation_0-rmse:2.48757	validation_1-rmse:2.45850
# [18]	validation_0-rmse:2.46827	validation_1-rmse:2.43920
# [19]	validation_0-rmse:2.45228	validation_1-rmse:2.42467
# [20]	validation_0-rmse:2.43758	validation_1-rmse:2.41142
# [21]	validation_0-rmse:2.42481	validation_1-rmse:2.40130
# [22]	validation_0-rmse:2.41397	validation_1-rmse:2.39109
# [23]	validation_0-rmse:2.40416	validation_1-rmse:2.38187
# [24]	validation_0-rmse:2.39965	validation_1-rmse:2.37774
# [25]	validation_0-rmse:2.39409	validation_1-rmse:2.37329
# [26]	validation_0-rmse:2.38793	validation_1-rmse:2.36939
# [27]	validation_0-rmse:2.38582	validation_1-rmse:2.36805
# [28]	validation_0-rmse:2.38137	validation_1-rmse:2.36395
# [29]	validation_0-rmse:2.37695	validation_1-rmse:2.36137
# [30]	validation_0-rmse:2.37388	validation_1-rmse:2.35938
# [31]	validation_0-rmse:2.36902	validation_1-rmse:2.35602
# [32]	validation_0-rmse:2.36568	validation_1-rmse:2.35312
# [33]	validation_0-rmse:2.36228	validation_1-rmse:2.35182
# [34]	validation_0-rmse:2.35819	validation_1-rmse:2.34830
# [35]	validation_0-rmse:2.35616	validation_1-rmse:2.34743
# [36]	validation_0-rmse:2.35435	validation_1-rmse:2.34687
# [37]	validation_0-rmse:2.35238	validation_1-rmse:2.34542
# [38]	validation_0-rmse:2.34988	validation_1-rmse:2.34445
# [39]	validation_0-rmse:2.34806	validation_1-rmse:2.34333
# [40]	validation_0-rmse:2.34706	validation_1-rmse:2.34197
# [41]	validation_0-rmse:2.34477	validation_1-rmse:2.34206
# [42]	validation_0-rmse:2.34341	validation_1-rmse:2.34203
# [43]	validation_0-rmse:2.34097	validation_1-rmse:2.34019
# [44]	validation_0-rmse:2.34046	validation_1-rmse:2.33969
# [45]	validation_0-rmse:2.33927	validation_1-rmse:2.33954
# [46]	validation_0-rmse:2.33724	validation_1-rmse:2.33976
# [47]	validation_0-rmse:2.33706	validation_1-rmse:2.33966
# [48]	validation_0-rmse:2.33520	validation_1-rmse:2.34023
# [49]	validation_0-rmse:2.33463	validation_1-rmse:2.33969
# [50]	validation_0-rmse:2.33458	validation_1-rmse:2.33986
# [0]	validation_0-rmse:4.56905	validation_1-rmse:4.49279
# [1]	validation_0-rmse:4.24284	validation_1-rmse:4.16699
# [2]	validation_0-rmse:3.95933	validation_1-rmse:3.88648
# [3]	validation_0-rmse:3.71128	validation_1-rmse:3.64250
# [4]	validation_0-rmse:3.49779	validation_1-rmse:3.43094
# [5]	validation_0-rmse:3.31504	validation_1-rmse:3.25300
# [6]	validation_0-rmse:3.15763	validation_1-rmse:3.09974
# [7]	validation_0-rmse:3.02367	validation_1-rmse:2.97232
# [8]	validation_0-rmse:2.91065	validation_1-rmse:2.86302
# [9]	validation_0-rmse:2.81527	validation_1-rmse:2.77179
# [10]	validation_0-rmse:2.73468	validation_1-rmse:2.69598
# [11]	validation_0-rmse:2.66697	validation_1-rmse:2.63256
# [12]	validation_0-rmse:2.61106	validation_1-rmse:2.58157
# [13]	validation_0-rmse:2.56476	validation_1-rmse:2.53852
# [14]	validation_0-rmse:2.52249	validation_1-rmse:2.49832
# [15]	validation_0-rmse:2.49030	validation_1-rmse:2.46776
# [16]	validation_0-rmse:2.46255	validation_1-rmse:2.44189
# [17]	validation_0-rmse:2.44113	validation_1-rmse:2.42190
# [18]	validation_0-rmse:2.42398	validation_1-rmse:2.40627
# [19]	validation_0-rmse:2.40926	validation_1-rmse:2.39414
# [20]	validation_0-rmse:2.39607	validation_1-rmse:2.38317
# [21]	validation_0-rmse:2.38459	validation_1-rmse:2.37316
# [22]	validation_0-rmse:2.37668	validation_1-rmse:2.36736
# [23]	validation_0-rmse:2.36948	validation_1-rmse:2.36278
# [24]	validation_0-rmse:2.36402	validation_1-rmse:2.35966
# [25]	validation_0-rmse:2.35795	validation_1-rmse:2.35458
# [26]	validation_0-rmse:2.35310	validation_1-rmse:2.35063
# [27]	validation_0-rmse:2.34946	validation_1-rmse:2.34980
# [28]	validation_0-rmse:2.34671	validation_1-rmse:2.34896
# [29]	validation_0-rmse:2.34448	validation_1-rmse:2.34697
# [30]	validation_0-rmse:2.34167	validation_1-rmse:2.34460
# [31]	validation_0-rmse:2.34121	validation_1-rmse:2.34480
# [32]	validation_0-rmse:2.33977	validation_1-rmse:2.34536
# [33]	validation_0-rmse:2.34063	validation_1-rmse:2.34771
# [34]	validation_0-rmse:2.33945	validation_1-rmse:2.34765
# [0]	validation_0-rmse:4.58169	validation_1-rmse:4.50637
# [1]	validation_0-rmse:4.26411	validation_1-rmse:4.18736
# [2]	validation_0-rmse:3.98672	validation_1-rmse:3.91330
# [3]	validation_0-rmse:3.74377	validation_1-rmse:3.67255
# [4]	validation_0-rmse:3.53337	validation_1-rmse:3.46520
# [5]	validation_0-rmse:3.35116	validation_1-rmse:3.28678
# [6]	validation_0-rmse:3.19568	validation_1-rmse:3.13515
# [7]	validation_0-rmse:3.06223	validation_1-rmse:3.00508
# [8]	validation_0-rmse:2.94811	validation_1-rmse:2.89565
# [9]	validation_0-rmse:2.85212	validation_1-rmse:2.80327
# [10]	validation_0-rmse:2.77056	validation_1-rmse:2.72629
# [11]	validation_0-rmse:2.70176	validation_1-rmse:2.66237
# [12]	validation_0-rmse:2.64169	validation_1-rmse:2.60525
# [13]	validation_0-rmse:2.59213	validation_1-rmse:2.55795
# [14]	validation_0-rmse:2.55129	validation_1-rmse:2.52094
# [15]	validation_0-rmse:2.51832	validation_1-rmse:2.49167
# [16]	validation_0-rmse:2.48916	validation_1-rmse:2.46456
# [17]	validation_0-rmse:2.46554	validation_1-rmse:2.44392
# [18]	validation_0-rmse:2.44576	validation_1-rmse:2.42679
# [19]	validation_0-rmse:2.43041	validation_1-rmse:2.41379
# [20]	validation_0-rmse:2.41848	validation_1-rmse:2.40312
# [21]	validation_0-rmse:2.40678	validation_1-rmse:2.39259
# [22]	validation_0-rmse:2.39655	validation_1-rmse:2.38406
# [23]	validation_0-rmse:2.38784	validation_1-rmse:2.37703
# [24]	validation_0-rmse:2.38049	validation_1-rmse:2.37113
# [25]	validation_0-rmse:2.37409	validation_1-rmse:2.36540
# [26]	validation_0-rmse:2.36767	validation_1-rmse:2.36023
# [27]	validation_0-rmse:2.36258	validation_1-rmse:2.35633
# [28]	validation_0-rmse:2.35733	validation_1-rmse:2.35231
# [29]	validation_0-rmse:2.35328	validation_1-rmse:2.34912
# [30]	validation_0-rmse:2.34997	validation_1-rmse:2.34722
# [31]	validation_0-rmse:2.34609	validation_1-rmse:2.34431
# [32]	validation_0-rmse:2.34318	validation_1-rmse:2.34202
# [33]	validation_0-rmse:2.34066	validation_1-rmse:2.34060
# [34]	validation_0-rmse:2.34117	validation_1-rmse:2.34093
# [35]	validation_0-rmse:2.33839	validation_1-rmse:2.33911
# [36]	validation_0-rmse:2.33742	validation_1-rmse:2.33843
# [37]	validation_0-rmse:2.33435	validation_1-rmse:2.33646
# [38]	validation_0-rmse:2.33282	validation_1-rmse:2.33588
# [39]	validation_0-rmse:2.33143	validation_1-rmse:2.33557
# [40]	validation_0-rmse:2.33006	validation_1-rmse:2.33516
# [41]	validation_0-rmse:2.32823	validation_1-rmse:2.33419
# [42]	validation_0-rmse:2.32716	validation_1-rmse:2.33407
# [43]	validation_0-rmse:2.32566	validation_1-rmse:2.33382
# [44]	validation_0-rmse:2.32440	validation_1-rmse:2.33275
# [45]	validation_0-rmse:2.32363	validation_1-rmse:2.33273
# [46]	validation_0-rmse:2.32246	validation_1-rmse:2.33263
# [47]	validation_0-rmse:2.32179	validation_1-rmse:2.33252
# [48]	validation_0-rmse:2.31954	validation_1-rmse:2.33113
# [49]	validation_0-rmse:2.31909	validation_1-rmse:2.33099
# [50]	validation_0-rmse:2.31848	validation_1-rmse:2.33083
# [51]	validation_0-rmse:2.31762	validation_1-rmse:2.33003
# [52]	validation_0-rmse:2.31668	validation_1-rmse:2.32985
# [53]	validation_0-rmse:2.31626	validation_1-rmse:2.32969
# [54]	validation_0-rmse:2.31436	validation_1-rmse:2.32815
# [55]	validation_0-rmse:2.31252	validation_1-rmse:2.32880
# [56]	validation_0-rmse:2.31179	validation_1-rmse:2.32885
# [57]	validation_0-rmse:2.31066	validation_1-rmse:2.32827
# [58]	validation_0-rmse:2.31050	validation_1-rmse:2.32801
# [59]	validation_0-rmse:2.31041	validation_1-rmse:2.32874
# [60]	validation_0-rmse:2.30974	validation_1-rmse:2.32848
# [61]	validation_0-rmse:2.30915	validation_1-rmse:2.32807
# [62]	validation_0-rmse:2.30845	validation_1-rmse:2.32804
# [63]	validation_0-rmse:2.30670	validation_1-rmse:2.32662
# [64]	validation_0-rmse:2.30608	validation_1-rmse:2.32674
# [65]	validation_0-rmse:2.30560	validation_1-rmse:2.32635
# [66]	validation_0-rmse:2.30471	validation_1-rmse:2.32536
# [67]	validation_0-rmse:2.30339	validation_1-rmse:2.32687
# [68]	validation_0-rmse:2.30631	validation_1-rmse:2.32889
# [69]	validation_0-rmse:2.30577	validation_1-rmse:2.32886
# [70]	validation_0-rmse:2.30506	validation_1-rmse:2.32891
# [0]	validation_0-rmse:4.58148	validation_1-rmse:4.50426
# [1]	validation_0-rmse:4.26522	validation_1-rmse:4.18828
# [2]	validation_0-rmse:3.99136	validation_1-rmse:3.91813
# [3]	validation_0-rmse:3.74728	validation_1-rmse:3.67752
# [4]	validation_0-rmse:3.53921	validation_1-rmse:3.47239
# [5]	validation_0-rmse:3.35962	validation_1-rmse:3.29507
# [6]	validation_0-rmse:3.20605	validation_1-rmse:3.14549
# [7]	validation_0-rmse:3.07125	validation_1-rmse:3.01458
# [8]	validation_0-rmse:2.95608	validation_1-rmse:2.90355
# [9]	validation_0-rmse:2.86574	validation_1-rmse:2.81404
# [10]	validation_0-rmse:2.78217	validation_1-rmse:2.73490
# [11]	validation_0-rmse:2.71838	validation_1-rmse:2.67251
# [12]	validation_0-rmse:2.66409	validation_1-rmse:2.61980
# [13]	validation_0-rmse:2.61313	validation_1-rmse:2.57318
# [14]	validation_0-rmse:2.57139	validation_1-rmse:2.53661
# [15]	validation_0-rmse:2.53944	validation_1-rmse:2.50624
# [16]	validation_0-rmse:2.51253	validation_1-rmse:2.48006
# [17]	validation_0-rmse:2.48909	validation_1-rmse:2.45848
# [18]	validation_0-rmse:2.46973	validation_1-rmse:2.43909
# [19]	validation_0-rmse:2.45360	validation_1-rmse:2.42443
# [20]	validation_0-rmse:2.43881	validation_1-rmse:2.41107
# [21]	validation_0-rmse:2.42617	validation_1-rmse:2.40100
# [22]	validation_0-rmse:2.41485	validation_1-rmse:2.39011
# [23]	validation_0-rmse:2.40550	validation_1-rmse:2.38144
# [24]	validation_0-rmse:2.40097	validation_1-rmse:2.37728
# [25]	validation_0-rmse:2.39536	validation_1-rmse:2.37279
# [26]	validation_0-rmse:2.38920	validation_1-rmse:2.36889
# [27]	validation_0-rmse:2.38343	validation_1-rmse:2.36566
# [28]	validation_0-rmse:2.37894	validation_1-rmse:2.36162
# [29]	validation_0-rmse:2.37281	validation_1-rmse:2.35761
# [30]	validation_0-rmse:2.36920	validation_1-rmse:2.35468
# [31]	validation_0-rmse:2.36562	validation_1-rmse:2.35117
# [32]	validation_0-rmse:2.36236	validation_1-rmse:2.34963
# [33]	validation_0-rmse:2.35928	validation_1-rmse:2.34797
# [34]	validation_0-rmse:2.35758	validation_1-rmse:2.34734
# [35]	validation_0-rmse:2.35359	validation_1-rmse:2.34382
# [36]	validation_0-rmse:2.35134	validation_1-rmse:2.34277
# [37]	validation_0-rmse:2.34980	validation_1-rmse:2.34223
# [38]	validation_0-rmse:2.34812	validation_1-rmse:2.34211
# [39]	validation_0-rmse:2.34708	validation_1-rmse:2.34087
# [40]	validation_0-rmse:2.34508	validation_1-rmse:2.33961
# [41]	validation_0-rmse:2.34353	validation_1-rmse:2.33866
# [42]	validation_0-rmse:2.34196	validation_1-rmse:2.33832
# [43]	validation_0-rmse:2.34146	validation_1-rmse:2.33780
# [44]	validation_0-rmse:2.33909	validation_1-rmse:2.33750
# [45]	validation_0-rmse:2.33747	validation_1-rmse:2.33669
# [46]	validation_0-rmse:2.33797	validation_1-rmse:2.33599
# [47]	validation_0-rmse:2.33624	validation_1-rmse:2.33639
# [48]	validation_0-rmse:2.33510	validation_1-rmse:2.33653
# [49]	validation_0-rmse:2.33586	validation_1-rmse:2.33642
# [50]	validation_0-rmse:2.33437	validation_1-rmse:2.33499
# [51]	validation_0-rmse:2.33388	validation_1-rmse:2.33539
# [52]	validation_0-rmse:2.33263	validation_1-rmse:2.33651
# [53]	validation_0-rmse:2.33170	validation_1-rmse:2.33566
# [54]	validation_0-rmse:2.33064	validation_1-rmse:2.33474
# [55]	validation_0-rmse:2.32974	validation_1-rmse:2.33458
# [56]	validation_0-rmse:2.33070	validation_1-rmse:2.33436
# [57]	validation_0-rmse:2.32897	validation_1-rmse:2.33437
# [58]	validation_0-rmse:2.32821	validation_1-rmse:2.33383
# [59]	validation_0-rmse:2.32711	validation_1-rmse:2.33279
# [60]	validation_0-rmse:2.32618	validation_1-rmse:2.33191
# [61]	validation_0-rmse:2.32615	validation_1-rmse:2.33224
# [62]	validation_0-rmse:2.32505	validation_1-rmse:2.33225
# [63]	validation_0-rmse:2.32442	validation_1-rmse:2.33151
# [64]	validation_0-rmse:2.32419	validation_1-rmse:2.33151
# [65]	validation_0-rmse:2.32354	validation_1-rmse:2.33091
# [66]	validation_0-rmse:2.32380	validation_1-rmse:2.33103
# [67]	validation_0-rmse:2.32275	validation_1-rmse:2.33208
# [68]	validation_0-rmse:2.32171	validation_1-rmse:2.33173
# [69]	validation_0-rmse:2.32139	validation_1-rmse:2.33146
# [70]	validation_0-rmse:2.32176	validation_1-rmse:2.33159
# [0]	validation_0-rmse:4.56956	validation_1-rmse:4.49325
# [1]	validation_0-rmse:4.24367	validation_1-rmse:4.16774
# [2]	validation_0-rmse:3.96045	validation_1-rmse:3.88748
# [3]	validation_0-rmse:3.71252	validation_1-rmse:3.64359
# [4]	validation_0-rmse:3.49911	validation_1-rmse:3.43208
# [5]	validation_0-rmse:3.31644	validation_1-rmse:3.25419
# [6]	validation_0-rmse:3.15902	validation_1-rmse:3.10090
# [7]	validation_0-rmse:3.02509	validation_1-rmse:2.97346
# [8]	validation_0-rmse:2.91245	validation_1-rmse:2.86477
# [9]	validation_0-rmse:2.81689	validation_1-rmse:2.77267
# [10]	validation_0-rmse:2.73630	validation_1-rmse:2.69691
# [11]	validation_0-rmse:2.66855	validation_1-rmse:2.63353
# [12]	validation_0-rmse:2.61248	validation_1-rmse:2.58242
# [13]	validation_0-rmse:2.56605	validation_1-rmse:2.53931
# [14]	validation_0-rmse:2.52368	validation_1-rmse:2.49915
# [15]	validation_0-rmse:2.49145	validation_1-rmse:2.46863
# [16]	validation_0-rmse:2.46358	validation_1-rmse:2.44276
# [17]	validation_0-rmse:2.44196	validation_1-rmse:2.42285
# [18]	validation_0-rmse:2.42453	validation_1-rmse:2.40696
# [19]	validation_0-rmse:2.41005	validation_1-rmse:2.39385
# [20]	validation_0-rmse:2.39703	validation_1-rmse:2.38368
# [21]	validation_0-rmse:2.38703	validation_1-rmse:2.37633
# [22]	validation_0-rmse:2.37722	validation_1-rmse:2.36785
# [23]	validation_0-rmse:2.37002	validation_1-rmse:2.36250
# [24]	validation_0-rmse:2.36392	validation_1-rmse:2.35875
# [25]	validation_0-rmse:2.35910	validation_1-rmse:2.35640
# [26]	validation_0-rmse:2.35400	validation_1-rmse:2.35190
# [27]	validation_0-rmse:2.35060	validation_1-rmse:2.35048
# [28]	validation_0-rmse:2.34869	validation_1-rmse:2.34973
# [29]	validation_0-rmse:2.34617	validation_1-rmse:2.34910
# [30]	validation_0-rmse:2.34269	validation_1-rmse:2.34578
# [31]	validation_0-rmse:2.34039	validation_1-rmse:2.34465
# [32]	validation_0-rmse:2.33807	validation_1-rmse:2.34274
# [33]	validation_0-rmse:2.33689	validation_1-rmse:2.34304
# [34]	validation_0-rmse:2.33691	validation_1-rmse:2.34362
# [35]	validation_0-rmse:2.33786	validation_1-rmse:2.34552
# [36]	validation_0-rmse:2.33633	validation_1-rmse:2.34506
# [0]	validation_0-rmse:4.56818	validation_1-rmse:4.49829
# [1]	validation_0-rmse:4.23997	validation_1-rmse:4.17707
# [2]	validation_0-rmse:3.95667	validation_1-rmse:3.89515
# [3]	validation_0-rmse:3.71036	validation_1-rmse:3.65704
# [4]	validation_0-rmse:3.49897	validation_1-rmse:3.44812
# [5]	validation_0-rmse:3.30976	validation_1-rmse:3.26118
# [6]	validation_0-rmse:3.15265	validation_1-rmse:3.11446
# [7]	validation_0-rmse:3.01476	validation_1-rmse:2.98668
# [8]	validation_0-rmse:2.90319	validation_1-rmse:2.87953
# [9]	validation_0-rmse:2.80257	validation_1-rmse:2.78567
# [10]	validation_0-rmse:2.72040	validation_1-rmse:2.70809
# [11]	validation_0-rmse:2.65105	validation_1-rmse:2.64483
# [12]	validation_0-rmse:2.59432	validation_1-rmse:2.59212
# [13]	validation_0-rmse:2.54345	validation_1-rmse:2.54492
# [14]	validation_0-rmse:2.50191	validation_1-rmse:2.50906
# [15]	validation_0-rmse:2.46951	validation_1-rmse:2.48040
# [16]	validation_0-rmse:2.43855	validation_1-rmse:2.45483
# [17]	validation_0-rmse:2.41017	validation_1-rmse:2.43170
# [18]	validation_0-rmse:2.38632	validation_1-rmse:2.41418
# [19]	validation_0-rmse:2.38088	validation_1-rmse:2.40746
# [20]	validation_0-rmse:2.36599	validation_1-rmse:2.39637
# [21]	validation_0-rmse:2.34928	validation_1-rmse:2.38435
# [22]	validation_0-rmse:2.33878	validation_1-rmse:2.37829
# [23]	validation_0-rmse:2.32549	validation_1-rmse:2.36870
# [24]	validation_0-rmse:2.32713	validation_1-rmse:2.36999
# [25]	validation_0-rmse:2.32923	validation_1-rmse:2.37049
# [26]	validation_0-rmse:2.31945	validation_1-rmse:2.36479
# [27]	validation_0-rmse:2.31826	validation_1-rmse:2.36518
# [28]	validation_0-rmse:2.31169	validation_1-rmse:2.36271
# [29]	validation_0-rmse:2.30544	validation_1-rmse:2.36080
# [30]	validation_0-rmse:2.29912	validation_1-rmse:2.35823
# [31]	validation_0-rmse:2.29212	validation_1-rmse:2.35351
# [32]	validation_0-rmse:2.28753	validation_1-rmse:2.35175
# [33]	validation_0-rmse:2.28324	validation_1-rmse:2.35019
# [34]	validation_0-rmse:2.29637	validation_1-rmse:2.36048
# [35]	validation_0-rmse:2.29048	validation_1-rmse:2.35777
# [36]	validation_0-rmse:2.28999	validation_1-rmse:2.36004
# [37]	validation_0-rmse:2.28944	validation_1-rmse:2.35898
# [0]	validation_0-rmse:4.57060	validation_1-rmse:4.49279
# [1]	validation_0-rmse:4.24638	validation_1-rmse:4.17104
# [2]	validation_0-rmse:3.96444	validation_1-rmse:3.89119
# [3]	validation_0-rmse:3.71737	validation_1-rmse:3.64837
# [4]	validation_0-rmse:3.50521	validation_1-rmse:3.43944
# [5]	validation_0-rmse:3.32152	validation_1-rmse:3.25688
# [6]	validation_0-rmse:3.16302	validation_1-rmse:3.10621
# [7]	validation_0-rmse:3.02883	validation_1-rmse:2.97753
# [8]	validation_0-rmse:2.91256	validation_1-rmse:2.86956
# [9]	validation_0-rmse:2.81203	validation_1-rmse:2.77804
# [10]	validation_0-rmse:2.72955	validation_1-rmse:2.70076
# [11]	validation_0-rmse:2.66976	validation_1-rmse:2.64426
# [12]	validation_0-rmse:2.60977	validation_1-rmse:2.59001
# [13]	validation_0-rmse:2.55888	validation_1-rmse:2.54488
# [14]	validation_0-rmse:2.51724	validation_1-rmse:2.50804
# [15]	validation_0-rmse:2.47768	validation_1-rmse:2.47749
# [16]	validation_0-rmse:2.44449	validation_1-rmse:2.45040
# [17]	validation_0-rmse:2.41506	validation_1-rmse:2.42478
# [18]	validation_0-rmse:2.39129	validation_1-rmse:2.40569
# [19]	validation_0-rmse:2.36924	validation_1-rmse:2.39108
# [20]	validation_0-rmse:2.35136	validation_1-rmse:2.37702
# [21]	validation_0-rmse:2.33596	validation_1-rmse:2.36709
# [22]	validation_0-rmse:2.32306	validation_1-rmse:2.35724
# [23]	validation_0-rmse:2.31037	validation_1-rmse:2.34911
# [24]	validation_0-rmse:2.29808	validation_1-rmse:2.34074
# [25]	validation_0-rmse:2.28853	validation_1-rmse:2.33587
# [26]	validation_0-rmse:2.28678	validation_1-rmse:2.33498
# [27]	validation_0-rmse:2.27999	validation_1-rmse:2.33124
# [28]	validation_0-rmse:2.27183	validation_1-rmse:2.32639
# [29]	validation_0-rmse:2.26498	validation_1-rmse:2.32360
# [30]	validation_0-rmse:2.26071	validation_1-rmse:2.32223
# [31]	validation_0-rmse:2.25514	validation_1-rmse:2.31987
# [32]	validation_0-rmse:2.25286	validation_1-rmse:2.32002
# [33]	validation_0-rmse:2.24807	validation_1-rmse:2.31793
# [34]	validation_0-rmse:2.24339	validation_1-rmse:2.31821
# [35]	validation_0-rmse:2.24100	validation_1-rmse:2.31864
# [36]	validation_0-rmse:2.23657	validation_1-rmse:2.31646
# [37]	validation_0-rmse:2.23265	validation_1-rmse:2.31485
# [38]	validation_0-rmse:2.22991	validation_1-rmse:2.31369
# [39]	validation_0-rmse:2.22723	validation_1-rmse:2.31321
# [40]	validation_0-rmse:2.22325	validation_1-rmse:2.31215
# [41]	validation_0-rmse:2.22019	validation_1-rmse:2.30992
# [42]	validation_0-rmse:2.21933	validation_1-rmse:2.31141
# [43]	validation_0-rmse:2.21688	validation_1-rmse:2.31115
# [44]	validation_0-rmse:2.21313	validation_1-rmse:2.31119
# [45]	validation_0-rmse:2.21330	validation_1-rmse:2.31389
# [0]	validation_0-rmse:4.55239	validation_1-rmse:4.47855
# [1]	validation_0-rmse:4.21233	validation_1-rmse:4.14231
# [2]	validation_0-rmse:3.91475	validation_1-rmse:3.85053
# [3]	validation_0-rmse:3.65735	validation_1-rmse:3.59839
# [4]	validation_0-rmse:3.43659	validation_1-rmse:3.38499
# [5]	validation_0-rmse:3.24030	validation_1-rmse:3.19592
# [6]	validation_0-rmse:3.07919	validation_1-rmse:3.04292
# [7]	validation_0-rmse:2.93885	validation_1-rmse:2.90960
# [8]	validation_0-rmse:2.81888	validation_1-rmse:2.79654
# [9]	validation_0-rmse:2.71578	validation_1-rmse:2.70149
# [10]	validation_0-rmse:2.63423	validation_1-rmse:2.62801
# [11]	validation_0-rmse:2.56547	validation_1-rmse:2.56719
# [12]	validation_0-rmse:2.50750	validation_1-rmse:2.51709
# [13]	validation_0-rmse:2.46026	validation_1-rmse:2.47665
# [14]	validation_0-rmse:2.42223	validation_1-rmse:2.44581
# [15]	validation_0-rmse:2.38847	validation_1-rmse:2.41801
# [16]	validation_0-rmse:2.36247	validation_1-rmse:2.39726
# [17]	validation_0-rmse:2.33844	validation_1-rmse:2.37481
# [18]	validation_0-rmse:2.31878	validation_1-rmse:2.35847
# [19]	validation_0-rmse:2.30426	validation_1-rmse:2.35088
# [20]	validation_0-rmse:2.29101	validation_1-rmse:2.34099
# [21]	validation_0-rmse:2.27874	validation_1-rmse:2.33466
# [22]	validation_0-rmse:2.26869	validation_1-rmse:2.32895
# [23]	validation_0-rmse:2.26290	validation_1-rmse:2.32520
# [24]	validation_0-rmse:2.25482	validation_1-rmse:2.32077
# [25]	validation_0-rmse:2.25542	validation_1-rmse:2.32485
# [26]	validation_0-rmse:2.25001	validation_1-rmse:2.32252
# [27]	validation_0-rmse:2.25031	validation_1-rmse:2.32432
# [28]	validation_0-rmse:2.24748	validation_1-rmse:2.32387
# [0]	validation_0-rmse:4.57239	validation_1-rmse:4.50100
# [1]	validation_0-rmse:4.24683	validation_1-rmse:4.17826
# [2]	validation_0-rmse:3.96420	validation_1-rmse:3.89708
# [3]	validation_0-rmse:3.71547	validation_1-rmse:3.65673
# [4]	validation_0-rmse:3.51118	validation_1-rmse:3.44581
# [5]	validation_0-rmse:3.33054	validation_1-rmse:3.27117
# [6]	validation_0-rmse:3.17042	validation_1-rmse:3.11762
# [7]	validation_0-rmse:3.03081	validation_1-rmse:2.98782
# [8]	validation_0-rmse:2.92007	validation_1-rmse:2.87809
# [9]	validation_0-rmse:2.81917	validation_1-rmse:2.78475
# [10]	validation_0-rmse:2.74083	validation_1-rmse:2.71204
# [11]	validation_0-rmse:2.67088	validation_1-rmse:2.64861
# [12]	validation_0-rmse:2.61071	validation_1-rmse:2.59392
# [13]	validation_0-rmse:2.55971	validation_1-rmse:2.54840
# [14]	validation_0-rmse:2.51421	validation_1-rmse:2.50784
# [15]	validation_0-rmse:2.48097	validation_1-rmse:2.47901
# [16]	validation_0-rmse:2.44903	validation_1-rmse:2.45156
# [17]	validation_0-rmse:2.42847	validation_1-rmse:2.43617
# [18]	validation_0-rmse:2.40443	validation_1-rmse:2.41698
# [19]	validation_0-rmse:2.39131	validation_1-rmse:2.40676
# [20]	validation_0-rmse:2.37708	validation_1-rmse:2.39968
# [21]	validation_0-rmse:2.36035	validation_1-rmse:2.38638
# [22]	validation_0-rmse:2.35048	validation_1-rmse:2.37960
# [23]	validation_0-rmse:2.33712	validation_1-rmse:2.36840
# [24]	validation_0-rmse:2.33032	validation_1-rmse:2.36481
# [25]	validation_0-rmse:2.32015	validation_1-rmse:2.35756
# [26]	validation_0-rmse:2.31233	validation_1-rmse:2.35206
# [27]	validation_0-rmse:2.30357	validation_1-rmse:2.34771
# [28]	validation_0-rmse:2.30352	validation_1-rmse:2.35002
# [29]	validation_0-rmse:2.29983	validation_1-rmse:2.35002
# [30]	validation_0-rmse:2.29336	validation_1-rmse:2.34606
# [31]	validation_0-rmse:2.28943	validation_1-rmse:2.34377
# [32]	validation_0-rmse:2.28803	validation_1-rmse:2.34455
# [33]	validation_0-rmse:2.28168	validation_1-rmse:2.34230
# [34]	validation_0-rmse:2.27820	validation_1-rmse:2.33878
# [35]	validation_0-rmse:2.27403	validation_1-rmse:2.33784
# [36]	validation_0-rmse:2.26912	validation_1-rmse:2.33528
# [37]	validation_0-rmse:2.26638	validation_1-rmse:2.33470
# [38]	validation_0-rmse:2.26585	validation_1-rmse:2.33421
# [39]	validation_0-rmse:2.26227	validation_1-rmse:2.33283
# [40]	validation_0-rmse:2.26017	validation_1-rmse:2.33283
# [41]	validation_0-rmse:2.25688	validation_1-rmse:2.33045
# [42]	validation_0-rmse:2.25455	validation_1-rmse:2.33059
# [43]	validation_0-rmse:2.25165	validation_1-rmse:2.32895
# [44]	validation_0-rmse:2.24616	validation_1-rmse:2.32575
# [45]	validation_0-rmse:2.24638	validation_1-rmse:2.32821
# [46]	validation_0-rmse:2.24494	validation_1-rmse:2.32761
# [47]	validation_0-rmse:2.24310	validation_1-rmse:2.32716
# [48]	validation_0-rmse:2.24138	validation_1-rmse:2.32591
# [49]	validation_0-rmse:2.23852	validation_1-rmse:2.32505
# [50]	validation_0-rmse:2.23709	validation_1-rmse:2.32473
# [51]	validation_0-rmse:2.23604	validation_1-rmse:2.32467
# [52]	validation_0-rmse:2.23600	validation_1-rmse:2.32510
# [53]	validation_0-rmse:2.23407	validation_1-rmse:2.32404
# [54]	validation_0-rmse:2.23320	validation_1-rmse:2.32410
# [55]	validation_0-rmse:2.23326	validation_1-rmse:2.32565
# [56]	validation_0-rmse:2.23283	validation_1-rmse:2.32616
# [57]	validation_0-rmse:2.23488	validation_1-rmse:2.32999
# [58]	validation_0-rmse:2.23148	validation_1-rmse:2.32872
# [0]	validation_0-rmse:4.56938	validation_1-rmse:4.49196
# [1]	validation_0-rmse:4.25134	validation_1-rmse:4.17129
# [2]	validation_0-rmse:3.96714	validation_1-rmse:3.89380
# [3]	validation_0-rmse:3.71975	validation_1-rmse:3.65281
# [4]	validation_0-rmse:3.50860	validation_1-rmse:3.44278
# [5]	validation_0-rmse:3.32607	validation_1-rmse:3.26520
# [6]	validation_0-rmse:3.16561	validation_1-rmse:3.11344
# [7]	validation_0-rmse:3.02968	validation_1-rmse:2.98213
# [8]	validation_0-rmse:2.91793	validation_1-rmse:2.87762
# [9]	validation_0-rmse:2.81999	validation_1-rmse:2.78328
# [10]	validation_0-rmse:2.73992	validation_1-rmse:2.70720
# [11]	validation_0-rmse:2.66555	validation_1-rmse:2.64175
# [12]	validation_0-rmse:2.60821	validation_1-rmse:2.58945
# [13]	validation_0-rmse:2.55490	validation_1-rmse:2.54533
# [14]	validation_0-rmse:2.51453	validation_1-rmse:2.50828
# [15]	validation_0-rmse:2.47572	validation_1-rmse:2.47610
# [16]	validation_0-rmse:2.44053	validation_1-rmse:2.44636
# [17]	validation_0-rmse:2.41239	validation_1-rmse:2.42390
# [18]	validation_0-rmse:2.38833	validation_1-rmse:2.40449
# [19]	validation_0-rmse:2.36919	validation_1-rmse:2.38927
# [20]	validation_0-rmse:2.35049	validation_1-rmse:2.37414
# [21]	validation_0-rmse:2.33676	validation_1-rmse:2.36376
# [22]	validation_0-rmse:2.32410	validation_1-rmse:2.35551
# [23]	validation_0-rmse:2.31146	validation_1-rmse:2.34569
# ...
# [11]	validation_0-rmse:2.53189	validation_1-rmse:2.63583
# [12]	validation_0-rmse:2.46375	validation_1-rmse:2.58515
# [13]	validation_0-rmse:2.41192	validation_1-rmse:2.54767
# [14]	validation_0-rmse:2.35935	validation_1-rmse:2.51711
# [15]	validation_0-rmse:2.31185	validation_1-rmse:2.48834
# [16]	validation_0-rmse:2.26954	validation_1-rmse:2.46367
# [17]	validation_0-rmse:2.23687	validation_1-rmse:2.44606
# [18]	validation_0-rmse:2.20492	validation_1-rmse:2.42757
# [19]	validation_0-rmse:2.17730	validation_1-rmse:2.41385
# [20]	validation_0-rmse:2.15428	validation_1-rmse:2.40111
# [21]	validation_0-rmse:2.13325	validation_1-rmse:2.39144
# [22]	validation_0-rmse:2.11313	validation_1-rmse:2.38468
# [23]	validation_0-rmse:2.09723	validation_1-rmse:2.37902
# [24]	validation_0-rmse:2.08210	validation_1-rmse:2.37496
# [25]	validation_0-rmse:2.06721	validation_1-rmse:2.36835
# [26]	validation_0-rmse:2.05576	validation_1-rmse:2.36373
# [27]	validation_0-rmse:2.04542	validation_1-rmse:2.36114
# [28]	validation_0-rmse:2.03472	validation_1-rmse:2.35775
# [29]	validation_0-rmse:2.02442	validation_1-rmse:2.35430
# [30]	validation_0-rmse:2.01462	validation_1-rmse:2.35614
# [31]	validation_0-rmse:2.00779	validation_1-rmse:2.35357
# [32]	validation_0-rmse:1.99889	validation_1-rmse:2.35047
# [33]	validation_0-rmse:1.99186	validation_1-rmse:2.34790
# [34]	validation_0-rmse:1.98422	validation_1-rmse:2.34524
# [35]	validation_0-rmse:1.97716	validation_1-rmse:2.34433
# [36]	validation_0-rmse:1.96929	validation_1-rmse:2.34147
# [37]	validation_0-rmse:1.96376	validation_1-rmse:2.33980
# [38]	validation_0-rmse:1.95823	validation_1-rmse:2.33777
# [39]	validation_0-rmse:1.95275	validation_1-rmse:2.33757
# [40]	validation_0-rmse:1.94903	validation_1-rmse:2.33556
# [41]	validation_0-rmse:1.94277	validation_1-rmse:2.33285
# [42]	validation_0-rmse:1.93639	validation_1-rmse:2.33148
# [43]	validation_0-rmse:1.93788	validation_1-rmse:2.33815
# [44]	validation_0-rmse:1.93377	validation_1-rmse:2.33708
# [45]	validation_0-rmse:1.92860	validation_1-rmse:2.33684
# [46]	validation_0-rmse:1.92424	validation_1-rmse:2.33756
# [0]	validation_0-rmse:4.53554	validation_1-rmse:4.46311
# [1]	validation_0-rmse:4.17366	validation_1-rmse:4.10832
# [2]	validation_0-rmse:3.86483	validation_1-rmse:3.80987
# [3]	validation_0-rmse:3.59805	validation_1-rmse:3.55147
# [4]	validation_0-rmse:3.36009	validation_1-rmse:3.33391
# [5]	validation_0-rmse:3.15624	validation_1-rmse:3.14784
# [6]	validation_0-rmse:2.97985	validation_1-rmse:3.00081
# [7]	validation_0-rmse:2.82699	validation_1-rmse:2.86562
# [8]	validation_0-rmse:2.70238	validation_1-rmse:2.76056
# [9]	validation_0-rmse:2.59551	validation_1-rmse:2.67627
# [10]	validation_0-rmse:2.50289	validation_1-rmse:2.59949
# [11]	validation_0-rmse:2.42820	validation_1-rmse:2.53703
# [12]	validation_0-rmse:2.36495	validation_1-rmse:2.48820
# [13]	validation_0-rmse:2.31090	validation_1-rmse:2.45165
# [14]	validation_0-rmse:2.26898	validation_1-rmse:2.42648
# [15]	validation_0-rmse:2.23273	validation_1-rmse:2.40776
# [16]	validation_0-rmse:2.20339	validation_1-rmse:2.39504
# [17]	validation_0-rmse:2.18348	validation_1-rmse:2.38453
# [18]	validation_0-rmse:2.16709	validation_1-rmse:2.38208
# [19]	validation_0-rmse:2.15072	validation_1-rmse:2.37834
# [20]	validation_0-rmse:2.13820	validation_1-rmse:2.37812
# [21]	validation_0-rmse:2.12785	validation_1-rmse:2.38132
# [22]	validation_0-rmse:2.11438	validation_1-rmse:2.38254
# [23]	validation_0-rmse:2.10884	validation_1-rmse:2.38901
# [24]	validation_0-rmse:2.10472	validation_1-rmse:2.40025
# [0]	validation_0-rmse:4.58266	validation_1-rmse:4.51575
# [1]	validation_0-rmse:4.27243	validation_1-rmse:4.21243
# [2]	validation_0-rmse:3.99360	validation_1-rmse:3.94293
# [3]	validation_0-rmse:3.73829	validation_1-rmse:3.70566
# [4]	validation_0-rmse:3.53919	validation_1-rmse:3.51262
# [5]	validation_0-rmse:3.35622	validation_1-rmse:3.34089
# [6]	validation_0-rmse:3.20137	validation_1-rmse:3.19632
# [7]	validation_0-rmse:3.06337	validation_1-rmse:3.06931
# [8]	validation_0-rmse:2.94011	validation_1-rmse:2.96169
# [9]	validation_0-rmse:2.83402	validation_1-rmse:2.86875
# [10]	validation_0-rmse:2.73965	validation_1-rmse:2.78958
# [11]	validation_0-rmse:2.65832	validation_1-rmse:2.72565
# [12]	validation_0-rmse:2.59159	validation_1-rmse:2.67670
# [13]	validation_0-rmse:2.52904	validation_1-rmse:2.62756
# [14]	validation_0-rmse:2.47770	validation_1-rmse:2.58822
# [15]	validation_0-rmse:2.43107	validation_1-rmse:2.55109
# [16]	validation_0-rmse:2.39413	validation_1-rmse:2.52563
# [17]	validation_0-rmse:2.35903	validation_1-rmse:2.50175
# [18]	validation_0-rmse:2.32378	validation_1-rmse:2.47761
# [19]	validation_0-rmse:2.29659	validation_1-rmse:2.45753
# [20]	validation_0-rmse:2.27331	validation_1-rmse:2.44327
# [21]	validation_0-rmse:2.25170	validation_1-rmse:2.43123
# [22]	validation_0-rmse:2.22989	validation_1-rmse:2.42271
# [23]	validation_0-rmse:2.21385	validation_1-rmse:2.41897
# [24]	validation_0-rmse:2.19656	validation_1-rmse:2.41084
# [25]	validation_0-rmse:2.18381	validation_1-rmse:2.40461
# [26]	validation_0-rmse:2.16890	validation_1-rmse:2.39978
# [27]	validation_0-rmse:2.15587	validation_1-rmse:2.39277
# [28]	validation_0-rmse:2.14568	validation_1-rmse:2.39017
# [29]	validation_0-rmse:2.14007	validation_1-rmse:2.39101
# [30]	validation_0-rmse:2.13450	validation_1-rmse:2.39215
# [31]	validation_0-rmse:2.12866	validation_1-rmse:2.39302
# [32]	validation_0-rmse:2.12290	validation_1-rmse:2.39348
# [33]	validation_0-rmse:2.11435	validation_1-rmse:2.39183
# [0]	validation_0-rmse:4.56588	validation_1-rmse:4.49124
# [1]	validation_0-rmse:4.24055	validation_1-rmse:4.16685
# [2]	validation_0-rmse:3.95368	validation_1-rmse:3.89455
# [3]	validation_0-rmse:3.70538	validation_1-rmse:3.65752
# [4]	validation_0-rmse:3.48599	validation_1-rmse:3.45573
# [5]	validation_0-rmse:3.29924	validation_1-rmse:3.28108
# [6]	validation_0-rmse:3.13393	validation_1-rmse:3.13092
# [7]	validation_0-rmse:2.99407	validation_1-rmse:3.00422
# [8]	validation_0-rmse:2.86884	validation_1-rmse:2.88946
# [9]	validation_0-rmse:2.75805	validation_1-rmse:2.79340
# [10]	validation_0-rmse:2.66740	validation_1-rmse:2.71139
# [11]	validation_0-rmse:2.58992	validation_1-rmse:2.65129
# [12]	validation_0-rmse:2.51803	validation_1-rmse:2.59328
# [13]	validation_0-rmse:2.45650	validation_1-rmse:2.54499
# [14]	validation_0-rmse:2.40393	validation_1-rmse:2.50884
# [15]	validation_0-rmse:2.35765	validation_1-rmse:2.47424
# [16]	validation_0-rmse:2.32017	validation_1-rmse:2.44601
# [17]	validation_0-rmse:2.28957	validation_1-rmse:2.42344
# [18]	validation_0-rmse:2.25859	validation_1-rmse:2.40410
# [19]	validation_0-rmse:2.22990	validation_1-rmse:2.38608
# [20]	validation_0-rmse:2.20521	validation_1-rmse:2.37088
# [21]	validation_0-rmse:2.18229	validation_1-rmse:2.36007
# [22]	validation_0-rmse:2.16270	validation_1-rmse:2.34998
# [23]	validation_0-rmse:2.14490	validation_1-rmse:2.34143
# [24]	validation_0-rmse:2.13109	validation_1-rmse:2.33574
# [25]	validation_0-rmse:2.11846	validation_1-rmse:2.33102
# [26]	validation_0-rmse:2.10492	validation_1-rmse:2.32571
# [27]	validation_0-rmse:2.09202	validation_1-rmse:2.32109
# [28]	validation_0-rmse:2.08241	validation_1-rmse:2.31938
# [29]	validation_0-rmse:2.07050	validation_1-rmse:2.31483
# [30]	validation_0-rmse:2.05998	validation_1-rmse:2.31150
# [31]	validation_0-rmse:2.05057	validation_1-rmse:2.30736
# [32]	validation_0-rmse:2.04399	validation_1-rmse:2.30609
# [33]	validation_0-rmse:2.03619	validation_1-rmse:2.30303
# [34]	validation_0-rmse:2.02964	validation_1-rmse:2.30171
# [35]	validation_0-rmse:2.02434	validation_1-rmse:2.30055
# [36]	validation_0-rmse:2.01771	validation_1-rmse:2.29826
# [37]	validation_0-rmse:2.01209	validation_1-rmse:2.29715
# [38]	validation_0-rmse:2.00813	validation_1-rmse:2.29588
# [39]	validation_0-rmse:2.00202	validation_1-rmse:2.29455
# [40]	validation_0-rmse:1.99543	validation_1-rmse:2.29286
# [41]	validation_0-rmse:1.99230	validation_1-rmse:2.29346
# [42]	validation_0-rmse:1.98689	validation_1-rmse:2.29289
# [43]	validation_0-rmse:1.98329	validation_1-rmse:2.29224
# [44]	validation_0-rmse:1.97824	validation_1-rmse:2.29418
# [45]	validation_0-rmse:1.97245	validation_1-rmse:2.29198
# [46]	validation_0-rmse:1.96875	validation_1-rmse:2.29193
# [47]	validation_0-rmse:1.96453	validation_1-rmse:2.29042
# [48]	validation_0-rmse:1.96114	validation_1-rmse:2.29140
# [49]	validation_0-rmse:1.95762	validation_1-rmse:2.29244
# [50]	validation_0-rmse:1.95463	validation_1-rmse:2.29375
# [51]	validation_0-rmse:1.95184	validation_1-rmse:2.29521
# [0]	validation_0-rmse:4.54562	validation_1-rmse:4.47382
# [1]	validation_0-rmse:4.19969	validation_1-rmse:4.13062
# [2]	validation_0-rmse:3.90459	validation_1-rmse:3.83952
# [3]	validation_0-rmse:3.64175	validation_1-rmse:3.59186
# [4]	validation_0-rmse:3.40846	validation_1-rmse:3.37739
# [5]	validation_0-rmse:3.20478	validation_1-rmse:3.19262
# [6]	validation_0-rmse:3.03286	validation_1-rmse:3.04147
# [7]	validation_0-rmse:2.88470	validation_1-rmse:2.90387
# [8]	validation_0-rmse:2.75431	validation_1-rmse:2.79790
# [9]	validation_0-rmse:2.64570	validation_1-rmse:2.70496
# [10]	validation_0-rmse:2.55090	validation_1-rmse:2.62647
# [11]	validation_0-rmse:2.46963	validation_1-rmse:2.56178
# [12]	validation_0-rmse:2.40174	validation_1-rmse:2.51613
# [13]	validation_0-rmse:2.34743	validation_1-rmse:2.47709
# [14]	validation_0-rmse:2.30209	validation_1-rmse:2.44879
# [15]	validation_0-rmse:2.26404	validation_1-rmse:2.42540
# [16]	validation_0-rmse:2.22867	validation_1-rmse:2.40420
# [17]	validation_0-rmse:2.19995	validation_1-rmse:2.38899
# [18]	validation_0-rmse:2.17877	validation_1-rmse:2.37924
# [19]	validation_0-rmse:2.16243	validation_1-rmse:2.36899
# [20]	validation_0-rmse:2.14660	validation_1-rmse:2.36268
# [21]	validation_0-rmse:2.13311	validation_1-rmse:2.36043
# [22]	validation_0-rmse:2.12101	validation_1-rmse:2.36063
# [23]	validation_0-rmse:2.10800	validation_1-rmse:2.35630
# [24]	validation_0-rmse:2.10187	validation_1-rmse:2.35511
# [25]	validation_0-rmse:2.09522	validation_1-rmse:2.35270
# [26]	validation_0-rmse:2.09597	validation_1-rmse:2.36128
# [27]	validation_0-rmse:2.09529	validation_1-rmse:2.36391
# [28]	validation_0-rmse:2.09361	validation_1-rmse:2.37107
# [29]	validation_0-rmse:2.09071	validation_1-rmse:2.37555
# [30]	validation_0-rmse:2.09381	validation_1-rmse:2.38469
# [0]	validation_0-rmse:4.57423	validation_1-rmse:4.49645
# [1]	validation_0-rmse:4.25486	validation_1-rmse:4.17873
# [2]	validation_0-rmse:3.97575	validation_1-rmse:3.90169
# [3]	validation_0-rmse:3.73153	validation_1-rmse:3.66042
# [4]	validation_0-rmse:3.51956	validation_1-rmse:3.45241
# [5]	validation_0-rmse:3.33775	validation_1-rmse:3.27475
# [6]	validation_0-rmse:3.18134	validation_1-rmse:3.12153
# [7]	validation_0-rmse:3.04740	validation_1-rmse:2.99424
# [8]	validation_0-rmse:2.93327	validation_1-rmse:2.88525
# [9]	validation_0-rmse:2.83726	validation_1-rmse:2.79252
# [10]	validation_0-rmse:2.75577	validation_1-rmse:2.71749
# [11]	validation_0-rmse:2.68778	validation_1-rmse:2.65198
# [12]	validation_0-rmse:2.63097	validation_1-rmse:2.59943
# [13]	validation_0-rmse:2.58340	validation_1-rmse:2.55537
# [14]	validation_0-rmse:2.54357	validation_1-rmse:2.51896
# [15]	validation_0-rmse:2.51004	validation_1-rmse:2.48823
# [16]	validation_0-rmse:2.48237	validation_1-rmse:2.46229
# [17]	validation_0-rmse:2.45886	validation_1-rmse:2.44104
# [18]	validation_0-rmse:2.43922	validation_1-rmse:2.42336
# [19]	validation_0-rmse:2.42265	validation_1-rmse:2.40847
# [20]	validation_0-rmse:2.40867	validation_1-rmse:2.39573
# [21]	validation_0-rmse:2.39668	validation_1-rmse:2.38555
# [22]	validation_0-rmse:2.38650	validation_1-rmse:2.37707
# [23]	validation_0-rmse:2.37643	validation_1-rmse:2.36758
# [24]	validation_0-rmse:2.36917	validation_1-rmse:2.36180
# [25]	validation_0-rmse:2.36177	validation_1-rmse:2.35481
# [26]	validation_0-rmse:2.35596	validation_1-rmse:2.35178
# [27]	validation_0-rmse:2.35086	validation_1-rmse:2.34700
# [28]	validation_0-rmse:2.34693	validation_1-rmse:2.34449
# [29]	validation_0-rmse:2.34312	validation_1-rmse:2.34197
# [30]	validation_0-rmse:2.33938	validation_1-rmse:2.33959
# [31]	validation_0-rmse:2.33532	validation_1-rmse:2.33582
# [32]	validation_0-rmse:2.33235	validation_1-rmse:2.33376
# [33]	validation_0-rmse:2.32997	validation_1-rmse:2.33224
# [34]	validation_0-rmse:2.32765	validation_1-rmse:2.33111
# [35]	validation_0-rmse:2.32485	validation_1-rmse:2.32888
# [36]	validation_0-rmse:2.32288	validation_1-rmse:2.32826
# [37]	validation_0-rmse:2.32060	validation_1-rmse:2.32651
# [38]	validation_0-rmse:2.31911	validation_1-rmse:2.32605
# [39]	validation_0-rmse:2.31733	validation_1-rmse:2.32499
# [40]	validation_0-rmse:2.31559	validation_1-rmse:2.32464
# [41]	validation_0-rmse:2.31425	validation_1-rmse:2.32427
# [42]	validation_0-rmse:2.31242	validation_1-rmse:2.32329
# [43]	validation_0-rmse:2.31075	validation_1-rmse:2.32311
# [44]	validation_0-rmse:2.30901	validation_1-rmse:2.32160
# [45]	validation_0-rmse:2.30779	validation_1-rmse:2.32109
# [46]	validation_0-rmse:2.30646	validation_1-rmse:2.32102
# [47]	validation_0-rmse:2.30504	validation_1-rmse:2.32083
# [48]	validation_0-rmse:2.30332	validation_1-rmse:2.31960
# [49]	validation_0-rmse:2.30128	validation_1-rmse:2.31766
# [50]	validation_0-rmse:2.30042	validation_1-rmse:2.31786
# [51]	validation_0-rmse:2.29897	validation_1-rmse:2.31643
# [52]	validation_0-rmse:2.29795	validation_1-rmse:2.31627
# [53]	validation_0-rmse:2.29724	validation_1-rmse:2.31581
# [54]	validation_0-rmse:2.29549	validation_1-rmse:2.31613
# [55]	validation_0-rmse:2.29411	validation_1-rmse:2.31462
# [56]	validation_0-rmse:2.29266	validation_1-rmse:2.31345
# [57]	validation_0-rmse:2.29130	validation_1-rmse:2.31343
# [58]	validation_0-rmse:2.29074	validation_1-rmse:2.31356
# [59]	validation_0-rmse:2.28920	validation_1-rmse:2.31247
# [60]	validation_0-rmse:2.28842	validation_1-rmse:2.31168
# [61]	validation_0-rmse:2.28700	validation_1-rmse:2.31238
# [62]	validation_0-rmse:2.28575	validation_1-rmse:2.31240
# [63]	validation_0-rmse:2.28496	validation_1-rmse:2.31224
# [64]	validation_0-rmse:2.28407	validation_1-rmse:2.31211
# [65]	validation_0-rmse:2.28278	validation_1-rmse:2.31123
# [66]	validation_0-rmse:2.28169	validation_1-rmse:2.31040
# [67]	validation_0-rmse:2.28111	validation_1-rmse:2.30973
# [68]	validation_0-rmse:2.28006	validation_1-rmse:2.30904
# [69]	validation_0-rmse:2.27970	validation_1-rmse:2.30899
# [70]	validation_0-rmse:2.27898	validation_1-rmse:2.30899
# [71]	validation_0-rmse:2.27818	validation_1-rmse:2.30886
# [72]	validation_0-rmse:2.27770	validation_1-rmse:2.30831
# [73]	validation_0-rmse:2.27546	validation_1-rmse:2.30681
# [74]	validation_0-rmse:2.27461	validation_1-rmse:2.30651
# [75]	validation_0-rmse:2.27413	validation_1-rmse:2.30650
# [76]	validation_0-rmse:2.27348	validation_1-rmse:2.30606
# [77]	validation_0-rmse:2.27299	validation_1-rmse:2.30559
# [78]	validation_0-rmse:2.27269	validation_1-rmse:2.30559
# [79]	validation_0-rmse:2.27210	validation_1-rmse:2.30559
# [80]	validation_0-rmse:2.27151	validation_1-rmse:2.30549
# [81]	validation_0-rmse:2.27070	validation_1-rmse:2.30523
# [82]	validation_0-rmse:2.27016	validation_1-rmse:2.30487
# [83]	validation_0-rmse:2.26820	validation_1-rmse:2.30322
# [84]	validation_0-rmse:2.26692	validation_1-rmse:2.30462
# [85]	validation_0-rmse:2.26595	validation_1-rmse:2.30417
# [86]	validation_0-rmse:2.26434	validation_1-rmse:2.30306
# [87]	validation_0-rmse:2.26342	validation_1-rmse:2.30217
# [88]	validation_0-rmse:2.26269	validation_1-rmse:2.30188
# [89]	validation_0-rmse:2.26231	validation_1-rmse:2.30143
# [90]	validation_0-rmse:2.26211	validation_1-rmse:2.30132
# [91]	validation_0-rmse:2.26111	validation_1-rmse:2.30043
# [92]	validation_0-rmse:2.26075	validation_1-rmse:2.30038
# [93]	validation_0-rmse:2.26037	validation_1-rmse:2.30037
# [94]	validation_0-rmse:2.26020	validation_1-rmse:2.30028
# [95]	validation_0-rmse:2.25961	validation_1-rmse:2.30028
# [96]	validation_0-rmse:2.25929	validation_1-rmse:2.29990
# [97]	validation_0-rmse:2.25848	validation_1-rmse:2.29932
# [98]	validation_0-rmse:2.25799	validation_1-rmse:2.29924
# [99]	validation_0-rmse:2.25742	validation_1-rmse:2.29925
# Best Hyperparameters:  {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': 'reg:squarederror', 'reg_alpha': 0.1, 'reg_lambda': 1}
# Best Score:  -5.765607897253836

# %% [markdown]
# **Train an XGboost model**
#
# We will fit all the data in this model using the optimum parameters we found above.

# %%
# Define XGBoost regressor
reg = xgb.XGBRegressor(
    reg_lambda = xgb_grid.best_params_['reg_lambda'],
    reg_alpha = xgb_grid.best_params_['reg_alpha'],
    learning_rate = xgb_grid.best_params_['learning_rate'],
    max_depth = xgb_grid.best_params_['max_depth'],
    n_estimators = 100,
    gamma = xgb_grid.best_params_['gamma'],
    objective = xgb_grid.best_params_['objective'],
    early_stopping_rounds = 5
)

# Train the XGBoost model with feature weights (use validation set on test data)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test,y_test)],
        verbose=False)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=5,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# Make predictions on the test set

# %%
# Make predictions on the X_test set
y_pred_xgboost = reg.predict(X_test)

# %%
# Calculate the MAE of XGBoost model
mae_xgboost = mean_absolute_error(y_test, y_pred_xgboost)
print("Mae is: ",mae_xgboost)

# Calculate RMSE score of XGBoost model
rmse_xgboost = mean_squared_error(y_test, y_pred_xgboost, squared=False)
print("RMSE score:", rmse_xgboost)
# Out:
# Mae is:  1.379464659992579
# RMSE score: 2.2992430014514533

# %% [markdown]
# **Train LSTM for time series forecasting**

# %% [markdown]
# Use the same train and test sets as in the XGBoost model. In order to create more accurate predictions, we scale those two sets before giving them as input to the LSTM Recurrent Neural Network model.

# %%
# Scale the data
scaler = MinMaxScaler()
X_tr = scaler.fit_transform(X_train)
X_te = scaler.fit_transform(X_test)

y_tr = scaler.fit_transform(y_train)
y_te = scaler.fit_transform(y_test)

# %%
# Create 3D train set for LSTM
trainX = []
trainY = []

for i in range(len(X_tr)):
    trainX.append(X_tr[i:i+1,:])

for i in range(len(y_tr)):
    trainY.append(y_tr[i:i+1,:])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# Create 3D test set for LSTM
testX = []
testY = []

for i in range(len(X_te)):
    testX.append(X_te[i:i+1,:])

for i in range(len(y_te)):
    testY.append(y_te[i:i+1,:])

testX, testY = np.array(testX), np.array(testY)

# %% [markdown]
# In the LSTM model, we include dense layers to capture more complex non linear patterns and dropout layers to prevent overfitting.

# %%
# Define LSTM model
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(50, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(25, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(12, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

# Additional Dense layers
model.add(Dense(6, activation='relu'))
model.add(Dense(3, activation='linear'))

# Output layer
model.add(Dense(trainY.shape[1]))

# Add early stopping mechanism
early_stopping = EarlyStopping(patience=5, monitor='val_loss', restore_best_weights=True)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# Compile LSTM model
model.compile(optimizer='adam', loss='mse')

# %%
# Fit model on training data
history = model.fit(trainX, trainY,
          epochs=50,
          batch_size=len(trainX)//100,
          validation_data=(testX,testY),
          callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 12s 43ms/step - loss: 0.0082 - val_loss: 0.0120
# Epoch 2/50
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0041 - val_loss: 0.0032
# Epoch 3/50
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0027 - val_loss: 0.0032
# Epoch 4/50
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0025 - val_loss: 0.0032
# Epoch 5/50
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 6/50
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 7/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 8/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 9/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0021 - val_loss: 0.0038
# Epoch 10/50
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0021 - val_loss: 0.0033

# %%
# Evaluate model on test data
loss_lstm = model.evaluate(testX, testY)
print("Test Loss:", loss_lstm)
# Out:
# 441/441 [==============================] - 5s 10ms/step - loss: 0.0031
# Test Loss: 0.0031471720430999994

# %%
# Predict on test data
y_pred_lstm = model.predict(testX)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm.reshape(-1,1))
# Out:
# 441/441 [==============================] - 6s 12ms/step

# %% [markdown]
# Evaluate the LSTM model

# %%
# Calculate the MAE score of LSTM model
mae_lstm = mean_absolute_error(scaler.inverse_transform(testY.reshape(-1,1)),y_pred_lstm)
print("Mae LSTM is: ",mae_lstm)

# Calculate the RMSE score of LSTM model
rmse_lstm = mean_squared_error(scaler.inverse_transform(testY.reshape(-1,1)), y_pred_lstm, squared=False)
print("RMSE LSTM score:", rmse_lstm)
# Out:
# Mae LSTM is:  1.5280657241171134
# RMSE LSTM score: 2.4683852405478373

# %% [markdown]
# Add in the same dataframe the RMSE and MAE scores of each model, in order to compare them

# %%
# Create dataframe with scores (length == 2)
scores = pd.DataFrame(columns=['Model','RMSE Score','MAE Score'])

# Define rows for dataframe
new_row = {'Model': 'XGBoost', 'RMSE Score': rmse_xgboost, 'MAE Score': mae_xgboost}
new_row1 = {'Model': 'LSTM', 'RMSE Score': rmse_lstm, 'MAE Score': mae_lstm}

# Add rows to dataframe
scores = scores.append(new_row, ignore_index=True)
scores = scores.append(new_row1, ignore_index=True)

# %%
scores # length is 2
# Out:
#      Model  RMSE Score  MAE Score
# 0  XGBoost    2.299243   1.379465
# 1     LSTM    2.468385   1.528066

# %%
# Save XGBoost model to a file
reg.save_model('/content/drive/MyDrive/Paper/Models/xgboost_traffic_flow_length-'+str(optimum_lookback)+'.model')

# %%
# Save the LSTM model
model.save("/content/drive/MyDrive/Paper/Models/LSTM-length-"+str(optimum_lookback)+".h5")

# %% [markdown]
# ##### Sliding Window Length Equals to 3

# %%
# Define Window Length
optimum_lookback = 3

# %%
# Define train data
train= traffic_flow.loc[traffic_flow['Time Column'] < '2008-05-29']

# Define test data
test = traffic_flow.loc[traffic_flow['Time Column'] >= '2008-05-29']

# %%
# Convert train and test data to supervised problem based in the optimum lookback step we defined above.
train = generate_X_y_pairs(train, optimum_lookback)
test = generate_X_y_pairs(test, optimum_lookback)

# %%
# Add rolling mean information
train['rolling_mean'] = 0
test['rolling_mean'] = 0

# Add rolling var information
train['rolling_var'] = 0
test['rolling_var'] = 0

# Calculate rolling mean of window
train['rolling_mean'] = train.iloc[:,0:2].mean(axis=1)
test['rolling_mean'] = test.iloc[:,0:optimum_lookback].mean(axis=1)

# Calculate rolling variance of window
train['rolling_var'] = train.iloc[:, 0:optimum_lookback].var(axis=1)
test['rolling_var'] = test.iloc[:, 0:optimum_lookback].var(axis=1)

# %%
# Define features
features = train.drop(removable_items,axis=1).columns

# Define labels
labels = ['Record 1(t)']

# Create X_train and y_train data sets
X_train = train[features]
y_train = train[labels]

# Create X_test and y_test data sets
X_test = test[features]
y_test = test[labels]

# %% [markdown]
# **Apply GridSearchCV**
#
# Use a 3-fold K-fold cross-validation was used for learning the optimum hyperparameters for the XGBoost algorithm.

# %%
xgb_params = {
    "n_estimators": [100],
    "learning_rate": [0.1],
    "max_depth": [3,6,9],
    "objective":['reg:squarederror'],
    "gamma": [0,0.1],
    "reg_lambda": [0,1],
    'reg_alpha': [0, 0.1]
}

# Define GridSearchCV object
xgb_grid = GridSearchCV(xgb.XGBRegressor(),
                        xgb_params,cv=3,
                        scoring= "neg_mean_squared_error")

# Train on train data using 3 fold Cross Validation
xgb_grid.fit(X_train,y_train,
             early_stopping_rounds=5,
             eval_set=[(X_train, y_train), (X_test,y_test)],
             eval_metric='rmse')

# print the best hyperparameters and corresponding score
print("Best Hyperparameters: ", xgb_grid.best_params_)
print("Best Score: ", xgb_grid.best_score_)
# Out:
# [0]	validation_0-rmse:4.59273	validation_1-rmse:4.51405
# [1]	validation_0-rmse:4.28164	validation_1-rmse:4.20766
# [2]	validation_0-rmse:4.00767	validation_1-rmse:3.93736
# [3]	validation_0-rmse:3.76879	validation_1-rmse:3.69682
# [4]	validation_0-rmse:3.55830	validation_1-rmse:3.49054
# [5]	validation_0-rmse:3.37818	validation_1-rmse:3.31094
# [6]	validation_0-rmse:3.21991	validation_1-rmse:3.15420
# [7]	validation_0-rmse:3.08415	validation_1-rmse:3.02037
# [8]	validation_0-rmse:2.96812	validation_1-rmse:2.90898
# [9]	validation_0-rmse:2.86942	validation_1-rmse:2.81231
# [10]	validation_0-rmse:2.78442	validation_1-rmse:2.73294
# [11]	validation_0-rmse:2.71227	validation_1-rmse:2.66448
# [12]	validation_0-rmse:2.65191	validation_1-rmse:2.60852
# [13]	validation_0-rmse:2.60050	validation_1-rmse:2.56148
# [14]	validation_0-rmse:2.55549	validation_1-rmse:2.51907
# [15]	validation_0-rmse:2.51725	validation_1-rmse:2.48241
# [16]	validation_0-rmse:2.48640	validation_1-rmse:2.45499
# [17]	validation_0-rmse:2.46016	validation_1-rmse:2.43096
# [18]	validation_0-rmse:2.43782	validation_1-rmse:2.41222
# [19]	validation_0-rmse:2.41868	validation_1-rmse:2.39658
# [20]	validation_0-rmse:2.40192	validation_1-rmse:2.38266
# [21]	validation_0-rmse:2.38926	validation_1-rmse:2.37168
# [22]	validation_0-rmse:2.37795	validation_1-rmse:2.36095
# [23]	validation_0-rmse:2.36834	validation_1-rmse:2.35411
# [24]	validation_0-rmse:2.35958	validation_1-rmse:2.34738
# [25]	validation_0-rmse:2.35172	validation_1-rmse:2.34099
# [26]	validation_0-rmse:2.34585	validation_1-rmse:2.33660
# [27]	validation_0-rmse:2.33879	validation_1-rmse:2.33088
# [28]	validation_0-rmse:2.33381	validation_1-rmse:2.32748
# [29]	validation_0-rmse:2.32860	validation_1-rmse:2.32309
# [30]	validation_0-rmse:2.32396	validation_1-rmse:2.31935
# [31]	validation_0-rmse:2.32043	validation_1-rmse:2.31871
# [32]	validation_0-rmse:2.31776	validation_1-rmse:2.31663
# [33]	validation_0-rmse:2.31442	validation_1-rmse:2.31399
# [34]	validation_0-rmse:2.31186	validation_1-rmse:2.31242
# [35]	validation_0-rmse:2.30873	validation_1-rmse:2.31089
# [36]	validation_0-rmse:2.30733	validation_1-rmse:2.31074
# [37]	validation_0-rmse:2.30527	validation_1-rmse:2.31027
# [38]	validation_0-rmse:2.30200	validation_1-rmse:2.30852
# [39]	validation_0-rmse:2.30026	validation_1-rmse:2.30851
# [40]	validation_0-rmse:2.29740	validation_1-rmse:2.30777
# [41]	validation_0-rmse:2.29503	validation_1-rmse:2.30643
# [42]	validation_0-rmse:2.29426	validation_1-rmse:2.30604
# [43]	validation_0-rmse:2.29245	validation_1-rmse:2.30571
# [44]	validation_0-rmse:2.29200	validation_1-rmse:2.30532
# [45]	validation_0-rmse:2.29172	validation_1-rmse:2.30508
# [46]	validation_0-rmse:2.29106	validation_1-rmse:2.30515
# [47]	validation_0-rmse:2.28934	validation_1-rmse:2.30385
# [48]	validation_0-rmse:2.28858	validation_1-rmse:2.30444
# [49]	validation_0-rmse:2.28650	validation_1-rmse:2.30399
# [50]	validation_0-rmse:2.28559	validation_1-rmse:2.30414
# [51]	validation_0-rmse:2.28358	validation_1-rmse:2.30336
# [52]	validation_0-rmse:2.28261	validation_1-rmse:2.30336
# [53]	validation_0-rmse:2.28129	validation_1-rmse:2.30265
# [54]	validation_0-rmse:2.27943	validation_1-rmse:2.30092
# [55]	validation_0-rmse:2.27845	validation_1-rmse:2.30124
# [56]	validation_0-rmse:2.27795	validation_1-rmse:2.30123
# [57]	validation_0-rmse:2.27610	validation_1-rmse:2.29997
# [58]	validation_0-rmse:2.27488	validation_1-rmse:2.29891
# [59]	validation_0-rmse:2.27401	validation_1-rmse:2.29932
# [60]	validation_0-rmse:2.27248	validation_1-rmse:2.30074
# [61]	validation_0-rmse:2.27142	validation_1-rmse:2.30040
# [62]	validation_0-rmse:2.27040	validation_1-rmse:2.29968
# [63]	validation_0-rmse:2.27058	validation_1-rmse:2.29963
# [0]	validation_0-rmse:4.59213	validation_1-rmse:4.51127
# [1]	validation_0-rmse:4.28422	validation_1-rmse:4.20245
# [2]	validation_0-rmse:4.01035	validation_1-rmse:3.92792
# [3]	validation_0-rmse:3.77386	validation_1-rmse:3.69096
# [4]	validation_0-rmse:3.56478	validation_1-rmse:3.48622
# [5]	validation_0-rmse:3.38609	validation_1-rmse:3.31195
# [6]	validation_0-rmse:3.23177	validation_1-rmse:3.15730
# [7]	validation_0-rmse:3.09803	validation_1-rmse:3.02688
# [8]	validation_0-rmse:2.99070	validation_1-rmse:2.91788
# [9]	validation_0-rmse:2.89761	validation_1-rmse:2.82563
# [10]	validation_0-rmse:2.81180	validation_1-rmse:2.74232
# [11]	validation_0-rmse:2.73684	validation_1-rmse:2.67290
# [12]	validation_0-rmse:2.68052	validation_1-rmse:2.61819
# [13]	validation_0-rmse:2.62615	validation_1-rmse:2.56992
# [14]	validation_0-rmse:2.58058	validation_1-rmse:2.52969
# [15]	validation_0-rmse:2.54592	validation_1-rmse:2.49719
# [16]	validation_0-rmse:2.51620	validation_1-rmse:2.46848
# [17]	validation_0-rmse:2.48661	validation_1-rmse:2.44419
# [18]	validation_0-rmse:2.46506	validation_1-rmse:2.42439
# [19]	validation_0-rmse:2.44438	validation_1-rmse:2.40855
# [20]	validation_0-rmse:2.42815	validation_1-rmse:2.39413
# [21]	validation_0-rmse:2.41493	validation_1-rmse:2.38199
# [22]	validation_0-rmse:2.40242	validation_1-rmse:2.37255
# [23]	validation_0-rmse:2.39208	validation_1-rmse:2.36265
# [24]	validation_0-rmse:2.38104	validation_1-rmse:2.35457
# [25]	validation_0-rmse:2.37294	validation_1-rmse:2.34759
# [26]	validation_0-rmse:2.36319	validation_1-rmse:2.34148
# [27]	validation_0-rmse:2.35674	validation_1-rmse:2.33614
# [28]	validation_0-rmse:2.35118	validation_1-rmse:2.33123
# [29]	validation_0-rmse:2.34458	validation_1-rmse:2.32610
# [30]	validation_0-rmse:2.34055	validation_1-rmse:2.32384
# [31]	validation_0-rmse:2.33682	validation_1-rmse:2.32170
# [32]	validation_0-rmse:2.33340	validation_1-rmse:2.31868
# [33]	validation_0-rmse:2.33060	validation_1-rmse:2.31726
# [34]	validation_0-rmse:2.32742	validation_1-rmse:2.31512
# [35]	validation_0-rmse:2.32462	validation_1-rmse:2.31405
# [36]	validation_0-rmse:2.32155	validation_1-rmse:2.31325
# [37]	validation_0-rmse:2.31884	validation_1-rmse:2.31219
# [38]	validation_0-rmse:2.31715	validation_1-rmse:2.31154
# [39]	validation_0-rmse:2.31529	validation_1-rmse:2.31169
# [40]	validation_0-rmse:2.31401	validation_1-rmse:2.31185
# [41]	validation_0-rmse:2.31259	validation_1-rmse:2.31137
# [42]	validation_0-rmse:2.30965	validation_1-rmse:2.31003
# [43]	validation_0-rmse:2.30885	validation_1-rmse:2.31074
# [44]	validation_0-rmse:2.30648	validation_1-rmse:2.30977
# [45]	validation_0-rmse:2.30643	validation_1-rmse:2.31016
# [46]	validation_0-rmse:2.30491	validation_1-rmse:2.30891
# [47]	validation_0-rmse:2.30417	validation_1-rmse:2.30891
# [48]	validation_0-rmse:2.30273	validation_1-rmse:2.30767
# [49]	validation_0-rmse:2.30067	validation_1-rmse:2.30813
# [50]	validation_0-rmse:2.30004	validation_1-rmse:2.30841
# [51]	validation_0-rmse:2.29974	validation_1-rmse:2.30812
# [52]	validation_0-rmse:2.29787	validation_1-rmse:2.30904
# [53]	validation_0-rmse:2.29635	validation_1-rmse:2.30840
# [0]	validation_0-rmse:4.57705	validation_1-rmse:4.49784
# [1]	validation_0-rmse:4.25717	validation_1-rmse:4.17421
# [2]	validation_0-rmse:3.97621	validation_1-rmse:3.89379
# [3]	validation_0-rmse:3.73065	validation_1-rmse:3.65266
# [4]	validation_0-rmse:3.51833	validation_1-rmse:3.43997
# [5]	validation_0-rmse:3.33503	validation_1-rmse:3.25918
# [6]	validation_0-rmse:3.17568	validation_1-rmse:3.10269
# [7]	validation_0-rmse:3.03860	validation_1-rmse:2.96832
# [8]	validation_0-rmse:2.92284	validation_1-rmse:2.85856
# [9]	validation_0-rmse:2.82512	validation_1-rmse:2.76548
# [10]	validation_0-rmse:2.74237	validation_1-rmse:2.68875
# [11]	validation_0-rmse:2.67245	validation_1-rmse:2.62268
# [12]	validation_0-rmse:2.61316	validation_1-rmse:2.56916
# [13]	validation_0-rmse:2.56284	validation_1-rmse:2.52264
# [14]	validation_0-rmse:2.51839	validation_1-rmse:2.48154
# [15]	validation_0-rmse:2.48106	validation_1-rmse:2.44768
# [16]	validation_0-rmse:2.45140	validation_1-rmse:2.42389
# [17]	validation_0-rmse:2.42432	validation_1-rmse:2.40097
# [18]	validation_0-rmse:2.40247	validation_1-rmse:2.38254
# [19]	validation_0-rmse:2.38594	validation_1-rmse:2.36843
# [20]	validation_0-rmse:2.37208	validation_1-rmse:2.35756
# [21]	validation_0-rmse:2.35952	validation_1-rmse:2.34731
# [22]	validation_0-rmse:2.34825	validation_1-rmse:2.34027
# [23]	validation_0-rmse:2.33970	validation_1-rmse:2.33381
# [24]	validation_0-rmse:2.33277	validation_1-rmse:2.32983
# [25]	validation_0-rmse:2.32605	validation_1-rmse:2.32446
# [26]	validation_0-rmse:2.32124	validation_1-rmse:2.32279
# [27]	validation_0-rmse:2.31718	validation_1-rmse:2.32214
# [28]	validation_0-rmse:2.31275	validation_1-rmse:2.31885
# [29]	validation_0-rmse:2.30880	validation_1-rmse:2.31572
# [30]	validation_0-rmse:2.30583	validation_1-rmse:2.31454
# [31]	validation_0-rmse:2.30436	validation_1-rmse:2.31548
# [32]	validation_0-rmse:2.30166	validation_1-rmse:2.31282
# [33]	validation_0-rmse:2.29936	validation_1-rmse:2.31210
# [34]	validation_0-rmse:2.29725	validation_1-rmse:2.31159
# [35]	validation_0-rmse:2.29527	validation_1-rmse:2.31125
# [36]	validation_0-rmse:2.29322	validation_1-rmse:2.31028
# [37]	validation_0-rmse:2.29159	validation_1-rmse:2.31086
# [38]	validation_0-rmse:2.29184	validation_1-rmse:2.31217
# [39]	validation_0-rmse:2.29035	validation_1-rmse:2.31161
# [40]	validation_0-rmse:2.28910	validation_1-rmse:2.31084
# [41]	validation_0-rmse:2.28713	validation_1-rmse:2.31047
# [0]	validation_0-rmse:4.59321	validation_1-rmse:4.51448
# [1]	validation_0-rmse:4.28254	validation_1-rmse:4.20845
# [2]	validation_0-rmse:4.00890	validation_1-rmse:3.93843
# [3]	validation_0-rmse:3.77016	validation_1-rmse:3.69801
# [4]	validation_0-rmse:3.55993	validation_1-rmse:3.49192
# [5]	validation_0-rmse:3.38003	validation_1-rmse:3.31248
# [6]	validation_0-rmse:3.22194	validation_1-rmse:3.15584
# [7]	validation_0-rmse:3.08620	validation_1-rmse:3.02201
# [8]	validation_0-rmse:2.97011	validation_1-rmse:2.91055
# [9]	validation_0-rmse:2.87131	validation_1-rmse:2.81378
# [10]	validation_0-rmse:2.78637	validation_1-rmse:2.73436
# [11]	validation_0-rmse:2.71223	validation_1-rmse:2.66237
# [12]	validation_0-rmse:2.65186	validation_1-rmse:2.60649
# [13]	validation_0-rmse:2.60027	validation_1-rmse:2.55901
# [14]	validation_0-rmse:2.55571	validation_1-rmse:2.51885
# [15]	validation_0-rmse:2.51763	validation_1-rmse:2.48236
# [16]	validation_0-rmse:2.48695	validation_1-rmse:2.45491
# [17]	validation_0-rmse:2.46071	validation_1-rmse:2.43027
# [18]	validation_0-rmse:2.43847	validation_1-rmse:2.41102
# [19]	validation_0-rmse:2.41955	validation_1-rmse:2.39420
# [20]	validation_0-rmse:2.40416	validation_1-rmse:2.38087
# [21]	validation_0-rmse:2.39086	validation_1-rmse:2.37079
# [22]	validation_0-rmse:2.37848	validation_1-rmse:2.36166
# [23]	validation_0-rmse:2.36861	validation_1-rmse:2.35348
# [24]	validation_0-rmse:2.36031	validation_1-rmse:2.34783
# [25]	validation_0-rmse:2.35154	validation_1-rmse:2.34101
# [26]	validation_0-rmse:2.34455	validation_1-rmse:2.33527
# [27]	validation_0-rmse:2.33783	validation_1-rmse:2.32958
# [28]	validation_0-rmse:2.33341	validation_1-rmse:2.32759
# [29]	validation_0-rmse:2.32807	validation_1-rmse:2.32336
# [30]	validation_0-rmse:2.32412	validation_1-rmse:2.32114
# [31]	validation_0-rmse:2.32101	validation_1-rmse:2.31920
# [32]	validation_0-rmse:2.31648	validation_1-rmse:2.31551
# [33]	validation_0-rmse:2.31376	validation_1-rmse:2.31409
# [34]	validation_0-rmse:2.31061	validation_1-rmse:2.31243
# [35]	validation_0-rmse:2.30876	validation_1-rmse:2.31141
# [36]	validation_0-rmse:2.30680	validation_1-rmse:2.31076
# [37]	validation_0-rmse:2.30513	validation_1-rmse:2.31035
# [38]	validation_0-rmse:2.30334	validation_1-rmse:2.31067
# [39]	validation_0-rmse:2.30171	validation_1-rmse:2.30950
# [40]	validation_0-rmse:2.29911	validation_1-rmse:2.30775
# [41]	validation_0-rmse:2.29748	validation_1-rmse:2.30714
# [42]	validation_0-rmse:2.29677	validation_1-rmse:2.30676
# [43]	validation_0-rmse:2.29321	validation_1-rmse:2.30482
# [44]	validation_0-rmse:2.29269	validation_1-rmse:2.30490
# [45]	validation_0-rmse:2.29219	validation_1-rmse:2.30476
# [46]	validation_0-rmse:2.29191	validation_1-rmse:2.30450
# [47]	validation_0-rmse:2.28978	validation_1-rmse:2.30284
# [48]	validation_0-rmse:2.28858	validation_1-rmse:2.30293
# [49]	validation_0-rmse:2.28830	validation_1-rmse:2.30304
# [50]	validation_0-rmse:2.28756	validation_1-rmse:2.30356
# [51]	validation_0-rmse:2.28699	validation_1-rmse:2.30356
# [52]	validation_0-rmse:2.28658	validation_1-rmse:2.30350
# [0]	validation_0-rmse:4.59274	validation_1-rmse:4.51179
# [1]	validation_0-rmse:4.28517	validation_1-rmse:4.20328
# [2]	validation_0-rmse:4.01172	validation_1-rmse:3.92909
# [3]	validation_0-rmse:3.77556	validation_1-rmse:3.69238
# [4]	validation_0-rmse:3.56670	validation_1-rmse:3.48780
# [5]	validation_0-rmse:3.38806	validation_1-rmse:3.31354
# [6]	validation_0-rmse:3.23371	validation_1-rmse:3.15885
# [7]	validation_0-rmse:3.10003	validation_1-rmse:3.02844
# [8]	validation_0-rmse:2.99263	validation_1-rmse:2.91937
# [9]	validation_0-rmse:2.89949	validation_1-rmse:2.82707
# [10]	validation_0-rmse:2.81467	validation_1-rmse:2.74426
# [11]	validation_0-rmse:2.73962	validation_1-rmse:2.67457
# [12]	validation_0-rmse:2.67668	validation_1-rmse:2.61501
# [13]	validation_0-rmse:2.62748	validation_1-rmse:2.56858
# [14]	validation_0-rmse:2.58185	validation_1-rmse:2.52641
# [15]	validation_0-rmse:2.54303	validation_1-rmse:2.49288
# [16]	validation_0-rmse:2.51377	validation_1-rmse:2.46537
# [17]	validation_0-rmse:2.48421	validation_1-rmse:2.44080
# [18]	validation_0-rmse:2.46246	validation_1-rmse:2.41965
# [19]	validation_0-rmse:2.44140	validation_1-rmse:2.40381
# [20]	validation_0-rmse:2.42274	validation_1-rmse:2.38871
# [21]	validation_0-rmse:2.40857	validation_1-rmse:2.37527
# [22]	validation_0-rmse:2.39449	validation_1-rmse:2.36394
# [23]	validation_0-rmse:2.38343	validation_1-rmse:2.35676
# [24]	validation_0-rmse:2.37364	validation_1-rmse:2.34888
# [25]	validation_0-rmse:2.36643	validation_1-rmse:2.34244
# [26]	validation_0-rmse:2.35975	validation_1-rmse:2.33755
# [27]	validation_0-rmse:2.35291	validation_1-rmse:2.33159
# [28]	validation_0-rmse:2.34740	validation_1-rmse:2.32748
# [29]	validation_0-rmse:2.34278	validation_1-rmse:2.32496
# [30]	validation_0-rmse:2.33811	validation_1-rmse:2.32191
# [31]	validation_0-rmse:2.33428	validation_1-rmse:2.31888
# [32]	validation_0-rmse:2.33042	validation_1-rmse:2.31623
# [33]	validation_0-rmse:2.32718	validation_1-rmse:2.31475
# [34]	validation_0-rmse:2.32464	validation_1-rmse:2.31344
# [35]	validation_0-rmse:2.32042	validation_1-rmse:2.31073
# [36]	validation_0-rmse:2.31753	validation_1-rmse:2.30979
# [37]	validation_0-rmse:2.31500	validation_1-rmse:2.30807
# [38]	validation_0-rmse:2.31348	validation_1-rmse:2.30770
# [39]	validation_0-rmse:2.31158	validation_1-rmse:2.30672
# [40]	validation_0-rmse:2.31022	validation_1-rmse:2.30689
# [41]	validation_0-rmse:2.30882	validation_1-rmse:2.30648
# [42]	validation_0-rmse:2.30777	validation_1-rmse:2.30671
# [43]	validation_0-rmse:2.30663	validation_1-rmse:2.30609
# [44]	validation_0-rmse:2.30490	validation_1-rmse:2.30639
# [45]	validation_0-rmse:2.30476	validation_1-rmse:2.30649
# [46]	validation_0-rmse:2.30282	validation_1-rmse:2.30737
# [47]	validation_0-rmse:2.30091	validation_1-rmse:2.30694
# [48]	validation_0-rmse:2.30069	validation_1-rmse:2.30721
# [0]	validation_0-rmse:4.57716	validation_1-rmse:4.49606
# [1]	validation_0-rmse:4.25786	validation_1-rmse:4.17281
# [2]	validation_0-rmse:3.97775	validation_1-rmse:3.89341
# [3]	validation_0-rmse:3.73223	validation_1-rmse:3.65232
# [4]	validation_0-rmse:3.52014	validation_1-rmse:3.44134
# [5]	validation_0-rmse:3.33599	validation_1-rmse:3.26178
# [6]	validation_0-rmse:3.17707	validation_1-rmse:3.10553
# [7]	validation_0-rmse:3.03989	validation_1-rmse:2.97266
# [8]	validation_0-rmse:2.92306	validation_1-rmse:2.85995
# [9]	validation_0-rmse:2.82565	validation_1-rmse:2.76483
# [10]	validation_0-rmse:2.74295	validation_1-rmse:2.68655
# [11]	validation_0-rmse:2.67203	validation_1-rmse:2.62027
# [12]	validation_0-rmse:2.61244	validation_1-rmse:2.56488
# [13]	validation_0-rmse:2.56307	validation_1-rmse:2.52032
# [14]	validation_0-rmse:2.52174	validation_1-rmse:2.48442
# [15]	validation_0-rmse:2.48669	validation_1-rmse:2.45264
# [16]	validation_0-rmse:2.45763	validation_1-rmse:2.42571
# [17]	validation_0-rmse:2.43146	validation_1-rmse:2.40375
# [18]	validation_0-rmse:2.40860	validation_1-rmse:2.38452
# [19]	validation_0-rmse:2.38993	validation_1-rmse:2.36973
# [20]	validation_0-rmse:2.37533	validation_1-rmse:2.35987
# [21]	validation_0-rmse:2.36215	validation_1-rmse:2.34908
# [22]	validation_0-rmse:2.35291	validation_1-rmse:2.34383
# [23]	validation_0-rmse:2.34294	validation_1-rmse:2.33818
# [24]	validation_0-rmse:2.33564	validation_1-rmse:2.33367
# [25]	validation_0-rmse:2.32857	validation_1-rmse:2.32871
# [26]	validation_0-rmse:2.32243	validation_1-rmse:2.32522
# [27]	validation_0-rmse:2.31803	validation_1-rmse:2.32215
# [28]	validation_0-rmse:2.31423	validation_1-rmse:2.31963
# [29]	validation_0-rmse:2.31041	validation_1-rmse:2.31715
# [30]	validation_0-rmse:2.30748	validation_1-rmse:2.31546
# [31]	validation_0-rmse:2.30510	validation_1-rmse:2.31454
# [32]	validation_0-rmse:2.30384	validation_1-rmse:2.31495
# [33]	validation_0-rmse:2.30133	validation_1-rmse:2.31356
# [34]	validation_0-rmse:2.29885	validation_1-rmse:2.31109
# [35]	validation_0-rmse:2.29696	validation_1-rmse:2.31040
# [36]	validation_0-rmse:2.29474	validation_1-rmse:2.30992
# [37]	validation_0-rmse:2.29496	validation_1-rmse:2.31214
# [38]	validation_0-rmse:2.29514	validation_1-rmse:2.31374
# [39]	validation_0-rmse:2.29358	validation_1-rmse:2.31341
# [40]	validation_0-rmse:2.29192	validation_1-rmse:2.31301
# [41]	validation_0-rmse:2.29087	validation_1-rmse:2.31310
# [0]	validation_0-rmse:4.59273	validation_1-rmse:4.51405
# [1]	validation_0-rmse:4.28165	validation_1-rmse:4.20766
# [2]	validation_0-rmse:4.00768	validation_1-rmse:3.93737
# [3]	validation_0-rmse:3.76880	validation_1-rmse:3.69683
# [4]	validation_0-rmse:3.55831	validation_1-rmse:3.49055
# [5]	validation_0-rmse:3.37819	validation_1-rmse:3.31096
# [6]	validation_0-rmse:3.21993	validation_1-rmse:3.15421
# [7]	validation_0-rmse:3.08417	validation_1-rmse:3.02038
# [8]	validation_0-rmse:2.96813	validation_1-rmse:2.90899
# [9]	validation_0-rmse:2.86944	validation_1-rmse:2.81232
# [10]	validation_0-rmse:2.78444	validation_1-rmse:2.73295
# [11]	validation_0-rmse:2.71229	validation_1-rmse:2.66450
# [12]	validation_0-rmse:2.65193	validation_1-rmse:2.60854
# [13]	validation_0-rmse:2.60052	validation_1-rmse:2.56149
# [14]	validation_0-rmse:2.55551	validation_1-rmse:2.51908
# [15]	validation_0-rmse:2.51727	validation_1-rmse:2.48242
# [16]	validation_0-rmse:2.48641	validation_1-rmse:2.45500
# [17]	validation_0-rmse:2.46018	validation_1-rmse:2.43097
# [18]	validation_0-rmse:2.43784	validation_1-rmse:2.41223
# [19]	validation_0-rmse:2.41870	validation_1-rmse:2.39659
# [20]	validation_0-rmse:2.40193	validation_1-rmse:2.38267
# [21]	validation_0-rmse:2.38928	validation_1-rmse:2.37168
# [22]	validation_0-rmse:2.37797	validation_1-rmse:2.36096
# [23]	validation_0-rmse:2.36836	validation_1-rmse:2.35412
# [24]	validation_0-rmse:2.35960	validation_1-rmse:2.34739
# [25]	validation_0-rmse:2.35173	validation_1-rmse:2.34099
# [26]	validation_0-rmse:2.34586	validation_1-rmse:2.33660
# [27]	validation_0-rmse:2.33881	validation_1-rmse:2.33088
# [28]	validation_0-rmse:2.33383	validation_1-rmse:2.32748
# [29]	validation_0-rmse:2.32861	validation_1-rmse:2.32310
# [30]	validation_0-rmse:2.32367	validation_1-rmse:2.31896
# [31]	validation_0-rmse:2.32017	validation_1-rmse:2.31796
# [32]	validation_0-rmse:2.31720	validation_1-rmse:2.31640
# [33]	validation_0-rmse:2.31359	validation_1-rmse:2.31489
# [34]	validation_0-rmse:2.31134	validation_1-rmse:2.31319
# [35]	validation_0-rmse:2.30853	validation_1-rmse:2.31108
# [36]	validation_0-rmse:2.30679	validation_1-rmse:2.31046
# [37]	validation_0-rmse:2.30561	validation_1-rmse:2.31035
# [38]	validation_0-rmse:2.30228	validation_1-rmse:2.30853
# [39]	validation_0-rmse:2.30052	validation_1-rmse:2.30819
# [40]	validation_0-rmse:2.29961	validation_1-rmse:2.30777
# [41]	validation_0-rmse:2.29771	validation_1-rmse:2.30745
# [42]	validation_0-rmse:2.29726	validation_1-rmse:2.30764
# [43]	validation_0-rmse:2.29435	validation_1-rmse:2.30576
# [44]	validation_0-rmse:2.29262	validation_1-rmse:2.30552
# [45]	validation_0-rmse:2.29151	validation_1-rmse:2.30478
# [46]	validation_0-rmse:2.29097	validation_1-rmse:2.30490
# [47]	validation_0-rmse:2.28982	validation_1-rmse:2.30490
# [48]	validation_0-rmse:2.28819	validation_1-rmse:2.30492
# [49]	validation_0-rmse:2.28753	validation_1-rmse:2.30503
# [50]	validation_0-rmse:2.28550	validation_1-rmse:2.30458
# [51]	validation_0-rmse:2.28398	validation_1-rmse:2.30319
# [52]	validation_0-rmse:2.28263	validation_1-rmse:2.30204
# [53]	validation_0-rmse:2.28069	validation_1-rmse:2.30025
# [54]	validation_0-rmse:2.28077	validation_1-rmse:2.30014
# [55]	validation_0-rmse:2.27829	validation_1-rmse:2.29826
# [56]	validation_0-rmse:2.27669	validation_1-rmse:2.29974
# [57]	validation_0-rmse:2.27553	validation_1-rmse:2.29913
# [58]	validation_0-rmse:2.27440	validation_1-rmse:2.29823
# [59]	validation_0-rmse:2.27455	validation_1-rmse:2.29823
# [60]	validation_0-rmse:2.27409	validation_1-rmse:2.29793
# [61]	validation_0-rmse:2.27264	validation_1-rmse:2.29798
# [62]	validation_0-rmse:2.27240	validation_1-rmse:2.29798
# [63]	validation_0-rmse:2.27177	validation_1-rmse:2.29798
# [64]	validation_0-rmse:2.27088	validation_1-rmse:2.29827
# [65]	validation_0-rmse:2.27107	validation_1-rmse:2.29822
# [0]	validation_0-rmse:4.59214	validation_1-rmse:4.51127
# [1]	validation_0-rmse:4.28422	validation_1-rmse:4.20246
# [2]	validation_0-rmse:4.01036	validation_1-rmse:3.92793
# [3]	validation_0-rmse:3.77387	validation_1-rmse:3.69097
# [4]	validation_0-rmse:3.56479	validation_1-rmse:3.48623
# [5]	validation_0-rmse:3.38611	validation_1-rmse:3.31196
# [6]	validation_0-rmse:3.23179	validation_1-rmse:3.15731
# [7]	validation_0-rmse:3.09805	validation_1-rmse:3.02689
# [8]	validation_0-rmse:2.99072	validation_1-rmse:2.91789
# [9]	validation_0-rmse:2.89763	validation_1-rmse:2.82565
# [10]	validation_0-rmse:2.81182	validation_1-rmse:2.74233
# [11]	validation_0-rmse:2.73685	validation_1-rmse:2.67291
# [12]	validation_0-rmse:2.68054	validation_1-rmse:2.61820
# [13]	validation_0-rmse:2.62617	validation_1-rmse:2.56993
# [14]	validation_0-rmse:2.58060	validation_1-rmse:2.52970
# [15]	validation_0-rmse:2.54594	validation_1-rmse:2.49720
# [16]	validation_0-rmse:2.51622	validation_1-rmse:2.46849
# [17]	validation_0-rmse:2.48662	validation_1-rmse:2.44420
# [18]	validation_0-rmse:2.46507	validation_1-rmse:2.42440
# [19]	validation_0-rmse:2.44440	validation_1-rmse:2.40856
# [20]	validation_0-rmse:2.42817	validation_1-rmse:2.39414
# [21]	validation_0-rmse:2.41495	validation_1-rmse:2.38200
# [22]	validation_0-rmse:2.40244	validation_1-rmse:2.37256
# [23]	validation_0-rmse:2.39209	validation_1-rmse:2.36266
# [24]	validation_0-rmse:2.38106	validation_1-rmse:2.35458
# [25]	validation_0-rmse:2.37296	validation_1-rmse:2.34760
# [26]	validation_0-rmse:2.36320	validation_1-rmse:2.34149
# [27]	validation_0-rmse:2.35676	validation_1-rmse:2.33615
# [28]	validation_0-rmse:2.35120	validation_1-rmse:2.33123
# [29]	validation_0-rmse:2.34460	validation_1-rmse:2.32611
# [30]	validation_0-rmse:2.34057	validation_1-rmse:2.32385
# [31]	validation_0-rmse:2.33684	validation_1-rmse:2.32171
# [32]	validation_0-rmse:2.33342	validation_1-rmse:2.31868
# [33]	validation_0-rmse:2.33062	validation_1-rmse:2.31726
# [34]	validation_0-rmse:2.32744	validation_1-rmse:2.31513
# [35]	validation_0-rmse:2.32464	validation_1-rmse:2.31406
# [36]	validation_0-rmse:2.32157	validation_1-rmse:2.31325
# [37]	validation_0-rmse:2.31887	validation_1-rmse:2.31220
# [38]	validation_0-rmse:2.31717	validation_1-rmse:2.31155
# [39]	validation_0-rmse:2.31531	validation_1-rmse:2.31170
# [40]	validation_0-rmse:2.31404	validation_1-rmse:2.31185
# [41]	validation_0-rmse:2.31261	validation_1-rmse:2.31138
# [42]	validation_0-rmse:2.30967	validation_1-rmse:2.31003
# [43]	validation_0-rmse:2.30870	validation_1-rmse:2.31035
# [44]	validation_0-rmse:2.30865	validation_1-rmse:2.31075
# [45]	validation_0-rmse:2.30630	validation_1-rmse:2.30980
# [46]	validation_0-rmse:2.30541	validation_1-rmse:2.30980
# [47]	validation_0-rmse:2.30349	validation_1-rmse:2.30954
# [48]	validation_0-rmse:2.30296	validation_1-rmse:2.31024
# [49]	validation_0-rmse:2.30150	validation_1-rmse:2.30898
# [50]	validation_0-rmse:2.29947	validation_1-rmse:2.30942
# [51]	validation_0-rmse:2.29819	validation_1-rmse:2.30935
# [52]	validation_0-rmse:2.29775	validation_1-rmse:2.31009
# [53]	validation_0-rmse:2.29579	validation_1-rmse:2.30884
# [54]	validation_0-rmse:2.29548	validation_1-rmse:2.30851
# [55]	validation_0-rmse:2.29496	validation_1-rmse:2.30944
# [56]	validation_0-rmse:2.29409	validation_1-rmse:2.30926
# [57]	validation_0-rmse:2.29411	validation_1-rmse:2.30918
# [58]	validation_0-rmse:2.29384	validation_1-rmse:2.31011
# [0]	validation_0-rmse:4.57705	validation_1-rmse:4.49785
# [1]	validation_0-rmse:4.25718	validation_1-rmse:4.17422
# [2]	validation_0-rmse:3.97622	validation_1-rmse:3.89380
# [3]	validation_0-rmse:3.73065	validation_1-rmse:3.65267
# [4]	validation_0-rmse:3.51834	validation_1-rmse:3.43998
# [5]	validation_0-rmse:3.33505	validation_1-rmse:3.25919
# [6]	validation_0-rmse:3.17570	validation_1-rmse:3.10270
# [7]	validation_0-rmse:3.03861	validation_1-rmse:2.96833
# [8]	validation_0-rmse:2.92285	validation_1-rmse:2.85857
# [9]	validation_0-rmse:2.82514	validation_1-rmse:2.76549
# [10]	validation_0-rmse:2.74239	validation_1-rmse:2.68876
# [11]	validation_0-rmse:2.67247	validation_1-rmse:2.62269
# [12]	validation_0-rmse:2.61318	validation_1-rmse:2.56917
# [13]	validation_0-rmse:2.56285	validation_1-rmse:2.52265
# [14]	validation_0-rmse:2.51840	validation_1-rmse:2.48155
# [15]	validation_0-rmse:2.48107	validation_1-rmse:2.44769
# [16]	validation_0-rmse:2.45141	validation_1-rmse:2.42389
# [17]	validation_0-rmse:2.42433	validation_1-rmse:2.40098
# [18]	validation_0-rmse:2.40248	validation_1-rmse:2.38255
# [19]	validation_0-rmse:2.38595	validation_1-rmse:2.36843
# [20]	validation_0-rmse:2.37209	validation_1-rmse:2.35757
# [21]	validation_0-rmse:2.35954	validation_1-rmse:2.34732
# [22]	validation_0-rmse:2.34827	validation_1-rmse:2.34027
# [23]	validation_0-rmse:2.33971	validation_1-rmse:2.33381
# [24]	validation_0-rmse:2.33278	validation_1-rmse:2.32984
# [25]	validation_0-rmse:2.32606	validation_1-rmse:2.32446
# [26]	validation_0-rmse:2.32125	validation_1-rmse:2.32279
# [27]	validation_0-rmse:2.31719	validation_1-rmse:2.32214
# [28]	validation_0-rmse:2.31276	validation_1-rmse:2.31885
# [29]	validation_0-rmse:2.30882	validation_1-rmse:2.31572
# [30]	validation_0-rmse:2.30584	validation_1-rmse:2.31454
# [31]	validation_0-rmse:2.30437	validation_1-rmse:2.31548
# [32]	validation_0-rmse:2.30167	validation_1-rmse:2.31282
# [33]	validation_0-rmse:2.29937	validation_1-rmse:2.31210
# [34]	validation_0-rmse:2.29726	validation_1-rmse:2.31159
# [35]	validation_0-rmse:2.29528	validation_1-rmse:2.31124
# [36]	validation_0-rmse:2.29323	validation_1-rmse:2.31028
# [37]	validation_0-rmse:2.29160	validation_1-rmse:2.31086
# [38]	validation_0-rmse:2.29186	validation_1-rmse:2.31217
# [39]	validation_0-rmse:2.29037	validation_1-rmse:2.31161
# [40]	validation_0-rmse:2.28912	validation_1-rmse:2.31085
# [41]	validation_0-rmse:2.28715	validation_1-rmse:2.31048
# [0]	validation_0-rmse:4.59321	validation_1-rmse:4.51449
# [1]	validation_0-rmse:4.28254	validation_1-rmse:4.20845
# [2]	validation_0-rmse:4.00891	validation_1-rmse:3.93844
# [3]	validation_0-rmse:3.77017	validation_1-rmse:3.69802
# [4]	validation_0-rmse:3.55994	validation_1-rmse:3.49193
# [5]	validation_0-rmse:3.38004	validation_1-rmse:3.31249
# [6]	validation_0-rmse:3.22196	validation_1-rmse:3.15585
# [7]	validation_0-rmse:3.08622	validation_1-rmse:3.02203
# [8]	validation_0-rmse:2.97012	validation_1-rmse:2.91057
# [9]	validation_0-rmse:2.87133	validation_1-rmse:2.81379
# [10]	validation_0-rmse:2.78638	validation_1-rmse:2.73437
# [11]	validation_0-rmse:2.71225	validation_1-rmse:2.66239
# [12]	validation_0-rmse:2.65188	validation_1-rmse:2.60650
# [13]	validation_0-rmse:2.60029	validation_1-rmse:2.55902
# [14]	validation_0-rmse:2.55573	validation_1-rmse:2.51886
# [15]	validation_0-rmse:2.51765	validation_1-rmse:2.48237
# [16]	validation_0-rmse:2.48696	validation_1-rmse:2.45492
# [17]	validation_0-rmse:2.46073	validation_1-rmse:2.43028
# [18]	validation_0-rmse:2.43849	validation_1-rmse:2.41103
# [19]	validation_0-rmse:2.41956	validation_1-rmse:2.39421
# [20]	validation_0-rmse:2.40417	validation_1-rmse:2.38088
# [21]	validation_0-rmse:2.39087	validation_1-rmse:2.37079
# [22]	validation_0-rmse:2.37849	validation_1-rmse:2.36167
# [23]	validation_0-rmse:2.36862	validation_1-rmse:2.35349
# [24]	validation_0-rmse:2.36032	validation_1-rmse:2.34784
# [25]	validation_0-rmse:2.35156	validation_1-rmse:2.34102
# [26]	validation_0-rmse:2.34456	validation_1-rmse:2.33528
# [27]	validation_0-rmse:2.33785	validation_1-rmse:2.32958
# [28]	validation_0-rmse:2.33343	validation_1-rmse:2.32759
# [29]	validation_0-rmse:2.32808	validation_1-rmse:2.32337
# [30]	validation_0-rmse:2.32413	validation_1-rmse:2.32114
# [31]	validation_0-rmse:2.32102	validation_1-rmse:2.31921
# [32]	validation_0-rmse:2.31650	validation_1-rmse:2.31552
# [33]	validation_0-rmse:2.31378	validation_1-rmse:2.31409
# [34]	validation_0-rmse:2.31063	validation_1-rmse:2.31244
# [35]	validation_0-rmse:2.30877	validation_1-rmse:2.31142
# [36]	validation_0-rmse:2.30682	validation_1-rmse:2.31076
# [37]	validation_0-rmse:2.30515	validation_1-rmse:2.31035
# [38]	validation_0-rmse:2.30336	validation_1-rmse:2.31068
# [39]	validation_0-rmse:2.30173	validation_1-rmse:2.30950
# [40]	validation_0-rmse:2.29912	validation_1-rmse:2.30775
# [41]	validation_0-rmse:2.29750	validation_1-rmse:2.30715
# [42]	validation_0-rmse:2.29679	validation_1-rmse:2.30676
# [43]	validation_0-rmse:2.29323	validation_1-rmse:2.30482
# [44]	validation_0-rmse:2.29271	validation_1-rmse:2.30490
# [45]	validation_0-rmse:2.29221	validation_1-rmse:2.30476
# [46]	validation_0-rmse:2.29193	validation_1-rmse:2.30450
# [47]	validation_0-rmse:2.28980	validation_1-rmse:2.30285
# [48]	validation_0-rmse:2.28861	validation_1-rmse:2.30293
# [49]	validation_0-rmse:2.28832	validation_1-rmse:2.30304
# [50]	validation_0-rmse:2.28759	validation_1-rmse:2.30356
# [51]	validation_0-rmse:2.28701	validation_1-rmse:2.30357
# [52]	validation_0-rmse:2.28660	validation_1-rmse:2.30350
# [0]	validation_0-rmse:4.59274	validation_1-rmse:4.51179
# [1]	validation_0-rmse:4.28517	validation_1-rmse:4.20329
# [2]	validation_0-rmse:4.01173	validation_1-rmse:3.92910
# [3]	validation_0-rmse:3.77558	validation_1-rmse:3.69239
# [4]	validation_0-rmse:3.56672	validation_1-rmse:3.48781
# [5]	validation_0-rmse:3.38807	validation_1-rmse:3.31355
# [6]	validation_0-rmse:3.23372	validation_1-rmse:3.15886
# [7]	validation_0-rmse:3.10004	validation_1-rmse:3.02845
# [8]	validation_0-rmse:2.99264	validation_1-rmse:2.91938
# [9]	validation_0-rmse:2.89951	validation_1-rmse:2.82708
# [10]	validation_0-rmse:2.81469	validation_1-rmse:2.74427
# [11]	validation_0-rmse:2.73963	validation_1-rmse:2.67458
# [12]	validation_0-rmse:2.67669	validation_1-rmse:2.61503
# [13]	validation_0-rmse:2.62750	validation_1-rmse:2.56859
# [14]	validation_0-rmse:2.58186	validation_1-rmse:2.52642
# [15]	validation_0-rmse:2.54304	validation_1-rmse:2.49289
# [16]	validation_0-rmse:2.51378	validation_1-rmse:2.46538
# [17]	validation_0-rmse:2.48422	validation_1-rmse:2.44081
# [18]	validation_0-rmse:2.46248	validation_1-rmse:2.41966
# [19]	validation_0-rmse:2.44142	validation_1-rmse:2.40382
# [20]	validation_0-rmse:2.42275	validation_1-rmse:2.38872
# [21]	validation_0-rmse:2.40859	validation_1-rmse:2.37528
# [22]	validation_0-rmse:2.39450	validation_1-rmse:2.36395
# [23]	validation_0-rmse:2.38345	validation_1-rmse:2.35677
# [24]	validation_0-rmse:2.37365	validation_1-rmse:2.34889
# [25]	validation_0-rmse:2.36645	validation_1-rmse:2.34244
# [26]	validation_0-rmse:2.35976	validation_1-rmse:2.33756
# [27]	validation_0-rmse:2.35293	validation_1-rmse:2.33160
# [28]	validation_0-rmse:2.34741	validation_1-rmse:2.32749
# [29]	validation_0-rmse:2.34280	validation_1-rmse:2.32497
# [30]	validation_0-rmse:2.33813	validation_1-rmse:2.32192
# [31]	validation_0-rmse:2.33430	validation_1-rmse:2.31889
# [32]	validation_0-rmse:2.33043	validation_1-rmse:2.31624
# [33]	validation_0-rmse:2.32719	validation_1-rmse:2.31476
# [34]	validation_0-rmse:2.32465	validation_1-rmse:2.31344
# [35]	validation_0-rmse:2.32044	validation_1-rmse:2.31074
# [36]	validation_0-rmse:2.31755	validation_1-rmse:2.30979
# [37]	validation_0-rmse:2.31501	validation_1-rmse:2.30808
# [38]	validation_0-rmse:2.31350	validation_1-rmse:2.30771
# [39]	validation_0-rmse:2.31160	validation_1-rmse:2.30672
# [40]	validation_0-rmse:2.31024	validation_1-rmse:2.30690
# [41]	validation_0-rmse:2.30884	validation_1-rmse:2.30649
# [42]	validation_0-rmse:2.30779	validation_1-rmse:2.30672
# [43]	validation_0-rmse:2.30665	validation_1-rmse:2.30609
# [44]	validation_0-rmse:2.30492	validation_1-rmse:2.30639
# [45]	validation_0-rmse:2.30478	validation_1-rmse:2.30649
# [46]	validation_0-rmse:2.30285	validation_1-rmse:2.30738
# [47]	validation_0-rmse:2.30093	validation_1-rmse:2.30694
# [0]	validation_0-rmse:4.57716	validation_1-rmse:4.49607
# [1]	validation_0-rmse:4.25787	validation_1-rmse:4.17281
# [2]	validation_0-rmse:3.97775	validation_1-rmse:3.89342
# [3]	validation_0-rmse:3.73223	validation_1-rmse:3.65233
# [4]	validation_0-rmse:3.52015	validation_1-rmse:3.44135
# [5]	validation_0-rmse:3.33601	validation_1-rmse:3.26179
# [6]	validation_0-rmse:3.17708	validation_1-rmse:3.10554
# [7]	validation_0-rmse:3.03991	validation_1-rmse:2.97268
# [8]	validation_0-rmse:2.92307	validation_1-rmse:2.85996
# [9]	validation_0-rmse:2.82567	validation_1-rmse:2.76484
# [10]	validation_0-rmse:2.74296	validation_1-rmse:2.68656
# [11]	validation_0-rmse:2.67204	validation_1-rmse:2.62028
# [12]	validation_0-rmse:2.61245	validation_1-rmse:2.56490
# [13]	validation_0-rmse:2.56308	validation_1-rmse:2.52033
# [14]	validation_0-rmse:2.52175	validation_1-rmse:2.48443
# [15]	validation_0-rmse:2.48670	validation_1-rmse:2.45265
# [16]	validation_0-rmse:2.45764	validation_1-rmse:2.42572
# [17]	validation_0-rmse:2.43147	validation_1-rmse:2.40375
# [18]	validation_0-rmse:2.40861	validation_1-rmse:2.38453
# [19]	validation_0-rmse:2.38994	validation_1-rmse:2.36974
# [20]	validation_0-rmse:2.37534	validation_1-rmse:2.35988
# [21]	validation_0-rmse:2.36216	validation_1-rmse:2.34908
# [22]	validation_0-rmse:2.35292	validation_1-rmse:2.34384
# [23]	validation_0-rmse:2.34295	validation_1-rmse:2.33818
# [24]	validation_0-rmse:2.33565	validation_1-rmse:2.33367
# [25]	validation_0-rmse:2.32858	validation_1-rmse:2.32871
# [26]	validation_0-rmse:2.32244	validation_1-rmse:2.32522
# [27]	validation_0-rmse:2.31804	validation_1-rmse:2.32215
# [28]	validation_0-rmse:2.31424	validation_1-rmse:2.31963
# [29]	validation_0-rmse:2.31042	validation_1-rmse:2.31715
# [30]	validation_0-rmse:2.30749	validation_1-rmse:2.31546
# [31]	validation_0-rmse:2.30511	validation_1-rmse:2.31454
# [32]	validation_0-rmse:2.30385	validation_1-rmse:2.31495
# [33]	validation_0-rmse:2.30135	validation_1-rmse:2.31356
# [34]	validation_0-rmse:2.29886	validation_1-rmse:2.31109
# [35]	validation_0-rmse:2.29697	validation_1-rmse:2.31040
# [36]	validation_0-rmse:2.29475	validation_1-rmse:2.30992
# [37]	validation_0-rmse:2.29497	validation_1-rmse:2.31214
# [38]	validation_0-rmse:2.29515	validation_1-rmse:2.31374
# [39]	validation_0-rmse:2.29360	validation_1-rmse:2.31341
# [40]	validation_0-rmse:2.29193	validation_1-rmse:2.31301
# [0]	validation_0-rmse:4.56958	validation_1-rmse:4.50144
# [1]	validation_0-rmse:4.24002	validation_1-rmse:4.18382
# [2]	validation_0-rmse:3.94935	validation_1-rmse:3.89401
# [3]	validation_0-rmse:3.70115	validation_1-rmse:3.65585
# [4]	validation_0-rmse:3.48185	validation_1-rmse:3.44361
# [5]	validation_0-rmse:3.30295	validation_1-rmse:3.27471
# [6]	validation_0-rmse:3.14005	validation_1-rmse:3.11809
# [7]	validation_0-rmse:3.00275	validation_1-rmse:2.98244
# [8]	validation_0-rmse:2.88046	validation_1-rmse:2.86241
# [9]	validation_0-rmse:2.77717	validation_1-rmse:2.76690
# [10]	validation_0-rmse:2.69191	validation_1-rmse:2.68675
# [11]	validation_0-rmse:2.62207	validation_1-rmse:2.62316
# [12]	validation_0-rmse:2.55706	validation_1-rmse:2.56521
# [13]	validation_0-rmse:2.50408	validation_1-rmse:2.51755
# [14]	validation_0-rmse:2.46246	validation_1-rmse:2.48299
# [15]	validation_0-rmse:2.42607	validation_1-rmse:2.45256
# [16]	validation_0-rmse:2.39676	validation_1-rmse:2.42670
# [17]	validation_0-rmse:2.37345	validation_1-rmse:2.40782
# [18]	validation_0-rmse:2.35083	validation_1-rmse:2.39109
# [19]	validation_0-rmse:2.32845	validation_1-rmse:2.37437
# [20]	validation_0-rmse:2.30973	validation_1-rmse:2.35925
# [21]	validation_0-rmse:2.29275	validation_1-rmse:2.34592
# [22]	validation_0-rmse:2.27956	validation_1-rmse:2.33516
# [23]	validation_0-rmse:2.26754	validation_1-rmse:2.32618
# [24]	validation_0-rmse:2.25667	validation_1-rmse:2.31977
# [25]	validation_0-rmse:2.24629	validation_1-rmse:2.31234
# [26]	validation_0-rmse:2.23937	validation_1-rmse:2.30882
# [27]	validation_0-rmse:2.23028	validation_1-rmse:2.30442
# [28]	validation_0-rmse:2.22287	validation_1-rmse:2.30044
# [29]	validation_0-rmse:2.23285	validation_1-rmse:2.31117
# [30]	validation_0-rmse:2.22794	validation_1-rmse:2.30944
# [31]	validation_0-rmse:2.22216	validation_1-rmse:2.30717
# [32]	validation_0-rmse:2.21794	validation_1-rmse:2.30709
# [33]	validation_0-rmse:2.21210	validation_1-rmse:2.30456
# [0]	validation_0-rmse:4.58153	validation_1-rmse:4.49556
# [1]	validation_0-rmse:4.26415	validation_1-rmse:4.17593
# [2]	validation_0-rmse:3.97714	validation_1-rmse:3.88797
# [3]	validation_0-rmse:3.72619	validation_1-rmse:3.64395
# [4]	validation_0-rmse:3.50993	validation_1-rmse:3.43652
# [5]	validation_0-rmse:3.31872	validation_1-rmse:3.25366
# [6]	validation_0-rmse:3.15809	validation_1-rmse:3.09797
# [7]	validation_0-rmse:3.01999	validation_1-rmse:2.96673
# [8]	validation_0-rmse:2.90055	validation_1-rmse:2.85553
# [9]	validation_0-rmse:2.79982	validation_1-rmse:2.76296
# [10]	validation_0-rmse:2.71208	validation_1-rmse:2.68249
# [11]	validation_0-rmse:2.63944	validation_1-rmse:2.61609
# [12]	validation_0-rmse:2.57749	validation_1-rmse:2.56128
# [13]	validation_0-rmse:2.52494	validation_1-rmse:2.51742
# [14]	validation_0-rmse:2.48030	validation_1-rmse:2.48037
# [15]	validation_0-rmse:2.44209	validation_1-rmse:2.45015
# [16]	validation_0-rmse:2.40760	validation_1-rmse:2.42187
# [17]	validation_0-rmse:2.38090	validation_1-rmse:2.40218
# [18]	validation_0-rmse:2.35620	validation_1-rmse:2.38518
# [19]	validation_0-rmse:2.33492	validation_1-rmse:2.36940
# [20]	validation_0-rmse:2.31697	validation_1-rmse:2.35570
# [21]	validation_0-rmse:2.30014	validation_1-rmse:2.34239
# [22]	validation_0-rmse:2.28547	validation_1-rmse:2.33242
# [23]	validation_0-rmse:2.27254	validation_1-rmse:2.32576
# [24]	validation_0-rmse:2.26118	validation_1-rmse:2.31988
# [25]	validation_0-rmse:2.25029	validation_1-rmse:2.31420
# [26]	validation_0-rmse:2.24031	validation_1-rmse:2.30722
# [27]	validation_0-rmse:2.23197	validation_1-rmse:2.30430
# [28]	validation_0-rmse:2.22764	validation_1-rmse:2.30143
# [29]	validation_0-rmse:2.22388	validation_1-rmse:2.29896
# [30]	validation_0-rmse:2.22031	validation_1-rmse:2.29592
# [31]	validation_0-rmse:2.21440	validation_1-rmse:2.29385
# [32]	validation_0-rmse:2.20899	validation_1-rmse:2.29153
# [33]	validation_0-rmse:2.20098	validation_1-rmse:2.28598
# [34]	validation_0-rmse:2.19750	validation_1-rmse:2.28485
# [35]	validation_0-rmse:2.19229	validation_1-rmse:2.28340
# [36]	validation_0-rmse:2.18999	validation_1-rmse:2.28291
# [37]	validation_0-rmse:2.18646	validation_1-rmse:2.28203
# [38]	validation_0-rmse:2.18172	validation_1-rmse:2.28052
# [39]	validation_0-rmse:2.18172	validation_1-rmse:2.28291
# [40]	validation_0-rmse:2.17901	validation_1-rmse:2.28291
# [41]	validation_0-rmse:2.17623	validation_1-rmse:2.28172
# [42]	validation_0-rmse:2.17351	validation_1-rmse:2.27965
# [43]	validation_0-rmse:2.17124	validation_1-rmse:2.28134
# [44]	validation_0-rmse:2.16907	validation_1-rmse:2.28094
# [45]	validation_0-rmse:2.16601	validation_1-rmse:2.28208
# [46]	validation_0-rmse:2.16555	validation_1-rmse:2.28270
# [47]	validation_0-rmse:2.16436	validation_1-rmse:2.28297
# [0]	validation_0-rmse:4.55255	validation_1-rmse:4.47682
# [1]	validation_0-rmse:4.21323	validation_1-rmse:4.14211
# [2]	validation_0-rmse:3.91149	validation_1-rmse:3.84069
# [3]	validation_0-rmse:3.65092	validation_1-rmse:3.58889
# [4]	validation_0-rmse:3.42607	validation_1-rmse:3.36705
# [5]	validation_0-rmse:3.23431	validation_1-rmse:3.18603
# [6]	validation_0-rmse:3.06791	validation_1-rmse:3.02964
# [7]	validation_0-rmse:2.92381	validation_1-rmse:2.89644
# [8]	validation_0-rmse:2.80433	validation_1-rmse:2.78948
# [9]	validation_0-rmse:2.70208	validation_1-rmse:2.69773
# [10]	validation_0-rmse:2.61623	validation_1-rmse:2.62278
# [11]	validation_0-rmse:2.54135	validation_1-rmse:2.55777
# [12]	validation_0-rmse:2.48004	validation_1-rmse:2.50764
# [13]	validation_0-rmse:2.43102	validation_1-rmse:2.46617
# [14]	validation_0-rmse:2.38849	validation_1-rmse:2.43281
# [15]	validation_0-rmse:2.35246	validation_1-rmse:2.40392
# [16]	validation_0-rmse:2.32259	validation_1-rmse:2.38343
# [17]	validation_0-rmse:2.29821	validation_1-rmse:2.36671
# [18]	validation_0-rmse:2.27858	validation_1-rmse:2.35512
# [19]	validation_0-rmse:2.26257	validation_1-rmse:2.34682
# [20]	validation_0-rmse:2.24937	validation_1-rmse:2.33992
# [21]	validation_0-rmse:2.23790	validation_1-rmse:2.33380
# [22]	validation_0-rmse:2.22810	validation_1-rmse:2.32993
# [23]	validation_0-rmse:2.21961	validation_1-rmse:2.32264
# [24]	validation_0-rmse:2.21371	validation_1-rmse:2.32121
# [25]	validation_0-rmse:2.21354	validation_1-rmse:2.32136
# [26]	validation_0-rmse:2.20683	validation_1-rmse:2.32030
# [27]	validation_0-rmse:2.20405	validation_1-rmse:2.31844
# [28]	validation_0-rmse:2.19999	validation_1-rmse:2.31706
# [29]	validation_0-rmse:2.19944	validation_1-rmse:2.31449
# [30]	validation_0-rmse:2.19623	validation_1-rmse:2.31381
# [31]	validation_0-rmse:2.19326	validation_1-rmse:2.31251
# [32]	validation_0-rmse:2.18905	validation_1-rmse:2.31405
# [33]	validation_0-rmse:2.18396	validation_1-rmse:2.31183
# [34]	validation_0-rmse:2.18045	validation_1-rmse:2.31163
# [35]	validation_0-rmse:2.17705	validation_1-rmse:2.31198
# [36]	validation_0-rmse:2.17462	validation_1-rmse:2.31271
# [37]	validation_0-rmse:2.17718	validation_1-rmse:2.31519
# [38]	validation_0-rmse:2.17911	validation_1-rmse:2.31921
# [0]	validation_0-rmse:4.57831	validation_1-rmse:4.50845
# [1]	validation_0-rmse:4.25511	validation_1-rmse:4.19212
# [2]	validation_0-rmse:3.97962	validation_1-rmse:3.92168
# [3]	validation_0-rmse:3.73026	validation_1-rmse:3.67860
# [4]	validation_0-rmse:3.53280	validation_1-rmse:3.48710
# [5]	validation_0-rmse:3.34270	validation_1-rmse:3.30517
# [6]	validation_0-rmse:3.17370	validation_1-rmse:3.14215
# [7]	validation_0-rmse:3.03633	validation_1-rmse:3.01026
# [8]	validation_0-rmse:2.92273	validation_1-rmse:2.89984
# [9]	validation_0-rmse:2.82210	validation_1-rmse:2.80416
# [10]	validation_0-rmse:2.73614	validation_1-rmse:2.72111
# [11]	validation_0-rmse:2.66064	validation_1-rmse:2.64579
# [12]	validation_0-rmse:2.59834	validation_1-rmse:2.58850
# [13]	validation_0-rmse:2.54459	validation_1-rmse:2.53540
# [14]	validation_0-rmse:2.50245	validation_1-rmse:2.49753
# [15]	validation_0-rmse:2.46148	validation_1-rmse:2.46304
# [16]	validation_0-rmse:2.42973	validation_1-rmse:2.43444
# [17]	validation_0-rmse:2.40032	validation_1-rmse:2.40982
# [18]	validation_0-rmse:2.37883	validation_1-rmse:2.39013
# [19]	validation_0-rmse:2.35974	validation_1-rmse:2.37559
# [20]	validation_0-rmse:2.34429	validation_1-rmse:2.36376
# [21]	validation_0-rmse:2.32821	validation_1-rmse:2.35277
# [22]	validation_0-rmse:2.31317	validation_1-rmse:2.34315
# [23]	validation_0-rmse:2.29830	validation_1-rmse:2.33375
# [24]	validation_0-rmse:2.28910	validation_1-rmse:2.32925
# [25]	validation_0-rmse:2.27961	validation_1-rmse:2.32370
# [26]	validation_0-rmse:2.27048	validation_1-rmse:2.31841
# [27]	validation_0-rmse:2.26037	validation_1-rmse:2.31214
# [28]	validation_0-rmse:2.25229	validation_1-rmse:2.30615
# [29]	validation_0-rmse:2.24599	validation_1-rmse:2.30182
# [30]	validation_0-rmse:2.24034	validation_1-rmse:2.29811
# [31]	validation_0-rmse:2.23392	validation_1-rmse:2.29566
# [32]	validation_0-rmse:2.22841	validation_1-rmse:2.29230
# [33]	validation_0-rmse:2.23061	validation_1-rmse:2.29501
# [34]	validation_0-rmse:2.22639	validation_1-rmse:2.29364
# [35]	validation_0-rmse:2.22063	validation_1-rmse:2.29212
# [36]	validation_0-rmse:2.22526	validation_1-rmse:2.29780
# [37]	validation_0-rmse:2.22261	validation_1-rmse:2.29818
# [38]	validation_0-rmse:2.22778	validation_1-rmse:2.30480
# [39]	validation_0-rmse:2.22346	validation_1-rmse:2.30444
# [0]	validation_0-rmse:4.58433	validation_1-rmse:4.49753
# [1]	validation_0-rmse:4.27212	validation_1-rmse:4.17967
# [2]	validation_0-rmse:3.99066	validation_1-rmse:3.89721
# [3]	validation_0-rmse:3.74160	validation_1-rmse:3.65448
# [4]	validation_0-rmse:3.52612	validation_1-rmse:3.44745
# [5]	validation_0-rmse:3.33867	validation_1-rmse:3.26769
# [6]	validation_0-rmse:3.17505	validation_1-rmse:3.11317
# [7]	validation_0-rmse:3.03624	validation_1-rmse:2.98214
# [8]	validation_0-rmse:2.91833	validation_1-rmse:2.87096
# [9]	validation_0-rmse:2.81678	validation_1-rmse:2.77486
# [10]	validation_0-rmse:2.73216	validation_1-rmse:2.69434
# [11]	validation_0-rmse:2.65648	validation_1-rmse:2.62386
# [12]	validation_0-rmse:2.59503	validation_1-rmse:2.57104
# [13]	validation_0-rmse:2.54261	validation_1-rmse:2.52704
# [14]	validation_0-rmse:2.49628	validation_1-rmse:2.48939
# [15]	validation_0-rmse:2.45655	validation_1-rmse:2.45498
# [16]	validation_0-rmse:2.42346	validation_1-rmse:2.42849
# [17]	validation_0-rmse:2.39314	validation_1-rmse:2.40429
# [18]	validation_0-rmse:2.36787	validation_1-rmse:2.38662
# [19]	validation_0-rmse:2.34849	validation_1-rmse:2.37330
# [20]	validation_0-rmse:2.33110	validation_1-rmse:2.35968
# [21]	validation_0-rmse:2.31456	validation_1-rmse:2.34872
# [22]	validation_0-rmse:2.30004	validation_1-rmse:2.33793
# [23]	validation_0-rmse:2.28660	validation_1-rmse:2.33072
# [24]	validation_0-rmse:2.27532	validation_1-rmse:2.32023
# [25]	validation_0-rmse:2.26303	validation_1-rmse:2.31142
# [26]	validation_0-rmse:2.25285	validation_1-rmse:2.30537
# [27]	validation_0-rmse:2.24513	validation_1-rmse:2.30365
# [28]	validation_0-rmse:2.23620	validation_1-rmse:2.29692
# [29]	validation_0-rmse:2.23238	validation_1-rmse:2.29522
# [30]	validation_0-rmse:2.22945	validation_1-rmse:2.29390
# [31]	validation_0-rmse:2.22600	validation_1-rmse:2.29239
# [32]	validation_0-rmse:2.22153	validation_1-rmse:2.29112
# [33]	validation_0-rmse:2.21823	validation_1-rmse:2.29035
# [34]	validation_0-rmse:2.21603	validation_1-rmse:2.29041
# [35]	validation_0-rmse:2.21088	validation_1-rmse:2.28898
# [36]	validation_0-rmse:2.20677	validation_1-rmse:2.28711
# [37]	validation_0-rmse:2.20159	validation_1-rmse:2.28599
# [38]	validation_0-rmse:2.20167	validation_1-rmse:2.28727
# [39]	validation_0-rmse:2.19822	validation_1-rmse:2.28715
# [40]	validation_0-rmse:2.19348	validation_1-rmse:2.28570
# [41]	validation_0-rmse:2.19029	validation_1-rmse:2.28517
# [42]	validation_0-rmse:2.18591	validation_1-rmse:2.28419
# [43]	validation_0-rmse:2.18554	validation_1-rmse:2.28561
# [44]	validation_0-rmse:2.18243	validation_1-rmse:2.28642
# [45]	validation_0-rmse:2.17985	validation_1-rmse:2.28731
# [46]	validation_0-rmse:2.17885	validation_1-rmse:2.28714
# [0]	validation_0-rmse:4.56102	validation_1-rmse:4.48031
# [1]	validation_0-rmse:4.22441	validation_1-rmse:4.14866
# [2]	validation_0-rmse:3.92585	validation_1-rmse:3.85091
# [3]	validation_0-rmse:3.66841	validation_1-rmse:3.59970
# [4]	validation_0-rmse:3.44491	validation_1-rmse:3.38332
# [5]	validation_0-rmse:3.25013	validation_1-rmse:3.19769
# [6]	validation_0-rmse:3.08377	validation_1-rmse:3.03371
# [7]	validation_0-rmse:2.94250	validation_1-rmse:2.90225
# [8]	validation_0-rmse:2.82082	validation_1-rmse:2.78883
# [9]	validation_0-rmse:2.71551	validation_1-rmse:2.69315
# [10]	validation_0-rmse:2.62673	validation_1-rmse:2.61753
# [11]	validation_0-rmse:2.55238	validation_1-rmse:2.55340
# [12]	validation_0-rmse:2.49085	validation_1-rmse:2.50357
# [13]	validation_0-rmse:2.43954	validation_1-rmse:2.46069
# [14]	validation_0-rmse:2.39617	validation_1-rmse:2.42551
# [15]	validation_0-rmse:2.36038	validation_1-rmse:2.39761
# [16]	validation_0-rmse:2.33022	validation_1-rmse:2.37549
# [17]	validation_0-rmse:2.30616	validation_1-rmse:2.35972
# [18]	validation_0-rmse:2.28375	validation_1-rmse:2.34534
# [19]	validation_0-rmse:2.26739	validation_1-rmse:2.33620
# [20]	validation_0-rmse:2.25237	validation_1-rmse:2.32673
# [21]	validation_0-rmse:2.24104	validation_1-rmse:2.31881
# [22]	validation_0-rmse:2.22832	validation_1-rmse:2.31310
# [23]	validation_0-rmse:2.21950	validation_1-rmse:2.30948
# ...
# [14]	validation_0-rmse:2.37694	validation_1-rmse:2.64079
# [15]	validation_0-rmse:2.33080	validation_1-rmse:2.60565
# [16]	validation_0-rmse:2.29229	validation_1-rmse:2.57640
# [17]	validation_0-rmse:2.25742	validation_1-rmse:2.55014
# [18]	validation_0-rmse:2.22593	validation_1-rmse:2.53002
# [19]	validation_0-rmse:2.19653	validation_1-rmse:2.51111
# [20]	validation_0-rmse:2.17382	validation_1-rmse:2.49905
# [21]	validation_0-rmse:2.15650	validation_1-rmse:2.49362
# [22]	validation_0-rmse:2.13756	validation_1-rmse:2.48180
# [23]	validation_0-rmse:2.12230	validation_1-rmse:2.47104
# [24]	validation_0-rmse:2.10825	validation_1-rmse:2.46667
# [25]	validation_0-rmse:2.09394	validation_1-rmse:2.45945
# [26]	validation_0-rmse:2.08567	validation_1-rmse:2.45864
# [27]	validation_0-rmse:2.07428	validation_1-rmse:2.45274
# [28]	validation_0-rmse:2.07459	validation_1-rmse:2.46458
# [29]	validation_0-rmse:2.07019	validation_1-rmse:2.46591
# [30]	validation_0-rmse:2.06544	validation_1-rmse:2.46709
# [31]	validation_0-rmse:2.05683	validation_1-rmse:2.46473
# [0]	validation_0-rmse:4.56802	validation_1-rmse:4.49954
# [1]	validation_0-rmse:4.23388	validation_1-rmse:4.17925
# [2]	validation_0-rmse:3.93229	validation_1-rmse:3.88553
# [3]	validation_0-rmse:3.67538	validation_1-rmse:3.64709
# [4]	validation_0-rmse:3.44585	validation_1-rmse:3.43523
# [5]	validation_0-rmse:3.24288	validation_1-rmse:3.25528
# [6]	validation_0-rmse:3.07068	validation_1-rmse:3.09787
# [7]	validation_0-rmse:2.92365	validation_1-rmse:2.96714
# [8]	validation_0-rmse:2.79272	validation_1-rmse:2.85665
# [9]	validation_0-rmse:2.67910	validation_1-rmse:2.77298
# [10]	validation_0-rmse:2.58200	validation_1-rmse:2.69922
# [11]	validation_0-rmse:2.49673	validation_1-rmse:2.63273
# [12]	validation_0-rmse:2.42605	validation_1-rmse:2.58206
# [13]	validation_0-rmse:2.36344	validation_1-rmse:2.53566
# [14]	validation_0-rmse:2.30979	validation_1-rmse:2.50062
# [15]	validation_0-rmse:2.26384	validation_1-rmse:2.46516
# [16]	validation_0-rmse:2.21980	validation_1-rmse:2.43927
# [17]	validation_0-rmse:2.18783	validation_1-rmse:2.42399
# [18]	validation_0-rmse:2.15613	validation_1-rmse:2.40773
# [19]	validation_0-rmse:2.12865	validation_1-rmse:2.39066
# [20]	validation_0-rmse:2.10193	validation_1-rmse:2.37736
# [21]	validation_0-rmse:2.08135	validation_1-rmse:2.36975
# [22]	validation_0-rmse:2.06089	validation_1-rmse:2.35885
# [23]	validation_0-rmse:2.04335	validation_1-rmse:2.35373
# [24]	validation_0-rmse:2.02699	validation_1-rmse:2.34543
# [25]	validation_0-rmse:2.01368	validation_1-rmse:2.33854
# [26]	validation_0-rmse:2.00189	validation_1-rmse:2.33291
# [27]	validation_0-rmse:1.99023	validation_1-rmse:2.32908
# [28]	validation_0-rmse:1.98221	validation_1-rmse:2.32792
# [29]	validation_0-rmse:1.97293	validation_1-rmse:2.32597
# [30]	validation_0-rmse:1.96323	validation_1-rmse:2.32346
# [31]	validation_0-rmse:1.95499	validation_1-rmse:2.32011
# [32]	validation_0-rmse:1.94533	validation_1-rmse:2.31918
# [33]	validation_0-rmse:1.93870	validation_1-rmse:2.31871
# [34]	validation_0-rmse:1.93129	validation_1-rmse:2.31592
# [35]	validation_0-rmse:1.92400	validation_1-rmse:2.31526
# [36]	validation_0-rmse:1.91894	validation_1-rmse:2.31266
# [37]	validation_0-rmse:1.91241	validation_1-rmse:2.31107
# [38]	validation_0-rmse:1.90615	validation_1-rmse:2.30892
# [39]	validation_0-rmse:1.90177	validation_1-rmse:2.30900
# [40]	validation_0-rmse:1.89640	validation_1-rmse:2.30798
# [41]	validation_0-rmse:1.89153	validation_1-rmse:2.30560
# [42]	validation_0-rmse:1.88681	validation_1-rmse:2.30501
# [43]	validation_0-rmse:1.88305	validation_1-rmse:2.30371
# [44]	validation_0-rmse:1.87906	validation_1-rmse:2.30385
# [45]	validation_0-rmse:1.87614	validation_1-rmse:2.30468
# [46]	validation_0-rmse:1.87299	validation_1-rmse:2.30428
# [47]	validation_0-rmse:1.86964	validation_1-rmse:2.30420
# [48]	validation_0-rmse:1.86574	validation_1-rmse:2.30671
# [0]	validation_0-rmse:4.53968	validation_1-rmse:4.46701
# [1]	validation_0-rmse:4.18526	validation_1-rmse:4.12998
# [2]	validation_0-rmse:3.87557	validation_1-rmse:3.83236
# [3]	validation_0-rmse:3.61144	validation_1-rmse:3.58918
# [4]	validation_0-rmse:3.37683	validation_1-rmse:3.37725
# [5]	validation_0-rmse:3.17522	validation_1-rmse:3.19799
# [6]	validation_0-rmse:2.99936	validation_1-rmse:3.04724
# [7]	validation_0-rmse:2.84583	validation_1-rmse:2.91621
# [8]	validation_0-rmse:2.71270	validation_1-rmse:2.81364
# [9]	validation_0-rmse:2.59761	validation_1-rmse:2.72213
# [10]	validation_0-rmse:2.49984	validation_1-rmse:2.64593
# [11]	validation_0-rmse:2.41634	validation_1-rmse:2.58487
# [12]	validation_0-rmse:2.34308	validation_1-rmse:2.53120
# [13]	validation_0-rmse:2.28688	validation_1-rmse:2.49608
# [14]	validation_0-rmse:2.23848	validation_1-rmse:2.46806
# [15]	validation_0-rmse:2.19738	validation_1-rmse:2.44631
# [16]	validation_0-rmse:2.15980	validation_1-rmse:2.42789
# [17]	validation_0-rmse:2.12856	validation_1-rmse:2.41278
# [18]	validation_0-rmse:2.10130	validation_1-rmse:2.40477
# [19]	validation_0-rmse:2.07897	validation_1-rmse:2.39727
# [20]	validation_0-rmse:2.06325	validation_1-rmse:2.39441
# [21]	validation_0-rmse:2.04473	validation_1-rmse:2.39034
# [22]	validation_0-rmse:2.03124	validation_1-rmse:2.38772
# [23]	validation_0-rmse:2.02235	validation_1-rmse:2.38894
# [24]	validation_0-rmse:2.01962	validation_1-rmse:2.39172
# [25]	validation_0-rmse:2.00959	validation_1-rmse:2.39102
# [26]	validation_0-rmse:2.00119	validation_1-rmse:2.39036
# [0]	validation_0-rmse:4.58995	validation_1-rmse:4.53182
# [1]	validation_0-rmse:4.26834	validation_1-rmse:4.22812
# [2]	validation_0-rmse:4.00295	validation_1-rmse:3.97077
# [3]	validation_0-rmse:3.74915	validation_1-rmse:3.73846
# [4]	validation_0-rmse:3.54122	validation_1-rmse:3.54677
# [5]	validation_0-rmse:3.34972	validation_1-rmse:3.37415
# [6]	validation_0-rmse:3.17704	validation_1-rmse:3.21787
# [7]	validation_0-rmse:3.04119	validation_1-rmse:3.10104
# [8]	validation_0-rmse:2.92338	validation_1-rmse:3.00205
# [9]	validation_0-rmse:2.80814	validation_1-rmse:2.90312
# [10]	validation_0-rmse:2.71690	validation_1-rmse:2.83398
# [11]	validation_0-rmse:2.63383	validation_1-rmse:2.76399
# [12]	validation_0-rmse:2.56209	validation_1-rmse:2.70654
# [13]	validation_0-rmse:2.50180	validation_1-rmse:2.66355
# [14]	validation_0-rmse:2.44646	validation_1-rmse:2.61775
# [15]	validation_0-rmse:2.39756	validation_1-rmse:2.57862
# [16]	validation_0-rmse:2.35727	validation_1-rmse:2.55009
# [17]	validation_0-rmse:2.31712	validation_1-rmse:2.52020
# [18]	validation_0-rmse:2.28735	validation_1-rmse:2.50033
# [19]	validation_0-rmse:2.25964	validation_1-rmse:2.48064
# [20]	validation_0-rmse:2.23241	validation_1-rmse:2.46497
# [21]	validation_0-rmse:2.21189	validation_1-rmse:2.45473
# [22]	validation_0-rmse:2.18936	validation_1-rmse:2.44295
# [23]	validation_0-rmse:2.17143	validation_1-rmse:2.43091
# [24]	validation_0-rmse:2.15707	validation_1-rmse:2.42553
# [25]	validation_0-rmse:2.14156	validation_1-rmse:2.41822
# [26]	validation_0-rmse:2.12833	validation_1-rmse:2.41413
# [27]	validation_0-rmse:2.11965	validation_1-rmse:2.41166
# [28]	validation_0-rmse:2.11005	validation_1-rmse:2.40804
# [29]	validation_0-rmse:2.09877	validation_1-rmse:2.40254
# [30]	validation_0-rmse:2.09143	validation_1-rmse:2.40007
# [31]	validation_0-rmse:2.08231	validation_1-rmse:2.39659
# [32]	validation_0-rmse:2.07178	validation_1-rmse:2.39220
# [33]	validation_0-rmse:2.06460	validation_1-rmse:2.39046
# [34]	validation_0-rmse:2.05787	validation_1-rmse:2.39095
# [35]	validation_0-rmse:2.05223	validation_1-rmse:2.39032
# [36]	validation_0-rmse:2.04572	validation_1-rmse:2.38818
# [37]	validation_0-rmse:2.04103	validation_1-rmse:2.38701
# [38]	validation_0-rmse:2.04213	validation_1-rmse:2.39167
# [39]	validation_0-rmse:2.03648	validation_1-rmse:2.39105
# [40]	validation_0-rmse:2.03512	validation_1-rmse:2.39276
# [41]	validation_0-rmse:2.02934	validation_1-rmse:2.39297
# [42]	validation_0-rmse:2.02813	validation_1-rmse:2.39350
# [0]	validation_0-rmse:4.57836	validation_1-rmse:4.50252
# [1]	validation_0-rmse:4.25677	validation_1-rmse:4.18538
# [2]	validation_0-rmse:3.96891	validation_1-rmse:3.90831
# [3]	validation_0-rmse:3.71706	validation_1-rmse:3.67098
# [4]	validation_0-rmse:3.50176	validation_1-rmse:3.46301
# [5]	validation_0-rmse:3.30412	validation_1-rmse:3.28936
# [6]	validation_0-rmse:3.13229	validation_1-rmse:3.13762
# [7]	validation_0-rmse:2.98006	validation_1-rmse:3.00421
# [8]	validation_0-rmse:2.85276	validation_1-rmse:2.89294
# [9]	validation_0-rmse:2.74514	validation_1-rmse:2.80100
# [10]	validation_0-rmse:2.64755	validation_1-rmse:2.71684
# [11]	validation_0-rmse:2.56321	validation_1-rmse:2.65330
# [12]	validation_0-rmse:2.48840	validation_1-rmse:2.59431
# [13]	validation_0-rmse:2.42485	validation_1-rmse:2.54605
# [14]	validation_0-rmse:2.37252	validation_1-rmse:2.50789
# [15]	validation_0-rmse:2.32377	validation_1-rmse:2.47497
# [16]	validation_0-rmse:2.28421	validation_1-rmse:2.44863
# [17]	validation_0-rmse:2.25136	validation_1-rmse:2.42869
# [18]	validation_0-rmse:2.22016	validation_1-rmse:2.41244
# [19]	validation_0-rmse:2.18988	validation_1-rmse:2.39520
# [20]	validation_0-rmse:2.16441	validation_1-rmse:2.38269
# [21]	validation_0-rmse:2.14268	validation_1-rmse:2.37008
# [22]	validation_0-rmse:2.12504	validation_1-rmse:2.36182
# [23]	validation_0-rmse:2.10608	validation_1-rmse:2.35456
# [24]	validation_0-rmse:2.08940	validation_1-rmse:2.35085
# [25]	validation_0-rmse:2.07461	validation_1-rmse:2.34911
# [26]	validation_0-rmse:2.05985	validation_1-rmse:2.34618
# [27]	validation_0-rmse:2.04723	validation_1-rmse:2.34261
# [28]	validation_0-rmse:2.03586	validation_1-rmse:2.33846
# [29]	validation_0-rmse:2.02474	validation_1-rmse:2.33527
# [30]	validation_0-rmse:2.01683	validation_1-rmse:2.33310
# [31]	validation_0-rmse:2.00695	validation_1-rmse:2.32973
# [32]	validation_0-rmse:1.99920	validation_1-rmse:2.32871
# [33]	validation_0-rmse:1.99283	validation_1-rmse:2.32706
# [34]	validation_0-rmse:1.98395	validation_1-rmse:2.32639
# [35]	validation_0-rmse:1.97653	validation_1-rmse:2.32575
# [36]	validation_0-rmse:1.97061	validation_1-rmse:2.32386
# [37]	validation_0-rmse:1.96420	validation_1-rmse:2.32364
# [38]	validation_0-rmse:1.95857	validation_1-rmse:2.32330
# [39]	validation_0-rmse:1.95593	validation_1-rmse:2.32324
# [40]	validation_0-rmse:1.95113	validation_1-rmse:2.32304
# [41]	validation_0-rmse:1.94797	validation_1-rmse:2.32326
# [42]	validation_0-rmse:1.94486	validation_1-rmse:2.32367
# [43]	validation_0-rmse:1.94133	validation_1-rmse:2.32327
# [44]	validation_0-rmse:1.93591	validation_1-rmse:2.32064
# [45]	validation_0-rmse:1.93299	validation_1-rmse:2.32003
# [46]	validation_0-rmse:1.92912	validation_1-rmse:2.31918
# [47]	validation_0-rmse:1.92498	validation_1-rmse:2.31993
# [48]	validation_0-rmse:1.92502	validation_1-rmse:2.32268
# [49]	validation_0-rmse:1.92223	validation_1-rmse:2.31972
# [50]	validation_0-rmse:1.91994	validation_1-rmse:2.32025
# [51]	validation_0-rmse:1.91663	validation_1-rmse:2.31955
# [0]	validation_0-rmse:4.55876	validation_1-rmse:4.48414
# [1]	validation_0-rmse:4.22248	validation_1-rmse:4.16903
# [2]	validation_0-rmse:3.92071	validation_1-rmse:3.88088
# [3]	validation_0-rmse:3.66157	validation_1-rmse:3.63939
# [4]	validation_0-rmse:3.42298	validation_1-rmse:3.41849
# [5]	validation_0-rmse:3.22196	validation_1-rmse:3.23889
# [6]	validation_0-rmse:3.04693	validation_1-rmse:3.08776
# [7]	validation_0-rmse:2.89541	validation_1-rmse:2.95570
# [8]	validation_0-rmse:2.76497	validation_1-rmse:2.84016
# [9]	validation_0-rmse:2.64655	validation_1-rmse:2.74173
# [10]	validation_0-rmse:2.54493	validation_1-rmse:2.65912
# [11]	validation_0-rmse:2.45958	validation_1-rmse:2.59264
# [12]	validation_0-rmse:2.38253	validation_1-rmse:2.53584
# [13]	validation_0-rmse:2.31772	validation_1-rmse:2.49557
# [14]	validation_0-rmse:2.26235	validation_1-rmse:2.46032
# [15]	validation_0-rmse:2.22158	validation_1-rmse:2.43822
# [16]	validation_0-rmse:2.18722	validation_1-rmse:2.42012
# [17]	validation_0-rmse:2.15517	validation_1-rmse:2.40060
# [18]	validation_0-rmse:2.12574	validation_1-rmse:2.38390
# [19]	validation_0-rmse:2.10197	validation_1-rmse:2.37115
# [20]	validation_0-rmse:2.08399	validation_1-rmse:2.36387
# [21]	validation_0-rmse:2.06511	validation_1-rmse:2.35767
# [22]	validation_0-rmse:2.05313	validation_1-rmse:2.35202
# [23]	validation_0-rmse:2.03891	validation_1-rmse:2.34765
# [24]	validation_0-rmse:2.03066	validation_1-rmse:2.34928
# [25]	validation_0-rmse:2.02079	validation_1-rmse:2.34797
# [26]	validation_0-rmse:2.01380	validation_1-rmse:2.34768
# [27]	validation_0-rmse:2.00660	validation_1-rmse:2.34573
# [28]	validation_0-rmse:1.99999	validation_1-rmse:2.34291
# [29]	validation_0-rmse:1.99531	validation_1-rmse:2.34135
# [30]	validation_0-rmse:1.99087	validation_1-rmse:2.34086
# [31]	validation_0-rmse:1.98893	validation_1-rmse:2.34251
# [32]	validation_0-rmse:1.98752	validation_1-rmse:2.34318
# [33]	validation_0-rmse:1.98906	validation_1-rmse:2.34476
# [34]	validation_0-rmse:1.98536	validation_1-rmse:2.34885
# [0]	validation_0-rmse:4.58481	validation_1-rmse:4.50381
# [1]	validation_0-rmse:4.27164	validation_1-rmse:4.19338
# [2]	validation_0-rmse:3.99764	validation_1-rmse:3.92359
# [3]	validation_0-rmse:3.75538	validation_1-rmse:3.68505
# [4]	validation_0-rmse:3.54661	validation_1-rmse:3.47677
# [5]	validation_0-rmse:3.36331	validation_1-rmse:3.29433
# [6]	validation_0-rmse:3.20648	validation_1-rmse:3.13905
# [7]	validation_0-rmse:3.07041	validation_1-rmse:3.00669
# [8]	validation_0-rmse:2.95423	validation_1-rmse:2.89469
# [9]	validation_0-rmse:2.85581	validation_1-rmse:2.79780
# [10]	validation_0-rmse:2.77089	validation_1-rmse:2.71681
# [11]	validation_0-rmse:2.69960	validation_1-rmse:2.64964
# [12]	validation_0-rmse:2.63913	validation_1-rmse:2.59355
# [13]	validation_0-rmse:2.58714	validation_1-rmse:2.54372
# [14]	validation_0-rmse:2.54409	validation_1-rmse:2.50391
# [15]	validation_0-rmse:2.50822	validation_1-rmse:2.47240
# [16]	validation_0-rmse:2.47767	validation_1-rmse:2.44468
# [17]	validation_0-rmse:2.45227	validation_1-rmse:2.42343
# [18]	validation_0-rmse:2.42795	validation_1-rmse:2.40166
# [19]	validation_0-rmse:2.40888	validation_1-rmse:2.38622
# [20]	validation_0-rmse:2.39304	validation_1-rmse:2.37254
# [21]	validation_0-rmse:2.37881	validation_1-rmse:2.36102
# [22]	validation_0-rmse:2.36510	validation_1-rmse:2.34908
# [23]	validation_0-rmse:2.35465	validation_1-rmse:2.34136
# [24]	validation_0-rmse:2.34619	validation_1-rmse:2.33582
# [25]	validation_0-rmse:2.33826	validation_1-rmse:2.32940
# [26]	validation_0-rmse:2.33175	validation_1-rmse:2.32461
# [27]	validation_0-rmse:2.32580	validation_1-rmse:2.32057
# [28]	validation_0-rmse:2.31944	validation_1-rmse:2.31593
# [29]	validation_0-rmse:2.31491	validation_1-rmse:2.31302
# [30]	validation_0-rmse:2.31093	validation_1-rmse:2.31037
# [31]	validation_0-rmse:2.30631	validation_1-rmse:2.30651
# [32]	validation_0-rmse:2.30297	validation_1-rmse:2.30423
# [33]	validation_0-rmse:2.30047	validation_1-rmse:2.30318
# [34]	validation_0-rmse:2.29728	validation_1-rmse:2.30096
# [35]	validation_0-rmse:2.29391	validation_1-rmse:2.29861
# [36]	validation_0-rmse:2.29109	validation_1-rmse:2.29811
# [37]	validation_0-rmse:2.28895	validation_1-rmse:2.29753
# [38]	validation_0-rmse:2.28656	validation_1-rmse:2.29658
# [39]	validation_0-rmse:2.28456	validation_1-rmse:2.29558
# [40]	validation_0-rmse:2.28270	validation_1-rmse:2.29495
# [41]	validation_0-rmse:2.28039	validation_1-rmse:2.29378
# [42]	validation_0-rmse:2.27902	validation_1-rmse:2.29350
# [43]	validation_0-rmse:2.27685	validation_1-rmse:2.29228
# [44]	validation_0-rmse:2.27538	validation_1-rmse:2.29226
# [45]	validation_0-rmse:2.27380	validation_1-rmse:2.29175
# [46]	validation_0-rmse:2.27277	validation_1-rmse:2.29186
# [47]	validation_0-rmse:2.27056	validation_1-rmse:2.29022
# [48]	validation_0-rmse:2.26835	validation_1-rmse:2.29027
# [49]	validation_0-rmse:2.26687	validation_1-rmse:2.28990
# [50]	validation_0-rmse:2.26558	validation_1-rmse:2.28992
# [51]	validation_0-rmse:2.26432	validation_1-rmse:2.29013
# [52]	validation_0-rmse:2.26252	validation_1-rmse:2.29119
# [53]	validation_0-rmse:2.26203	validation_1-rmse:2.29086
# Best Hyperparameters:  {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': 'reg:squarederror', 'reg_alpha': 0.1, 'reg_lambda': 0}
# Best Score:  -5.596344233633531

# %% [markdown]
# **Train an XGboost model**
#
# We will fit all the data in this model using the optimum parameters we found above.

# %%
# Define XGBoost regressor
reg = xgb.XGBRegressor(
    reg_lambda = xgb_grid.best_params_['reg_lambda'],
    reg_alpha = xgb_grid.best_params_['reg_alpha'],
    learning_rate = xgb_grid.best_params_['learning_rate'],
    max_depth = xgb_grid.best_params_['max_depth'],
    n_estimators = 100,
    gamma = xgb_grid.best_params_['gamma'],
    objective = xgb_grid.best_params_['objective'],
    early_stopping_rounds = 5
)

# Train the XGBoost model with feature weights (use validation set on test data)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test,y_test)])
# Out:
# [0]	validation_0-rmse:4.58481	validation_1-rmse:4.50381
# [1]	validation_0-rmse:4.27164	validation_1-rmse:4.19338
# [2]	validation_0-rmse:3.99764	validation_1-rmse:3.92359
# [3]	validation_0-rmse:3.75538	validation_1-rmse:3.68505
# [4]	validation_0-rmse:3.54661	validation_1-rmse:3.47677
# [5]	validation_0-rmse:3.36331	validation_1-rmse:3.29433
# [6]	validation_0-rmse:3.20648	validation_1-rmse:3.13905
# [7]	validation_0-rmse:3.07041	validation_1-rmse:3.00669
# [8]	validation_0-rmse:2.95423	validation_1-rmse:2.89469
# [9]	validation_0-rmse:2.85581	validation_1-rmse:2.79780
# [10]	validation_0-rmse:2.77089	validation_1-rmse:2.71681
# [11]	validation_0-rmse:2.69960	validation_1-rmse:2.64964
# [12]	validation_0-rmse:2.63913	validation_1-rmse:2.59355
# [13]	validation_0-rmse:2.58714	validation_1-rmse:2.54372
# [14]	validation_0-rmse:2.54409	validation_1-rmse:2.50391
# [15]	validation_0-rmse:2.50822	validation_1-rmse:2.47240
# [16]	validation_0-rmse:2.47767	validation_1-rmse:2.44468
# [17]	validation_0-rmse:2.45227	validation_1-rmse:2.42343
# [18]	validation_0-rmse:2.42795	validation_1-rmse:2.40166
# [19]	validation_0-rmse:2.40888	validation_1-rmse:2.38622
# [20]	validation_0-rmse:2.39304	validation_1-rmse:2.37254
# [21]	validation_0-rmse:2.37881	validation_1-rmse:2.36102
# [22]	validation_0-rmse:2.36510	validation_1-rmse:2.34908
# [23]	validation_0-rmse:2.35465	validation_1-rmse:2.34136
# [24]	validation_0-rmse:2.34619	validation_1-rmse:2.33582
# [25]	validation_0-rmse:2.33826	validation_1-rmse:2.32940
# [26]	validation_0-rmse:2.33175	validation_1-rmse:2.32461
# [27]	validation_0-rmse:2.32580	validation_1-rmse:2.32057
# [28]	validation_0-rmse:2.31944	validation_1-rmse:2.31593
# [29]	validation_0-rmse:2.31491	validation_1-rmse:2.31302
# [30]	validation_0-rmse:2.31093	validation_1-rmse:2.31037
# [31]	validation_0-rmse:2.30631	validation_1-rmse:2.30651
# [32]	validation_0-rmse:2.30297	validation_1-rmse:2.30423
# [33]	validation_0-rmse:2.30047	validation_1-rmse:2.30318
# [34]	validation_0-rmse:2.29728	validation_1-rmse:2.30096
# [35]	validation_0-rmse:2.29391	validation_1-rmse:2.29861
# [36]	validation_0-rmse:2.29109	validation_1-rmse:2.29811
# [37]	validation_0-rmse:2.28895	validation_1-rmse:2.29753
# [38]	validation_0-rmse:2.28656	validation_1-rmse:2.29658
# [39]	validation_0-rmse:2.28456	validation_1-rmse:2.29558
# [40]	validation_0-rmse:2.28270	validation_1-rmse:2.29495
# [41]	validation_0-rmse:2.28039	validation_1-rmse:2.29378
# [42]	validation_0-rmse:2.27902	validation_1-rmse:2.29350
# [43]	validation_0-rmse:2.27685	validation_1-rmse:2.29228
# [44]	validation_0-rmse:2.27538	validation_1-rmse:2.29226
# [45]	validation_0-rmse:2.27380	validation_1-rmse:2.29175
# [46]	validation_0-rmse:2.27277	validation_1-rmse:2.29186
# [47]	validation_0-rmse:2.27056	validation_1-rmse:2.29022
# [48]	validation_0-rmse:2.26835	validation_1-rmse:2.29027
# [49]	validation_0-rmse:2.26687	validation_1-rmse:2.28990
# [50]	validation_0-rmse:2.26558	validation_1-rmse:2.28992
# [51]	validation_0-rmse:2.26432	validation_1-rmse:2.29013
# [52]	validation_0-rmse:2.26252	validation_1-rmse:2.29119
# [53]	validation_0-rmse:2.26203	validation_1-rmse:2.29086
# [54]	validation_0-rmse:2.26020	validation_1-rmse:2.29021
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=5,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# Make predictions on the test set

# %%
# Make predictions on the X_test set
y_pred_xgboost = reg.predict(X_test)

# %%
# Calculate the MAE of XGBoost model
mae_xgboost = mean_absolute_error(y_test, y_pred_xgboost)
print("Mae is: ",mae_xgboost)

# Calculate RMSE score of XGBoost model
rmse_xgboost = mean_squared_error(y_test, y_pred_xgboost, squared=False)
print("RMSE score:", rmse_xgboost)
# Out:
# Mae is:  1.3656794949434699
# RMSE score: 2.289900625927125

# %% [markdown]
# **Train LSTM for time series forecasting**

# %% [markdown]
# Use the same train and test sets as in the XGBoost model. In order to create more accurate predictions, we scale those two sets before giving them as input to the LSTM Recurrent Neural Network model.

# %%
# Scale the data
scaler = MinMaxScaler()
X_tr = scaler.fit_transform(X_train)
X_te = scaler.fit_transform(X_test)

y_tr = scaler.fit_transform(y_train)
y_te = scaler.fit_transform(y_test)

# %%
# Create 3D train set for LSTM
trainX = []
trainY = []

for i in range(len(X_tr)):
    trainX.append(X_tr[i:i+1,:])

for i in range(len(y_tr)):
    trainY.append(y_tr[i:i+1,:])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# Create 3D test set for LSTM
testX = []
testY = []

for i in range(len(X_te)):
    testX.append(X_te[i:i+1,:])

for i in range(len(y_te)):
    testY.append(y_te[i:i+1,:])

testX, testY = np.array(testX), np.array(testY)

# %% [markdown]
# In the LSTM model, we include dense layers to capture more complex non linear patterns and dropout layers to prevent overfitting.

# %%
# Define LSTM model
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(50, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(25, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(12, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

# Additional Dense layers
model.add(Dense(6, activation='relu'))
model.add(Dense(3, activation='linear'))

# Output layer
model.add(Dense(trainY.shape[1]))

# Add early stopping mechanism
early_stopping = EarlyStopping(patience=5, monitor='val_loss', restore_best_weights=True)
# Out:
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# Compile LSTM model
model.compile(optimizer='adam', loss='mse')

# %%
# Fit model on training data
history = model.fit(trainX, trainY,
          epochs=50,
          batch_size=len(trainX)//100,
          validation_data=(testX,testY),
          callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 6s 14ms/step - loss: 0.0081 - val_loss: 0.0096
# Epoch 2/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 3/50
# 100/100 [==============================] - 5s 52ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 4/50
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 5/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 6/50
# 100/100 [==============================] - 1s 11ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 7/50
# 100/100 [==============================] - 5s 46ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 8/50
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 9/50
# 100/100 [==============================] - 3s 25ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 10/50
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0021 - val_loss: 0.0029
# Epoch 11/50
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0021 - val_loss: 0.0030

# %%
# Evaluate model on test data
loss_lstm = model.evaluate(testX, testY)
print("Test Loss:", loss_lstm)
# Out:
# 438/438 [==============================] - 3s 6ms/step - loss: 0.0029
# Test Loss: 0.0028565095271915197

# %%
# Predict on test data
y_pred_lstm = model.predict(testX)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm.reshape(-1,1))
# Out:
# 438/438 [==============================] - 5s 11ms/step

# %% [markdown]
# Evaluate the LSTM model

# %%
# Calculate the MAE score of LSTM model
mae_lstm = mean_absolute_error(scaler.inverse_transform(testY.reshape(-1,1)),y_pred_lstm)
print("Mae LSTM is: ",mae_lstm)

# Calculate the RMSE score of LSTM model
rmse_lstm = mean_squared_error(scaler.inverse_transform(testY.reshape(-1,1)), y_pred_lstm, squared=False)
print("RMSE LSTM score:", rmse_lstm)
# Out:
# Mae LSTM is:  1.4184950097629
# RMSE LSTM score: 2.3516379576141713

# %% [markdown]
# Add in the same dataframe the RMSE and MAE scores of each model, in order to compare them

# %%
# Create dataframe with scores (length == 3)
scores = pd.DataFrame(columns=['Model','RMSE Score','MAE Score'])

# Define rows for dataframe
new_row = {'Model': 'XGBoost', 'RMSE Score': rmse_xgboost, 'MAE Score': mae_xgboost}
new_row1 = {'Model': 'LSTM', 'RMSE Score': rmse_lstm, 'MAE Score': mae_lstm}

# Add rows to dataframe
scores = scores.append(new_row, ignore_index=True)
scores = scores.append(new_row1, ignore_index=True)

# %%
scores # length is 3
# Out:
#      Model  RMSE Score  MAE Score
# 0  XGBoost    2.289901   1.365679
# 1     LSTM    2.351638   1.418495

# %%
# Save XGBoost model to a file
reg.save_model('/content/drive/MyDrive/Paper/Models/xgboost_traffic_flow_length-'+str(optimum_lookback)+'.model')

# %%
# Save the model
model.save("/content/drive/MyDrive/Paper/Models/LSTM-length-"+str(optimum_lookback)+".h5")

# %% [markdown]
# ##### Sliding Window Length Equals to 4

# %%
optimum_lookback = 4

# %%
# Define train data
train= traffic_flow.loc[traffic_flow['Time Column'] < '2008-05-29']

# Define test data
test = traffic_flow.loc[traffic_flow['Time Column'] >= '2008-05-29']

# %%
# Convert train and test data to supervised problem based in the optimum lookback step we defined above.
train = generate_X_y_pairs(train, optimum_lookback)
test = generate_X_y_pairs(test, optimum_lookback)

# %%
# Add rolling mean information
train['rolling_mean'] = 0
test['rolling_mean'] = 0

# Add rolling var information
train['rolling_var'] = 0
test['rolling_var'] = 0

# Calculate rolling mean of window
train['rolling_mean'] = train.iloc[:,0:2].mean(axis=1)
test['rolling_mean'] = test.iloc[:,0:optimum_lookback].mean(axis=1)

# Calculate rolling variance of window
train['rolling_var'] = train.iloc[:, 0:optimum_lookback].var(axis=1)
test['rolling_var'] = test.iloc[:, 0:optimum_lookback].var(axis=1)

# %%
# Define features
features = train.drop(removable_items,axis=1).columns

# Define labels
labels = ['Record 1(t)']

# Create X_train and y_train data sets
X_train = train[features]
y_train = train[labels]

# Create X_test and y_test data sets
X_test = test[features]
y_test = test[labels]

# %% [markdown]
# **Apply GridSearchCV**
#
# Use a 3-fold K-fold cross-validation was used for learning the optimum hyperparameters for the XGBoost algorithm.

# %%
# Tune hyperparameters using XGboost
xgb_params = {
    "n_estimators": [100],
    "learning_rate": [0.1],
    "max_depth": [3,6,9],
    "objective":['reg:squarederror'],
    "gamma": [0,0.1],
    "reg_lambda": [0,1],
    'reg_alpha': [0, 0.1]
}

# Define GridSearchCV object
xgb_grid = GridSearchCV(xgb.XGBRegressor(),
                        xgb_params,cv=3,
                        scoring= "neg_mean_squared_error")

# Train on train data using 3 fold Cross Validation
xgb_grid.fit(X_train,y_train,
             early_stopping_rounds=5,
             eval_set=[(X_train, y_train), (X_test,y_test)],
             eval_metric='rmse')

# print the best hyperparameters and corresponding score
print("Best Hyperparameters: ", xgb_grid.best_params_)
print("Best Score: ", xgb_grid.best_score_)
# Out:
# [0]	validation_0-rmse:4.59465	validation_1-rmse:4.51120
# [1]	validation_0-rmse:4.28510	validation_1-rmse:4.20583
# [2]	validation_0-rmse:4.01244	validation_1-rmse:3.93811
# [3]	validation_0-rmse:3.77404	validation_1-rmse:3.69979
# [4]	validation_0-rmse:3.56439	validation_1-rmse:3.48918
# [5]	validation_0-rmse:3.38540	validation_1-rmse:3.31201
# [6]	validation_0-rmse:3.22863	validation_1-rmse:3.15946
# [7]	validation_0-rmse:3.09300	validation_1-rmse:3.02797
# [8]	validation_0-rmse:2.97623	validation_1-rmse:2.91587
# [9]	validation_0-rmse:2.87748	validation_1-rmse:2.81967
# [10]	validation_0-rmse:2.79203	validation_1-rmse:2.73808
# [11]	validation_0-rmse:2.71717	validation_1-rmse:2.66626
# [12]	validation_0-rmse:2.65592	validation_1-rmse:2.60831
# [13]	validation_0-rmse:2.60325	validation_1-rmse:2.55654
# [14]	validation_0-rmse:2.55887	validation_1-rmse:2.51792
# [15]	validation_0-rmse:2.51940	validation_1-rmse:2.48063
# [16]	validation_0-rmse:2.48881	validation_1-rmse:2.45270
# [17]	validation_0-rmse:2.46054	validation_1-rmse:2.42832
# [18]	validation_0-rmse:2.43857	validation_1-rmse:2.40862
# [19]	validation_0-rmse:2.41890	validation_1-rmse:2.39165
# [20]	validation_0-rmse:2.40234	validation_1-rmse:2.37838
# [21]	validation_0-rmse:2.38811	validation_1-rmse:2.36770
# [22]	validation_0-rmse:2.37455	validation_1-rmse:2.35766
# [23]	validation_0-rmse:2.36488	validation_1-rmse:2.34998
# [24]	validation_0-rmse:2.35479	validation_1-rmse:2.34263
# [25]	validation_0-rmse:2.34607	validation_1-rmse:2.33540
# [26]	validation_0-rmse:2.33907	validation_1-rmse:2.32950
# [27]	validation_0-rmse:2.33271	validation_1-rmse:2.32535
# [28]	validation_0-rmse:2.32797	validation_1-rmse:2.32225
# [29]	validation_0-rmse:2.32238	validation_1-rmse:2.31849
# [30]	validation_0-rmse:2.31864	validation_1-rmse:2.31606
# [31]	validation_0-rmse:2.31617	validation_1-rmse:2.31530
# [32]	validation_0-rmse:2.31209	validation_1-rmse:2.31247
# [33]	validation_0-rmse:2.30794	validation_1-rmse:2.31033
# [34]	validation_0-rmse:2.30511	validation_1-rmse:2.30934
# [35]	validation_0-rmse:2.30268	validation_1-rmse:2.30800
# [36]	validation_0-rmse:2.29988	validation_1-rmse:2.30690
# [37]	validation_0-rmse:2.29805	validation_1-rmse:2.30559
# [38]	validation_0-rmse:2.29690	validation_1-rmse:2.30522
# [39]	validation_0-rmse:2.29364	validation_1-rmse:2.30353
# [40]	validation_0-rmse:2.29185	validation_1-rmse:2.30271
# [41]	validation_0-rmse:2.29014	validation_1-rmse:2.30204
# [42]	validation_0-rmse:2.28774	validation_1-rmse:2.30046
# [43]	validation_0-rmse:2.28662	validation_1-rmse:2.30019
# [44]	validation_0-rmse:2.28543	validation_1-rmse:2.30048
# [45]	validation_0-rmse:2.28336	validation_1-rmse:2.29982
# [46]	validation_0-rmse:2.28221	validation_1-rmse:2.29922
# [47]	validation_0-rmse:2.28161	validation_1-rmse:2.29943
# [48]	validation_0-rmse:2.27951	validation_1-rmse:2.29729
# [49]	validation_0-rmse:2.27865	validation_1-rmse:2.29783
# [50]	validation_0-rmse:2.27773	validation_1-rmse:2.29815
# [51]	validation_0-rmse:2.27657	validation_1-rmse:2.29838
# [52]	validation_0-rmse:2.27479	validation_1-rmse:2.29928
# [53]	validation_0-rmse:2.27306	validation_1-rmse:2.29813
# [0]	validation_0-rmse:4.59448	validation_1-rmse:4.50802
# [1]	validation_0-rmse:4.28747	validation_1-rmse:4.20273
# [2]	validation_0-rmse:4.01466	validation_1-rmse:3.93459
# [3]	validation_0-rmse:3.77960	validation_1-rmse:3.70333
# [4]	validation_0-rmse:3.57112	validation_1-rmse:3.49834
# [5]	validation_0-rmse:3.39250	validation_1-rmse:3.31997
# [6]	validation_0-rmse:3.23434	validation_1-rmse:3.16708
# [7]	validation_0-rmse:3.09843	validation_1-rmse:3.03419
# [8]	validation_0-rmse:2.98197	validation_1-rmse:2.92210
# [9]	validation_0-rmse:2.88364	validation_1-rmse:2.82543
# [10]	validation_0-rmse:2.80575	validation_1-rmse:2.74709
# [11]	validation_0-rmse:2.73892	validation_1-rmse:2.68279
# [12]	validation_0-rmse:2.68112	validation_1-rmse:2.62516
# [13]	validation_0-rmse:2.62535	validation_1-rmse:2.57311
# [14]	validation_0-rmse:2.58474	validation_1-rmse:2.53199
# [15]	validation_0-rmse:2.54491	validation_1-rmse:2.49746
# [16]	validation_0-rmse:2.51047	validation_1-rmse:2.46761
# [17]	validation_0-rmse:2.47992	validation_1-rmse:2.44165
# [18]	validation_0-rmse:2.45513	validation_1-rmse:2.42236
# [19]	validation_0-rmse:2.43410	validation_1-rmse:2.40371
# [20]	validation_0-rmse:2.41837	validation_1-rmse:2.38950
# [21]	validation_0-rmse:2.40198	validation_1-rmse:2.37672
# [22]	validation_0-rmse:2.38919	validation_1-rmse:2.36550
# [23]	validation_0-rmse:2.37893	validation_1-rmse:2.35652
# [24]	validation_0-rmse:2.36799	validation_1-rmse:2.34716
# [25]	validation_0-rmse:2.35830	validation_1-rmse:2.34058
# [26]	validation_0-rmse:2.35148	validation_1-rmse:2.33455
# [27]	validation_0-rmse:2.34450	validation_1-rmse:2.32828
# [28]	validation_0-rmse:2.33867	validation_1-rmse:2.32476
# [29]	validation_0-rmse:2.33311	validation_1-rmse:2.32095
# [30]	validation_0-rmse:2.32631	validation_1-rmse:2.31552
# [31]	validation_0-rmse:2.32194	validation_1-rmse:2.31325
# [32]	validation_0-rmse:2.31816	validation_1-rmse:2.31008
# [33]	validation_0-rmse:2.31479	validation_1-rmse:2.30812
# [34]	validation_0-rmse:2.31176	validation_1-rmse:2.30661
# [35]	validation_0-rmse:2.30818	validation_1-rmse:2.30418
# [36]	validation_0-rmse:2.30525	validation_1-rmse:2.30242
# [37]	validation_0-rmse:2.30308	validation_1-rmse:2.30223
# [38]	validation_0-rmse:2.30064	validation_1-rmse:2.30079
# [39]	validation_0-rmse:2.29817	validation_1-rmse:2.30056
# [40]	validation_0-rmse:2.29584	validation_1-rmse:2.30095
# [41]	validation_0-rmse:2.29410	validation_1-rmse:2.30099
# [42]	validation_0-rmse:2.29295	validation_1-rmse:2.30085
# [43]	validation_0-rmse:2.29169	validation_1-rmse:2.29968
# [44]	validation_0-rmse:2.28992	validation_1-rmse:2.29920
# [45]	validation_0-rmse:2.28802	validation_1-rmse:2.29957
# [46]	validation_0-rmse:2.28687	validation_1-rmse:2.29871
# [47]	validation_0-rmse:2.28455	validation_1-rmse:2.29946
# [48]	validation_0-rmse:2.28340	validation_1-rmse:2.29927
# [49]	validation_0-rmse:2.28188	validation_1-rmse:2.29838
# [50]	validation_0-rmse:2.28049	validation_1-rmse:2.29811
# [51]	validation_0-rmse:2.27934	validation_1-rmse:2.29714
# [52]	validation_0-rmse:2.27752	validation_1-rmse:2.29849
# [53]	validation_0-rmse:2.27594	validation_1-rmse:2.29866
# [54]	validation_0-rmse:2.27441	validation_1-rmse:2.29853
# [55]	validation_0-rmse:2.27364	validation_1-rmse:2.29929
# [0]	validation_0-rmse:4.57918	validation_1-rmse:4.49435
# [1]	validation_0-rmse:4.26145	validation_1-rmse:4.17917
# [2]	validation_0-rmse:3.98042	validation_1-rmse:3.90426
# [3]	validation_0-rmse:3.73541	validation_1-rmse:3.65960
# [4]	validation_0-rmse:3.52378	validation_1-rmse:3.45079
# [5]	validation_0-rmse:3.33920	validation_1-rmse:3.27176
# [6]	validation_0-rmse:3.18120	validation_1-rmse:3.11820
# [7]	validation_0-rmse:3.04475	validation_1-rmse:2.98709
# [8]	validation_0-rmse:2.93010	validation_1-rmse:2.87540
# [9]	validation_0-rmse:2.83035	validation_1-rmse:2.77836
# [10]	validation_0-rmse:2.74706	validation_1-rmse:2.69942
# [11]	validation_0-rmse:2.67574	validation_1-rmse:2.63225
# [12]	validation_0-rmse:2.61528	validation_1-rmse:2.57614
# [13]	validation_0-rmse:2.56124	validation_1-rmse:2.52447
# [14]	validation_0-rmse:2.51909	validation_1-rmse:2.48406
# [15]	validation_0-rmse:2.48342	validation_1-rmse:2.45151
# [16]	validation_0-rmse:2.45008	validation_1-rmse:2.42137
# [17]	validation_0-rmse:2.42392	validation_1-rmse:2.39803
# [18]	validation_0-rmse:2.40079	validation_1-rmse:2.37646
# [19]	validation_0-rmse:2.38378	validation_1-rmse:2.36240
# [20]	validation_0-rmse:2.36956	validation_1-rmse:2.35103
# [21]	validation_0-rmse:2.35652	validation_1-rmse:2.34095
# [22]	validation_0-rmse:2.34492	validation_1-rmse:2.33116
# [23]	validation_0-rmse:2.33554	validation_1-rmse:2.32344
# [24]	validation_0-rmse:2.32780	validation_1-rmse:2.31803
# [25]	validation_0-rmse:2.32073	validation_1-rmse:2.31282
# [26]	validation_0-rmse:2.31546	validation_1-rmse:2.30999
# [27]	validation_0-rmse:2.31059	validation_1-rmse:2.30644
# [28]	validation_0-rmse:2.30622	validation_1-rmse:2.30346
# [29]	validation_0-rmse:2.30309	validation_1-rmse:2.30231
# [30]	validation_0-rmse:2.29949	validation_1-rmse:2.29993
# [31]	validation_0-rmse:2.29696	validation_1-rmse:2.29880
# [32]	validation_0-rmse:2.29443	validation_1-rmse:2.29753
# [33]	validation_0-rmse:2.29218	validation_1-rmse:2.29628
# [34]	validation_0-rmse:2.28982	validation_1-rmse:2.29614
# [35]	validation_0-rmse:2.28762	validation_1-rmse:2.29586
# [36]	validation_0-rmse:2.28582	validation_1-rmse:2.29459
# [37]	validation_0-rmse:2.28412	validation_1-rmse:2.29407
# [38]	validation_0-rmse:2.28259	validation_1-rmse:2.29373
# [39]	validation_0-rmse:2.28016	validation_1-rmse:2.29428
# [40]	validation_0-rmse:2.27924	validation_1-rmse:2.29464
# [41]	validation_0-rmse:2.27772	validation_1-rmse:2.29454
# [42]	validation_0-rmse:2.27667	validation_1-rmse:2.29462
# [43]	validation_0-rmse:2.27616	validation_1-rmse:2.29469
# [0]	validation_0-rmse:4.59513	validation_1-rmse:4.51164
# [1]	validation_0-rmse:4.28602	validation_1-rmse:4.20663
# [2]	validation_0-rmse:4.01373	validation_1-rmse:3.93921
# [3]	validation_0-rmse:3.77547	validation_1-rmse:3.70101
# [4]	validation_0-rmse:3.56614	validation_1-rmse:3.49066
# [5]	validation_0-rmse:3.38722	validation_1-rmse:3.31352
# [6]	validation_0-rmse:3.23101	validation_1-rmse:3.16272
# [7]	validation_0-rmse:3.09490	validation_1-rmse:3.03004
# [8]	validation_0-rmse:2.97820	validation_1-rmse:2.91797
# [9]	validation_0-rmse:2.87960	validation_1-rmse:2.82183
# [10]	validation_0-rmse:2.79405	validation_1-rmse:2.74013
# [11]	validation_0-rmse:2.71915	validation_1-rmse:2.66826
# [12]	validation_0-rmse:2.65767	validation_1-rmse:2.61085
# [13]	validation_0-rmse:2.60486	validation_1-rmse:2.55897
# [14]	validation_0-rmse:2.56126	validation_1-rmse:2.51787
# [15]	validation_0-rmse:2.52404	validation_1-rmse:2.48352
# [16]	validation_0-rmse:2.49243	validation_1-rmse:2.45590
# [17]	validation_0-rmse:2.46547	validation_1-rmse:2.43306
# [18]	validation_0-rmse:2.44208	validation_1-rmse:2.41345
# [19]	validation_0-rmse:2.42224	validation_1-rmse:2.39592
# [20]	validation_0-rmse:2.40531	validation_1-rmse:2.38099
# [21]	validation_0-rmse:2.39015	validation_1-rmse:2.36713
# [22]	validation_0-rmse:2.37640	validation_1-rmse:2.35566
# [23]	validation_0-rmse:2.36656	validation_1-rmse:2.34705
# [24]	validation_0-rmse:2.35750	validation_1-rmse:2.33991
# [25]	validation_0-rmse:2.34965	validation_1-rmse:2.33371
# [26]	validation_0-rmse:2.34147	validation_1-rmse:2.32758
# [27]	validation_0-rmse:2.33507	validation_1-rmse:2.32241
# [28]	validation_0-rmse:2.33055	validation_1-rmse:2.31953
# [29]	validation_0-rmse:2.32611	validation_1-rmse:2.31667
# [30]	validation_0-rmse:2.32182	validation_1-rmse:2.31352
# [31]	validation_0-rmse:2.31853	validation_1-rmse:2.31200
# [32]	validation_0-rmse:2.31402	validation_1-rmse:2.30961
# [33]	validation_0-rmse:2.31118	validation_1-rmse:2.30768
# [34]	validation_0-rmse:2.30856	validation_1-rmse:2.30639
# [35]	validation_0-rmse:2.30645	validation_1-rmse:2.30501
# [36]	validation_0-rmse:2.30362	validation_1-rmse:2.30357
# [37]	validation_0-rmse:2.30222	validation_1-rmse:2.30328
# [38]	validation_0-rmse:2.30063	validation_1-rmse:2.30226
# [39]	validation_0-rmse:2.29819	validation_1-rmse:2.30022
# [40]	validation_0-rmse:2.29646	validation_1-rmse:2.29957
# [41]	validation_0-rmse:2.29430	validation_1-rmse:2.29973
# [42]	validation_0-rmse:2.29300	validation_1-rmse:2.29958
# [43]	validation_0-rmse:2.29180	validation_1-rmse:2.30013
# [44]	validation_0-rmse:2.28850	validation_1-rmse:2.29847
# [45]	validation_0-rmse:2.28753	validation_1-rmse:2.29871
# [46]	validation_0-rmse:2.28622	validation_1-rmse:2.29822
# [47]	validation_0-rmse:2.28513	validation_1-rmse:2.29894
# [48]	validation_0-rmse:2.28404	validation_1-rmse:2.29854
# [49]	validation_0-rmse:2.28200	validation_1-rmse:2.29814
# [50]	validation_0-rmse:2.28152	validation_1-rmse:2.29835
# [51]	validation_0-rmse:2.28057	validation_1-rmse:2.29786
# [52]	validation_0-rmse:2.27852	validation_1-rmse:2.29577
# [53]	validation_0-rmse:2.27790	validation_1-rmse:2.29559
# [54]	validation_0-rmse:2.27554	validation_1-rmse:2.29389
# [55]	validation_0-rmse:2.27354	validation_1-rmse:2.29446
# [56]	validation_0-rmse:2.27302	validation_1-rmse:2.29502
# [57]	validation_0-rmse:2.27215	validation_1-rmse:2.29518
# [58]	validation_0-rmse:2.27053	validation_1-rmse:2.29459
# [59]	validation_0-rmse:2.26928	validation_1-rmse:2.29416
# [0]	validation_0-rmse:4.59508	validation_1-rmse:4.50854
# [1]	validation_0-rmse:4.28842	validation_1-rmse:4.20355
# [2]	validation_0-rmse:4.01613	validation_1-rmse:3.93583
# [3]	validation_0-rmse:3.78126	validation_1-rmse:3.70472
# [4]	validation_0-rmse:3.57315	validation_1-rmse:3.49997
# [5]	validation_0-rmse:3.39509	validation_1-rmse:3.32144
# [6]	validation_0-rmse:3.23730	validation_1-rmse:3.16877
# [7]	validation_0-rmse:3.10128	validation_1-rmse:3.03526
# [8]	validation_0-rmse:2.98461	validation_1-rmse:2.92297
# [9]	validation_0-rmse:2.88617	validation_1-rmse:2.82622
# [10]	validation_0-rmse:2.80815	validation_1-rmse:2.74774
# [11]	validation_0-rmse:2.74128	validation_1-rmse:2.68338
# [12]	validation_0-rmse:2.67807	validation_1-rmse:2.62377
# [13]	validation_0-rmse:2.62786	validation_1-rmse:2.57478
# [14]	validation_0-rmse:2.58707	validation_1-rmse:2.53350
# [15]	validation_0-rmse:2.54628	validation_1-rmse:2.49765
# [16]	validation_0-rmse:2.51443	validation_1-rmse:2.47016
# [17]	validation_0-rmse:2.48457	validation_1-rmse:2.44427
# [18]	validation_0-rmse:2.45813	validation_1-rmse:2.42213
# [19]	validation_0-rmse:2.43874	validation_1-rmse:2.40395
# [20]	validation_0-rmse:2.42087	validation_1-rmse:2.38942
# [21]	validation_0-rmse:2.40588	validation_1-rmse:2.37617
# [22]	validation_0-rmse:2.39234	validation_1-rmse:2.36619
# [23]	validation_0-rmse:2.37962	validation_1-rmse:2.35646
# [24]	validation_0-rmse:2.37105	validation_1-rmse:2.34836
# [25]	validation_0-rmse:2.36304	validation_1-rmse:2.34116
# [26]	validation_0-rmse:2.35515	validation_1-rmse:2.33591
# [27]	validation_0-rmse:2.34721	validation_1-rmse:2.33055
# [28]	validation_0-rmse:2.34131	validation_1-rmse:2.32529
# [29]	validation_0-rmse:2.33586	validation_1-rmse:2.32176
# [30]	validation_0-rmse:2.33071	validation_1-rmse:2.31885
# [31]	validation_0-rmse:2.32655	validation_1-rmse:2.31525
# [32]	validation_0-rmse:2.32270	validation_1-rmse:2.31270
# [33]	validation_0-rmse:2.31719	validation_1-rmse:2.30855
# [34]	validation_0-rmse:2.31440	validation_1-rmse:2.30706
# [35]	validation_0-rmse:2.31218	validation_1-rmse:2.30607
# [36]	validation_0-rmse:2.30956	validation_1-rmse:2.30475
# [37]	validation_0-rmse:2.30635	validation_1-rmse:2.30349
# [38]	validation_0-rmse:2.30380	validation_1-rmse:2.30251
# [39]	validation_0-rmse:2.30192	validation_1-rmse:2.30207
# [40]	validation_0-rmse:2.29977	validation_1-rmse:2.30115
# [41]	validation_0-rmse:2.29801	validation_1-rmse:2.30053
# [42]	validation_0-rmse:2.29660	validation_1-rmse:2.30109
# [43]	validation_0-rmse:2.29512	validation_1-rmse:2.30085
# [44]	validation_0-rmse:2.29318	validation_1-rmse:2.30125
# [45]	validation_0-rmse:2.29123	validation_1-rmse:2.30027
# [46]	validation_0-rmse:2.29000	validation_1-rmse:2.29968
# [47]	validation_0-rmse:2.28818	validation_1-rmse:2.29815
# [48]	validation_0-rmse:2.28663	validation_1-rmse:2.29755
# [49]	validation_0-rmse:2.28519	validation_1-rmse:2.29842
# [50]	validation_0-rmse:2.28378	validation_1-rmse:2.29754
# [51]	validation_0-rmse:2.28263	validation_1-rmse:2.29651
# [52]	validation_0-rmse:2.28169	validation_1-rmse:2.29588
# [53]	validation_0-rmse:2.28112	validation_1-rmse:2.29596
# [54]	validation_0-rmse:2.28021	validation_1-rmse:2.29541
# [55]	validation_0-rmse:2.27866	validation_1-rmse:2.29399
# [56]	validation_0-rmse:2.27821	validation_1-rmse:2.29408
# [57]	validation_0-rmse:2.27718	validation_1-rmse:2.29345
# [58]	validation_0-rmse:2.27645	validation_1-rmse:2.29339
# [59]	validation_0-rmse:2.27521	validation_1-rmse:2.29254
# [60]	validation_0-rmse:2.27392	validation_1-rmse:2.29266
# [61]	validation_0-rmse:2.27151	validation_1-rmse:2.29092
# [62]	validation_0-rmse:2.27087	validation_1-rmse:2.29038
# [63]	validation_0-rmse:2.27015	validation_1-rmse:2.29081
# [64]	validation_0-rmse:2.26978	validation_1-rmse:2.29106
# [65]	validation_0-rmse:2.26877	validation_1-rmse:2.29098
# [66]	validation_0-rmse:2.26866	validation_1-rmse:2.29098
# [67]	validation_0-rmse:2.26777	validation_1-rmse:2.29054
# [0]	validation_0-rmse:4.57930	validation_1-rmse:4.49265
# [1]	validation_0-rmse:4.26223	validation_1-rmse:4.17725
# [2]	validation_0-rmse:3.98271	validation_1-rmse:3.90086
# [3]	validation_0-rmse:3.73704	validation_1-rmse:3.65742
# [4]	validation_0-rmse:3.52523	validation_1-rmse:3.44740
# [5]	validation_0-rmse:3.34178	validation_1-rmse:3.27006
# [6]	validation_0-rmse:3.18352	validation_1-rmse:3.11602
# [7]	validation_0-rmse:3.04843	validation_1-rmse:2.98579
# [8]	validation_0-rmse:2.93131	validation_1-rmse:2.87195
# [9]	validation_0-rmse:2.83250	validation_1-rmse:2.77818
# [10]	validation_0-rmse:2.74859	validation_1-rmse:2.69546
# [11]	validation_0-rmse:2.67815	validation_1-rmse:2.62842
# [12]	validation_0-rmse:2.61634	validation_1-rmse:2.57262
# [13]	validation_0-rmse:2.56594	validation_1-rmse:2.52788
# [14]	validation_0-rmse:2.52337	validation_1-rmse:2.48833
# [15]	validation_0-rmse:2.48457	validation_1-rmse:2.45303
# [16]	validation_0-rmse:2.45418	validation_1-rmse:2.42449
# [17]	validation_0-rmse:2.42439	validation_1-rmse:2.39707
# [18]	validation_0-rmse:2.40145	validation_1-rmse:2.37806
# [19]	validation_0-rmse:2.38399	validation_1-rmse:2.36376
# [20]	validation_0-rmse:2.36805	validation_1-rmse:2.34948
# [21]	validation_0-rmse:2.35465	validation_1-rmse:2.33841
# [22]	validation_0-rmse:2.34303	validation_1-rmse:2.32860
# [23]	validation_0-rmse:2.33419	validation_1-rmse:2.32228
# [24]	validation_0-rmse:2.32625	validation_1-rmse:2.31757
# [25]	validation_0-rmse:2.31936	validation_1-rmse:2.31254
# [26]	validation_0-rmse:2.31285	validation_1-rmse:2.30900
# [27]	validation_0-rmse:2.30883	validation_1-rmse:2.30791
# [28]	validation_0-rmse:2.30516	validation_1-rmse:2.30552
# [29]	validation_0-rmse:2.30135	validation_1-rmse:2.30361
# [30]	validation_0-rmse:2.29820	validation_1-rmse:2.30292
# [31]	validation_0-rmse:2.29517	validation_1-rmse:2.30132
# [32]	validation_0-rmse:2.29241	validation_1-rmse:2.29988
# [33]	validation_0-rmse:2.28998	validation_1-rmse:2.29844
# [34]	validation_0-rmse:2.28809	validation_1-rmse:2.29776
# [35]	validation_0-rmse:2.28667	validation_1-rmse:2.29697
# [36]	validation_0-rmse:2.28485	validation_1-rmse:2.29636
# [37]	validation_0-rmse:2.28484	validation_1-rmse:2.29859
# [38]	validation_0-rmse:2.28433	validation_1-rmse:2.29891
# [39]	validation_0-rmse:2.28299	validation_1-rmse:2.29877
# [40]	validation_0-rmse:2.28151	validation_1-rmse:2.29747
# [0]	validation_0-rmse:4.59465	validation_1-rmse:4.51120
# [1]	validation_0-rmse:4.28511	validation_1-rmse:4.20584
# [2]	validation_0-rmse:4.01245	validation_1-rmse:3.93812
# [3]	validation_0-rmse:3.77405	validation_1-rmse:3.69980
# [4]	validation_0-rmse:3.56441	validation_1-rmse:3.48920
# [5]	validation_0-rmse:3.38541	validation_1-rmse:3.31202
# [6]	validation_0-rmse:3.22864	validation_1-rmse:3.15947
# [7]	validation_0-rmse:3.09301	validation_1-rmse:3.02799
# [8]	validation_0-rmse:2.97624	validation_1-rmse:2.91589
# [9]	validation_0-rmse:2.87749	validation_1-rmse:2.81969
# [10]	validation_0-rmse:2.79205	validation_1-rmse:2.73809
# [11]	validation_0-rmse:2.71718	validation_1-rmse:2.66627
# [12]	validation_0-rmse:2.65594	validation_1-rmse:2.60833
# [13]	validation_0-rmse:2.60326	validation_1-rmse:2.55656
# [14]	validation_0-rmse:2.55888	validation_1-rmse:2.51794
# [15]	validation_0-rmse:2.51941	validation_1-rmse:2.48064
# [16]	validation_0-rmse:2.48883	validation_1-rmse:2.45271
# [17]	validation_0-rmse:2.46056	validation_1-rmse:2.42833
# [18]	validation_0-rmse:2.43858	validation_1-rmse:2.40863
# [19]	validation_0-rmse:2.41892	validation_1-rmse:2.39166
# [20]	validation_0-rmse:2.40236	validation_1-rmse:2.37839
# [21]	validation_0-rmse:2.38813	validation_1-rmse:2.36770
# [22]	validation_0-rmse:2.37456	validation_1-rmse:2.35766
# [23]	validation_0-rmse:2.36489	validation_1-rmse:2.34999
# [24]	validation_0-rmse:2.35480	validation_1-rmse:2.34263
# [25]	validation_0-rmse:2.34609	validation_1-rmse:2.33541
# [26]	validation_0-rmse:2.33908	validation_1-rmse:2.32950
# [27]	validation_0-rmse:2.33273	validation_1-rmse:2.32536
# [28]	validation_0-rmse:2.32799	validation_1-rmse:2.32225
# [29]	validation_0-rmse:2.32240	validation_1-rmse:2.31849
# [30]	validation_0-rmse:2.31866	validation_1-rmse:2.31568
# [31]	validation_0-rmse:2.31625	validation_1-rmse:2.31495
# [32]	validation_0-rmse:2.31217	validation_1-rmse:2.31211
# [33]	validation_0-rmse:2.30805	validation_1-rmse:2.31018
# [34]	validation_0-rmse:2.30511	validation_1-rmse:2.30918
# [35]	validation_0-rmse:2.30272	validation_1-rmse:2.30788
# [36]	validation_0-rmse:2.30026	validation_1-rmse:2.30672
# [37]	validation_0-rmse:2.29873	validation_1-rmse:2.30642
# [38]	validation_0-rmse:2.29705	validation_1-rmse:2.30529
# [39]	validation_0-rmse:2.29351	validation_1-rmse:2.30316
# [40]	validation_0-rmse:2.29175	validation_1-rmse:2.30233
# [41]	validation_0-rmse:2.28926	validation_1-rmse:2.30067
# [42]	validation_0-rmse:2.28763	validation_1-rmse:2.29996
# [43]	validation_0-rmse:2.28643	validation_1-rmse:2.30026
# [44]	validation_0-rmse:2.28537	validation_1-rmse:2.30003
# [45]	validation_0-rmse:2.28334	validation_1-rmse:2.29944
# [46]	validation_0-rmse:2.28100	validation_1-rmse:2.29802
# [47]	validation_0-rmse:2.27997	validation_1-rmse:2.29836
# [48]	validation_0-rmse:2.27893	validation_1-rmse:2.29795
# [49]	validation_0-rmse:2.27863	validation_1-rmse:2.29794
# [50]	validation_0-rmse:2.27809	validation_1-rmse:2.29814
# [51]	validation_0-rmse:2.27592	validation_1-rmse:2.29762
# [52]	validation_0-rmse:2.27578	validation_1-rmse:2.29738
# [53]	validation_0-rmse:2.27545	validation_1-rmse:2.29744
# [54]	validation_0-rmse:2.27489	validation_1-rmse:2.29763
# [55]	validation_0-rmse:2.27302	validation_1-rmse:2.29924
# [56]	validation_0-rmse:2.27209	validation_1-rmse:2.29871
# [57]	validation_0-rmse:2.27178	validation_1-rmse:2.29908
# [0]	validation_0-rmse:4.59448	validation_1-rmse:4.50802
# [1]	validation_0-rmse:4.28747	validation_1-rmse:4.20273
# [2]	validation_0-rmse:4.01467	validation_1-rmse:3.93460
# [3]	validation_0-rmse:3.77961	validation_1-rmse:3.70334
# [4]	validation_0-rmse:3.57114	validation_1-rmse:3.49835
# [5]	validation_0-rmse:3.39252	validation_1-rmse:3.31998
# [6]	validation_0-rmse:3.23435	validation_1-rmse:3.16710
# [7]	validation_0-rmse:3.09845	validation_1-rmse:3.03421
# [8]	validation_0-rmse:2.98199	validation_1-rmse:2.92211
# [9]	validation_0-rmse:2.88366	validation_1-rmse:2.82545
# [10]	validation_0-rmse:2.80577	validation_1-rmse:2.74711
# [11]	validation_0-rmse:2.73894	validation_1-rmse:2.68281
# [12]	validation_0-rmse:2.68114	validation_1-rmse:2.62518
# [13]	validation_0-rmse:2.62536	validation_1-rmse:2.57312
# [14]	validation_0-rmse:2.58475	validation_1-rmse:2.53200
# [15]	validation_0-rmse:2.54492	validation_1-rmse:2.49747
# [16]	validation_0-rmse:2.51048	validation_1-rmse:2.46762
# [17]	validation_0-rmse:2.47994	validation_1-rmse:2.44167
# [18]	validation_0-rmse:2.45515	validation_1-rmse:2.42237
# [19]	validation_0-rmse:2.43411	validation_1-rmse:2.40372
# [20]	validation_0-rmse:2.41839	validation_1-rmse:2.38951
# [21]	validation_0-rmse:2.40200	validation_1-rmse:2.37673
# [22]	validation_0-rmse:2.38921	validation_1-rmse:2.36551
# [23]	validation_0-rmse:2.37894	validation_1-rmse:2.35653
# [24]	validation_0-rmse:2.36801	validation_1-rmse:2.34717
# [25]	validation_0-rmse:2.35832	validation_1-rmse:2.34059
# [26]	validation_0-rmse:2.35150	validation_1-rmse:2.33456
# [27]	validation_0-rmse:2.34451	validation_1-rmse:2.32829
# [28]	validation_0-rmse:2.33869	validation_1-rmse:2.32477
# [29]	validation_0-rmse:2.33313	validation_1-rmse:2.32096
# [30]	validation_0-rmse:2.32633	validation_1-rmse:2.31553
# [31]	validation_0-rmse:2.32195	validation_1-rmse:2.31325
# [32]	validation_0-rmse:2.31817	validation_1-rmse:2.31009
# [33]	validation_0-rmse:2.31481	validation_1-rmse:2.30813
# [34]	validation_0-rmse:2.31178	validation_1-rmse:2.30661
# [35]	validation_0-rmse:2.30820	validation_1-rmse:2.30418
# [36]	validation_0-rmse:2.30527	validation_1-rmse:2.30242
# [37]	validation_0-rmse:2.30310	validation_1-rmse:2.30223
# [38]	validation_0-rmse:2.30066	validation_1-rmse:2.30080
# [39]	validation_0-rmse:2.29817	validation_1-rmse:2.30101
# [40]	validation_0-rmse:2.29583	validation_1-rmse:2.30138
# [41]	validation_0-rmse:2.29453	validation_1-rmse:2.30093
# [42]	validation_0-rmse:2.29295	validation_1-rmse:2.30028
# [43]	validation_0-rmse:2.29091	validation_1-rmse:2.30065
# [44]	validation_0-rmse:2.28869	validation_1-rmse:2.29910
# [45]	validation_0-rmse:2.28719	validation_1-rmse:2.29971
# [46]	validation_0-rmse:2.28549	validation_1-rmse:2.29930
# [47]	validation_0-rmse:2.28322	validation_1-rmse:2.30004
# [48]	validation_0-rmse:2.28184	validation_1-rmse:2.29886
# [49]	validation_0-rmse:2.28000	validation_1-rmse:2.29918
# [50]	validation_0-rmse:2.27947	validation_1-rmse:2.29904
# [51]	validation_0-rmse:2.27804	validation_1-rmse:2.29821
# [52]	validation_0-rmse:2.27700	validation_1-rmse:2.29729
# [53]	validation_0-rmse:2.27593	validation_1-rmse:2.29811
# [54]	validation_0-rmse:2.27505	validation_1-rmse:2.29745
# [55]	validation_0-rmse:2.27406	validation_1-rmse:2.29721
# [56]	validation_0-rmse:2.27305	validation_1-rmse:2.29754
# [57]	validation_0-rmse:2.27247	validation_1-rmse:2.29782
# [58]	validation_0-rmse:2.27251	validation_1-rmse:2.29815
# [59]	validation_0-rmse:2.27114	validation_1-rmse:2.29682
# [60]	validation_0-rmse:2.27009	validation_1-rmse:2.29760
# [61]	validation_0-rmse:2.26913	validation_1-rmse:2.29766
# [62]	validation_0-rmse:2.26789	validation_1-rmse:2.29675
# [63]	validation_0-rmse:2.26615	validation_1-rmse:2.29614
# [64]	validation_0-rmse:2.26541	validation_1-rmse:2.29542
# [65]	validation_0-rmse:2.26483	validation_1-rmse:2.29515
# [66]	validation_0-rmse:2.26472	validation_1-rmse:2.29643
# [67]	validation_0-rmse:2.26423	validation_1-rmse:2.29710
# [68]	validation_0-rmse:2.26383	validation_1-rmse:2.29743
# [69]	validation_0-rmse:2.26354	validation_1-rmse:2.29734
# [70]	validation_0-rmse:2.26291	validation_1-rmse:2.29690
# [0]	validation_0-rmse:4.57918	validation_1-rmse:4.49435
# [1]	validation_0-rmse:4.26145	validation_1-rmse:4.17918
# [2]	validation_0-rmse:3.98043	validation_1-rmse:3.90426
# [3]	validation_0-rmse:3.73542	validation_1-rmse:3.65961
# [4]	validation_0-rmse:3.52379	validation_1-rmse:3.45080
# [5]	validation_0-rmse:3.33921	validation_1-rmse:3.27177
# [6]	validation_0-rmse:3.18121	validation_1-rmse:3.11821
# [7]	validation_0-rmse:3.04477	validation_1-rmse:2.98710
# [8]	validation_0-rmse:2.93011	validation_1-rmse:2.87541
# [9]	validation_0-rmse:2.83037	validation_1-rmse:2.77837
# [10]	validation_0-rmse:2.74708	validation_1-rmse:2.69944
# [11]	validation_0-rmse:2.67575	validation_1-rmse:2.63226
# [12]	validation_0-rmse:2.61530	validation_1-rmse:2.57615
# [13]	validation_0-rmse:2.56126	validation_1-rmse:2.52448
# [14]	validation_0-rmse:2.51911	validation_1-rmse:2.48407
# [15]	validation_0-rmse:2.48344	validation_1-rmse:2.45152
# [16]	validation_0-rmse:2.45010	validation_1-rmse:2.42138
# [17]	validation_0-rmse:2.42393	validation_1-rmse:2.39804
# [18]	validation_0-rmse:2.40080	validation_1-rmse:2.37647
# [19]	validation_0-rmse:2.38379	validation_1-rmse:2.36241
# [20]	validation_0-rmse:2.36958	validation_1-rmse:2.35103
# [21]	validation_0-rmse:2.35653	validation_1-rmse:2.34096
# [22]	validation_0-rmse:2.34498	validation_1-rmse:2.33130
# [23]	validation_0-rmse:2.33549	validation_1-rmse:2.32348
# [24]	validation_0-rmse:2.32767	validation_1-rmse:2.31799
# [25]	validation_0-rmse:2.32051	validation_1-rmse:2.31270
# [26]	validation_0-rmse:2.31516	validation_1-rmse:2.30980
# [27]	validation_0-rmse:2.31018	validation_1-rmse:2.30615
# [28]	validation_0-rmse:2.30575	validation_1-rmse:2.30309
# [29]	validation_0-rmse:2.30220	validation_1-rmse:2.30161
# [30]	validation_0-rmse:2.29853	validation_1-rmse:2.29969
# [31]	validation_0-rmse:2.29610	validation_1-rmse:2.29865
# [32]	validation_0-rmse:2.29357	validation_1-rmse:2.29726
# [33]	validation_0-rmse:2.29126	validation_1-rmse:2.29632
# [34]	validation_0-rmse:2.28876	validation_1-rmse:2.29646
# [35]	validation_0-rmse:2.28788	validation_1-rmse:2.29647
# [36]	validation_0-rmse:2.28583	validation_1-rmse:2.29587
# [37]	validation_0-rmse:2.28452	validation_1-rmse:2.29591
# [38]	validation_0-rmse:2.28257	validation_1-rmse:2.29513
# [39]	validation_0-rmse:2.28150	validation_1-rmse:2.29527
# [40]	validation_0-rmse:2.27957	validation_1-rmse:2.29564
# [41]	validation_0-rmse:2.27783	validation_1-rmse:2.29583
# [42]	validation_0-rmse:2.27692	validation_1-rmse:2.29590
# [0]	validation_0-rmse:4.59513	validation_1-rmse:4.51164
# [1]	validation_0-rmse:4.28603	validation_1-rmse:4.20664
# [2]	validation_0-rmse:4.01374	validation_1-rmse:3.93922
# [3]	validation_0-rmse:3.77548	validation_1-rmse:3.70102
# [4]	validation_0-rmse:3.56615	validation_1-rmse:3.49067
# [5]	validation_0-rmse:3.38723	validation_1-rmse:3.31354
# [6]	validation_0-rmse:3.23102	validation_1-rmse:3.16273
# [7]	validation_0-rmse:3.09491	validation_1-rmse:3.03005
# [8]	validation_0-rmse:2.97822	validation_1-rmse:2.91799
# [9]	validation_0-rmse:2.87962	validation_1-rmse:2.82184
# [10]	validation_0-rmse:2.79407	validation_1-rmse:2.74014
# [11]	validation_0-rmse:2.71917	validation_1-rmse:2.66828
# [12]	validation_0-rmse:2.65769	validation_1-rmse:2.61087
# [13]	validation_0-rmse:2.60488	validation_1-rmse:2.55898
# [14]	validation_0-rmse:2.56127	validation_1-rmse:2.51788
# [15]	validation_0-rmse:2.52406	validation_1-rmse:2.48353
# [16]	validation_0-rmse:2.49245	validation_1-rmse:2.45591
# [17]	validation_0-rmse:2.46549	validation_1-rmse:2.43307
# [18]	validation_0-rmse:2.44209	validation_1-rmse:2.41346
# [19]	validation_0-rmse:2.42226	validation_1-rmse:2.39593
# [20]	validation_0-rmse:2.40533	validation_1-rmse:2.38100
# [21]	validation_0-rmse:2.39016	validation_1-rmse:2.36713
# [22]	validation_0-rmse:2.37641	validation_1-rmse:2.35566
# [23]	validation_0-rmse:2.36657	validation_1-rmse:2.34706
# [24]	validation_0-rmse:2.35751	validation_1-rmse:2.33992
# [25]	validation_0-rmse:2.34967	validation_1-rmse:2.33372
# [26]	validation_0-rmse:2.34149	validation_1-rmse:2.32758
# [27]	validation_0-rmse:2.33508	validation_1-rmse:2.32241
# [28]	validation_0-rmse:2.33056	validation_1-rmse:2.31954
# [29]	validation_0-rmse:2.32612	validation_1-rmse:2.31667
# [30]	validation_0-rmse:2.32183	validation_1-rmse:2.31352
# [31]	validation_0-rmse:2.31855	validation_1-rmse:2.31200
# [32]	validation_0-rmse:2.31404	validation_1-rmse:2.30962
# [33]	validation_0-rmse:2.31112	validation_1-rmse:2.30768
# [34]	validation_0-rmse:2.30849	validation_1-rmse:2.30639
# [35]	validation_0-rmse:2.30639	validation_1-rmse:2.30502
# [36]	validation_0-rmse:2.30356	validation_1-rmse:2.30358
# [37]	validation_0-rmse:2.30215	validation_1-rmse:2.30329
# [38]	validation_0-rmse:2.30058	validation_1-rmse:2.30227
# [39]	validation_0-rmse:2.29814	validation_1-rmse:2.30022
# [40]	validation_0-rmse:2.29642	validation_1-rmse:2.29957
# [41]	validation_0-rmse:2.29425	validation_1-rmse:2.29973
# [42]	validation_0-rmse:2.29292	validation_1-rmse:2.29950
# [43]	validation_0-rmse:2.29171	validation_1-rmse:2.30005
# [44]	validation_0-rmse:2.28841	validation_1-rmse:2.29839
# [45]	validation_0-rmse:2.28743	validation_1-rmse:2.29863
# [46]	validation_0-rmse:2.28613	validation_1-rmse:2.29814
# [47]	validation_0-rmse:2.28504	validation_1-rmse:2.29886
# [48]	validation_0-rmse:2.28395	validation_1-rmse:2.29846
# [49]	validation_0-rmse:2.28191	validation_1-rmse:2.29806
# [50]	validation_0-rmse:2.28128	validation_1-rmse:2.29835
# [51]	validation_0-rmse:2.28035	validation_1-rmse:2.29799
# [52]	validation_0-rmse:2.27791	validation_1-rmse:2.29624
# [53]	validation_0-rmse:2.27594	validation_1-rmse:2.29445
# [54]	validation_0-rmse:2.27503	validation_1-rmse:2.29476
# [55]	validation_0-rmse:2.27303	validation_1-rmse:2.29535
# [56]	validation_0-rmse:2.27158	validation_1-rmse:2.29479
# [57]	validation_0-rmse:2.27109	validation_1-rmse:2.29535
# [58]	validation_0-rmse:2.27030	validation_1-rmse:2.29556
# [0]	validation_0-rmse:4.59509	validation_1-rmse:4.50855
# [1]	validation_0-rmse:4.28842	validation_1-rmse:4.20356
# [2]	validation_0-rmse:4.01614	validation_1-rmse:3.93584
# [3]	validation_0-rmse:3.78127	validation_1-rmse:3.70473
# [4]	validation_0-rmse:3.57316	validation_1-rmse:3.49998
# [5]	validation_0-rmse:3.39510	validation_1-rmse:3.32145
# [6]	validation_0-rmse:3.23732	validation_1-rmse:3.16878
# [7]	validation_0-rmse:3.10130	validation_1-rmse:3.03527
# [8]	validation_0-rmse:2.98463	validation_1-rmse:2.92298
# [9]	validation_0-rmse:2.88618	validation_1-rmse:2.82624
# [10]	validation_0-rmse:2.80816	validation_1-rmse:2.74775
# [11]	validation_0-rmse:2.74130	validation_1-rmse:2.68339
# [12]	validation_0-rmse:2.67809	validation_1-rmse:2.62379
# [13]	validation_0-rmse:2.62788	validation_1-rmse:2.57480
# [14]	validation_0-rmse:2.58709	validation_1-rmse:2.53351
# [15]	validation_0-rmse:2.54630	validation_1-rmse:2.49766
# [16]	validation_0-rmse:2.51445	validation_1-rmse:2.47017
# [17]	validation_0-rmse:2.48459	validation_1-rmse:2.44428
# [18]	validation_0-rmse:2.45815	validation_1-rmse:2.42214
# [19]	validation_0-rmse:2.43875	validation_1-rmse:2.40396
# [20]	validation_0-rmse:2.42089	validation_1-rmse:2.38943
# [21]	validation_0-rmse:2.40590	validation_1-rmse:2.37618
# [22]	validation_0-rmse:2.39236	validation_1-rmse:2.36620
# [23]	validation_0-rmse:2.37964	validation_1-rmse:2.35647
# [24]	validation_0-rmse:2.37107	validation_1-rmse:2.34837
# [25]	validation_0-rmse:2.36306	validation_1-rmse:2.34117
# [26]	validation_0-rmse:2.35517	validation_1-rmse:2.33591
# [27]	validation_0-rmse:2.34723	validation_1-rmse:2.33056
# [28]	validation_0-rmse:2.34133	validation_1-rmse:2.32530
# [29]	validation_0-rmse:2.33587	validation_1-rmse:2.32177
# [30]	validation_0-rmse:2.33073	validation_1-rmse:2.31886
# [31]	validation_0-rmse:2.32656	validation_1-rmse:2.31526
# [32]	validation_0-rmse:2.32271	validation_1-rmse:2.31271
# [33]	validation_0-rmse:2.31721	validation_1-rmse:2.30855
# [34]	validation_0-rmse:2.31442	validation_1-rmse:2.30706
# [35]	validation_0-rmse:2.31220	validation_1-rmse:2.30607
# [36]	validation_0-rmse:2.30958	validation_1-rmse:2.30476
# [37]	validation_0-rmse:2.30637	validation_1-rmse:2.30349
# [38]	validation_0-rmse:2.30382	validation_1-rmse:2.30252
# [39]	validation_0-rmse:2.30194	validation_1-rmse:2.30208
# [40]	validation_0-rmse:2.29979	validation_1-rmse:2.30116
# [41]	validation_0-rmse:2.29803	validation_1-rmse:2.30054
# [42]	validation_0-rmse:2.29662	validation_1-rmse:2.30110
# [43]	validation_0-rmse:2.29514	validation_1-rmse:2.30086
# [44]	validation_0-rmse:2.29317	validation_1-rmse:2.29986
# [45]	validation_0-rmse:2.29107	validation_1-rmse:2.29978
# [46]	validation_0-rmse:2.28927	validation_1-rmse:2.29868
# [47]	validation_0-rmse:2.28791	validation_1-rmse:2.29747
# [48]	validation_0-rmse:2.28590	validation_1-rmse:2.29820
# [49]	validation_0-rmse:2.28461	validation_1-rmse:2.29736
# [50]	validation_0-rmse:2.28358	validation_1-rmse:2.29702
# [51]	validation_0-rmse:2.28256	validation_1-rmse:2.29799
# [52]	validation_0-rmse:2.28153	validation_1-rmse:2.29706
# [53]	validation_0-rmse:2.27994	validation_1-rmse:2.29758
# [54]	validation_0-rmse:2.27937	validation_1-rmse:2.29783
# [0]	validation_0-rmse:4.57931	validation_1-rmse:4.49265
# [1]	validation_0-rmse:4.26224	validation_1-rmse:4.17726
# [2]	validation_0-rmse:3.98272	validation_1-rmse:3.90087
# [3]	validation_0-rmse:3.73705	validation_1-rmse:3.65743
# [4]	validation_0-rmse:3.52524	validation_1-rmse:3.44741
# [5]	validation_0-rmse:3.34179	validation_1-rmse:3.27007
# [6]	validation_0-rmse:3.18354	validation_1-rmse:3.11603
# [7]	validation_0-rmse:3.04844	validation_1-rmse:2.98581
# [8]	validation_0-rmse:2.93132	validation_1-rmse:2.87196
# [9]	validation_0-rmse:2.83252	validation_1-rmse:2.77819
# [10]	validation_0-rmse:2.74860	validation_1-rmse:2.69547
# [11]	validation_0-rmse:2.67816	validation_1-rmse:2.62843
# [12]	validation_0-rmse:2.61635	validation_1-rmse:2.57263
# [13]	validation_0-rmse:2.56595	validation_1-rmse:2.52789
# [14]	validation_0-rmse:2.52338	validation_1-rmse:2.48834
# [15]	validation_0-rmse:2.48458	validation_1-rmse:2.45304
# [16]	validation_0-rmse:2.45419	validation_1-rmse:2.42450
# [17]	validation_0-rmse:2.42441	validation_1-rmse:2.39708
# [18]	validation_0-rmse:2.40146	validation_1-rmse:2.37807
# [19]	validation_0-rmse:2.38400	validation_1-rmse:2.36377
# [20]	validation_0-rmse:2.36806	validation_1-rmse:2.34948
# [21]	validation_0-rmse:2.35466	validation_1-rmse:2.33842
# [22]	validation_0-rmse:2.34305	validation_1-rmse:2.32860
# [23]	validation_0-rmse:2.33420	validation_1-rmse:2.32228
# [24]	validation_0-rmse:2.32626	validation_1-rmse:2.31758
# [25]	validation_0-rmse:2.31937	validation_1-rmse:2.31254
# [26]	validation_0-rmse:2.31286	validation_1-rmse:2.30900
# [27]	validation_0-rmse:2.30884	validation_1-rmse:2.30791
# [28]	validation_0-rmse:2.30518	validation_1-rmse:2.30552
# [29]	validation_0-rmse:2.30136	validation_1-rmse:2.30361
# [30]	validation_0-rmse:2.29821	validation_1-rmse:2.30292
# [31]	validation_0-rmse:2.29518	validation_1-rmse:2.30132
# [32]	validation_0-rmse:2.29242	validation_1-rmse:2.29988
# [33]	validation_0-rmse:2.28999	validation_1-rmse:2.29843
# [34]	validation_0-rmse:2.28810	validation_1-rmse:2.29776
# [35]	validation_0-rmse:2.28668	validation_1-rmse:2.29697
# [36]	validation_0-rmse:2.28486	validation_1-rmse:2.29636
# [37]	validation_0-rmse:2.28485	validation_1-rmse:2.29859
# [38]	validation_0-rmse:2.28434	validation_1-rmse:2.29890
# [39]	validation_0-rmse:2.28301	validation_1-rmse:2.29877
# [40]	validation_0-rmse:2.28152	validation_1-rmse:2.29747
# [0]	validation_0-rmse:4.57574	validation_1-rmse:4.50165
# [1]	validation_0-rmse:4.24204	validation_1-rmse:4.17569
# [2]	validation_0-rmse:3.95256	validation_1-rmse:3.89255
# [3]	validation_0-rmse:3.69864	validation_1-rmse:3.64782
# [4]	validation_0-rmse:3.47838	validation_1-rmse:3.43456
# [5]	validation_0-rmse:3.29025	validation_1-rmse:3.25482
# [6]	validation_0-rmse:3.12921	validation_1-rmse:3.10054
# [7]	validation_0-rmse:2.99069	validation_1-rmse:2.96610
# [8]	validation_0-rmse:2.87022	validation_1-rmse:2.85565
# [9]	validation_0-rmse:2.76988	validation_1-rmse:2.76261
# [10]	validation_0-rmse:2.68641	validation_1-rmse:2.68548
# [11]	validation_0-rmse:2.61431	validation_1-rmse:2.61938
# [12]	validation_0-rmse:2.55353	validation_1-rmse:2.56226
# [13]	validation_0-rmse:2.49946	validation_1-rmse:2.51444
# [14]	validation_0-rmse:2.45572	validation_1-rmse:2.47553
# [15]	validation_0-rmse:2.41618	validation_1-rmse:2.44351
# [16]	validation_0-rmse:2.38473	validation_1-rmse:2.41878
# [17]	validation_0-rmse:2.35637	validation_1-rmse:2.39768
# [18]	validation_0-rmse:2.33093	validation_1-rmse:2.37828
# [19]	validation_0-rmse:2.31002	validation_1-rmse:2.36212
# [20]	validation_0-rmse:2.29179	validation_1-rmse:2.35040
# [21]	validation_0-rmse:2.27685	validation_1-rmse:2.33972
# [22]	validation_0-rmse:2.26379	validation_1-rmse:2.33052
# [23]	validation_0-rmse:2.25241	validation_1-rmse:2.32213
# [24]	validation_0-rmse:2.23719	validation_1-rmse:2.31061
# [25]	validation_0-rmse:2.22625	validation_1-rmse:2.30338
# [26]	validation_0-rmse:2.21718	validation_1-rmse:2.29877
# [27]	validation_0-rmse:2.21116	validation_1-rmse:2.29510
# [28]	validation_0-rmse:2.20379	validation_1-rmse:2.29160
# [29]	validation_0-rmse:2.19675	validation_1-rmse:2.28528
# [30]	validation_0-rmse:2.19175	validation_1-rmse:2.28301
# [31]	validation_0-rmse:2.18572	validation_1-rmse:2.28112
# [32]	validation_0-rmse:2.19068	validation_1-rmse:2.28583
# [33]	validation_0-rmse:2.18448	validation_1-rmse:2.28286
# [34]	validation_0-rmse:2.17704	validation_1-rmse:2.27834
# [35]	validation_0-rmse:2.17278	validation_1-rmse:2.27622
# [36]	validation_0-rmse:2.17793	validation_1-rmse:2.28300
# [37]	validation_0-rmse:2.18353	validation_1-rmse:2.29014
# [38]	validation_0-rmse:2.18021	validation_1-rmse:2.28941
# [39]	validation_0-rmse:2.17761	validation_1-rmse:2.28814
# [0]	validation_0-rmse:4.57325	validation_1-rmse:4.48757
# [1]	validation_0-rmse:4.24538	validation_1-rmse:4.16369
# [2]	validation_0-rmse:3.95954	validation_1-rmse:3.88296
# [3]	validation_0-rmse:3.70781	validation_1-rmse:3.63874
# [4]	validation_0-rmse:3.48929	validation_1-rmse:3.42981
# [5]	validation_0-rmse:3.30553	validation_1-rmse:3.25205
# [6]	validation_0-rmse:3.14394	validation_1-rmse:3.09613
# [7]	validation_0-rmse:3.00422	validation_1-rmse:2.96443
# [8]	validation_0-rmse:2.88631	validation_1-rmse:2.85281
# [9]	validation_0-rmse:2.78831	validation_1-rmse:2.75717
# [10]	validation_0-rmse:2.70343	validation_1-rmse:2.67869
# [11]	validation_0-rmse:2.62844	validation_1-rmse:2.61089
# [12]	validation_0-rmse:2.56417	validation_1-rmse:2.55548
# [13]	validation_0-rmse:2.51176	validation_1-rmse:2.51028
# [14]	validation_0-rmse:2.47019	validation_1-rmse:2.47393
# [15]	validation_0-rmse:2.43107	validation_1-rmse:2.44042
# [16]	validation_0-rmse:2.39789	validation_1-rmse:2.41462
# [17]	validation_0-rmse:2.36896	validation_1-rmse:2.39353
# [18]	validation_0-rmse:2.34631	validation_1-rmse:2.37737
# [19]	validation_0-rmse:2.32377	validation_1-rmse:2.36092
# [20]	validation_0-rmse:2.30559	validation_1-rmse:2.34812
# [21]	validation_0-rmse:2.28980	validation_1-rmse:2.33841
# [22]	validation_0-rmse:2.27772	validation_1-rmse:2.33175
# [23]	validation_0-rmse:2.26655	validation_1-rmse:2.32404
# [24]	validation_0-rmse:2.25473	validation_1-rmse:2.31866
# [25]	validation_0-rmse:2.24593	validation_1-rmse:2.31501
# [26]	validation_0-rmse:2.23605	validation_1-rmse:2.30831
# [27]	validation_0-rmse:2.22652	validation_1-rmse:2.30251
# [28]	validation_0-rmse:2.21697	validation_1-rmse:2.29836
# [29]	validation_0-rmse:2.21170	validation_1-rmse:2.29653
# [30]	validation_0-rmse:2.20398	validation_1-rmse:2.29257
# [31]	validation_0-rmse:2.19687	validation_1-rmse:2.29031
# [32]	validation_0-rmse:2.19391	validation_1-rmse:2.28981
# [33]	validation_0-rmse:2.18890	validation_1-rmse:2.28703
# [34]	validation_0-rmse:2.18174	validation_1-rmse:2.28412
# [35]	validation_0-rmse:2.17705	validation_1-rmse:2.28240
# [36]	validation_0-rmse:2.17262	validation_1-rmse:2.28111
# [37]	validation_0-rmse:2.16771	validation_1-rmse:2.28153
# [38]	validation_0-rmse:2.16465	validation_1-rmse:2.28062
# [39]	validation_0-rmse:2.16157	validation_1-rmse:2.28019
# [40]	validation_0-rmse:2.15720	validation_1-rmse:2.28188
# [41]	validation_0-rmse:2.15385	validation_1-rmse:2.28223
# [42]	validation_0-rmse:2.15054	validation_1-rmse:2.28072
# [43]	validation_0-rmse:2.14746	validation_1-rmse:2.28060
# [44]	validation_0-rmse:2.14489	validation_1-rmse:2.28048
# [0]	validation_0-rmse:4.55558	validation_1-rmse:4.47394
# [1]	validation_0-rmse:4.21429	validation_1-rmse:4.13588
# [2]	validation_0-rmse:3.91834	validation_1-rmse:3.84662
# [3]	validation_0-rmse:3.66433	validation_1-rmse:3.59925
# [4]	validation_0-rmse:3.44129	validation_1-rmse:3.38671
# [5]	validation_0-rmse:3.24166	validation_1-rmse:3.19740
# [6]	validation_0-rmse:3.07429	validation_1-rmse:3.03985
# [7]	validation_0-rmse:2.93082	validation_1-rmse:2.90772
# [8]	validation_0-rmse:2.80443	validation_1-rmse:2.78986
# [9]	validation_0-rmse:2.70203	validation_1-rmse:2.69572
# [10]	validation_0-rmse:2.61353	validation_1-rmse:2.61549
# [11]	validation_0-rmse:2.53667	validation_1-rmse:2.55082
# [12]	validation_0-rmse:2.47412	validation_1-rmse:2.50000
# [13]	validation_0-rmse:2.42168	validation_1-rmse:2.45659
# [14]	validation_0-rmse:2.37724	validation_1-rmse:2.42007
# [15]	validation_0-rmse:2.34020	validation_1-rmse:2.39268
# [16]	validation_0-rmse:2.30934	validation_1-rmse:2.36801
# [17]	validation_0-rmse:2.28332	validation_1-rmse:2.34795
# [18]	validation_0-rmse:2.26174	validation_1-rmse:2.33355
# [19]	validation_0-rmse:2.24263	validation_1-rmse:2.32087
# [20]	validation_0-rmse:2.22750	validation_1-rmse:2.31095
# [21]	validation_0-rmse:2.21337	validation_1-rmse:2.30180
# [22]	validation_0-rmse:2.20226	validation_1-rmse:2.29724
# [23]	validation_0-rmse:2.19265	validation_1-rmse:2.29242
# [24]	validation_0-rmse:2.18441	validation_1-rmse:2.29201
# [25]	validation_0-rmse:2.17593	validation_1-rmse:2.28806
# [26]	validation_0-rmse:2.16780	validation_1-rmse:2.28444
# [27]	validation_0-rmse:2.16054	validation_1-rmse:2.28142
# [28]	validation_0-rmse:2.15408	validation_1-rmse:2.27882
# [29]	validation_0-rmse:2.14856	validation_1-rmse:2.27739
# [30]	validation_0-rmse:2.14401	validation_1-rmse:2.27607
# [31]	validation_0-rmse:2.13890	validation_1-rmse:2.27574
# [32]	validation_0-rmse:2.13374	validation_1-rmse:2.27480
# [33]	validation_0-rmse:2.13291	validation_1-rmse:2.27736
# [34]	validation_0-rmse:2.13016	validation_1-rmse:2.27775
# [35]	validation_0-rmse:2.13033	validation_1-rmse:2.28036
# [36]	validation_0-rmse:2.12705	validation_1-rmse:2.28135
# [37]	validation_0-rmse:2.12298	validation_1-rmse:2.28194
# [0]	validation_0-rmse:4.58105	validation_1-rmse:4.50795
# [1]	validation_0-rmse:4.25857	validation_1-rmse:4.19214
# [2]	validation_0-rmse:3.96948	validation_1-rmse:3.91225
# [3]	validation_0-rmse:3.72766	validation_1-rmse:3.67878
# [4]	validation_0-rmse:3.51759	validation_1-rmse:3.47610
# [5]	validation_0-rmse:3.32978	validation_1-rmse:3.29560
# [6]	validation_0-rmse:3.16245	validation_1-rmse:3.13530
# [7]	validation_0-rmse:3.02277	validation_1-rmse:2.99915
# [8]	validation_0-rmse:2.90089	validation_1-rmse:2.88367
# [9]	validation_0-rmse:2.79789	validation_1-rmse:2.78722
# [10]	validation_0-rmse:2.71134	validation_1-rmse:2.70326
# [11]	validation_0-rmse:2.63703	validation_1-rmse:2.63430
# [12]	validation_0-rmse:2.57447	validation_1-rmse:2.57620
# [13]	validation_0-rmse:2.52109	validation_1-rmse:2.52558
# [14]	validation_0-rmse:2.47420	validation_1-rmse:2.48607
# [15]	validation_0-rmse:2.43507	validation_1-rmse:2.45190
# [16]	validation_0-rmse:2.39914	validation_1-rmse:2.42300
# [17]	validation_0-rmse:2.36980	validation_1-rmse:2.40064
# [18]	validation_0-rmse:2.34707	validation_1-rmse:2.38220
# [19]	validation_0-rmse:2.32599	validation_1-rmse:2.36695
# [20]	validation_0-rmse:2.30726	validation_1-rmse:2.35300
# [21]	validation_0-rmse:2.29260	validation_1-rmse:2.34210
# [22]	validation_0-rmse:2.27767	validation_1-rmse:2.33228
# [23]	validation_0-rmse:2.26657	validation_1-rmse:2.32523
# [24]	validation_0-rmse:2.25906	validation_1-rmse:2.31883
# [25]	validation_0-rmse:2.25095	validation_1-rmse:2.31436
# [26]	validation_0-rmse:2.24129	validation_1-rmse:2.30920
# [27]	validation_0-rmse:2.23370	validation_1-rmse:2.30538
# [28]	validation_0-rmse:2.22727	validation_1-rmse:2.30246
# [29]	validation_0-rmse:2.22014	validation_1-rmse:2.29863
# [30]	validation_0-rmse:2.21927	validation_1-rmse:2.30065
# [31]	validation_0-rmse:2.21314	validation_1-rmse:2.29823
# [32]	validation_0-rmse:2.20772	validation_1-rmse:2.29580
# [33]	validation_0-rmse:2.20177	validation_1-rmse:2.29284
# [34]	validation_0-rmse:2.19521	validation_1-rmse:2.29001
# [35]	validation_0-rmse:2.19126	validation_1-rmse:2.28819
# [36]	validation_0-rmse:2.18763	validation_1-rmse:2.28678
# [37]	validation_0-rmse:2.18570	validation_1-rmse:2.28687
# [38]	validation_0-rmse:2.18089	validation_1-rmse:2.28508
# [39]	validation_0-rmse:2.17601	validation_1-rmse:2.28331
# [40]	validation_0-rmse:2.17081	validation_1-rmse:2.28209
# [41]	validation_0-rmse:2.16779	validation_1-rmse:2.28082
# [42]	validation_0-rmse:2.16484	validation_1-rmse:2.28108
# [43]	validation_0-rmse:2.16311	validation_1-rmse:2.28194
# [44]	validation_0-rmse:2.16140	validation_1-rmse:2.28130
# [45]	validation_0-rmse:2.16023	validation_1-rmse:2.28243
# [0]	validation_0-rmse:4.57849	validation_1-rmse:4.48926
# [1]	validation_0-rmse:4.25619	validation_1-rmse:4.16996
# [2]	validation_0-rmse:3.97019	validation_1-rmse:3.88939
# [3]	validation_0-rmse:3.72439	validation_1-rmse:3.64726
# [4]	validation_0-rmse:3.50942	validation_1-rmse:3.44250
# [5]	validation_0-rmse:3.32705	validation_1-rmse:3.26370
# [6]	validation_0-rmse:3.16622	validation_1-rmse:3.10784
# [7]	validation_0-rmse:3.02843	validation_1-rmse:2.97628
# [8]	validation_0-rmse:2.90751	validation_1-rmse:2.86561
# [9]	validation_0-rmse:2.80757	validation_1-rmse:2.77212
# [10]	validation_0-rmse:2.72063	validation_1-rmse:2.69065
# [11]	validation_0-rmse:2.64533	validation_1-rmse:2.62340
# [12]	validation_0-rmse:2.58348	validation_1-rmse:2.56921
# [13]	validation_0-rmse:2.53509	validation_1-rmse:2.52632
# [14]	validation_0-rmse:2.48738	validation_1-rmse:2.48582
# [15]	validation_0-rmse:2.44972	validation_1-rmse:2.45268
# [16]	validation_0-rmse:2.41628	validation_1-rmse:2.42540
# [17]	validation_0-rmse:2.38680	validation_1-rmse:2.40089
# [18]	validation_0-rmse:2.36165	validation_1-rmse:2.38343
# [19]	validation_0-rmse:2.34063	validation_1-rmse:2.36906
# [20]	validation_0-rmse:2.32167	validation_1-rmse:2.35581
# [21]	validation_0-rmse:2.30561	validation_1-rmse:2.34523
# [22]	validation_0-rmse:2.29163	validation_1-rmse:2.33624
# [23]	validation_0-rmse:2.28001	validation_1-rmse:2.32878
# [24]	validation_0-rmse:2.26880	validation_1-rmse:2.32094
# [25]	validation_0-rmse:2.25789	validation_1-rmse:2.31654
# ...
# [18]	validation_0-rmse:2.13046	validation_1-rmse:2.37748
# [19]	validation_0-rmse:2.10423	validation_1-rmse:2.36834
# [20]	validation_0-rmse:2.08205	validation_1-rmse:2.35949
# [21]	validation_0-rmse:2.06100	validation_1-rmse:2.35146
# [22]	validation_0-rmse:2.04280	validation_1-rmse:2.34574
# [23]	validation_0-rmse:2.02428	validation_1-rmse:2.33847
# [24]	validation_0-rmse:2.00888	validation_1-rmse:2.33589
# [25]	validation_0-rmse:1.99432	validation_1-rmse:2.33085
# [26]	validation_0-rmse:1.98091	validation_1-rmse:2.32708
# [27]	validation_0-rmse:1.96868	validation_1-rmse:2.32456
# [28]	validation_0-rmse:1.95812	validation_1-rmse:2.32221
# [29]	validation_0-rmse:1.94899	validation_1-rmse:2.31913
# [30]	validation_0-rmse:1.93650	validation_1-rmse:2.31565
# [31]	validation_0-rmse:1.92757	validation_1-rmse:2.31227
# [32]	validation_0-rmse:1.91916	validation_1-rmse:2.30968
# [33]	validation_0-rmse:1.91255	validation_1-rmse:2.30939
# [34]	validation_0-rmse:1.90635	validation_1-rmse:2.30787
# [35]	validation_0-rmse:1.89874	validation_1-rmse:2.30575
# [36]	validation_0-rmse:1.89523	validation_1-rmse:2.30672
# [37]	validation_0-rmse:1.88976	validation_1-rmse:2.30554
# [38]	validation_0-rmse:1.88518	validation_1-rmse:2.30452
# [39]	validation_0-rmse:1.88250	validation_1-rmse:2.30535
# [40]	validation_0-rmse:1.87729	validation_1-rmse:2.30438
# [41]	validation_0-rmse:1.87179	validation_1-rmse:2.30420
# [42]	validation_0-rmse:1.86744	validation_1-rmse:2.30454
# [43]	validation_0-rmse:1.86244	validation_1-rmse:2.30524
# [44]	validation_0-rmse:1.85741	validation_1-rmse:2.30576
# [45]	validation_0-rmse:1.85171	validation_1-rmse:2.30393
# [46]	validation_0-rmse:1.84655	validation_1-rmse:2.30502
# [47]	validation_0-rmse:1.84252	validation_1-rmse:2.30501
# [48]	validation_0-rmse:1.83757	validation_1-rmse:2.30391
# [49]	validation_0-rmse:1.83283	validation_1-rmse:2.30328
# [50]	validation_0-rmse:1.82830	validation_1-rmse:2.30303
# [51]	validation_0-rmse:1.82466	validation_1-rmse:2.30288
# [52]	validation_0-rmse:1.82231	validation_1-rmse:2.30456
# [53]	validation_0-rmse:1.81870	validation_1-rmse:2.30301
# [54]	validation_0-rmse:1.81495	validation_1-rmse:2.30294
# [55]	validation_0-rmse:1.81184	validation_1-rmse:2.30240
# [56]	validation_0-rmse:1.80954	validation_1-rmse:2.30213
# [57]	validation_0-rmse:1.80722	validation_1-rmse:2.30433
# [58]	validation_0-rmse:1.80551	validation_1-rmse:2.30458
# [59]	validation_0-rmse:1.80211	validation_1-rmse:2.30348
# [60]	validation_0-rmse:1.79928	validation_1-rmse:2.30640
# [0]	validation_0-rmse:4.54126	validation_1-rmse:4.47132
# [1]	validation_0-rmse:4.18686	validation_1-rmse:4.13710
# [2]	validation_0-rmse:3.86769	validation_1-rmse:3.84022
# [3]	validation_0-rmse:3.59266	validation_1-rmse:3.58224
# [4]	validation_0-rmse:3.35369	validation_1-rmse:3.36371
# [5]	validation_0-rmse:3.14280	validation_1-rmse:3.17837
# [6]	validation_0-rmse:2.96867	validation_1-rmse:3.02541
# [7]	validation_0-rmse:2.81013	validation_1-rmse:2.89000
# [8]	validation_0-rmse:2.67608	validation_1-rmse:2.78264
# [9]	validation_0-rmse:2.55755	validation_1-rmse:2.68955
# [10]	validation_0-rmse:2.45777	validation_1-rmse:2.61728
# [11]	validation_0-rmse:2.37172	validation_1-rmse:2.55737
# [12]	validation_0-rmse:2.29993	validation_1-rmse:2.50687
# [13]	validation_0-rmse:2.23820	validation_1-rmse:2.46967
# [14]	validation_0-rmse:2.18652	validation_1-rmse:2.43907
# [15]	validation_0-rmse:2.14528	validation_1-rmse:2.41841
# [16]	validation_0-rmse:2.10779	validation_1-rmse:2.39723
# [17]	validation_0-rmse:2.07446	validation_1-rmse:2.38167
# [18]	validation_0-rmse:2.04959	validation_1-rmse:2.37199
# [19]	validation_0-rmse:2.02437	validation_1-rmse:2.36362
# [20]	validation_0-rmse:2.00224	validation_1-rmse:2.35620
# [21]	validation_0-rmse:1.98290	validation_1-rmse:2.34893
# [22]	validation_0-rmse:1.96607	validation_1-rmse:2.34472
# [23]	validation_0-rmse:1.95215	validation_1-rmse:2.34044
# [24]	validation_0-rmse:1.93939	validation_1-rmse:2.33936
# [25]	validation_0-rmse:1.92815	validation_1-rmse:2.33892
# [26]	validation_0-rmse:1.92074	validation_1-rmse:2.33865
# [27]	validation_0-rmse:1.91098	validation_1-rmse:2.33880
# [28]	validation_0-rmse:1.90029	validation_1-rmse:2.34164
# [29]	validation_0-rmse:1.89343	validation_1-rmse:2.34330
# [30]	validation_0-rmse:1.88688	validation_1-rmse:2.34577
# [31]	validation_0-rmse:1.87931	validation_1-rmse:2.34639
# [0]	validation_0-rmse:4.58694	validation_1-rmse:4.52859
# [1]	validation_0-rmse:4.25937	validation_1-rmse:4.21870
# [2]	validation_0-rmse:3.98606	validation_1-rmse:3.96277
# [3]	validation_0-rmse:3.73012	validation_1-rmse:3.72266
# [4]	validation_0-rmse:3.51027	validation_1-rmse:3.52233
# [5]	validation_0-rmse:3.31188	validation_1-rmse:3.34748
# [6]	validation_0-rmse:3.13829	validation_1-rmse:3.18937
# [7]	validation_0-rmse:2.98856	validation_1-rmse:3.06070
# [8]	validation_0-rmse:2.86342	validation_1-rmse:2.95424
# [9]	validation_0-rmse:2.74985	validation_1-rmse:2.85697
# [10]	validation_0-rmse:2.65429	validation_1-rmse:2.78651
# [11]	validation_0-rmse:2.56430	validation_1-rmse:2.71365
# [12]	validation_0-rmse:2.49182	validation_1-rmse:2.65594
# [13]	validation_0-rmse:2.42673	validation_1-rmse:2.60764
# [14]	validation_0-rmse:2.37817	validation_1-rmse:2.57264
# [15]	validation_0-rmse:2.32730	validation_1-rmse:2.53705
# [16]	validation_0-rmse:2.28109	validation_1-rmse:2.50518
# [17]	validation_0-rmse:2.24290	validation_1-rmse:2.47909
# [18]	validation_0-rmse:2.20811	validation_1-rmse:2.45665
# [19]	validation_0-rmse:2.17649	validation_1-rmse:2.43997
# [20]	validation_0-rmse:2.15123	validation_1-rmse:2.42470
# [21]	validation_0-rmse:2.12817	validation_1-rmse:2.41193
# [22]	validation_0-rmse:2.10891	validation_1-rmse:2.40034
# [23]	validation_0-rmse:2.09182	validation_1-rmse:2.39185
# [24]	validation_0-rmse:2.08247	validation_1-rmse:2.38887
# [25]	validation_0-rmse:2.06705	validation_1-rmse:2.38029
# [26]	validation_0-rmse:2.05312	validation_1-rmse:2.37417
# [27]	validation_0-rmse:2.04102	validation_1-rmse:2.37056
# [28]	validation_0-rmse:2.03317	validation_1-rmse:2.36729
# [29]	validation_0-rmse:2.02306	validation_1-rmse:2.36270
# [30]	validation_0-rmse:2.01458	validation_1-rmse:2.36068
# [31]	validation_0-rmse:2.00472	validation_1-rmse:2.35715
# [32]	validation_0-rmse:1.99812	validation_1-rmse:2.35431
# [33]	validation_0-rmse:1.99110	validation_1-rmse:2.35204
# [34]	validation_0-rmse:1.98429	validation_1-rmse:2.35031
# [35]	validation_0-rmse:1.97881	validation_1-rmse:2.34894
# [36]	validation_0-rmse:1.97236	validation_1-rmse:2.34712
# [37]	validation_0-rmse:1.96849	validation_1-rmse:2.34499
# [38]	validation_0-rmse:1.96328	validation_1-rmse:2.34381
# [39]	validation_0-rmse:1.95806	validation_1-rmse:2.34158
# [40]	validation_0-rmse:1.95286	validation_1-rmse:2.33888
# [41]	validation_0-rmse:1.94792	validation_1-rmse:2.33614
# [42]	validation_0-rmse:1.94335	validation_1-rmse:2.33507
# [43]	validation_0-rmse:1.93902	validation_1-rmse:2.33475
# [44]	validation_0-rmse:1.93395	validation_1-rmse:2.33363
# [45]	validation_0-rmse:1.92849	validation_1-rmse:2.33187
# [46]	validation_0-rmse:1.92634	validation_1-rmse:2.33253
# [47]	validation_0-rmse:1.92225	validation_1-rmse:2.33385
# [48]	validation_0-rmse:1.92226	validation_1-rmse:2.33538
# [49]	validation_0-rmse:1.91828	validation_1-rmse:2.33526
# [50]	validation_0-rmse:1.91473	validation_1-rmse:2.33540
# [0]	validation_0-rmse:4.57189	validation_1-rmse:4.49666
# [1]	validation_0-rmse:4.24267	validation_1-rmse:4.18843
# [2]	validation_0-rmse:3.95006	validation_1-rmse:3.90602
# [3]	validation_0-rmse:3.70823	validation_1-rmse:3.67555
# [4]	validation_0-rmse:3.48632	validation_1-rmse:3.46450
# [5]	validation_0-rmse:3.29529	validation_1-rmse:3.28560
# [6]	validation_0-rmse:3.12673	validation_1-rmse:3.13519
# [7]	validation_0-rmse:2.98113	validation_1-rmse:3.00127
# [8]	validation_0-rmse:2.85331	validation_1-rmse:2.89002
# [9]	validation_0-rmse:2.73876	validation_1-rmse:2.79197
# [10]	validation_0-rmse:2.64460	validation_1-rmse:2.71007
# [11]	validation_0-rmse:2.56051	validation_1-rmse:2.63919
# [12]	validation_0-rmse:2.48699	validation_1-rmse:2.58597
# [13]	validation_0-rmse:2.42201	validation_1-rmse:2.53990
# [14]	validation_0-rmse:2.36458	validation_1-rmse:2.50402
# [15]	validation_0-rmse:2.31453	validation_1-rmse:2.47188
# [16]	validation_0-rmse:2.27699	validation_1-rmse:2.44735
# [17]	validation_0-rmse:2.23913	validation_1-rmse:2.42262
# [18]	validation_0-rmse:2.20642	validation_1-rmse:2.40571
# [19]	validation_0-rmse:2.17761	validation_1-rmse:2.39201
# [20]	validation_0-rmse:2.15273	validation_1-rmse:2.37767
# [21]	validation_0-rmse:2.13148	validation_1-rmse:2.36948
# [22]	validation_0-rmse:2.10966	validation_1-rmse:2.36144
# [23]	validation_0-rmse:2.09174	validation_1-rmse:2.35246
# [24]	validation_0-rmse:2.07606	validation_1-rmse:2.34420
# [25]	validation_0-rmse:2.06253	validation_1-rmse:2.33818
# [26]	validation_0-rmse:2.05042	validation_1-rmse:2.33405
# [27]	validation_0-rmse:2.03726	validation_1-rmse:2.32715
# [28]	validation_0-rmse:2.02620	validation_1-rmse:2.32432
# [29]	validation_0-rmse:2.01382	validation_1-rmse:2.32039
# [30]	validation_0-rmse:2.00498	validation_1-rmse:2.32009
# [31]	validation_0-rmse:1.99764	validation_1-rmse:2.31961
# [32]	validation_0-rmse:1.99031	validation_1-rmse:2.31967
# [33]	validation_0-rmse:1.98234	validation_1-rmse:2.31687
# [34]	validation_0-rmse:1.97559	validation_1-rmse:2.31551
# [35]	validation_0-rmse:1.96811	validation_1-rmse:2.31429
# [36]	validation_0-rmse:1.96375	validation_1-rmse:2.31397
# [37]	validation_0-rmse:1.95879	validation_1-rmse:2.31360
# [38]	validation_0-rmse:1.95359	validation_1-rmse:2.31280
# [39]	validation_0-rmse:1.94791	validation_1-rmse:2.31113
# [40]	validation_0-rmse:1.94460	validation_1-rmse:2.31045
# [41]	validation_0-rmse:1.94040	validation_1-rmse:2.31012
# [42]	validation_0-rmse:1.93687	validation_1-rmse:2.30976
# [43]	validation_0-rmse:1.93147	validation_1-rmse:2.30858
# [44]	validation_0-rmse:1.92879	validation_1-rmse:2.30834
# [45]	validation_0-rmse:1.92397	validation_1-rmse:2.30845
# [46]	validation_0-rmse:1.91730	validation_1-rmse:2.31000
# [47]	validation_0-rmse:1.91304	validation_1-rmse:2.30974
# [48]	validation_0-rmse:1.90884	validation_1-rmse:2.30915
# [49]	validation_0-rmse:1.90567	validation_1-rmse:2.30849
# [0]	validation_0-rmse:4.55437	validation_1-rmse:4.47893
# [1]	validation_0-rmse:4.21085	validation_1-rmse:4.14239
# [2]	validation_0-rmse:3.90619	validation_1-rmse:3.85055
# [3]	validation_0-rmse:3.64204	validation_1-rmse:3.60527
# [4]	validation_0-rmse:3.40884	validation_1-rmse:3.38824
# [5]	validation_0-rmse:3.20662	validation_1-rmse:3.20485
# [6]	validation_0-rmse:3.02840	validation_1-rmse:3.05742
# [7]	validation_0-rmse:2.87537	validation_1-rmse:2.92763
# [8]	validation_0-rmse:2.74391	validation_1-rmse:2.81536
# [9]	validation_0-rmse:2.63054	validation_1-rmse:2.72386
# [10]	validation_0-rmse:2.52610	validation_1-rmse:2.65329
# [11]	validation_0-rmse:2.43918	validation_1-rmse:2.59070
# [12]	validation_0-rmse:2.36461	validation_1-rmse:2.53675
# [13]	validation_0-rmse:2.29899	validation_1-rmse:2.49302
# [14]	validation_0-rmse:2.24357	validation_1-rmse:2.45427
# [15]	validation_0-rmse:2.19536	validation_1-rmse:2.42632
# [16]	validation_0-rmse:2.15494	validation_1-rmse:2.40321
# [17]	validation_0-rmse:2.11945	validation_1-rmse:2.38660
# [18]	validation_0-rmse:2.08791	validation_1-rmse:2.37269
# [19]	validation_0-rmse:2.06090	validation_1-rmse:2.36129
# [20]	validation_0-rmse:2.03998	validation_1-rmse:2.35944
# [21]	validation_0-rmse:2.02029	validation_1-rmse:2.35896
# [22]	validation_0-rmse:2.00263	validation_1-rmse:2.35258
# [23]	validation_0-rmse:1.98551	validation_1-rmse:2.34941
# [24]	validation_0-rmse:1.97130	validation_1-rmse:2.34740
# [25]	validation_0-rmse:1.95875	validation_1-rmse:2.34402
# [26]	validation_0-rmse:1.94765	validation_1-rmse:2.34317
# [27]	validation_0-rmse:1.93699	validation_1-rmse:2.34076
# [28]	validation_0-rmse:1.93012	validation_1-rmse:2.34231
# [29]	validation_0-rmse:1.92296	validation_1-rmse:2.34072
# [30]	validation_0-rmse:1.91449	validation_1-rmse:2.33922
# [31]	validation_0-rmse:1.90669	validation_1-rmse:2.33797
# [32]	validation_0-rmse:1.90060	validation_1-rmse:2.33937
# [33]	validation_0-rmse:1.89435	validation_1-rmse:2.33926
# [34]	validation_0-rmse:1.88924	validation_1-rmse:2.33742
# [35]	validation_0-rmse:1.88463	validation_1-rmse:2.33647
# [36]	validation_0-rmse:1.87808	validation_1-rmse:2.33482
# [37]	validation_0-rmse:1.87318	validation_1-rmse:2.33371
# [38]	validation_0-rmse:1.86961	validation_1-rmse:2.33286
# [39]	validation_0-rmse:1.86524	validation_1-rmse:2.33172
# [40]	validation_0-rmse:1.86123	validation_1-rmse:2.33208
# [41]	validation_0-rmse:1.85902	validation_1-rmse:2.33233
# [42]	validation_0-rmse:1.85593	validation_1-rmse:2.33276
# [43]	validation_0-rmse:1.85314	validation_1-rmse:2.33297
# [0]	validation_0-rmse:4.58731	validation_1-rmse:4.50191
# [1]	validation_0-rmse:4.27442	validation_1-rmse:4.19245
# [2]	validation_0-rmse:3.99983	validation_1-rmse:3.92280
# [3]	validation_0-rmse:3.76138	validation_1-rmse:3.68848
# [4]	validation_0-rmse:3.55048	validation_1-rmse:3.48043
# [5]	validation_0-rmse:3.36949	validation_1-rmse:3.30225
# [6]	validation_0-rmse:3.21111	validation_1-rmse:3.14475
# [7]	validation_0-rmse:3.07519	validation_1-rmse:3.01097
# [8]	validation_0-rmse:2.95947	validation_1-rmse:2.89717
# [9]	validation_0-rmse:2.85989	validation_1-rmse:2.80292
# [10]	validation_0-rmse:2.77527	validation_1-rmse:2.72174
# [11]	validation_0-rmse:2.70330	validation_1-rmse:2.65330
# [12]	validation_0-rmse:2.64195	validation_1-rmse:2.59564
# [13]	validation_0-rmse:2.59012	validation_1-rmse:2.54740
# [14]	validation_0-rmse:2.54559	validation_1-rmse:2.50690
# [15]	validation_0-rmse:2.50843	validation_1-rmse:2.47359
# [16]	validation_0-rmse:2.47692	validation_1-rmse:2.44565
# [17]	validation_0-rmse:2.44797	validation_1-rmse:2.41869
# [18]	validation_0-rmse:2.42558	validation_1-rmse:2.39921
# [19]	validation_0-rmse:2.40534	validation_1-rmse:2.38232
# [20]	validation_0-rmse:2.38729	validation_1-rmse:2.36565
# [21]	validation_0-rmse:2.37320	validation_1-rmse:2.35469
# [22]	validation_0-rmse:2.36022	validation_1-rmse:2.34338
# [23]	validation_0-rmse:2.34818	validation_1-rmse:2.33306
# [24]	validation_0-rmse:2.33880	validation_1-rmse:2.32561
# [25]	validation_0-rmse:2.33124	validation_1-rmse:2.32095
# [26]	validation_0-rmse:2.32422	validation_1-rmse:2.31491
# [27]	validation_0-rmse:2.31642	validation_1-rmse:2.30930
# [28]	validation_0-rmse:2.31112	validation_1-rmse:2.30529
# [29]	validation_0-rmse:2.30547	validation_1-rmse:2.30119
# [30]	validation_0-rmse:2.30096	validation_1-rmse:2.29896
# [31]	validation_0-rmse:2.29608	validation_1-rmse:2.29527
# [32]	validation_0-rmse:2.29252	validation_1-rmse:2.29265
# [33]	validation_0-rmse:2.28946	validation_1-rmse:2.29067
# [34]	validation_0-rmse:2.28664	validation_1-rmse:2.28978
# [35]	validation_0-rmse:2.28314	validation_1-rmse:2.28738
# [36]	validation_0-rmse:2.28086	validation_1-rmse:2.28693
# [37]	validation_0-rmse:2.27778	validation_1-rmse:2.28633
# [38]	validation_0-rmse:2.27523	validation_1-rmse:2.28563
# [39]	validation_0-rmse:2.27295	validation_1-rmse:2.28495
# [40]	validation_0-rmse:2.27116	validation_1-rmse:2.28475
# [41]	validation_0-rmse:2.26849	validation_1-rmse:2.28357
# [42]	validation_0-rmse:2.26700	validation_1-rmse:2.28312
# [43]	validation_0-rmse:2.26553	validation_1-rmse:2.28312
# [44]	validation_0-rmse:2.26426	validation_1-rmse:2.28288
# [45]	validation_0-rmse:2.26329	validation_1-rmse:2.28300
# [46]	validation_0-rmse:2.26125	validation_1-rmse:2.28240
# [47]	validation_0-rmse:2.25955	validation_1-rmse:2.28111
# [48]	validation_0-rmse:2.25847	validation_1-rmse:2.28123
# [49]	validation_0-rmse:2.25722	validation_1-rmse:2.28115
# [50]	validation_0-rmse:2.25552	validation_1-rmse:2.28018
# [51]	validation_0-rmse:2.25408	validation_1-rmse:2.27959
# [52]	validation_0-rmse:2.25192	validation_1-rmse:2.27851
# [53]	validation_0-rmse:2.25079	validation_1-rmse:2.27874
# [54]	validation_0-rmse:2.24874	validation_1-rmse:2.27887
# [55]	validation_0-rmse:2.24777	validation_1-rmse:2.27899
# [56]	validation_0-rmse:2.24729	validation_1-rmse:2.27886
# [57]	validation_0-rmse:2.24653	validation_1-rmse:2.27909
# Best Hyperparameters:  {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': 'reg:squarederror', 'reg_alpha': 0, 'reg_lambda': 1}
# Best Score:  -5.551894933674876

# %% [markdown]
# **Train an XGboost model**
#
# We will fit all the data in this model using the optimum parameters we found above.

# %%
# Define XGBoost regressor
reg = xgb.XGBRegressor(
    reg_lambda = xgb_grid.best_params_['reg_lambda'],
    reg_alpha = xgb_grid.best_params_['reg_alpha'],
    learning_rate = xgb_grid.best_params_['learning_rate'],
    max_depth = xgb_grid.best_params_['max_depth'],
    n_estimators = 100,
    gamma = xgb_grid.best_params_['gamma'],
    objective = xgb_grid.best_params_['objective'],
    early_stopping_rounds = 5
)

# Train the XGBoost model with feature weights (use validation set on test data)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test,y_test)])
# Out:
# [0]	validation_0-rmse:4.58731	validation_1-rmse:4.50191
# [1]	validation_0-rmse:4.27442	validation_1-rmse:4.19245
# [2]	validation_0-rmse:3.99983	validation_1-rmse:3.92280
# [3]	validation_0-rmse:3.76138	validation_1-rmse:3.68848
# [4]	validation_0-rmse:3.55048	validation_1-rmse:3.48043
# [5]	validation_0-rmse:3.36949	validation_1-rmse:3.30225
# [6]	validation_0-rmse:3.21111	validation_1-rmse:3.14475
# [7]	validation_0-rmse:3.07519	validation_1-rmse:3.01097
# [8]	validation_0-rmse:2.95947	validation_1-rmse:2.89717
# [9]	validation_0-rmse:2.85989	validation_1-rmse:2.80292
# [10]	validation_0-rmse:2.77527	validation_1-rmse:2.72174
# [11]	validation_0-rmse:2.70330	validation_1-rmse:2.65330
# [12]	validation_0-rmse:2.64195	validation_1-rmse:2.59564
# [13]	validation_0-rmse:2.59012	validation_1-rmse:2.54740
# [14]	validation_0-rmse:2.54559	validation_1-rmse:2.50690
# [15]	validation_0-rmse:2.50843	validation_1-rmse:2.47359
# [16]	validation_0-rmse:2.47692	validation_1-rmse:2.44565
# [17]	validation_0-rmse:2.44797	validation_1-rmse:2.41869
# [18]	validation_0-rmse:2.42558	validation_1-rmse:2.39921
# [19]	validation_0-rmse:2.40534	validation_1-rmse:2.38232
# [20]	validation_0-rmse:2.38729	validation_1-rmse:2.36565
# [21]	validation_0-rmse:2.37320	validation_1-rmse:2.35469
# [22]	validation_0-rmse:2.36022	validation_1-rmse:2.34338
# [23]	validation_0-rmse:2.34818	validation_1-rmse:2.33306
# [24]	validation_0-rmse:2.33880	validation_1-rmse:2.32561
# [25]	validation_0-rmse:2.33124	validation_1-rmse:2.32095
# [26]	validation_0-rmse:2.32422	validation_1-rmse:2.31491
# [27]	validation_0-rmse:2.31642	validation_1-rmse:2.30930
# [28]	validation_0-rmse:2.31112	validation_1-rmse:2.30529
# [29]	validation_0-rmse:2.30547	validation_1-rmse:2.30119
# [30]	validation_0-rmse:2.30096	validation_1-rmse:2.29896
# [31]	validation_0-rmse:2.29608	validation_1-rmse:2.29527
# [32]	validation_0-rmse:2.29252	validation_1-rmse:2.29265
# [33]	validation_0-rmse:2.28946	validation_1-rmse:2.29067
# [34]	validation_0-rmse:2.28664	validation_1-rmse:2.28978
# [35]	validation_0-rmse:2.28314	validation_1-rmse:2.28738
# [36]	validation_0-rmse:2.28086	validation_1-rmse:2.28693
# [37]	validation_0-rmse:2.27778	validation_1-rmse:2.28633
# [38]	validation_0-rmse:2.27523	validation_1-rmse:2.28563
# [39]	validation_0-rmse:2.27295	validation_1-rmse:2.28495
# [40]	validation_0-rmse:2.27116	validation_1-rmse:2.28475
# [41]	validation_0-rmse:2.26849	validation_1-rmse:2.28357
# [42]	validation_0-rmse:2.26700	validation_1-rmse:2.28312
# [43]	validation_0-rmse:2.26553	validation_1-rmse:2.28312
# [44]	validation_0-rmse:2.26426	validation_1-rmse:2.28288
# [45]	validation_0-rmse:2.26329	validation_1-rmse:2.28300
# [46]	validation_0-rmse:2.26125	validation_1-rmse:2.28240
# [47]	validation_0-rmse:2.25955	validation_1-rmse:2.28111
# [48]	validation_0-rmse:2.25847	validation_1-rmse:2.28123
# [49]	validation_0-rmse:2.25722	validation_1-rmse:2.28115
# [50]	validation_0-rmse:2.25552	validation_1-rmse:2.28018
# [51]	validation_0-rmse:2.25408	validation_1-rmse:2.27959
# [52]	validation_0-rmse:2.25192	validation_1-rmse:2.27851
# [53]	validation_0-rmse:2.25079	validation_1-rmse:2.27874
# [54]	validation_0-rmse:2.24874	validation_1-rmse:2.27887
# [55]	validation_0-rmse:2.24777	validation_1-rmse:2.27899
# [56]	validation_0-rmse:2.24729	validation_1-rmse:2.27886
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=5,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# Make predictions on the test set

# %%
# Make predictions on the X_test set
y_pred_xgboost = reg.predict(X_test)

# %%
# Calculate the MAE of XGBoost model
mae_xgboost = mean_absolute_error(y_test, y_pred_xgboost)
print("Mae is: ",mae_xgboost)

# Calculate RMSE score of XGBoost model
rmse_xgboost = mean_squared_error(y_test, y_pred_xgboost, squared=False)
print("RMSE score:", rmse_xgboost)
# Out:
# Mae is:  1.353531499500219
# RMSE score: 2.278507319006701

# %% [markdown]
# **Train LSTM for time series forecasting**

# %% [markdown]
# Use the same train and test sets as in the XGBoost model. In order to create more accurate predictions, we scale those two sets before giving them as input to the LSTM Recurrent Neural Network model.

# %%
# Scale the data
scaler = MinMaxScaler()
X_tr = scaler.fit_transform(X_train)
X_te = scaler.fit_transform(X_test)

y_tr = scaler.fit_transform(y_train)
y_te = scaler.fit_transform(y_test)

# %%
# Create 3D train set for LSTM
trainX = []
trainY = []

for i in range(len(X_tr)):
    trainX.append(X_tr[i:i+1,:])

for i in range(len(y_tr)):
    trainY.append(y_tr[i:i+1,:])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# Create 3D test set for LSTM
testX = []
testY = []

for i in range(len(X_te)):
    testX.append(X_te[i:i+1,:])

for i in range(len(y_te)):
    testY.append(y_te[i:i+1,:])

testX, testY = np.array(testX), np.array(testY)

# %% [markdown]
# In the LSTM model, we include dense layers to capture more complex non linear patterns and dropout layers to prevent overfitting.

# %%
# Define LSTM model
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(50, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(25, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(12, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

# Additional Dense layers
model.add(Dense(6, activation='relu'))
model.add(Dense(3, activation='linear'))

# Output layer
model.add(Dense(trainY.shape[1]))

# Add early stopping mechanism
early_stopping = EarlyStopping(patience=5, monitor='val_loss', restore_best_weights=True)
# Out:
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# Compile LSTM model
model.compile(optimizer='adam', loss='mse')

# %%
# Fit model on training data
history = model.fit(trainX, trainY,
          epochs=50,
          batch_size=len(trainX)//100,
          validation_data=(testX,testY),
          callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 10s 33ms/step - loss: 0.0080 - val_loss: 0.0087
# Epoch 2/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 3/50
# 100/100 [==============================] - 5s 54ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 4/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 5/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 6/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 7/50
# 100/100 [==============================] - 3s 30ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 8/50
# 100/100 [==============================] - 4s 42ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 9/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 10/50
# 100/100 [==============================] - 5s 51ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 11/50
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0021 - val_loss: 0.0030
# Epoch 12/50
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 13/50
# 100/100 [==============================] - 5s 51ms/step - loss: 0.0020 - val_loss: 0.0030

# %%
# Evaluate model on test data
loss_lstm = model.evaluate(testX, testY)
print("Test Loss:", loss_lstm)
# Out:
# 435/435 [==============================] - 5s 12ms/step - loss: 0.0028
# Test Loss: 0.0028338092379271984

# %%
# Predict on test data
y_pred_lstm = model.predict(testX)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm.reshape(-1,1))
# Out:
# 435/435 [==============================] - 5s 9ms/step

# %% [markdown]
# Evaluate the LSTM model

# %%
# Calculate the MAE score of LSTM model
mae_lstm = mean_absolute_error(scaler.inverse_transform(testY.reshape(-1,1)),y_pred_lstm)
print("Mae LSTM is: ",mae_lstm)

# Calculate the RMSE score of LSTM model
rmse_lstm = mean_squared_error(scaler.inverse_transform(testY.reshape(-1,1)), y_pred_lstm, squared=False)
print("RMSE LSTM score:", rmse_lstm)
# Out:
# Mae LSTM is:  1.4481338808969628
# RMSE LSTM score: 2.3422753422724343

# %% [markdown]
# Add in the same dataframe the RMSE and MAE scores of each model, in order to compare them

# %%
# Create dataframe with scores (length == 4)
scores = pd.DataFrame(columns=['Model','RMSE Score','MAE Score'])

# Define rows for dataframe
new_row = {'Model': 'XGBoost', 'RMSE Score': rmse_xgboost, 'MAE Score': mae_xgboost}
new_row1 = {'Model': 'LSTM', 'RMSE Score': rmse_lstm, 'MAE Score': mae_lstm}

# Add rows to dataframe
scores = scores.append(new_row, ignore_index=True)
scores = scores.append(new_row1, ignore_index=True)

# %%
scores # length is 4
# Out:
#      Model  RMSE Score  MAE Score
# 0  XGBoost    2.278507   1.353531
# 1     LSTM    2.342275   1.448134

# %%
# Save XGBoost model to a file
reg.save_model('/content/drive/MyDrive/Paper/Models/xgboost_traffic_flow_length-'+str(optimum_lookback)+'.model')

# %%
# Save the model
model.save("/content/drive/MyDrive/Paper/Models/LSTM-length-"+str(optimum_lookback)+".h5")

# %% [markdown]
# ##### Sliding Window Length equals to 5

# %%
optimum_lookback = 5

# %%
# Define train data
train= traffic_flow.loc[traffic_flow['Time Column'] < '2008-05-29']

# Define test data
test = traffic_flow.loc[traffic_flow['Time Column'] >= '2008-05-29']

# %%
# Convert train and test data to supervised problem based in the optimum lookback step we defined above.
train = generate_X_y_pairs(train, optimum_lookback)
test = generate_X_y_pairs(test, optimum_lookback)

# %%
# Add rolling mean information
train['rolling_mean'] = 0
test['rolling_mean'] = 0

# Add rolling var information
train['rolling_var'] = 0
test['rolling_var'] = 0

# Calculate rolling mean of window
train['rolling_mean'] = train.iloc[:,0:2].mean(axis=1)
test['rolling_mean'] = test.iloc[:,0:optimum_lookback].mean(axis=1)

# Calculate rolling variance of window
train['rolling_var'] = train.iloc[:, 0:optimum_lookback].var(axis=1)
test['rolling_var'] = test.iloc[:, 0:optimum_lookback].var(axis=1)

# %%
# Define features
features = train.drop(removable_items,axis=1).columns

# Define labels
labels = ['Record 1(t)']

# Create X_train and y_train data sets
X_train = train[features]
y_train = train[labels]

# Create X_test and y_test data sets
X_test = test[features]
y_test = test[labels]

# %% [markdown]
# **Apply GridSearchCV**
#
# Use a 3-fold K-fold cross-validation was used for learning the optimum hyperparameters for the XGBoost algorithm.

# %%
# Tune hyperparameters using XGboost
xgb_params = {
    "n_estimators": [100],
    "learning_rate": [0.1],
    "max_depth": [3,6,9],
    "objective":['reg:squarederror'],
    "gamma": [0,0.1],
    "reg_lambda": [0,1],
    'reg_alpha': [0, 0.1]
}

# Define GridSearchCV object
xgb_grid = GridSearchCV(xgb.XGBRegressor(),
                        xgb_params,cv=3,
                        scoring= "neg_mean_squared_error")

# Train on train data using 3 fold Cross Validation
xgb_grid.fit(X_train,y_train,
             early_stopping_rounds=5,
             eval_set=[(X_train, y_train), (X_test,y_test)],
             eval_metric='rmse')

# print the best hyperparameters and corresponding score
print("Best Hyperparameters: ", xgb_grid.best_params_)
print("Best Score: ", xgb_grid.best_score_)
# Out:
# [0]	validation_0-rmse:4.59518	validation_1-rmse:4.50377
# [1]	validation_0-rmse:4.28540	validation_1-rmse:4.20081
# [2]	validation_0-rmse:4.01272	validation_1-rmse:3.93353
# [3]	validation_0-rmse:3.77454	validation_1-rmse:3.69556
# [4]	validation_0-rmse:3.56571	validation_1-rmse:3.48832
# [5]	validation_0-rmse:3.38660	validation_1-rmse:3.31076
# [6]	validation_0-rmse:3.23082	validation_1-rmse:3.15995
# [7]	validation_0-rmse:3.09304	validation_1-rmse:3.02666
# [8]	validation_0-rmse:2.97554	validation_1-rmse:2.91240
# [9]	validation_0-rmse:2.87628	validation_1-rmse:2.81539
# [10]	validation_0-rmse:2.79066	validation_1-rmse:2.73475
# [11]	validation_0-rmse:2.71547	validation_1-rmse:2.66176
# [12]	validation_0-rmse:2.65155	validation_1-rmse:2.60089
# [13]	validation_0-rmse:2.59928	validation_1-rmse:2.55183
# [14]	validation_0-rmse:2.55418	validation_1-rmse:2.50979
# [15]	validation_0-rmse:2.51727	validation_1-rmse:2.47568
# [16]	validation_0-rmse:2.48538	validation_1-rmse:2.44769
# [17]	validation_0-rmse:2.45892	validation_1-rmse:2.42503
# [18]	validation_0-rmse:2.43589	validation_1-rmse:2.40511
# [19]	validation_0-rmse:2.41557	validation_1-rmse:2.38814
# [20]	validation_0-rmse:2.39751	validation_1-rmse:2.37191
# [21]	validation_0-rmse:2.38423	validation_1-rmse:2.35994
# [22]	validation_0-rmse:2.37262	validation_1-rmse:2.35094
# [23]	validation_0-rmse:2.36157	validation_1-rmse:2.34253
# [24]	validation_0-rmse:2.35098	validation_1-rmse:2.33343
# [25]	validation_0-rmse:2.34332	validation_1-rmse:2.32740
# [26]	validation_0-rmse:2.33663	validation_1-rmse:2.32222
# [27]	validation_0-rmse:2.32903	validation_1-rmse:2.31716
# [28]	validation_0-rmse:2.32369	validation_1-rmse:2.31293
# [29]	validation_0-rmse:2.31801	validation_1-rmse:2.30924
# [30]	validation_0-rmse:2.31286	validation_1-rmse:2.30626
# [31]	validation_0-rmse:2.30815	validation_1-rmse:2.30298
# [32]	validation_0-rmse:2.30440	validation_1-rmse:2.30041
# [33]	validation_0-rmse:2.30137	validation_1-rmse:2.29900
# [34]	validation_0-rmse:2.29795	validation_1-rmse:2.29729
# [35]	validation_0-rmse:2.29562	validation_1-rmse:2.29502
# [36]	validation_0-rmse:2.29308	validation_1-rmse:2.29419
# [37]	validation_0-rmse:2.29100	validation_1-rmse:2.29315
# [38]	validation_0-rmse:2.28877	validation_1-rmse:2.29212
# [39]	validation_0-rmse:2.28667	validation_1-rmse:2.29150
# [40]	validation_0-rmse:2.28538	validation_1-rmse:2.29123
# [41]	validation_0-rmse:2.28401	validation_1-rmse:2.29124
# [42]	validation_0-rmse:2.28210	validation_1-rmse:2.29231
# [43]	validation_0-rmse:2.27906	validation_1-rmse:2.29109
# [44]	validation_0-rmse:2.27796	validation_1-rmse:2.29065
# [45]	validation_0-rmse:2.27713	validation_1-rmse:2.29086
# [46]	validation_0-rmse:2.27580	validation_1-rmse:2.28984
# [47]	validation_0-rmse:2.27465	validation_1-rmse:2.28975
# [48]	validation_0-rmse:2.27237	validation_1-rmse:2.28760
# [49]	validation_0-rmse:2.27019	validation_1-rmse:2.28730
# [50]	validation_0-rmse:2.26962	validation_1-rmse:2.28716
# [51]	validation_0-rmse:2.26863	validation_1-rmse:2.28732
# [52]	validation_0-rmse:2.26770	validation_1-rmse:2.28683
# [53]	validation_0-rmse:2.26628	validation_1-rmse:2.28613
# [54]	validation_0-rmse:2.26446	validation_1-rmse:2.28779
# [55]	validation_0-rmse:2.26369	validation_1-rmse:2.28804
# [56]	validation_0-rmse:2.26276	validation_1-rmse:2.28789
# [57]	validation_0-rmse:2.26212	validation_1-rmse:2.28752
# [58]	validation_0-rmse:2.26199	validation_1-rmse:2.28753
# [0]	validation_0-rmse:4.59501	validation_1-rmse:4.50055
# [1]	validation_0-rmse:4.28781	validation_1-rmse:4.19708
# [2]	validation_0-rmse:4.01519	validation_1-rmse:3.92919
# [3]	validation_0-rmse:3.77993	validation_1-rmse:3.69450
# [4]	validation_0-rmse:3.57163	validation_1-rmse:3.49040
# [5]	validation_0-rmse:3.39292	validation_1-rmse:3.31445
# [6]	validation_0-rmse:3.24465	validation_1-rmse:3.16608
# [7]	validation_0-rmse:3.10916	validation_1-rmse:3.03371
# [8]	validation_0-rmse:2.99272	validation_1-rmse:2.92041
# [9]	validation_0-rmse:2.90063	validation_1-rmse:2.82886
# [10]	validation_0-rmse:2.82020	validation_1-rmse:2.74875
# [11]	validation_0-rmse:2.74537	validation_1-rmse:2.67648
# [12]	validation_0-rmse:2.68112	validation_1-rmse:2.61635
# [13]	validation_0-rmse:2.63164	validation_1-rmse:2.56725
# [14]	validation_0-rmse:2.58531	validation_1-rmse:2.52576
# [15]	validation_0-rmse:2.54454	validation_1-rmse:2.48989
# [16]	validation_0-rmse:2.50877	validation_1-rmse:2.45928
# [17]	validation_0-rmse:2.47979	validation_1-rmse:2.43581
# [18]	validation_0-rmse:2.45355	validation_1-rmse:2.41030
# [19]	validation_0-rmse:2.43178	validation_1-rmse:2.39147
# [20]	validation_0-rmse:2.41570	validation_1-rmse:2.37624
# [21]	validation_0-rmse:2.40045	validation_1-rmse:2.36233
# [22]	validation_0-rmse:2.38680	validation_1-rmse:2.35258
# [23]	validation_0-rmse:2.37549	validation_1-rmse:2.34199
# [24]	validation_0-rmse:2.36352	validation_1-rmse:2.33147
# [25]	validation_0-rmse:2.35381	validation_1-rmse:2.32451
# [26]	validation_0-rmse:2.34933	validation_1-rmse:2.32083
# [27]	validation_0-rmse:2.34248	validation_1-rmse:2.31564
# [28]	validation_0-rmse:2.33664	validation_1-rmse:2.31014
# [29]	validation_0-rmse:2.33054	validation_1-rmse:2.30519
# [30]	validation_0-rmse:2.32567	validation_1-rmse:2.30165
# [31]	validation_0-rmse:2.32216	validation_1-rmse:2.29935
# [32]	validation_0-rmse:2.31751	validation_1-rmse:2.29566
# [33]	validation_0-rmse:2.31323	validation_1-rmse:2.29361
# [34]	validation_0-rmse:2.31012	validation_1-rmse:2.29216
# [35]	validation_0-rmse:2.30577	validation_1-rmse:2.28841
# [36]	validation_0-rmse:2.30269	validation_1-rmse:2.28736
# [37]	validation_0-rmse:2.29908	validation_1-rmse:2.28602
# [38]	validation_0-rmse:2.29707	validation_1-rmse:2.28558
# [39]	validation_0-rmse:2.29337	validation_1-rmse:2.28434
# [40]	validation_0-rmse:2.29029	validation_1-rmse:2.28367
# [41]	validation_0-rmse:2.28838	validation_1-rmse:2.28371
# [42]	validation_0-rmse:2.28646	validation_1-rmse:2.28361
# [43]	validation_0-rmse:2.28462	validation_1-rmse:2.28452
# [44]	validation_0-rmse:2.28392	validation_1-rmse:2.28426
# [45]	validation_0-rmse:2.28104	validation_1-rmse:2.28223
# [46]	validation_0-rmse:2.27961	validation_1-rmse:2.28233
# [47]	validation_0-rmse:2.27831	validation_1-rmse:2.28179
# [48]	validation_0-rmse:2.27578	validation_1-rmse:2.28001
# [49]	validation_0-rmse:2.27436	validation_1-rmse:2.28016
# [50]	validation_0-rmse:2.27315	validation_1-rmse:2.28086
# [51]	validation_0-rmse:2.27162	validation_1-rmse:2.27963
# [52]	validation_0-rmse:2.27010	validation_1-rmse:2.28071
# [53]	validation_0-rmse:2.26906	validation_1-rmse:2.28080
# [54]	validation_0-rmse:2.26686	validation_1-rmse:2.27941
# [55]	validation_0-rmse:2.26558	validation_1-rmse:2.28047
# [56]	validation_0-rmse:2.26517	validation_1-rmse:2.28158
# [57]	validation_0-rmse:2.26496	validation_1-rmse:2.28132
# [58]	validation_0-rmse:2.26320	validation_1-rmse:2.28010
# [59]	validation_0-rmse:2.26203	validation_1-rmse:2.27976
# [0]	validation_0-rmse:4.57980	validation_1-rmse:4.48805
# [1]	validation_0-rmse:4.26230	validation_1-rmse:4.17282
# [2]	validation_0-rmse:3.98111	validation_1-rmse:3.90004
# [3]	validation_0-rmse:3.73615	validation_1-rmse:3.65970
# [4]	validation_0-rmse:3.52496	validation_1-rmse:3.45174
# [5]	validation_0-rmse:3.34095	validation_1-rmse:3.27398
# [6]	validation_0-rmse:3.18136	validation_1-rmse:3.11878
# [7]	validation_0-rmse:3.04579	validation_1-rmse:2.98760
# [8]	validation_0-rmse:2.92993	validation_1-rmse:2.87719
# [9]	validation_0-rmse:2.82987	validation_1-rmse:2.77932
# [10]	validation_0-rmse:2.74606	validation_1-rmse:2.69884
# [11]	validation_0-rmse:2.67506	validation_1-rmse:2.63263
# [12]	validation_0-rmse:2.61528	validation_1-rmse:2.57596
# [13]	validation_0-rmse:2.56446	validation_1-rmse:2.52798
# [14]	validation_0-rmse:2.52158	validation_1-rmse:2.48843
# [15]	validation_0-rmse:2.48509	validation_1-rmse:2.45423
# [16]	validation_0-rmse:2.45497	validation_1-rmse:2.42614
# [17]	validation_0-rmse:2.42668	validation_1-rmse:2.40114
# [18]	validation_0-rmse:2.40526	validation_1-rmse:2.38191
# [19]	validation_0-rmse:2.38649	validation_1-rmse:2.36490
# [20]	validation_0-rmse:2.37078	validation_1-rmse:2.35158
# [21]	validation_0-rmse:2.35556	validation_1-rmse:2.33860
# [22]	validation_0-rmse:2.34390	validation_1-rmse:2.32894
# [23]	validation_0-rmse:2.33402	validation_1-rmse:2.32067
# [24]	validation_0-rmse:2.32453	validation_1-rmse:2.31371
# [25]	validation_0-rmse:2.31783	validation_1-rmse:2.31029
# [26]	validation_0-rmse:2.31106	validation_1-rmse:2.30443
# [27]	validation_0-rmse:2.30525	validation_1-rmse:2.30061
# [28]	validation_0-rmse:2.30097	validation_1-rmse:2.29799
# [29]	validation_0-rmse:2.29680	validation_1-rmse:2.29587
# [30]	validation_0-rmse:2.29298	validation_1-rmse:2.29411
# [31]	validation_0-rmse:2.28946	validation_1-rmse:2.29207
# [32]	validation_0-rmse:2.28705	validation_1-rmse:2.29046
# [33]	validation_0-rmse:2.28480	validation_1-rmse:2.29077
# [34]	validation_0-rmse:2.28178	validation_1-rmse:2.28835
# [35]	validation_0-rmse:2.27962	validation_1-rmse:2.28684
# [36]	validation_0-rmse:2.27843	validation_1-rmse:2.28672
# [37]	validation_0-rmse:2.27635	validation_1-rmse:2.28720
# [38]	validation_0-rmse:2.27472	validation_1-rmse:2.28694
# [39]	validation_0-rmse:2.27248	validation_1-rmse:2.28583
# [40]	validation_0-rmse:2.27105	validation_1-rmse:2.28548
# [41]	validation_0-rmse:2.26913	validation_1-rmse:2.28551
# [42]	validation_0-rmse:2.26796	validation_1-rmse:2.28571
# [43]	validation_0-rmse:2.26641	validation_1-rmse:2.28497
# [44]	validation_0-rmse:2.26453	validation_1-rmse:2.28472
# [45]	validation_0-rmse:2.26192	validation_1-rmse:2.28277
# [46]	validation_0-rmse:2.26106	validation_1-rmse:2.28294
# [47]	validation_0-rmse:2.26027	validation_1-rmse:2.28344
# [48]	validation_0-rmse:2.25933	validation_1-rmse:2.28345
# [49]	validation_0-rmse:2.25800	validation_1-rmse:2.28255
# [50]	validation_0-rmse:2.25783	validation_1-rmse:2.28308
# [51]	validation_0-rmse:2.25597	validation_1-rmse:2.28374
# [52]	validation_0-rmse:2.25505	validation_1-rmse:2.28380
# [53]	validation_0-rmse:2.25395	validation_1-rmse:2.28383
# [54]	validation_0-rmse:2.25303	validation_1-rmse:2.28356
# [0]	validation_0-rmse:4.59567	validation_1-rmse:4.50421
# [1]	validation_0-rmse:4.28632	validation_1-rmse:4.20161
# [2]	validation_0-rmse:4.01402	validation_1-rmse:3.93464
# [3]	validation_0-rmse:3.77597	validation_1-rmse:3.69677
# [4]	validation_0-rmse:3.56746	validation_1-rmse:3.48979
# [5]	validation_0-rmse:3.38842	validation_1-rmse:3.31228
# [6]	validation_0-rmse:3.23265	validation_1-rmse:3.16146
# [7]	validation_0-rmse:3.09506	validation_1-rmse:3.02819
# [8]	validation_0-rmse:2.97761	validation_1-rmse:2.91396
# [9]	validation_0-rmse:2.87829	validation_1-rmse:2.81687
# [10]	validation_0-rmse:2.79259	validation_1-rmse:2.73539
# [11]	validation_0-rmse:2.71736	validation_1-rmse:2.66232
# [12]	validation_0-rmse:2.65317	validation_1-rmse:2.60050
# [13]	validation_0-rmse:2.60080	validation_1-rmse:2.55212
# [14]	validation_0-rmse:2.55577	validation_1-rmse:2.51016
# [15]	validation_0-rmse:2.51900	validation_1-rmse:2.47740
# [16]	validation_0-rmse:2.48754	validation_1-rmse:2.44977
# [17]	validation_0-rmse:2.46060	validation_1-rmse:2.42590
# [18]	validation_0-rmse:2.43811	validation_1-rmse:2.40625
# [19]	validation_0-rmse:2.41749	validation_1-rmse:2.38860
# [20]	validation_0-rmse:2.40034	validation_1-rmse:2.37425
# [21]	validation_0-rmse:2.38450	validation_1-rmse:2.36065
# [22]	validation_0-rmse:2.37291	validation_1-rmse:2.35128
# [23]	validation_0-rmse:2.36108	validation_1-rmse:2.34119
# [24]	validation_0-rmse:2.35097	validation_1-rmse:2.33255
# [25]	validation_0-rmse:2.34266	validation_1-rmse:2.32583
# [26]	validation_0-rmse:2.33552	validation_1-rmse:2.32097
# [27]	validation_0-rmse:2.32814	validation_1-rmse:2.31588
# [28]	validation_0-rmse:2.32309	validation_1-rmse:2.31214
# [29]	validation_0-rmse:2.31624	validation_1-rmse:2.30734
# [30]	validation_0-rmse:2.31142	validation_1-rmse:2.30413
# [31]	validation_0-rmse:2.30844	validation_1-rmse:2.30227
# [32]	validation_0-rmse:2.30453	validation_1-rmse:2.29998
# [33]	validation_0-rmse:2.30148	validation_1-rmse:2.29824
# [34]	validation_0-rmse:2.29795	validation_1-rmse:2.29662
# [35]	validation_0-rmse:2.29500	validation_1-rmse:2.29494
# [36]	validation_0-rmse:2.29288	validation_1-rmse:2.29394
# [37]	validation_0-rmse:2.29102	validation_1-rmse:2.29333
# [38]	validation_0-rmse:2.28901	validation_1-rmse:2.29284
# [39]	validation_0-rmse:2.28663	validation_1-rmse:2.29164
# [40]	validation_0-rmse:2.28460	validation_1-rmse:2.29174
# [41]	validation_0-rmse:2.28316	validation_1-rmse:2.29091
# [42]	validation_0-rmse:2.28196	validation_1-rmse:2.28985
# [43]	validation_0-rmse:2.28079	validation_1-rmse:2.28976
# [44]	validation_0-rmse:2.27996	validation_1-rmse:2.28948
# [45]	validation_0-rmse:2.27901	validation_1-rmse:2.28947
# [46]	validation_0-rmse:2.27805	validation_1-rmse:2.28924
# [47]	validation_0-rmse:2.27638	validation_1-rmse:2.28995
# [48]	validation_0-rmse:2.27484	validation_1-rmse:2.28930
# [49]	validation_0-rmse:2.27449	validation_1-rmse:2.28915
# [50]	validation_0-rmse:2.27390	validation_1-rmse:2.28924
# [51]	validation_0-rmse:2.27330	validation_1-rmse:2.28924
# [52]	validation_0-rmse:2.27215	validation_1-rmse:2.28878
# [53]	validation_0-rmse:2.27122	validation_1-rmse:2.28807
# [54]	validation_0-rmse:2.26922	validation_1-rmse:2.28883
# [55]	validation_0-rmse:2.26726	validation_1-rmse:2.28691
# [56]	validation_0-rmse:2.26550	validation_1-rmse:2.28586
# [57]	validation_0-rmse:2.26509	validation_1-rmse:2.28585
# [58]	validation_0-rmse:2.26471	validation_1-rmse:2.28585
# [59]	validation_0-rmse:2.26439	validation_1-rmse:2.28584
# [60]	validation_0-rmse:2.26312	validation_1-rmse:2.28524
# [61]	validation_0-rmse:2.26251	validation_1-rmse:2.28487
# [62]	validation_0-rmse:2.26090	validation_1-rmse:2.28528
# [63]	validation_0-rmse:2.26065	validation_1-rmse:2.28528
# [64]	validation_0-rmse:2.26026	validation_1-rmse:2.28510
# [65]	validation_0-rmse:2.25902	validation_1-rmse:2.28414
# [66]	validation_0-rmse:2.25833	validation_1-rmse:2.28418
# [67]	validation_0-rmse:2.25702	validation_1-rmse:2.28406
# [68]	validation_0-rmse:2.25671	validation_1-rmse:2.28432
# [69]	validation_0-rmse:2.25625	validation_1-rmse:2.28452
# [70]	validation_0-rmse:2.25606	validation_1-rmse:2.28452
# [71]	validation_0-rmse:2.25572	validation_1-rmse:2.28485
# [0]	validation_0-rmse:4.59561	validation_1-rmse:4.50108
# [1]	validation_0-rmse:4.28876	validation_1-rmse:4.19790
# [2]	validation_0-rmse:4.01665	validation_1-rmse:3.93043
# [3]	validation_0-rmse:3.78158	validation_1-rmse:3.69589
# [4]	validation_0-rmse:3.57362	validation_1-rmse:3.49205
# [5]	validation_0-rmse:3.39524	validation_1-rmse:3.31659
# [6]	validation_0-rmse:3.24695	validation_1-rmse:3.16826
# [7]	validation_0-rmse:3.11191	validation_1-rmse:3.03693
# [8]	validation_0-rmse:2.99585	validation_1-rmse:2.92352
# [9]	validation_0-rmse:2.90375	validation_1-rmse:2.83202
# [10]	validation_0-rmse:2.82347	validation_1-rmse:2.75203
# [11]	validation_0-rmse:2.74868	validation_1-rmse:2.67978
# [12]	validation_0-rmse:2.68472	validation_1-rmse:2.61987
# [13]	validation_0-rmse:2.63525	validation_1-rmse:2.57078
# [14]	validation_0-rmse:2.58806	validation_1-rmse:2.52775
# [15]	validation_0-rmse:2.54658	validation_1-rmse:2.49161
# [16]	validation_0-rmse:2.51087	validation_1-rmse:2.46118
# [17]	validation_0-rmse:2.48273	validation_1-rmse:2.43530
# [18]	validation_0-rmse:2.45757	validation_1-rmse:2.41302
# [19]	validation_0-rmse:2.43518	validation_1-rmse:2.39232
# [20]	validation_0-rmse:2.41930	validation_1-rmse:2.37762
# [21]	validation_0-rmse:2.40337	validation_1-rmse:2.36563
# [22]	validation_0-rmse:2.38871	validation_1-rmse:2.35495
# [23]	validation_0-rmse:2.37820	validation_1-rmse:2.34583
# [24]	validation_0-rmse:2.36587	validation_1-rmse:2.33484
# [25]	validation_0-rmse:2.35695	validation_1-rmse:2.32806
# [26]	validation_0-rmse:2.34848	validation_1-rmse:2.32255
# [27]	validation_0-rmse:2.34157	validation_1-rmse:2.31724
# [28]	validation_0-rmse:2.33575	validation_1-rmse:2.31174
# [29]	validation_0-rmse:2.32794	validation_1-rmse:2.30735
# [30]	validation_0-rmse:2.32329	validation_1-rmse:2.30346
# [31]	validation_0-rmse:2.31963	validation_1-rmse:2.30067
# [32]	validation_0-rmse:2.31548	validation_1-rmse:2.29764
# [33]	validation_0-rmse:2.31240	validation_1-rmse:2.29607
# [34]	validation_0-rmse:2.30975	validation_1-rmse:2.29448
# [35]	validation_0-rmse:2.30634	validation_1-rmse:2.29296
# [36]	validation_0-rmse:2.30335	validation_1-rmse:2.29148
# [37]	validation_0-rmse:2.30007	validation_1-rmse:2.29016
# [38]	validation_0-rmse:2.29804	validation_1-rmse:2.28847
# [39]	validation_0-rmse:2.29529	validation_1-rmse:2.28791
# [40]	validation_0-rmse:2.29291	validation_1-rmse:2.28711
# [41]	validation_0-rmse:2.29168	validation_1-rmse:2.28710
# [42]	validation_0-rmse:2.28962	validation_1-rmse:2.28531
# [43]	validation_0-rmse:2.28761	validation_1-rmse:2.28537
# [44]	validation_0-rmse:2.28521	validation_1-rmse:2.28406
# [45]	validation_0-rmse:2.28358	validation_1-rmse:2.28465
# [46]	validation_0-rmse:2.28208	validation_1-rmse:2.28496
# [47]	validation_0-rmse:2.27999	validation_1-rmse:2.28387
# [48]	validation_0-rmse:2.27954	validation_1-rmse:2.28396
# [49]	validation_0-rmse:2.27831	validation_1-rmse:2.28417
# [50]	validation_0-rmse:2.27652	validation_1-rmse:2.28505
# [51]	validation_0-rmse:2.27392	validation_1-rmse:2.28338
# [52]	validation_0-rmse:2.27341	validation_1-rmse:2.28447
# [53]	validation_0-rmse:2.27132	validation_1-rmse:2.28457
# [54]	validation_0-rmse:2.27048	validation_1-rmse:2.28470
# [55]	validation_0-rmse:2.27018	validation_1-rmse:2.28426
# [56]	validation_0-rmse:2.26855	validation_1-rmse:2.28526
# [0]	validation_0-rmse:4.57992	validation_1-rmse:4.48618
# [1]	validation_0-rmse:4.26308	validation_1-rmse:4.17074
# [2]	validation_0-rmse:3.98337	validation_1-rmse:3.89639
# [3]	validation_0-rmse:3.73791	validation_1-rmse:3.65755
# [4]	validation_0-rmse:3.52636	validation_1-rmse:3.44830
# [5]	validation_0-rmse:3.34205	validation_1-rmse:3.27009
# [6]	validation_0-rmse:3.18274	validation_1-rmse:3.11540
# [7]	validation_0-rmse:3.04554	validation_1-rmse:2.98015
# [8]	validation_0-rmse:2.93049	validation_1-rmse:2.86992
# [9]	validation_0-rmse:2.83205	validation_1-rmse:2.77611
# [10]	validation_0-rmse:2.74843	validation_1-rmse:2.69611
# [11]	validation_0-rmse:2.67768	validation_1-rmse:2.62982
# [12]	validation_0-rmse:2.61711	validation_1-rmse:2.57328
# [13]	validation_0-rmse:2.56686	validation_1-rmse:2.52720
# [14]	validation_0-rmse:2.52330	validation_1-rmse:2.48696
# [15]	validation_0-rmse:2.48724	validation_1-rmse:2.45405
# [16]	validation_0-rmse:2.45481	validation_1-rmse:2.42453
# [17]	validation_0-rmse:2.42968	validation_1-rmse:2.40185
# [18]	validation_0-rmse:2.40635	validation_1-rmse:2.38018
# [19]	validation_0-rmse:2.38750	validation_1-rmse:2.36427
# [20]	validation_0-rmse:2.37032	validation_1-rmse:2.34920
# [21]	validation_0-rmse:2.35524	validation_1-rmse:2.33754
# [22]	validation_0-rmse:2.34382	validation_1-rmse:2.32724
# [23]	validation_0-rmse:2.33340	validation_1-rmse:2.31854
# [24]	validation_0-rmse:2.32520	validation_1-rmse:2.31199
# [25]	validation_0-rmse:2.31840	validation_1-rmse:2.30714
# [26]	validation_0-rmse:2.31239	validation_1-rmse:2.30338
# [27]	validation_0-rmse:2.30733	validation_1-rmse:2.30114
# [28]	validation_0-rmse:2.30337	validation_1-rmse:2.29919
# [29]	validation_0-rmse:2.29952	validation_1-rmse:2.29691
# [30]	validation_0-rmse:2.29585	validation_1-rmse:2.29472
# [31]	validation_0-rmse:2.29245	validation_1-rmse:2.29250
# [32]	validation_0-rmse:2.28980	validation_1-rmse:2.29191
# [33]	validation_0-rmse:2.28685	validation_1-rmse:2.29057
# [34]	validation_0-rmse:2.28523	validation_1-rmse:2.29007
# [35]	validation_0-rmse:2.28405	validation_1-rmse:2.29006
# [36]	validation_0-rmse:2.28183	validation_1-rmse:2.28947
# [37]	validation_0-rmse:2.28028	validation_1-rmse:2.28876
# [38]	validation_0-rmse:2.27796	validation_1-rmse:2.28678
# [39]	validation_0-rmse:2.27632	validation_1-rmse:2.28682
# [40]	validation_0-rmse:2.27519	validation_1-rmse:2.28717
# [41]	validation_0-rmse:2.27245	validation_1-rmse:2.28524
# [42]	validation_0-rmse:2.27085	validation_1-rmse:2.28550
# [43]	validation_0-rmse:2.26976	validation_1-rmse:2.28559
# [44]	validation_0-rmse:2.26845	validation_1-rmse:2.28499
# [45]	validation_0-rmse:2.26671	validation_1-rmse:2.28446
# [46]	validation_0-rmse:2.26593	validation_1-rmse:2.28428
# [47]	validation_0-rmse:2.26419	validation_1-rmse:2.28263
# [48]	validation_0-rmse:2.26273	validation_1-rmse:2.28264
# [49]	validation_0-rmse:2.26144	validation_1-rmse:2.28256
# [50]	validation_0-rmse:2.26040	validation_1-rmse:2.28308
# [51]	validation_0-rmse:2.25843	validation_1-rmse:2.28201
# [52]	validation_0-rmse:2.25760	validation_1-rmse:2.28197
# [53]	validation_0-rmse:2.25572	validation_1-rmse:2.28116
# [54]	validation_0-rmse:2.25475	validation_1-rmse:2.28164
# [55]	validation_0-rmse:2.25396	validation_1-rmse:2.28146
# [56]	validation_0-rmse:2.25189	validation_1-rmse:2.27934
# [57]	validation_0-rmse:2.25062	validation_1-rmse:2.27881
# [58]	validation_0-rmse:2.24969	validation_1-rmse:2.27850
# [59]	validation_0-rmse:2.24910	validation_1-rmse:2.27877
# [60]	validation_0-rmse:2.24507	validation_1-rmse:2.27552
# [61]	validation_0-rmse:2.24383	validation_1-rmse:2.27437
# [62]	validation_0-rmse:2.24259	validation_1-rmse:2.27359
# [63]	validation_0-rmse:2.24048	validation_1-rmse:2.27391
# [64]	validation_0-rmse:2.23993	validation_1-rmse:2.27382
# [65]	validation_0-rmse:2.23885	validation_1-rmse:2.27323
# [66]	validation_0-rmse:2.23801	validation_1-rmse:2.27286
# [67]	validation_0-rmse:2.23577	validation_1-rmse:2.27029
# [68]	validation_0-rmse:2.23467	validation_1-rmse:2.26966
# [69]	validation_0-rmse:2.23409	validation_1-rmse:2.26977
# [70]	validation_0-rmse:2.23334	validation_1-rmse:2.26959
# [71]	validation_0-rmse:2.23285	validation_1-rmse:2.26975
# [72]	validation_0-rmse:2.23232	validation_1-rmse:2.26973
# [73]	validation_0-rmse:2.23133	validation_1-rmse:2.27019
# [74]	validation_0-rmse:2.22915	validation_1-rmse:2.26815
# [75]	validation_0-rmse:2.22857	validation_1-rmse:2.26763
# [76]	validation_0-rmse:2.22791	validation_1-rmse:2.26734
# [77]	validation_0-rmse:2.22746	validation_1-rmse:2.26767
# [78]	validation_0-rmse:2.22683	validation_1-rmse:2.26766
# [79]	validation_0-rmse:2.22573	validation_1-rmse:2.26667
# [80]	validation_0-rmse:2.22537	validation_1-rmse:2.26681
# [81]	validation_0-rmse:2.22496	validation_1-rmse:2.26670
# [82]	validation_0-rmse:2.22410	validation_1-rmse:2.26610
# [83]	validation_0-rmse:2.22338	validation_1-rmse:2.26592
# [84]	validation_0-rmse:2.22280	validation_1-rmse:2.26580
# [85]	validation_0-rmse:2.22235	validation_1-rmse:2.26566
# [86]	validation_0-rmse:2.22158	validation_1-rmse:2.26525
# [87]	validation_0-rmse:2.21985	validation_1-rmse:2.26428
# [88]	validation_0-rmse:2.21892	validation_1-rmse:2.26484
# [89]	validation_0-rmse:2.21818	validation_1-rmse:2.26439
# [90]	validation_0-rmse:2.21760	validation_1-rmse:2.26452
# [91]	validation_0-rmse:2.21688	validation_1-rmse:2.26468
# [0]	validation_0-rmse:4.59519	validation_1-rmse:4.50378
# [1]	validation_0-rmse:4.28540	validation_1-rmse:4.20081
# [2]	validation_0-rmse:4.01273	validation_1-rmse:3.93354
# [3]	validation_0-rmse:3.77455	validation_1-rmse:3.69557
# [4]	validation_0-rmse:3.56573	validation_1-rmse:3.48833
# [5]	validation_0-rmse:3.38662	validation_1-rmse:3.31077
# [6]	validation_0-rmse:3.23083	validation_1-rmse:3.15997
# [7]	validation_0-rmse:3.09306	validation_1-rmse:3.02667
# [8]	validation_0-rmse:2.97556	validation_1-rmse:2.91242
# [9]	validation_0-rmse:2.87630	validation_1-rmse:2.81540
# [10]	validation_0-rmse:2.79068	validation_1-rmse:2.73477
# [11]	validation_0-rmse:2.71549	validation_1-rmse:2.66178
# [12]	validation_0-rmse:2.65157	validation_1-rmse:2.60090
# [13]	validation_0-rmse:2.59930	validation_1-rmse:2.55184
# [14]	validation_0-rmse:2.55420	validation_1-rmse:2.50981
# [15]	validation_0-rmse:2.51728	validation_1-rmse:2.47570
# [16]	validation_0-rmse:2.48540	validation_1-rmse:2.44770
# [17]	validation_0-rmse:2.45894	validation_1-rmse:2.42504
# [18]	validation_0-rmse:2.43591	validation_1-rmse:2.40512
# [19]	validation_0-rmse:2.41559	validation_1-rmse:2.38815
# [20]	validation_0-rmse:2.39753	validation_1-rmse:2.37192
# [21]	validation_0-rmse:2.38424	validation_1-rmse:2.35994
# [22]	validation_0-rmse:2.37264	validation_1-rmse:2.35095
# [23]	validation_0-rmse:2.36159	validation_1-rmse:2.34253
# [24]	validation_0-rmse:2.35100	validation_1-rmse:2.33343
# [25]	validation_0-rmse:2.34334	validation_1-rmse:2.32740
# [26]	validation_0-rmse:2.33665	validation_1-rmse:2.32223
# [27]	validation_0-rmse:2.32904	validation_1-rmse:2.31716
# [28]	validation_0-rmse:2.32322	validation_1-rmse:2.31245
# [29]	validation_0-rmse:2.31757	validation_1-rmse:2.30861
# [30]	validation_0-rmse:2.31254	validation_1-rmse:2.30584
# [31]	validation_0-rmse:2.30914	validation_1-rmse:2.30330
# [32]	validation_0-rmse:2.30475	validation_1-rmse:2.30029
# [33]	validation_0-rmse:2.30211	validation_1-rmse:2.29896
# [34]	validation_0-rmse:2.29705	validation_1-rmse:2.29607
# [35]	validation_0-rmse:2.29421	validation_1-rmse:2.29498
# [36]	validation_0-rmse:2.29118	validation_1-rmse:2.29375
# [37]	validation_0-rmse:2.28909	validation_1-rmse:2.29237
# [38]	validation_0-rmse:2.28756	validation_1-rmse:2.29199
# [39]	validation_0-rmse:2.28557	validation_1-rmse:2.29144
# [40]	validation_0-rmse:2.28384	validation_1-rmse:2.29124
# [41]	validation_0-rmse:2.28301	validation_1-rmse:2.29129
# [42]	validation_0-rmse:2.28120	validation_1-rmse:2.28988
# [43]	validation_0-rmse:2.27939	validation_1-rmse:2.29030
# [44]	validation_0-rmse:2.27707	validation_1-rmse:2.29010
# [45]	validation_0-rmse:2.27578	validation_1-rmse:2.28957
# [46]	validation_0-rmse:2.27394	validation_1-rmse:2.28924
# [47]	validation_0-rmse:2.27255	validation_1-rmse:2.28902
# [48]	validation_0-rmse:2.27148	validation_1-rmse:2.28931
# [49]	validation_0-rmse:2.27099	validation_1-rmse:2.28912
# [50]	validation_0-rmse:2.26817	validation_1-rmse:2.28793
# [51]	validation_0-rmse:2.26661	validation_1-rmse:2.28710
# [52]	validation_0-rmse:2.26605	validation_1-rmse:2.28705
# [53]	validation_0-rmse:2.26515	validation_1-rmse:2.28722
# [54]	validation_0-rmse:2.26309	validation_1-rmse:2.28701
# [55]	validation_0-rmse:2.26152	validation_1-rmse:2.28586
# [56]	validation_0-rmse:2.26082	validation_1-rmse:2.28586
# [57]	validation_0-rmse:2.25879	validation_1-rmse:2.28505
# [58]	validation_0-rmse:2.25723	validation_1-rmse:2.28682
# [59]	validation_0-rmse:2.25551	validation_1-rmse:2.28623
# [60]	validation_0-rmse:2.25519	validation_1-rmse:2.28621
# [61]	validation_0-rmse:2.25467	validation_1-rmse:2.28677
# [62]	validation_0-rmse:2.25284	validation_1-rmse:2.28623
# [0]	validation_0-rmse:4.59501	validation_1-rmse:4.50055
# [1]	validation_0-rmse:4.28781	validation_1-rmse:4.19708
# [2]	validation_0-rmse:4.01520	validation_1-rmse:3.92920
# [3]	validation_0-rmse:3.77994	validation_1-rmse:3.69451
# [4]	validation_0-rmse:3.57164	validation_1-rmse:3.49041
# [5]	validation_0-rmse:3.39293	validation_1-rmse:3.31446
# [6]	validation_0-rmse:3.24467	validation_1-rmse:3.16610
# [7]	validation_0-rmse:3.10917	validation_1-rmse:3.03373
# [8]	validation_0-rmse:2.99274	validation_1-rmse:2.92042
# [9]	validation_0-rmse:2.90065	validation_1-rmse:2.82887
# [10]	validation_0-rmse:2.82022	validation_1-rmse:2.74876
# [11]	validation_0-rmse:2.74538	validation_1-rmse:2.67650
# [12]	validation_0-rmse:2.68113	validation_1-rmse:2.61636
# [13]	validation_0-rmse:2.63166	validation_1-rmse:2.56726
# [14]	validation_0-rmse:2.58533	validation_1-rmse:2.52578
# [15]	validation_0-rmse:2.54456	validation_1-rmse:2.48990
# [16]	validation_0-rmse:2.50879	validation_1-rmse:2.45929
# [17]	validation_0-rmse:2.47981	validation_1-rmse:2.43582
# [18]	validation_0-rmse:2.45356	validation_1-rmse:2.41031
# [19]	validation_0-rmse:2.43179	validation_1-rmse:2.39149
# [20]	validation_0-rmse:2.41571	validation_1-rmse:2.37625
# [21]	validation_0-rmse:2.40046	validation_1-rmse:2.36234
# [22]	validation_0-rmse:2.38682	validation_1-rmse:2.35259
# [23]	validation_0-rmse:2.37551	validation_1-rmse:2.34200
# [24]	validation_0-rmse:2.36354	validation_1-rmse:2.33148
# [25]	validation_0-rmse:2.35383	validation_1-rmse:2.32452
# [26]	validation_0-rmse:2.34935	validation_1-rmse:2.32084
# [27]	validation_0-rmse:2.34250	validation_1-rmse:2.31565
# [28]	validation_0-rmse:2.33666	validation_1-rmse:2.31015
# [29]	validation_0-rmse:2.33055	validation_1-rmse:2.30520
# [30]	validation_0-rmse:2.32569	validation_1-rmse:2.30165
# [31]	validation_0-rmse:2.32218	validation_1-rmse:2.29936
# [32]	validation_0-rmse:2.31753	validation_1-rmse:2.29567
# [33]	validation_0-rmse:2.31325	validation_1-rmse:2.29362
# [34]	validation_0-rmse:2.31013	validation_1-rmse:2.29216
# [35]	validation_0-rmse:2.30578	validation_1-rmse:2.28842
# [36]	validation_0-rmse:2.30271	validation_1-rmse:2.28737
# [37]	validation_0-rmse:2.29910	validation_1-rmse:2.28602
# [38]	validation_0-rmse:2.29709	validation_1-rmse:2.28558
# [39]	validation_0-rmse:2.29340	validation_1-rmse:2.28434
# [40]	validation_0-rmse:2.29032	validation_1-rmse:2.28366
# [41]	validation_0-rmse:2.28841	validation_1-rmse:2.28371
# [42]	validation_0-rmse:2.28650	validation_1-rmse:2.28386
# [43]	validation_0-rmse:2.28467	validation_1-rmse:2.28478
# [44]	validation_0-rmse:2.28395	validation_1-rmse:2.28451
# [45]	validation_0-rmse:2.28108	validation_1-rmse:2.28248
# [46]	validation_0-rmse:2.27965	validation_1-rmse:2.28258
# [47]	validation_0-rmse:2.27835	validation_1-rmse:2.28204
# [48]	validation_0-rmse:2.27582	validation_1-rmse:2.28025
# [49]	validation_0-rmse:2.27440	validation_1-rmse:2.28040
# [50]	validation_0-rmse:2.27320	validation_1-rmse:2.28110
# [51]	validation_0-rmse:2.27166	validation_1-rmse:2.27987
# [52]	validation_0-rmse:2.27015	validation_1-rmse:2.28095
# [53]	validation_0-rmse:2.26935	validation_1-rmse:2.28116
# [54]	validation_0-rmse:2.26835	validation_1-rmse:2.28125
# [55]	validation_0-rmse:2.26658	validation_1-rmse:2.28026
# [0]	validation_0-rmse:4.57980	validation_1-rmse:4.48805
# [1]	validation_0-rmse:4.26230	validation_1-rmse:4.17282
# [2]	validation_0-rmse:3.98112	validation_1-rmse:3.90005
# [3]	validation_0-rmse:3.73616	validation_1-rmse:3.65971
# [4]	validation_0-rmse:3.52497	validation_1-rmse:3.45175
# [5]	validation_0-rmse:3.34097	validation_1-rmse:3.27400
# [6]	validation_0-rmse:3.18137	validation_1-rmse:3.11879
# [7]	validation_0-rmse:3.04580	validation_1-rmse:2.98761
# [8]	validation_0-rmse:2.92995	validation_1-rmse:2.87720
# [9]	validation_0-rmse:2.82989	validation_1-rmse:2.77933
# [10]	validation_0-rmse:2.74608	validation_1-rmse:2.69885
# [11]	validation_0-rmse:2.67507	validation_1-rmse:2.63264
# [12]	validation_0-rmse:2.61530	validation_1-rmse:2.57597
# [13]	validation_0-rmse:2.56448	validation_1-rmse:2.52799
# [14]	validation_0-rmse:2.52160	validation_1-rmse:2.48844
# [15]	validation_0-rmse:2.48511	validation_1-rmse:2.45424
# [16]	validation_0-rmse:2.45498	validation_1-rmse:2.42615
# [17]	validation_0-rmse:2.42669	validation_1-rmse:2.40115
# [18]	validation_0-rmse:2.40527	validation_1-rmse:2.38192
# [19]	validation_0-rmse:2.38650	validation_1-rmse:2.36490
# [20]	validation_0-rmse:2.37079	validation_1-rmse:2.35159
# [21]	validation_0-rmse:2.35557	validation_1-rmse:2.33860
# [22]	validation_0-rmse:2.34391	validation_1-rmse:2.32895
# [23]	validation_0-rmse:2.33403	validation_1-rmse:2.32068
# [24]	validation_0-rmse:2.32454	validation_1-rmse:2.31371
# [25]	validation_0-rmse:2.31784	validation_1-rmse:2.31029
# [26]	validation_0-rmse:2.31107	validation_1-rmse:2.30443
# [27]	validation_0-rmse:2.30526	validation_1-rmse:2.30061
# [28]	validation_0-rmse:2.30098	validation_1-rmse:2.29800
# [29]	validation_0-rmse:2.29681	validation_1-rmse:2.29587
# [30]	validation_0-rmse:2.29299	validation_1-rmse:2.29411
# [31]	validation_0-rmse:2.28948	validation_1-rmse:2.29207
# [32]	validation_0-rmse:2.28706	validation_1-rmse:2.29046
# [33]	validation_0-rmse:2.28481	validation_1-rmse:2.29077
# [34]	validation_0-rmse:2.28179	validation_1-rmse:2.28835
# [35]	validation_0-rmse:2.27964	validation_1-rmse:2.28684
# [36]	validation_0-rmse:2.27844	validation_1-rmse:2.28672
# [37]	validation_0-rmse:2.27637	validation_1-rmse:2.28720
# [38]	validation_0-rmse:2.27474	validation_1-rmse:2.28694
# [39]	validation_0-rmse:2.27249	validation_1-rmse:2.28583
# [40]	validation_0-rmse:2.27107	validation_1-rmse:2.28548
# [41]	validation_0-rmse:2.26915	validation_1-rmse:2.28550
# [42]	validation_0-rmse:2.26798	validation_1-rmse:2.28571
# [43]	validation_0-rmse:2.26643	validation_1-rmse:2.28497
# [44]	validation_0-rmse:2.26456	validation_1-rmse:2.28462
# [45]	validation_0-rmse:2.26194	validation_1-rmse:2.28267
# [46]	validation_0-rmse:2.26108	validation_1-rmse:2.28284
# [47]	validation_0-rmse:2.26030	validation_1-rmse:2.28334
# [48]	validation_0-rmse:2.25936	validation_1-rmse:2.28335
# [49]	validation_0-rmse:2.25802	validation_1-rmse:2.28245
# [50]	validation_0-rmse:2.25695	validation_1-rmse:2.28260
# [51]	validation_0-rmse:2.25492	validation_1-rmse:2.28172
# [52]	validation_0-rmse:2.25243	validation_1-rmse:2.28227
# [53]	validation_0-rmse:2.25167	validation_1-rmse:2.28243
# [54]	validation_0-rmse:2.25060	validation_1-rmse:2.28248
# [55]	validation_0-rmse:2.24881	validation_1-rmse:2.28160
# [56]	validation_0-rmse:2.24623	validation_1-rmse:2.27867
# [57]	validation_0-rmse:2.24458	validation_1-rmse:2.27771
# [58]	validation_0-rmse:2.24378	validation_1-rmse:2.27802
# [59]	validation_0-rmse:2.24262	validation_1-rmse:2.27745
# [60]	validation_0-rmse:2.24051	validation_1-rmse:2.27822
# [61]	validation_0-rmse:2.23909	validation_1-rmse:2.27729
# [62]	validation_0-rmse:2.23808	validation_1-rmse:2.27703
# [63]	validation_0-rmse:2.23743	validation_1-rmse:2.27735
# [64]	validation_0-rmse:2.23637	validation_1-rmse:2.27697
# [65]	validation_0-rmse:2.23554	validation_1-rmse:2.27659
# [66]	validation_0-rmse:2.23500	validation_1-rmse:2.27677
# [67]	validation_0-rmse:2.23380	validation_1-rmse:2.27599
# [68]	validation_0-rmse:2.23188	validation_1-rmse:2.27372
# [69]	validation_0-rmse:2.23107	validation_1-rmse:2.27385
# [70]	validation_0-rmse:2.23031	validation_1-rmse:2.27383
# [71]	validation_0-rmse:2.22960	validation_1-rmse:2.27296
# [72]	validation_0-rmse:2.22914	validation_1-rmse:2.27329
# [73]	validation_0-rmse:2.22848	validation_1-rmse:2.27297
# [74]	validation_0-rmse:2.22661	validation_1-rmse:2.27085
# [75]	validation_0-rmse:2.22570	validation_1-rmse:2.27081
# [76]	validation_0-rmse:2.22460	validation_1-rmse:2.27033
# [77]	validation_0-rmse:2.22336	validation_1-rmse:2.26891
# [78]	validation_0-rmse:2.22247	validation_1-rmse:2.26912
# [79]	validation_0-rmse:2.22177	validation_1-rmse:2.26913
# [80]	validation_0-rmse:2.22075	validation_1-rmse:2.26830
# [81]	validation_0-rmse:2.22015	validation_1-rmse:2.26796
# [82]	validation_0-rmse:2.21905	validation_1-rmse:2.26685
# [83]	validation_0-rmse:2.21818	validation_1-rmse:2.26638
# [84]	validation_0-rmse:2.21738	validation_1-rmse:2.26678
# [85]	validation_0-rmse:2.21660	validation_1-rmse:2.26737
# [86]	validation_0-rmse:2.21511	validation_1-rmse:2.26565
# [87]	validation_0-rmse:2.21453	validation_1-rmse:2.26577
# [88]	validation_0-rmse:2.21396	validation_1-rmse:2.26558
# [89]	validation_0-rmse:2.21361	validation_1-rmse:2.26555
# [90]	validation_0-rmse:2.21312	validation_1-rmse:2.26628
# [91]	validation_0-rmse:2.21150	validation_1-rmse:2.26848
# [92]	validation_0-rmse:2.21097	validation_1-rmse:2.26842
# [93]	validation_0-rmse:2.21028	validation_1-rmse:2.26824
# [94]	validation_0-rmse:2.20958	validation_1-rmse:2.26857
# [0]	validation_0-rmse:4.59567	validation_1-rmse:4.50422
# [1]	validation_0-rmse:4.28633	validation_1-rmse:4.20161
# [2]	validation_0-rmse:4.01403	validation_1-rmse:3.93464
# [3]	validation_0-rmse:3.77598	validation_1-rmse:3.69678
# [4]	validation_0-rmse:3.56748	validation_1-rmse:3.48981
# [5]	validation_0-rmse:3.38844	validation_1-rmse:3.31230
# [6]	validation_0-rmse:3.23266	validation_1-rmse:3.16148
# [7]	validation_0-rmse:3.09507	validation_1-rmse:3.02820
# [8]	validation_0-rmse:2.97763	validation_1-rmse:2.91398
# [9]	validation_0-rmse:2.87831	validation_1-rmse:2.81689
# [10]	validation_0-rmse:2.79261	validation_1-rmse:2.73540
# [11]	validation_0-rmse:2.71738	validation_1-rmse:2.66234
# [12]	validation_0-rmse:2.65319	validation_1-rmse:2.60051
# [13]	validation_0-rmse:2.60082	validation_1-rmse:2.55213
# [14]	validation_0-rmse:2.55579	validation_1-rmse:2.51017
# [15]	validation_0-rmse:2.51901	validation_1-rmse:2.47741
# [16]	validation_0-rmse:2.48756	validation_1-rmse:2.44979
# [17]	validation_0-rmse:2.46061	validation_1-rmse:2.42591
# [18]	validation_0-rmse:2.43812	validation_1-rmse:2.40626
# [19]	validation_0-rmse:2.41751	validation_1-rmse:2.38861
# [20]	validation_0-rmse:2.40036	validation_1-rmse:2.37425
# [21]	validation_0-rmse:2.38451	validation_1-rmse:2.36066
# [22]	validation_0-rmse:2.37292	validation_1-rmse:2.35129
# [23]	validation_0-rmse:2.36109	validation_1-rmse:2.34119
# [24]	validation_0-rmse:2.35098	validation_1-rmse:2.33255
# [25]	validation_0-rmse:2.34267	validation_1-rmse:2.32584
# [26]	validation_0-rmse:2.33553	validation_1-rmse:2.32098
# [27]	validation_0-rmse:2.32816	validation_1-rmse:2.31588
# [28]	validation_0-rmse:2.32301	validation_1-rmse:2.31218
# [29]	validation_0-rmse:2.31616	validation_1-rmse:2.30738
# [30]	validation_0-rmse:2.31134	validation_1-rmse:2.30417
# [31]	validation_0-rmse:2.30835	validation_1-rmse:2.30248
# [32]	validation_0-rmse:2.30442	validation_1-rmse:2.30018
# [33]	validation_0-rmse:2.30141	validation_1-rmse:2.29845
# [34]	validation_0-rmse:2.29789	validation_1-rmse:2.29685
# [35]	validation_0-rmse:2.29552	validation_1-rmse:2.29565
# [36]	validation_0-rmse:2.29353	validation_1-rmse:2.29495
# [37]	validation_0-rmse:2.29099	validation_1-rmse:2.29362
# [38]	validation_0-rmse:2.28895	validation_1-rmse:2.29279
# [39]	validation_0-rmse:2.28658	validation_1-rmse:2.29159
# [40]	validation_0-rmse:2.28455	validation_1-rmse:2.29169
# [41]	validation_0-rmse:2.28308	validation_1-rmse:2.29116
# [42]	validation_0-rmse:2.28120	validation_1-rmse:2.29154
# [43]	validation_0-rmse:2.27799	validation_1-rmse:2.28990
# [44]	validation_0-rmse:2.27713	validation_1-rmse:2.28948
# [45]	validation_0-rmse:2.27629	validation_1-rmse:2.28948
# [46]	validation_0-rmse:2.27530	validation_1-rmse:2.28864
# [47]	validation_0-rmse:2.27486	validation_1-rmse:2.28856
# [48]	validation_0-rmse:2.27351	validation_1-rmse:2.28951
# [49]	validation_0-rmse:2.27144	validation_1-rmse:2.29028
# [50]	validation_0-rmse:2.26916	validation_1-rmse:2.28808
# [51]	validation_0-rmse:2.26861	validation_1-rmse:2.28808
# [52]	validation_0-rmse:2.26759	validation_1-rmse:2.28764
# [53]	validation_0-rmse:2.26671	validation_1-rmse:2.28840
# [54]	validation_0-rmse:2.26574	validation_1-rmse:2.28921
# [55]	validation_0-rmse:2.26399	validation_1-rmse:2.28750
# [56]	validation_0-rmse:2.26360	validation_1-rmse:2.28749
# [57]	validation_0-rmse:2.26226	validation_1-rmse:2.28699
# [58]	validation_0-rmse:2.26003	validation_1-rmse:2.28608
# [59]	validation_0-rmse:2.25940	validation_1-rmse:2.28569
# [60]	validation_0-rmse:2.25800	validation_1-rmse:2.28624
# [61]	validation_0-rmse:2.25778	validation_1-rmse:2.28632
# [62]	validation_0-rmse:2.25730	validation_1-rmse:2.28654
# [63]	validation_0-rmse:2.25588	validation_1-rmse:2.28599
# [64]	validation_0-rmse:2.25435	validation_1-rmse:2.28639
# [0]	validation_0-rmse:4.59562	validation_1-rmse:4.50108
# [1]	validation_0-rmse:4.28876	validation_1-rmse:4.19791
# [2]	validation_0-rmse:4.01666	validation_1-rmse:3.93044
# [3]	validation_0-rmse:3.78159	validation_1-rmse:3.69590
# [4]	validation_0-rmse:3.57363	validation_1-rmse:3.49206
# [5]	validation_0-rmse:3.39525	validation_1-rmse:3.31660
# [6]	validation_0-rmse:3.24696	validation_1-rmse:3.16827
# [7]	validation_0-rmse:3.11192	validation_1-rmse:3.03694
# [8]	validation_0-rmse:2.99586	validation_1-rmse:2.92354
# [9]	validation_0-rmse:2.90377	validation_1-rmse:2.83204
# [10]	validation_0-rmse:2.82349	validation_1-rmse:2.75204
# [11]	validation_0-rmse:2.74870	validation_1-rmse:2.67980
# [12]	validation_0-rmse:2.68473	validation_1-rmse:2.61989
# [13]	validation_0-rmse:2.63527	validation_1-rmse:2.57080
# [14]	validation_0-rmse:2.58807	validation_1-rmse:2.52777
# [15]	validation_0-rmse:2.54660	validation_1-rmse:2.49162
# [16]	validation_0-rmse:2.51088	validation_1-rmse:2.46119
# [17]	validation_0-rmse:2.48274	validation_1-rmse:2.43531
# [18]	validation_0-rmse:2.45758	validation_1-rmse:2.41303
# [19]	validation_0-rmse:2.43505	validation_1-rmse:2.39147
# [20]	validation_0-rmse:2.41991	validation_1-rmse:2.37730
# [21]	validation_0-rmse:2.40439	validation_1-rmse:2.36610
# [22]	validation_0-rmse:2.38990	validation_1-rmse:2.35556
# [23]	validation_0-rmse:2.37926	validation_1-rmse:2.34656
# [24]	validation_0-rmse:2.36952	validation_1-rmse:2.33773
# [25]	validation_0-rmse:2.36017	validation_1-rmse:2.33116
# [26]	validation_0-rmse:2.35172	validation_1-rmse:2.32430
# [27]	validation_0-rmse:2.34489	validation_1-rmse:2.31826
# [28]	validation_0-rmse:2.33740	validation_1-rmse:2.31205
# [29]	validation_0-rmse:2.33145	validation_1-rmse:2.30755
# [30]	validation_0-rmse:2.32632	validation_1-rmse:2.30452
# [31]	validation_0-rmse:2.32166	validation_1-rmse:2.30177
# [32]	validation_0-rmse:2.31831	validation_1-rmse:2.29908
# [33]	validation_0-rmse:2.31540	validation_1-rmse:2.29760
# [34]	validation_0-rmse:2.31139	validation_1-rmse:2.29494
# [35]	validation_0-rmse:2.30711	validation_1-rmse:2.29382
# [36]	validation_0-rmse:2.30446	validation_1-rmse:2.29289
# [37]	validation_0-rmse:2.30206	validation_1-rmse:2.29241
# [38]	validation_0-rmse:2.29858	validation_1-rmse:2.29052
# [39]	validation_0-rmse:2.29616	validation_1-rmse:2.28931
# [40]	validation_0-rmse:2.29376	validation_1-rmse:2.28820
# [41]	validation_0-rmse:2.29108	validation_1-rmse:2.28659
# [42]	validation_0-rmse:2.28907	validation_1-rmse:2.28595
# [43]	validation_0-rmse:2.28687	validation_1-rmse:2.28629
# [44]	validation_0-rmse:2.28516	validation_1-rmse:2.28591
# [45]	validation_0-rmse:2.28389	validation_1-rmse:2.28620
# [46]	validation_0-rmse:2.28260	validation_1-rmse:2.28697
# [47]	validation_0-rmse:2.28051	validation_1-rmse:2.28577
# [48]	validation_0-rmse:2.28002	validation_1-rmse:2.28515
# [49]	validation_0-rmse:2.27898	validation_1-rmse:2.28530
# [50]	validation_0-rmse:2.27745	validation_1-rmse:2.28606
# [51]	validation_0-rmse:2.27657	validation_1-rmse:2.28618
# [52]	validation_0-rmse:2.27552	validation_1-rmse:2.28530
# [53]	validation_0-rmse:2.27196	validation_1-rmse:2.28236
# [54]	validation_0-rmse:2.27120	validation_1-rmse:2.28185
# [55]	validation_0-rmse:2.27060	validation_1-rmse:2.28142
# [56]	validation_0-rmse:2.27055	validation_1-rmse:2.28163
# [57]	validation_0-rmse:2.26851	validation_1-rmse:2.28027
# [58]	validation_0-rmse:2.26704	validation_1-rmse:2.28132
# [59]	validation_0-rmse:2.26627	validation_1-rmse:2.28149
# [60]	validation_0-rmse:2.26524	validation_1-rmse:2.28064
# [61]	validation_0-rmse:2.26373	validation_1-rmse:2.28057
# [62]	validation_0-rmse:2.26314	validation_1-rmse:2.28024
# [63]	validation_0-rmse:2.26219	validation_1-rmse:2.28140
# [64]	validation_0-rmse:2.26246	validation_1-rmse:2.28207
# [65]	validation_0-rmse:2.26140	validation_1-rmse:2.28210
# [66]	validation_0-rmse:2.26074	validation_1-rmse:2.28223
# [0]	validation_0-rmse:4.57993	validation_1-rmse:4.48619
# [1]	validation_0-rmse:4.26308	validation_1-rmse:4.17074
# [2]	validation_0-rmse:3.98337	validation_1-rmse:3.89640
# [3]	validation_0-rmse:3.73792	validation_1-rmse:3.65756
# [4]	validation_0-rmse:3.52637	validation_1-rmse:3.44831
# [5]	validation_0-rmse:3.34206	validation_1-rmse:3.27010
# [6]	validation_0-rmse:3.18275	validation_1-rmse:3.11541
# [7]	validation_0-rmse:3.04555	validation_1-rmse:2.98016
# [8]	validation_0-rmse:2.93050	validation_1-rmse:2.86993
# [9]	validation_0-rmse:2.83206	validation_1-rmse:2.77612
# [10]	validation_0-rmse:2.74844	validation_1-rmse:2.69612
# [11]	validation_0-rmse:2.67769	validation_1-rmse:2.62983
# [12]	validation_0-rmse:2.61712	validation_1-rmse:2.57329
# [13]	validation_0-rmse:2.56687	validation_1-rmse:2.52721
# [14]	validation_0-rmse:2.52331	validation_1-rmse:2.48697
# [15]	validation_0-rmse:2.48725	validation_1-rmse:2.45406
# [16]	validation_0-rmse:2.45483	validation_1-rmse:2.42454
# [17]	validation_0-rmse:2.42969	validation_1-rmse:2.40185
# [18]	validation_0-rmse:2.40636	validation_1-rmse:2.38019
# [19]	validation_0-rmse:2.38751	validation_1-rmse:2.36427
# [20]	validation_0-rmse:2.37033	validation_1-rmse:2.34920
# [21]	validation_0-rmse:2.35525	validation_1-rmse:2.33754
# [22]	validation_0-rmse:2.34383	validation_1-rmse:2.32724
# [23]	validation_0-rmse:2.33341	validation_1-rmse:2.31855
# [24]	validation_0-rmse:2.32521	validation_1-rmse:2.31199
# [25]	validation_0-rmse:2.31841	validation_1-rmse:2.30714
# [26]	validation_0-rmse:2.31240	validation_1-rmse:2.30339
# [27]	validation_0-rmse:2.30734	validation_1-rmse:2.30114
# [28]	validation_0-rmse:2.30338	validation_1-rmse:2.29920
# [29]	validation_0-rmse:2.29953	validation_1-rmse:2.29691
# [30]	validation_0-rmse:2.29586	validation_1-rmse:2.29472
# [31]	validation_0-rmse:2.29246	validation_1-rmse:2.29250
# [32]	validation_0-rmse:2.28981	validation_1-rmse:2.29191
# [33]	validation_0-rmse:2.28686	validation_1-rmse:2.29057
# [34]	validation_0-rmse:2.28524	validation_1-rmse:2.29007
# [35]	validation_0-rmse:2.28406	validation_1-rmse:2.29006
# [36]	validation_0-rmse:2.28183	validation_1-rmse:2.28946
# [37]	validation_0-rmse:2.28028	validation_1-rmse:2.28876
# [38]	validation_0-rmse:2.27797	validation_1-rmse:2.28678
# [39]	validation_0-rmse:2.27634	validation_1-rmse:2.28682
# [40]	validation_0-rmse:2.27520	validation_1-rmse:2.28717
# [41]	validation_0-rmse:2.27246	validation_1-rmse:2.28524
# [42]	validation_0-rmse:2.27087	validation_1-rmse:2.28550
# [43]	validation_0-rmse:2.26978	validation_1-rmse:2.28559
# [44]	validation_0-rmse:2.26847	validation_1-rmse:2.28499
# [45]	validation_0-rmse:2.26673	validation_1-rmse:2.28445
# [46]	validation_0-rmse:2.26594	validation_1-rmse:2.28427
# [47]	validation_0-rmse:2.26421	validation_1-rmse:2.28262
# [48]	validation_0-rmse:2.26274	validation_1-rmse:2.28264
# [49]	validation_0-rmse:2.26145	validation_1-rmse:2.28255
# [50]	validation_0-rmse:2.26042	validation_1-rmse:2.28307
# [51]	validation_0-rmse:2.25844	validation_1-rmse:2.28200
# [52]	validation_0-rmse:2.25762	validation_1-rmse:2.28196
# [53]	validation_0-rmse:2.25574	validation_1-rmse:2.28115
# [54]	validation_0-rmse:2.25477	validation_1-rmse:2.28163
# [55]	validation_0-rmse:2.25399	validation_1-rmse:2.28146
# [56]	validation_0-rmse:2.25191	validation_1-rmse:2.27933
# [57]	validation_0-rmse:2.25065	validation_1-rmse:2.27880
# [58]	validation_0-rmse:2.24971	validation_1-rmse:2.27849
# [59]	validation_0-rmse:2.24913	validation_1-rmse:2.27876
# [60]	validation_0-rmse:2.24510	validation_1-rmse:2.27552
# [61]	validation_0-rmse:2.24386	validation_1-rmse:2.27437
# [62]	validation_0-rmse:2.24262	validation_1-rmse:2.27359
# [63]	validation_0-rmse:2.24052	validation_1-rmse:2.27390
# [64]	validation_0-rmse:2.23997	validation_1-rmse:2.27382
# [65]	validation_0-rmse:2.23889	validation_1-rmse:2.27322
# [66]	validation_0-rmse:2.23804	validation_1-rmse:2.27286
# [67]	validation_0-rmse:2.23581	validation_1-rmse:2.27028
# [68]	validation_0-rmse:2.23470	validation_1-rmse:2.26966
# [69]	validation_0-rmse:2.23413	validation_1-rmse:2.26976
# [70]	validation_0-rmse:2.23337	validation_1-rmse:2.26959
# [71]	validation_0-rmse:2.23289	validation_1-rmse:2.26974
# [72]	validation_0-rmse:2.23236	validation_1-rmse:2.26972
# [73]	validation_0-rmse:2.23138	validation_1-rmse:2.27018
# [74]	validation_0-rmse:2.22919	validation_1-rmse:2.26815
# [75]	validation_0-rmse:2.22862	validation_1-rmse:2.26763
# [76]	validation_0-rmse:2.22795	validation_1-rmse:2.26733
# [77]	validation_0-rmse:2.22750	validation_1-rmse:2.26766
# [78]	validation_0-rmse:2.22687	validation_1-rmse:2.26765
# [79]	validation_0-rmse:2.22577	validation_1-rmse:2.26666
# [80]	validation_0-rmse:2.22542	validation_1-rmse:2.26681
# [81]	validation_0-rmse:2.22501	validation_1-rmse:2.26670
# [82]	validation_0-rmse:2.22415	validation_1-rmse:2.26610
# [83]	validation_0-rmse:2.22340	validation_1-rmse:2.26564
# [84]	validation_0-rmse:2.22282	validation_1-rmse:2.26552
# [85]	validation_0-rmse:2.22252	validation_1-rmse:2.26559
# [86]	validation_0-rmse:2.22081	validation_1-rmse:2.26360
# [87]	validation_0-rmse:2.21987	validation_1-rmse:2.26416
# [88]	validation_0-rmse:2.21928	validation_1-rmse:2.26429
# [89]	validation_0-rmse:2.21880	validation_1-rmse:2.26445
# [90]	validation_0-rmse:2.21799	validation_1-rmse:2.26492
# [0]	validation_0-rmse:4.57628	validation_1-rmse:4.49317
# [1]	validation_0-rmse:4.24380	validation_1-rmse:4.16921
# [2]	validation_0-rmse:3.95291	validation_1-rmse:3.88475
# [3]	validation_0-rmse:3.70091	validation_1-rmse:3.64409
# [4]	validation_0-rmse:3.48403	validation_1-rmse:3.43243
# [5]	validation_0-rmse:3.29390	validation_1-rmse:3.25004
# [6]	validation_0-rmse:3.13137	validation_1-rmse:3.09326
# [7]	validation_0-rmse:2.99545	validation_1-rmse:2.96487
# [8]	validation_0-rmse:2.87693	validation_1-rmse:2.85178
# [9]	validation_0-rmse:2.77530	validation_1-rmse:2.75682
# [10]	validation_0-rmse:2.68542	validation_1-rmse:2.67557
# [11]	validation_0-rmse:2.61081	validation_1-rmse:2.60685
# ...
# [47]	validation_0-rmse:1.88311	validation_1-rmse:2.33498
# [0]	validation_0-rmse:4.55921	validation_1-rmse:4.47750
# [1]	validation_0-rmse:4.21457	validation_1-rmse:4.14442
# [2]	validation_0-rmse:3.91586	validation_1-rmse:3.85561
# [3]	validation_0-rmse:3.65188	validation_1-rmse:3.60798
# [4]	validation_0-rmse:3.41712	validation_1-rmse:3.39271
# [5]	validation_0-rmse:3.21445	validation_1-rmse:3.21391
# [6]	validation_0-rmse:3.04095	validation_1-rmse:3.06455
# [7]	validation_0-rmse:2.88857	validation_1-rmse:2.93717
# [8]	validation_0-rmse:2.76272	validation_1-rmse:2.83430
# [9]	validation_0-rmse:2.64775	validation_1-rmse:2.74432
# [10]	validation_0-rmse:2.54698	validation_1-rmse:2.66430
# [11]	validation_0-rmse:2.45914	validation_1-rmse:2.59906
# [12]	validation_0-rmse:2.38559	validation_1-rmse:2.54944
# [13]	validation_0-rmse:2.32173	validation_1-rmse:2.50543
# [14]	validation_0-rmse:2.26791	validation_1-rmse:2.46777
# [15]	validation_0-rmse:2.22167	validation_1-rmse:2.43738
# [16]	validation_0-rmse:2.18135	validation_1-rmse:2.41397
# [17]	validation_0-rmse:2.14752	validation_1-rmse:2.39877
# [18]	validation_0-rmse:2.11720	validation_1-rmse:2.38111
# [19]	validation_0-rmse:2.08950	validation_1-rmse:2.36593
# [20]	validation_0-rmse:2.06592	validation_1-rmse:2.35886
# [21]	validation_0-rmse:2.04400	validation_1-rmse:2.34787
# [22]	validation_0-rmse:2.02245	validation_1-rmse:2.34127
# [23]	validation_0-rmse:2.00583	validation_1-rmse:2.33394
# [24]	validation_0-rmse:1.98977	validation_1-rmse:2.32812
# [25]	validation_0-rmse:1.97533	validation_1-rmse:2.32386
# [26]	validation_0-rmse:1.96253	validation_1-rmse:2.32060
# [27]	validation_0-rmse:1.94830	validation_1-rmse:2.31786
# [28]	validation_0-rmse:1.93594	validation_1-rmse:2.31497
# [29]	validation_0-rmse:1.92614	validation_1-rmse:2.31237
# [30]	validation_0-rmse:1.91670	validation_1-rmse:2.31002
# [31]	validation_0-rmse:1.90634	validation_1-rmse:2.31105
# [32]	validation_0-rmse:1.89740	validation_1-rmse:2.31039
# [33]	validation_0-rmse:1.88910	validation_1-rmse:2.31098
# [34]	validation_0-rmse:1.88230	validation_1-rmse:2.30938
# [35]	validation_0-rmse:1.87572	validation_1-rmse:2.30781
# [36]	validation_0-rmse:1.86938	validation_1-rmse:2.30756
# [37]	validation_0-rmse:1.86216	validation_1-rmse:2.30612
# [38]	validation_0-rmse:1.85642	validation_1-rmse:2.30543
# [39]	validation_0-rmse:1.85103	validation_1-rmse:2.30861
# [40]	validation_0-rmse:1.84331	validation_1-rmse:2.30729
# [41]	validation_0-rmse:1.83873	validation_1-rmse:2.30534
# [42]	validation_0-rmse:1.83521	validation_1-rmse:2.30738
# [43]	validation_0-rmse:1.83090	validation_1-rmse:2.30608
# [44]	validation_0-rmse:1.82544	validation_1-rmse:2.30476
# [45]	validation_0-rmse:1.82608	validation_1-rmse:2.30888
# [46]	validation_0-rmse:1.82154	validation_1-rmse:2.31245
# [47]	validation_0-rmse:1.81900	validation_1-rmse:2.31248
# [48]	validation_0-rmse:1.81662	validation_1-rmse:2.31184
# [49]	validation_0-rmse:1.81475	validation_1-rmse:2.31371
# [0]	validation_0-rmse:4.53992	validation_1-rmse:4.46755
# [1]	validation_0-rmse:4.18132	validation_1-rmse:4.13323
# [2]	validation_0-rmse:3.86321	validation_1-rmse:3.83515
# [3]	validation_0-rmse:3.58856	validation_1-rmse:3.58562
# [4]	validation_0-rmse:3.34394	validation_1-rmse:3.36057
# [5]	validation_0-rmse:3.13628	validation_1-rmse:3.17637
# [6]	validation_0-rmse:2.95422	validation_1-rmse:3.02665
# [7]	validation_0-rmse:2.80037	validation_1-rmse:2.89875
# [8]	validation_0-rmse:2.66574	validation_1-rmse:2.78915
# [9]	validation_0-rmse:2.55540	validation_1-rmse:2.70289
# [10]	validation_0-rmse:2.46130	validation_1-rmse:2.63253
# [11]	validation_0-rmse:2.37868	validation_1-rmse:2.57154
# [12]	validation_0-rmse:2.30686	validation_1-rmse:2.52378
# [13]	validation_0-rmse:2.24658	validation_1-rmse:2.48500
# [14]	validation_0-rmse:2.19149	validation_1-rmse:2.45135
# [15]	validation_0-rmse:2.14356	validation_1-rmse:2.42343
# [16]	validation_0-rmse:2.10343	validation_1-rmse:2.40185
# [17]	validation_0-rmse:2.06877	validation_1-rmse:2.38907
# [18]	validation_0-rmse:2.04043	validation_1-rmse:2.37256
# [19]	validation_0-rmse:2.02067	validation_1-rmse:2.36634
# [20]	validation_0-rmse:1.99879	validation_1-rmse:2.35851
# [21]	validation_0-rmse:1.98142	validation_1-rmse:2.35616
# [22]	validation_0-rmse:1.96510	validation_1-rmse:2.35259
# [23]	validation_0-rmse:1.95067	validation_1-rmse:2.35073
# [24]	validation_0-rmse:1.93654	validation_1-rmse:2.34761
# [25]	validation_0-rmse:1.93223	validation_1-rmse:2.34959
# [26]	validation_0-rmse:1.92138	validation_1-rmse:2.34838
# [27]	validation_0-rmse:1.91130	validation_1-rmse:2.34661
# [28]	validation_0-rmse:1.90238	validation_1-rmse:2.34654
# [29]	validation_0-rmse:1.89539	validation_1-rmse:2.34661
# [30]	validation_0-rmse:1.88915	validation_1-rmse:2.34755
# [31]	validation_0-rmse:1.88415	validation_1-rmse:2.34760
# [32]	validation_0-rmse:1.87837	validation_1-rmse:2.34887
# [0]	validation_0-rmse:4.58269	validation_1-rmse:4.51345
# [1]	validation_0-rmse:4.25928	validation_1-rmse:4.21127
# [2]	validation_0-rmse:3.96911	validation_1-rmse:3.93559
# [3]	validation_0-rmse:3.70920	validation_1-rmse:3.68446
# [4]	validation_0-rmse:3.48227	validation_1-rmse:3.47291
# [5]	validation_0-rmse:3.28664	validation_1-rmse:3.29509
# [6]	validation_0-rmse:3.12024	validation_1-rmse:3.15425
# [7]	validation_0-rmse:2.97253	validation_1-rmse:3.02971
# [8]	validation_0-rmse:2.84458	validation_1-rmse:2.91739
# [9]	validation_0-rmse:2.73422	validation_1-rmse:2.82087
# [10]	validation_0-rmse:2.63232	validation_1-rmse:2.73785
# [11]	validation_0-rmse:2.54879	validation_1-rmse:2.67020
# [12]	validation_0-rmse:2.47519	validation_1-rmse:2.60881
# [13]	validation_0-rmse:2.41121	validation_1-rmse:2.56111
# [14]	validation_0-rmse:2.35319	validation_1-rmse:2.51959
# [15]	validation_0-rmse:2.30400	validation_1-rmse:2.48162
# [16]	validation_0-rmse:2.26012	validation_1-rmse:2.45313
# [17]	validation_0-rmse:2.22696	validation_1-rmse:2.43265
# [18]	validation_0-rmse:2.19365	validation_1-rmse:2.41255
# [19]	validation_0-rmse:2.16266	validation_1-rmse:2.39305
# [20]	validation_0-rmse:2.13579	validation_1-rmse:2.37887
# [21]	validation_0-rmse:2.11452	validation_1-rmse:2.36556
# [22]	validation_0-rmse:2.09021	validation_1-rmse:2.35317
# [23]	validation_0-rmse:2.07481	validation_1-rmse:2.34691
# [24]	validation_0-rmse:2.05818	validation_1-rmse:2.34015
# [25]	validation_0-rmse:2.04394	validation_1-rmse:2.33442
# [26]	validation_0-rmse:2.03064	validation_1-rmse:2.32877
# [27]	validation_0-rmse:2.01853	validation_1-rmse:2.32600
# [28]	validation_0-rmse:2.00840	validation_1-rmse:2.32233
# [29]	validation_0-rmse:1.99833	validation_1-rmse:2.32033
# [30]	validation_0-rmse:1.99025	validation_1-rmse:2.32154
# [31]	validation_0-rmse:1.98134	validation_1-rmse:2.31992
# [32]	validation_0-rmse:1.97483	validation_1-rmse:2.31907
# [33]	validation_0-rmse:1.96845	validation_1-rmse:2.31522
# [34]	validation_0-rmse:1.95945	validation_1-rmse:2.31195
# [35]	validation_0-rmse:1.95466	validation_1-rmse:2.30974
# [36]	validation_0-rmse:1.94919	validation_1-rmse:2.30895
# [37]	validation_0-rmse:1.94629	validation_1-rmse:2.31081
# [38]	validation_0-rmse:1.94400	validation_1-rmse:2.31223
# [39]	validation_0-rmse:1.94044	validation_1-rmse:2.31056
# [40]	validation_0-rmse:1.93549	validation_1-rmse:2.30978
# [41]	validation_0-rmse:1.92954	validation_1-rmse:2.30892
# [42]	validation_0-rmse:1.92468	validation_1-rmse:2.30850
# [43]	validation_0-rmse:1.92119	validation_1-rmse:2.30704
# [44]	validation_0-rmse:1.91687	validation_1-rmse:2.30664
# [45]	validation_0-rmse:1.91266	validation_1-rmse:2.30731
# [46]	validation_0-rmse:1.90891	validation_1-rmse:2.30631
# [47]	validation_0-rmse:1.90637	validation_1-rmse:2.30671
# [48]	validation_0-rmse:1.90376	validation_1-rmse:2.30612
# [49]	validation_0-rmse:1.90037	validation_1-rmse:2.30483
# [50]	validation_0-rmse:1.89760	validation_1-rmse:2.30513
# [51]	validation_0-rmse:1.90232	validation_1-rmse:2.30997
# [52]	validation_0-rmse:1.90100	validation_1-rmse:2.30993
# [53]	validation_0-rmse:1.90005	validation_1-rmse:2.30978
# [0]	validation_0-rmse:4.57307	validation_1-rmse:4.49101
# [1]	validation_0-rmse:4.25066	validation_1-rmse:4.17578
# [2]	validation_0-rmse:3.96498	validation_1-rmse:3.89718
# [3]	validation_0-rmse:3.70935	validation_1-rmse:3.65924
# [4]	validation_0-rmse:3.48822	validation_1-rmse:3.45473
# [5]	validation_0-rmse:3.29860	validation_1-rmse:3.28023
# [6]	validation_0-rmse:3.13282	validation_1-rmse:3.13193
# [7]	validation_0-rmse:2.98579	validation_1-rmse:3.00217
# [8]	validation_0-rmse:2.85660	validation_1-rmse:2.89035
# [9]	validation_0-rmse:2.74901	validation_1-rmse:2.80077
# [10]	validation_0-rmse:2.65182	validation_1-rmse:2.72373
# [11]	validation_0-rmse:2.56513	validation_1-rmse:2.65528
# [12]	validation_0-rmse:2.49309	validation_1-rmse:2.59923
# [13]	validation_0-rmse:2.42836	validation_1-rmse:2.55304
# [14]	validation_0-rmse:2.37205	validation_1-rmse:2.51181
# [15]	validation_0-rmse:2.32526	validation_1-rmse:2.47849
# [16]	validation_0-rmse:2.28547	validation_1-rmse:2.45146
# [17]	validation_0-rmse:2.24926	validation_1-rmse:2.43019
# [18]	validation_0-rmse:2.21598	validation_1-rmse:2.41068
# [19]	validation_0-rmse:2.18993	validation_1-rmse:2.40030
# [20]	validation_0-rmse:2.16292	validation_1-rmse:2.38503
# [21]	validation_0-rmse:2.13910	validation_1-rmse:2.37397
# [22]	validation_0-rmse:2.11941	validation_1-rmse:2.36723
# [23]	validation_0-rmse:2.10103	validation_1-rmse:2.35957
# [24]	validation_0-rmse:2.08420	validation_1-rmse:2.35299
# [25]	validation_0-rmse:2.06840	validation_1-rmse:2.34654
# [26]	validation_0-rmse:2.05599	validation_1-rmse:2.34352
# [27]	validation_0-rmse:2.04100	validation_1-rmse:2.33891
# [28]	validation_0-rmse:2.02746	validation_1-rmse:2.33464
# [29]	validation_0-rmse:2.01560	validation_1-rmse:2.33088
# [30]	validation_0-rmse:2.00509	validation_1-rmse:2.32787
# [31]	validation_0-rmse:1.99719	validation_1-rmse:2.32467
# [32]	validation_0-rmse:1.98831	validation_1-rmse:2.32153
# [33]	validation_0-rmse:1.98170	validation_1-rmse:2.32270
# [34]	validation_0-rmse:1.97313	validation_1-rmse:2.32152
# [35]	validation_0-rmse:1.96705	validation_1-rmse:2.32049
# [36]	validation_0-rmse:1.96106	validation_1-rmse:2.31781
# [37]	validation_0-rmse:1.95413	validation_1-rmse:2.31603
# [38]	validation_0-rmse:1.94973	validation_1-rmse:2.31494
# [39]	validation_0-rmse:1.94271	validation_1-rmse:2.31380
# [40]	validation_0-rmse:1.93242	validation_1-rmse:2.31168
# [41]	validation_0-rmse:1.92392	validation_1-rmse:2.30972
# [42]	validation_0-rmse:1.91902	validation_1-rmse:2.30878
# [43]	validation_0-rmse:1.91362	validation_1-rmse:2.31015
# [44]	validation_0-rmse:1.91054	validation_1-rmse:2.30902
# [45]	validation_0-rmse:1.90600	validation_1-rmse:2.31059
# [46]	validation_0-rmse:1.90081	validation_1-rmse:2.31102
# [0]	validation_0-rmse:4.55407	validation_1-rmse:4.47043
# [1]	validation_0-rmse:4.20826	validation_1-rmse:4.14336
# [2]	validation_0-rmse:3.90211	validation_1-rmse:3.85156
# [3]	validation_0-rmse:3.63232	validation_1-rmse:3.59664
# [4]	validation_0-rmse:3.39876	validation_1-rmse:3.37981
# [5]	validation_0-rmse:3.19483	validation_1-rmse:3.19449
# [6]	validation_0-rmse:3.01484	validation_1-rmse:3.03428
# [7]	validation_0-rmse:2.86387	validation_1-rmse:2.90877
# [8]	validation_0-rmse:2.72935	validation_1-rmse:2.79667
# [9]	validation_0-rmse:2.61775	validation_1-rmse:2.71170
# [10]	validation_0-rmse:2.51718	validation_1-rmse:2.63631
# [11]	validation_0-rmse:2.42996	validation_1-rmse:2.57245
# [12]	validation_0-rmse:2.35246	validation_1-rmse:2.52270
# [13]	validation_0-rmse:2.28646	validation_1-rmse:2.47975
# [14]	validation_0-rmse:2.23131	validation_1-rmse:2.44623
# [15]	validation_0-rmse:2.18463	validation_1-rmse:2.41749
# [16]	validation_0-rmse:2.14381	validation_1-rmse:2.39601
# [17]	validation_0-rmse:2.10949	validation_1-rmse:2.37861
# [18]	validation_0-rmse:2.07895	validation_1-rmse:2.36507
# [19]	validation_0-rmse:2.05290	validation_1-rmse:2.35319
# [20]	validation_0-rmse:2.02861	validation_1-rmse:2.34448
# [21]	validation_0-rmse:2.00852	validation_1-rmse:2.33912
# [22]	validation_0-rmse:1.99258	validation_1-rmse:2.33718
# [23]	validation_0-rmse:1.97647	validation_1-rmse:2.33387
# [24]	validation_0-rmse:1.96554	validation_1-rmse:2.33328
# [25]	validation_0-rmse:1.95304	validation_1-rmse:2.33077
# [26]	validation_0-rmse:1.94139	validation_1-rmse:2.32516
# [27]	validation_0-rmse:1.93318	validation_1-rmse:2.32555
# [28]	validation_0-rmse:1.92680	validation_1-rmse:2.32538
# [29]	validation_0-rmse:1.91924	validation_1-rmse:2.32437
# [30]	validation_0-rmse:1.91163	validation_1-rmse:2.32422
# [31]	validation_0-rmse:1.90484	validation_1-rmse:2.32190
# [32]	validation_0-rmse:1.90046	validation_1-rmse:2.32124
# [33]	validation_0-rmse:1.89551	validation_1-rmse:2.32114
# [34]	validation_0-rmse:1.89208	validation_1-rmse:2.32264
# [35]	validation_0-rmse:1.88950	validation_1-rmse:2.32614
# [36]	validation_0-rmse:1.88453	validation_1-rmse:2.32719
# [37]	validation_0-rmse:1.87932	validation_1-rmse:2.32706
# [38]	validation_0-rmse:1.87450	validation_1-rmse:2.32719
# [0]	validation_0-rmse:4.58784	validation_1-rmse:4.49458
# [1]	validation_0-rmse:4.27512	validation_1-rmse:4.18779
# [2]	validation_0-rmse:4.00058	validation_1-rmse:3.91858
# [3]	validation_0-rmse:3.76256	validation_1-rmse:3.68479
# [4]	validation_0-rmse:3.55152	validation_1-rmse:3.47518
# [5]	validation_0-rmse:3.37053	validation_1-rmse:3.29718
# [6]	validation_0-rmse:3.21195	validation_1-rmse:3.14382
# [7]	validation_0-rmse:3.07569	validation_1-rmse:3.00917
# [8]	validation_0-rmse:2.95898	validation_1-rmse:2.89746
# [9]	validation_0-rmse:2.86006	validation_1-rmse:2.80108
# [10]	validation_0-rmse:2.77522	validation_1-rmse:2.71980
# [11]	validation_0-rmse:2.70273	validation_1-rmse:2.65225
# [12]	validation_0-rmse:2.64164	validation_1-rmse:2.59561
# [13]	validation_0-rmse:2.58934	validation_1-rmse:2.54643
# [14]	validation_0-rmse:2.54479	validation_1-rmse:2.50605
# [15]	validation_0-rmse:2.50670	validation_1-rmse:2.47060
# [16]	validation_0-rmse:2.47481	validation_1-rmse:2.44247
# [17]	validation_0-rmse:2.44691	validation_1-rmse:2.41616
# [18]	validation_0-rmse:2.42416	validation_1-rmse:2.39607
# [19]	validation_0-rmse:2.40390	validation_1-rmse:2.37924
# [20]	validation_0-rmse:2.38454	validation_1-rmse:2.36138
# [21]	validation_0-rmse:2.37036	validation_1-rmse:2.34998
# [22]	validation_0-rmse:2.35712	validation_1-rmse:2.33803
# [23]	validation_0-rmse:2.34508	validation_1-rmse:2.32769
# [24]	validation_0-rmse:2.33582	validation_1-rmse:2.31999
# [25]	validation_0-rmse:2.32685	validation_1-rmse:2.31262
# [26]	validation_0-rmse:2.31970	validation_1-rmse:2.30779
# [27]	validation_0-rmse:2.31280	validation_1-rmse:2.30311
# [28]	validation_0-rmse:2.30618	validation_1-rmse:2.29857
# [29]	validation_0-rmse:2.30007	validation_1-rmse:2.29429
# [30]	validation_0-rmse:2.29592	validation_1-rmse:2.29207
# [31]	validation_0-rmse:2.29113	validation_1-rmse:2.28836
# [32]	validation_0-rmse:2.28682	validation_1-rmse:2.28548
# [33]	validation_0-rmse:2.28352	validation_1-rmse:2.28439
# [34]	validation_0-rmse:2.27979	validation_1-rmse:2.28339
# [35]	validation_0-rmse:2.27664	validation_1-rmse:2.28183
# [36]	validation_0-rmse:2.27409	validation_1-rmse:2.28129
# [37]	validation_0-rmse:2.27174	validation_1-rmse:2.28043
# [38]	validation_0-rmse:2.26935	validation_1-rmse:2.27999
# [39]	validation_0-rmse:2.26668	validation_1-rmse:2.27883
# [40]	validation_0-rmse:2.26475	validation_1-rmse:2.27840
# [41]	validation_0-rmse:2.26259	validation_1-rmse:2.27770
# [42]	validation_0-rmse:2.26063	validation_1-rmse:2.27786
# [43]	validation_0-rmse:2.25909	validation_1-rmse:2.27759
# [44]	validation_0-rmse:2.25648	validation_1-rmse:2.27586
# [45]	validation_0-rmse:2.25472	validation_1-rmse:2.27613
# [46]	validation_0-rmse:2.25333	validation_1-rmse:2.27536
# [47]	validation_0-rmse:2.25185	validation_1-rmse:2.27639
# [48]	validation_0-rmse:2.24927	validation_1-rmse:2.27471
# [49]	validation_0-rmse:2.24781	validation_1-rmse:2.27572
# [50]	validation_0-rmse:2.24679	validation_1-rmse:2.27581
# [51]	validation_0-rmse:2.24471	validation_1-rmse:2.27502
# [52]	validation_0-rmse:2.24308	validation_1-rmse:2.27510
# [53]	validation_0-rmse:2.24196	validation_1-rmse:2.27494
# Best Hyperparameters:  {'gamma': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': 'reg:squarederror', 'reg_alpha': 0.1, 'reg_lambda': 1}
# Best Score:  -5.489352933671069

# %% [markdown]
# **Train an XGboost model**
#
# We will fit all the data in this model using the optimum parameters we found above.

# %%
# Define XGBoost regressor
reg = xgb.XGBRegressor(
    reg_lambda = xgb_grid.best_params_['reg_lambda'],
    reg_alpha = xgb_grid.best_params_['reg_alpha'],
    learning_rate = xgb_grid.best_params_['learning_rate'],
    max_depth = xgb_grid.best_params_['max_depth'],
    n_estimators = 100,
    gamma = xgb_grid.best_params_['gamma'],
    objective = xgb_grid.best_params_['objective'],
    early_stopping_rounds = 5
)

# Train the XGBoost model with feature weights (use validation set on test data)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test,y_test)])
# Out:
# [0]	validation_0-rmse:4.58784	validation_1-rmse:4.49458
# [1]	validation_0-rmse:4.27512	validation_1-rmse:4.18779
# [2]	validation_0-rmse:4.00058	validation_1-rmse:3.91858
# [3]	validation_0-rmse:3.76256	validation_1-rmse:3.68479
# [4]	validation_0-rmse:3.55152	validation_1-rmse:3.47518
# [5]	validation_0-rmse:3.37053	validation_1-rmse:3.29718
# [6]	validation_0-rmse:3.21195	validation_1-rmse:3.14382
# [7]	validation_0-rmse:3.07569	validation_1-rmse:3.00917
# [8]	validation_0-rmse:2.95898	validation_1-rmse:2.89746
# [9]	validation_0-rmse:2.86006	validation_1-rmse:2.80108
# [10]	validation_0-rmse:2.77522	validation_1-rmse:2.71980
# [11]	validation_0-rmse:2.70273	validation_1-rmse:2.65225
# [12]	validation_0-rmse:2.64164	validation_1-rmse:2.59561
# [13]	validation_0-rmse:2.58934	validation_1-rmse:2.54643
# [14]	validation_0-rmse:2.54479	validation_1-rmse:2.50605
# [15]	validation_0-rmse:2.50670	validation_1-rmse:2.47060
# [16]	validation_0-rmse:2.47481	validation_1-rmse:2.44247
# [17]	validation_0-rmse:2.44691	validation_1-rmse:2.41616
# [18]	validation_0-rmse:2.42416	validation_1-rmse:2.39607
# [19]	validation_0-rmse:2.40390	validation_1-rmse:2.37924
# [20]	validation_0-rmse:2.38454	validation_1-rmse:2.36138
# [21]	validation_0-rmse:2.37036	validation_1-rmse:2.34998
# [22]	validation_0-rmse:2.35712	validation_1-rmse:2.33803
# [23]	validation_0-rmse:2.34508	validation_1-rmse:2.32769
# [24]	validation_0-rmse:2.33582	validation_1-rmse:2.31999
# [25]	validation_0-rmse:2.32685	validation_1-rmse:2.31262
# [26]	validation_0-rmse:2.31970	validation_1-rmse:2.30779
# [27]	validation_0-rmse:2.31280	validation_1-rmse:2.30311
# [28]	validation_0-rmse:2.30618	validation_1-rmse:2.29857
# [29]	validation_0-rmse:2.30007	validation_1-rmse:2.29429
# [30]	validation_0-rmse:2.29592	validation_1-rmse:2.29207
# [31]	validation_0-rmse:2.29113	validation_1-rmse:2.28836
# [32]	validation_0-rmse:2.28682	validation_1-rmse:2.28548
# [33]	validation_0-rmse:2.28352	validation_1-rmse:2.28439
# [34]	validation_0-rmse:2.27979	validation_1-rmse:2.28339
# [35]	validation_0-rmse:2.27664	validation_1-rmse:2.28183
# [36]	validation_0-rmse:2.27409	validation_1-rmse:2.28129
# [37]	validation_0-rmse:2.27174	validation_1-rmse:2.28043
# [38]	validation_0-rmse:2.26935	validation_1-rmse:2.27999
# [39]	validation_0-rmse:2.26668	validation_1-rmse:2.27883
# [40]	validation_0-rmse:2.26475	validation_1-rmse:2.27840
# [41]	validation_0-rmse:2.26259	validation_1-rmse:2.27770
# [42]	validation_0-rmse:2.26063	validation_1-rmse:2.27786
# [43]	validation_0-rmse:2.25909	validation_1-rmse:2.27759
# [44]	validation_0-rmse:2.25648	validation_1-rmse:2.27586
# [45]	validation_0-rmse:2.25472	validation_1-rmse:2.27613
# [46]	validation_0-rmse:2.25333	validation_1-rmse:2.27536
# [47]	validation_0-rmse:2.25185	validation_1-rmse:2.27639
# [48]	validation_0-rmse:2.24927	validation_1-rmse:2.27471
# [49]	validation_0-rmse:2.24781	validation_1-rmse:2.27572
# [50]	validation_0-rmse:2.24679	validation_1-rmse:2.27581
# [51]	validation_0-rmse:2.24471	validation_1-rmse:2.27502
# [52]	validation_0-rmse:2.24308	validation_1-rmse:2.27510
# [53]	validation_0-rmse:2.24196	validation_1-rmse:2.27494
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=5,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.1, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# Make predictions on the test set

# %%
# Make predictions on the X_test set
y_pred_xgboost = reg.predict(X_test)

# %%
# Calculate the MAE of XGBoost model
mae_xgboost = mean_absolute_error(y_test, y_pred_xgboost)
print("Mae is: ",mae_xgboost)

# Calculate RMSE score of XGBoost model
rmse_xgboost = mean_squared_error(y_test, y_pred_xgboost, squared=False)
print("RMSE score:", rmse_xgboost)
# Out:
# Mae is:  1.3522534738443253
# RMSE score: 2.274714110638293

# %% [markdown]
# **Train LSTM for time series forecasting**

# %% [markdown]
# Use the same train and test sets as in the XGBoost model. In order to create more accurate predictions, we scale those two sets before giving them as input to the LSTM Recurrent Neural Network model.

# %%
# Scale the data
scaler = MinMaxScaler()
X_tr = scaler.fit_transform(X_train)
X_te = scaler.fit_transform(X_test)

y_tr = scaler.fit_transform(y_train)
y_te = scaler.fit_transform(y_test)

# %%
# Create 3D train set for LSTM
trainX = []
trainY = []

for i in range(len(X_tr)):
    trainX.append(X_tr[i:i+1,:])

for i in range(len(y_tr)):
    trainY.append(y_tr[i:i+1,:])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# Create 3D test set for LSTM
testX = []
testY = []

for i in range(len(X_te)):
    testX.append(X_te[i:i+1,:])

for i in range(len(y_te)):
    testY.append(y_te[i:i+1,:])

testX, testY = np.array(testX), np.array(testY)

# %% [markdown]
# In the LSTM model, we include dense layers to capture more complex non linear patterns and dropout layers to prevent overfitting.

# %%
# Define LSTM model
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(50, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(25, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(12, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

# Additional Dense layers
model.add(Dense(6, activation='relu'))
model.add(Dense(3, activation='linear'))

# Output layer
model.add(Dense(trainY.shape[1]))

# Add early stopping mechanism
early_stopping = EarlyStopping(patience=5, monitor='val_loss', restore_best_weights=True)
# Out:
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# Compile LSTM model
model.compile(optimizer='adam', loss='mse')

# %%
# Fit model on training data
history = model.fit(trainX, trainY,
          epochs=50,
          batch_size=len(trainX)//100,
          validation_data=(testX,testY),
          callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 10s 52ms/step - loss: 0.0083 - val_loss: 0.0123
# Epoch 2/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0075 - val_loss: 0.0045
# Epoch 3/50
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 4/50
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 5/50
# 100/100 [==============================] - 2s 24ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 6/50
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 7/50
# 100/100 [==============================] - 4s 44ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 8/50
# 100/100 [==============================] - 5s 47ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 9/50
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 10/50
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 11/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 12/50
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 13/50
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 14/50
# 100/100 [==============================] - 5s 51ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 15/50
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 16/50
# 100/100 [==============================] - 6s 56ms/step - loss: 0.0020 - val_loss: 0.0028
# Epoch 17/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 18/50
# 100/100 [==============================] - 6s 64ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 19/50
# 100/100 [==============================] - 3s 26ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 20/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 21/50
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 22/50
# 100/100 [==============================] - 3s 29ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 23/50
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 24/50
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 25/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0019 - val_loss: 0.0027

# %%
# Evaluate model on test data
loss_lstm = model.evaluate(testX, testY)
print("Test Loss:", loss_lstm)
# Out:
# 432/432 [==============================] - 5s 13ms/step - loss: 0.0027
# Test Loss: 0.0027014552615582943

# %%
# Predict on test data
y_pred_lstm = model.predict(testX)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm.reshape(-1,1))
# Out:
# 432/432 [==============================] - 8s 15ms/step

# %% [markdown]
# Evaluate the LSTM model

# %%
# Calculate the MAE score of LSTM model
mae_lstm = mean_absolute_error(scaler.inverse_transform(testY.reshape(-1,1)),y_pred_lstm)
print("Mae LSTM is: ",mae_lstm)

# Calculate the RMSE score of LSTM model
rmse_lstm = mean_squared_error(scaler.inverse_transform(testY.reshape(-1,1)), y_pred_lstm, squared=False)
print("RMSE LSTM score:", rmse_lstm)
# Out:
# Mae LSTM is:  1.3817632733890113
# RMSE LSTM score: 2.2869232419721985

# %% [markdown]
# Add in the same dataframe the RMSE and MAE scores of each model, in order to compare them

# %%
# Create dataframe with scores (length == 5)
scores = pd.DataFrame(columns=['Model','RMSE Score','MAE Score'])

# Define rows for dataframe
new_row = {'Model': 'XGBoost', 'RMSE Score': rmse_xgboost, 'MAE Score': mae_xgboost}
new_row1 = {'Model': 'LSTM', 'RMSE Score': rmse_lstm, 'MAE Score': mae_lstm}

# Add rows to dataframe
scores = scores.append(new_row, ignore_index=True)
scores = scores.append(new_row1, ignore_index=True)

# %%
scores # length is 5
# Out:
#      Model  RMSE Score  MAE Score
# 0  XGBoost    2.274714   1.352253
# 1     LSTM    2.286923   1.381763

# %%
# Save XGBoost model to a file
reg.save_model('/content/drive/MyDrive/Paper/Models/xgboost_traffic_flow_length-'+str(optimum_lookback)+'.model')

# %%
# Save the model
model.save("/content/drive/MyDrive/Paper/Models/LSTM-length-"+str(optimum_lookback)+".h5")

# %% [markdown]
# ##### Sliding Window Length Equal to 6

# %%
optimum_lookback = 6

# %%
# Define train data
train= traffic_flow.loc[traffic_flow['Time Column'] < '2008-05-29']

# Define test data
test = traffic_flow.loc[traffic_flow['Time Column'] >= '2008-05-29']

# %%
# Convert train and test data to supervised problem based in the optimum lookback step we defined above.
train = generate_X_y_pairs(train, optimum_lookback)
test = generate_X_y_pairs(test, optimum_lookback)

# %%
# Add rolling mean information
train['rolling_mean'] = 0
test['rolling_mean'] = 0

# Add rolling var information
train['rolling_var'] = 0
test['rolling_var'] = 0

# Calculate rolling mean of window
train['rolling_mean'] = train.iloc[:,0:2].mean(axis=1)
test['rolling_mean'] = test.iloc[:,0:optimum_lookback].mean(axis=1)

# Calculate rolling variance of window
train['rolling_var'] = train.iloc[:, 0:optimum_lookback].var(axis=1)
test['rolling_var'] = test.iloc[:, 0:optimum_lookback].var(axis=1)

# %%
# Define features
features = train.drop(removable_items,axis=1).columns

# Define labels
labels = ['Record 1(t)']

# Create X_train and y_train data sets
X_train = train[features]
y_train = train[labels]

# Create X_test and y_test data sets
X_test = test[features]
y_test = test[labels]

# %% [markdown]
# **Apply GridSearchCV**
#
# Use a 3-fold K-fold cross-validation was used for learning the optimum hyperparameters for the XGBoost algorithm.

# %%
# Tune hyperparameters using XGboost
xgb_params = {
    "n_estimators": [100],
    "learning_rate": [0.1],
    "max_depth": [3,6,9],
    "objective":['reg:squarederror'],
    "gamma": [0,0.1],
    "reg_lambda": [0,1],
    'reg_alpha': [0, 0.1]
}

# Define GridSearchCV object
xgb_grid = GridSearchCV(xgb.XGBRegressor(),
                        xgb_params,cv=3,
                        scoring= "neg_mean_squared_error")

# Train on train data using 3 fold Cross Validation
xgb_grid.fit(X_train,y_train,
             early_stopping_rounds=5,
             eval_set=[(X_train, y_train), (X_test,y_test)],
             eval_metric='rmse')

# print the best hyperparameters and corresponding score
print("Best Hyperparameters: ", xgb_grid.best_params_)
print("Best Score: ", xgb_grid.best_score_)
# Out:
# [0]	validation_0-rmse:4.59466	validation_1-rmse:4.49044
# [1]	validation_0-rmse:4.28505	validation_1-rmse:4.18827
# [2]	validation_0-rmse:4.01253	validation_1-rmse:3.92175
# [3]	validation_0-rmse:3.77433	validation_1-rmse:3.68408
# [4]	validation_0-rmse:3.56554	validation_1-rmse:3.47745
# [5]	validation_0-rmse:3.38669	validation_1-rmse:3.30164
# [6]	validation_0-rmse:3.23072	validation_1-rmse:3.15088
# [7]	validation_0-rmse:3.09326	validation_1-rmse:3.01885
# [8]	validation_0-rmse:2.97632	validation_1-rmse:2.90495
# [9]	validation_0-rmse:2.87582	validation_1-rmse:2.80851
# [10]	validation_0-rmse:2.78859	validation_1-rmse:2.72427
# [11]	validation_0-rmse:2.71661	validation_1-rmse:2.65581
# [12]	validation_0-rmse:2.65508	validation_1-rmse:2.59958
# [13]	validation_0-rmse:2.60184	validation_1-rmse:2.55006
# [14]	validation_0-rmse:2.55612	validation_1-rmse:2.50671
# [15]	validation_0-rmse:2.52071	validation_1-rmse:2.47365
# [16]	validation_0-rmse:2.48824	validation_1-rmse:2.44421
# [17]	validation_0-rmse:2.46216	validation_1-rmse:2.42023
# [18]	validation_0-rmse:2.43980	validation_1-rmse:2.40078
# [19]	validation_0-rmse:2.41925	validation_1-rmse:2.38335
# [20]	validation_0-rmse:2.40157	validation_1-rmse:2.36892
# [21]	validation_0-rmse:2.38758	validation_1-rmse:2.35773
# [22]	validation_0-rmse:2.37463	validation_1-rmse:2.34821
# [23]	validation_0-rmse:2.36230	validation_1-rmse:2.33776
# [24]	validation_0-rmse:2.35297	validation_1-rmse:2.32950
# [25]	validation_0-rmse:2.34442	validation_1-rmse:2.32288
# [26]	validation_0-rmse:2.33603	validation_1-rmse:2.31648
# [27]	validation_0-rmse:2.32807	validation_1-rmse:2.31031
# [28]	validation_0-rmse:2.32235	validation_1-rmse:2.30620
# [29]	validation_0-rmse:2.31676	validation_1-rmse:2.30198
# [30]	validation_0-rmse:2.31282	validation_1-rmse:2.29837
# [31]	validation_0-rmse:2.30807	validation_1-rmse:2.29606
# [32]	validation_0-rmse:2.30297	validation_1-rmse:2.29223
# [33]	validation_0-rmse:2.29986	validation_1-rmse:2.29102
# [34]	validation_0-rmse:2.29740	validation_1-rmse:2.29014
# [35]	validation_0-rmse:2.29494	validation_1-rmse:2.28776
# [36]	validation_0-rmse:2.29297	validation_1-rmse:2.28681
# [37]	validation_0-rmse:2.29080	validation_1-rmse:2.28533
# [38]	validation_0-rmse:2.28769	validation_1-rmse:2.28380
# [39]	validation_0-rmse:2.28492	validation_1-rmse:2.28225
# [40]	validation_0-rmse:2.28382	validation_1-rmse:2.28181
# [41]	validation_0-rmse:2.28200	validation_1-rmse:2.28172
# [42]	validation_0-rmse:2.28010	validation_1-rmse:2.28123
# [43]	validation_0-rmse:2.27918	validation_1-rmse:2.28101
# [44]	validation_0-rmse:2.27835	validation_1-rmse:2.28067
# [45]	validation_0-rmse:2.27755	validation_1-rmse:2.28068
# [46]	validation_0-rmse:2.27579	validation_1-rmse:2.27951
# [47]	validation_0-rmse:2.27475	validation_1-rmse:2.27934
# [48]	validation_0-rmse:2.27255	validation_1-rmse:2.27919
# [49]	validation_0-rmse:2.27106	validation_1-rmse:2.27904
# [50]	validation_0-rmse:2.26873	validation_1-rmse:2.27712
# [51]	validation_0-rmse:2.26840	validation_1-rmse:2.27713
# [52]	validation_0-rmse:2.26589	validation_1-rmse:2.27568
# [53]	validation_0-rmse:2.26462	validation_1-rmse:2.27560
# [54]	validation_0-rmse:2.26348	validation_1-rmse:2.27597
# [55]	validation_0-rmse:2.26202	validation_1-rmse:2.27546
# [56]	validation_0-rmse:2.26025	validation_1-rmse:2.27461
# [57]	validation_0-rmse:2.25978	validation_1-rmse:2.27461
# [58]	validation_0-rmse:2.25752	validation_1-rmse:2.27449
# [59]	validation_0-rmse:2.25577	validation_1-rmse:2.27337
# [60]	validation_0-rmse:2.25532	validation_1-rmse:2.27349
# [61]	validation_0-rmse:2.25419	validation_1-rmse:2.27307
# [62]	validation_0-rmse:2.25252	validation_1-rmse:2.27241
# [63]	validation_0-rmse:2.25164	validation_1-rmse:2.27264
# [64]	validation_0-rmse:2.25117	validation_1-rmse:2.27264
# [65]	validation_0-rmse:2.24988	validation_1-rmse:2.27188
# [66]	validation_0-rmse:2.24923	validation_1-rmse:2.27175
# [67]	validation_0-rmse:2.24761	validation_1-rmse:2.27255
# [68]	validation_0-rmse:2.24647	validation_1-rmse:2.27257
# [69]	validation_0-rmse:2.24591	validation_1-rmse:2.27270
# [70]	validation_0-rmse:2.24546	validation_1-rmse:2.27293
# [0]	validation_0-rmse:4.59440	validation_1-rmse:4.48841
# [1]	validation_0-rmse:4.28724	validation_1-rmse:4.18571
# [2]	validation_0-rmse:4.01474	validation_1-rmse:3.91831
# [3]	validation_0-rmse:3.77936	validation_1-rmse:3.68407
# [4]	validation_0-rmse:3.57106	validation_1-rmse:3.48023
# [5]	validation_0-rmse:3.39283	validation_1-rmse:3.30664
# [6]	validation_0-rmse:3.24527	validation_1-rmse:3.15877
# [7]	validation_0-rmse:3.11003	validation_1-rmse:3.02676
# [8]	validation_0-rmse:2.99306	validation_1-rmse:2.91401
# [9]	validation_0-rmse:2.89987	validation_1-rmse:2.82211
# [10]	validation_0-rmse:2.81913	validation_1-rmse:2.74152
# [11]	validation_0-rmse:2.74407	validation_1-rmse:2.67187
# [12]	validation_0-rmse:2.67958	validation_1-rmse:2.61181
# [13]	validation_0-rmse:2.63007	validation_1-rmse:2.56292
# [14]	validation_0-rmse:2.58330	validation_1-rmse:2.52237
# [15]	validation_0-rmse:2.54751	validation_1-rmse:2.48929
# [16]	validation_0-rmse:2.51210	validation_1-rmse:2.45785
# [17]	validation_0-rmse:2.48192	validation_1-rmse:2.43218
# [18]	validation_0-rmse:2.45870	validation_1-rmse:2.41226
# [19]	validation_0-rmse:2.43629	validation_1-rmse:2.39414
# [20]	validation_0-rmse:2.41936	validation_1-rmse:2.37760
# [21]	validation_0-rmse:2.40332	validation_1-rmse:2.36398
# [22]	validation_0-rmse:2.39051	validation_1-rmse:2.35259
# [23]	validation_0-rmse:2.37611	validation_1-rmse:2.34110
# [24]	validation_0-rmse:2.36512	validation_1-rmse:2.33280
# [25]	validation_0-rmse:2.35606	validation_1-rmse:2.32524
# [26]	validation_0-rmse:2.34913	validation_1-rmse:2.31939
# [27]	validation_0-rmse:2.34105	validation_1-rmse:2.31328
# [28]	validation_0-rmse:2.33147	validation_1-rmse:2.30672
# [29]	validation_0-rmse:2.32584	validation_1-rmse:2.30312
# [30]	validation_0-rmse:2.32093	validation_1-rmse:2.30029
# [31]	validation_0-rmse:2.31605	validation_1-rmse:2.29707
# [32]	validation_0-rmse:2.30967	validation_1-rmse:2.29314
# [33]	validation_0-rmse:2.30615	validation_1-rmse:2.29067
# [34]	validation_0-rmse:2.30275	validation_1-rmse:2.28835
# [35]	validation_0-rmse:2.29993	validation_1-rmse:2.28651
# [36]	validation_0-rmse:2.29622	validation_1-rmse:2.28402
# [37]	validation_0-rmse:2.29378	validation_1-rmse:2.28335
# [38]	validation_0-rmse:2.29051	validation_1-rmse:2.28204
# [39]	validation_0-rmse:2.28835	validation_1-rmse:2.28070
# [40]	validation_0-rmse:2.28577	validation_1-rmse:2.28004
# [41]	validation_0-rmse:2.28288	validation_1-rmse:2.27880
# [42]	validation_0-rmse:2.28128	validation_1-rmse:2.27891
# [43]	validation_0-rmse:2.27934	validation_1-rmse:2.27738
# [44]	validation_0-rmse:2.27763	validation_1-rmse:2.27738
# [45]	validation_0-rmse:2.27619	validation_1-rmse:2.27734
# [46]	validation_0-rmse:2.27353	validation_1-rmse:2.27636
# [47]	validation_0-rmse:2.27259	validation_1-rmse:2.27609
# [48]	validation_0-rmse:2.27102	validation_1-rmse:2.27606
# [49]	validation_0-rmse:2.27061	validation_1-rmse:2.27578
# [50]	validation_0-rmse:2.26841	validation_1-rmse:2.27677
# [51]	validation_0-rmse:2.26704	validation_1-rmse:2.27565
# [52]	validation_0-rmse:2.26520	validation_1-rmse:2.27702
# [53]	validation_0-rmse:2.26498	validation_1-rmse:2.27699
# [54]	validation_0-rmse:2.26379	validation_1-rmse:2.27647
# [55]	validation_0-rmse:2.26306	validation_1-rmse:2.27694
# [56]	validation_0-rmse:2.26186	validation_1-rmse:2.27681
# [0]	validation_0-rmse:4.57883	validation_1-rmse:4.47280
# [1]	validation_0-rmse:4.26192	validation_1-rmse:4.15841
# [2]	validation_0-rmse:3.98201	validation_1-rmse:3.88408
# [3]	validation_0-rmse:3.73655	validation_1-rmse:3.64556
# [4]	validation_0-rmse:3.52413	validation_1-rmse:3.43980
# [5]	validation_0-rmse:3.33987	validation_1-rmse:3.26177
# [6]	validation_0-rmse:3.18218	validation_1-rmse:3.11003
# [7]	validation_0-rmse:3.04494	validation_1-rmse:2.97508
# [8]	validation_0-rmse:2.92913	validation_1-rmse:2.86353
# [9]	validation_0-rmse:2.83093	validation_1-rmse:2.77128
# [10]	validation_0-rmse:2.74716	validation_1-rmse:2.69167
# [11]	validation_0-rmse:2.67509	validation_1-rmse:2.62253
# [12]	validation_0-rmse:2.61430	validation_1-rmse:2.56561
# [13]	validation_0-rmse:2.56404	validation_1-rmse:2.51923
# [14]	validation_0-rmse:2.52076	validation_1-rmse:2.47872
# [15]	validation_0-rmse:2.48113	validation_1-rmse:2.44228
# [16]	validation_0-rmse:2.44983	validation_1-rmse:2.41454
# [17]	validation_0-rmse:2.42518	validation_1-rmse:2.39256
# [18]	validation_0-rmse:2.40379	validation_1-rmse:2.37485
# [19]	validation_0-rmse:2.38353	validation_1-rmse:2.35581
# [20]	validation_0-rmse:2.36556	validation_1-rmse:2.33974
# [21]	validation_0-rmse:2.35185	validation_1-rmse:2.32726
# [22]	validation_0-rmse:2.34022	validation_1-rmse:2.31735
# [23]	validation_0-rmse:2.33014	validation_1-rmse:2.31051
# [24]	validation_0-rmse:2.32151	validation_1-rmse:2.30548
# [25]	validation_0-rmse:2.31430	validation_1-rmse:2.30045
# [26]	validation_0-rmse:2.30744	validation_1-rmse:2.29450
# [27]	validation_0-rmse:2.30153	validation_1-rmse:2.28996
# [28]	validation_0-rmse:2.29633	validation_1-rmse:2.28620
# [29]	validation_0-rmse:2.29260	validation_1-rmse:2.28496
# [30]	validation_0-rmse:2.28907	validation_1-rmse:2.28319
# [31]	validation_0-rmse:2.28605	validation_1-rmse:2.28182
# [32]	validation_0-rmse:2.28289	validation_1-rmse:2.28055
# [33]	validation_0-rmse:2.28101	validation_1-rmse:2.27973
# [34]	validation_0-rmse:2.27845	validation_1-rmse:2.27970
# [35]	validation_0-rmse:2.27613	validation_1-rmse:2.27875
# [36]	validation_0-rmse:2.27347	validation_1-rmse:2.27710
# [37]	validation_0-rmse:2.27217	validation_1-rmse:2.27649
# [38]	validation_0-rmse:2.26995	validation_1-rmse:2.27442
# [39]	validation_0-rmse:2.26775	validation_1-rmse:2.27415
# [40]	validation_0-rmse:2.26661	validation_1-rmse:2.27394
# [41]	validation_0-rmse:2.26453	validation_1-rmse:2.27337
# [42]	validation_0-rmse:2.26279	validation_1-rmse:2.27312
# [43]	validation_0-rmse:2.26132	validation_1-rmse:2.27332
# [44]	validation_0-rmse:2.26015	validation_1-rmse:2.27297
# [45]	validation_0-rmse:2.25901	validation_1-rmse:2.27305
# [46]	validation_0-rmse:2.25906	validation_1-rmse:2.27198
# [47]	validation_0-rmse:2.25765	validation_1-rmse:2.27204
# [48]	validation_0-rmse:2.25620	validation_1-rmse:2.27200
# [49]	validation_0-rmse:2.25444	validation_1-rmse:2.27126
# [50]	validation_0-rmse:2.25353	validation_1-rmse:2.27140
# [51]	validation_0-rmse:2.25124	validation_1-rmse:2.26924
# [52]	validation_0-rmse:2.24855	validation_1-rmse:2.26964
# [53]	validation_0-rmse:2.24706	validation_1-rmse:2.26830
# [54]	validation_0-rmse:2.24624	validation_1-rmse:2.26825
# [55]	validation_0-rmse:2.24449	validation_1-rmse:2.26792
# [56]	validation_0-rmse:2.24383	validation_1-rmse:2.26805
# [57]	validation_0-rmse:2.24288	validation_1-rmse:2.26881
# [58]	validation_0-rmse:2.24069	validation_1-rmse:2.26946
# [59]	validation_0-rmse:2.23970	validation_1-rmse:2.26976
# [60]	validation_0-rmse:2.23855	validation_1-rmse:2.26892
# [0]	validation_0-rmse:4.59515	validation_1-rmse:4.49088
# [1]	validation_0-rmse:4.28597	validation_1-rmse:4.18907
# [2]	validation_0-rmse:4.01383	validation_1-rmse:3.92285
# [3]	validation_0-rmse:3.77576	validation_1-rmse:3.68529
# [4]	validation_0-rmse:3.56729	validation_1-rmse:3.47893
# [5]	validation_0-rmse:3.38851	validation_1-rmse:3.30317
# [6]	validation_0-rmse:3.23256	validation_1-rmse:3.15240
# [7]	validation_0-rmse:3.09527	validation_1-rmse:3.02042
# [8]	validation_0-rmse:2.97832	validation_1-rmse:2.90650
# [9]	validation_0-rmse:2.87784	validation_1-rmse:2.81002
# [10]	validation_0-rmse:2.79048	validation_1-rmse:2.72564
# [11]	validation_0-rmse:2.71841	validation_1-rmse:2.65709
# [12]	validation_0-rmse:2.65681	validation_1-rmse:2.60077
# [13]	validation_0-rmse:2.60346	validation_1-rmse:2.55115
# [14]	validation_0-rmse:2.55730	validation_1-rmse:2.50671
# [15]	validation_0-rmse:2.52209	validation_1-rmse:2.47368
# [16]	validation_0-rmse:2.48980	validation_1-rmse:2.44512
# [17]	validation_0-rmse:2.46252	validation_1-rmse:2.42142
# [18]	validation_0-rmse:2.43943	validation_1-rmse:2.40124
# [19]	validation_0-rmse:2.42023	validation_1-rmse:2.38431
# [20]	validation_0-rmse:2.40347	validation_1-rmse:2.36944
# [21]	validation_0-rmse:2.38863	validation_1-rmse:2.35581
# [22]	validation_0-rmse:2.37407	validation_1-rmse:2.34326
# [23]	validation_0-rmse:2.36319	validation_1-rmse:2.33568
# [24]	validation_0-rmse:2.35191	validation_1-rmse:2.32658
# [25]	validation_0-rmse:2.34294	validation_1-rmse:2.32007
# [26]	validation_0-rmse:2.33596	validation_1-rmse:2.31500
# [27]	validation_0-rmse:2.32899	validation_1-rmse:2.31024
# [28]	validation_0-rmse:2.32388	validation_1-rmse:2.30684
# [29]	validation_0-rmse:2.31789	validation_1-rmse:2.30278
# [30]	validation_0-rmse:2.31259	validation_1-rmse:2.29932
# [31]	validation_0-rmse:2.30929	validation_1-rmse:2.29733
# [32]	validation_0-rmse:2.30440	validation_1-rmse:2.29351
# [33]	validation_0-rmse:2.30073	validation_1-rmse:2.29025
# [34]	validation_0-rmse:2.29707	validation_1-rmse:2.28892
# [35]	validation_0-rmse:2.29406	validation_1-rmse:2.28784
# [36]	validation_0-rmse:2.29241	validation_1-rmse:2.28652
# [37]	validation_0-rmse:2.29066	validation_1-rmse:2.28523
# [38]	validation_0-rmse:2.28775	validation_1-rmse:2.28310
# [39]	validation_0-rmse:2.28575	validation_1-rmse:2.28265
# [40]	validation_0-rmse:2.28429	validation_1-rmse:2.28187
# [41]	validation_0-rmse:2.28276	validation_1-rmse:2.28164
# [42]	validation_0-rmse:2.28037	validation_1-rmse:2.28078
# [43]	validation_0-rmse:2.27909	validation_1-rmse:2.28026
# [44]	validation_0-rmse:2.27813	validation_1-rmse:2.28028
# [45]	validation_0-rmse:2.27710	validation_1-rmse:2.28046
# [46]	validation_0-rmse:2.27502	validation_1-rmse:2.27924
# [47]	validation_0-rmse:2.27420	validation_1-rmse:2.27907
# [48]	validation_0-rmse:2.27326	validation_1-rmse:2.27925
# [49]	validation_0-rmse:2.27266	validation_1-rmse:2.27870
# [50]	validation_0-rmse:2.27119	validation_1-rmse:2.27868
# [51]	validation_0-rmse:2.27090	validation_1-rmse:2.27855
# [52]	validation_0-rmse:2.26878	validation_1-rmse:2.27756
# [53]	validation_0-rmse:2.26821	validation_1-rmse:2.27790
# [54]	validation_0-rmse:2.26709	validation_1-rmse:2.27793
# [55]	validation_0-rmse:2.26507	validation_1-rmse:2.27884
# [56]	validation_0-rmse:2.26511	validation_1-rmse:2.27889
# [57]	validation_0-rmse:2.26339	validation_1-rmse:2.27795
# [0]	validation_0-rmse:4.59500	validation_1-rmse:4.48894
# [1]	validation_0-rmse:4.28819	validation_1-rmse:4.18654
# [2]	validation_0-rmse:4.01621	validation_1-rmse:3.91955
# [3]	validation_0-rmse:3.78101	validation_1-rmse:3.68546
# [4]	validation_0-rmse:3.57305	validation_1-rmse:3.48188
# [5]	validation_0-rmse:3.39534	validation_1-rmse:3.30789
# [6]	validation_0-rmse:3.24821	validation_1-rmse:3.16029
# [7]	validation_0-rmse:3.11292	validation_1-rmse:3.02818
# [8]	validation_0-rmse:2.99602	validation_1-rmse:2.91538
# [9]	validation_0-rmse:2.89776	validation_1-rmse:2.82049
# [10]	validation_0-rmse:2.81115	validation_1-rmse:2.73655
# [11]	validation_0-rmse:2.74320	validation_1-rmse:2.67016
# [12]	validation_0-rmse:2.67960	validation_1-rmse:2.61101
# [13]	validation_0-rmse:2.62451	validation_1-rmse:2.56022
# [14]	validation_0-rmse:2.58128	validation_1-rmse:2.51909
# [15]	validation_0-rmse:2.54072	validation_1-rmse:2.48389
# [16]	validation_0-rmse:2.50699	validation_1-rmse:2.45490
# [17]	validation_0-rmse:2.48100	validation_1-rmse:2.43072
# [18]	validation_0-rmse:2.45612	validation_1-rmse:2.40849
# [19]	validation_0-rmse:2.43375	validation_1-rmse:2.39038
# [20]	validation_0-rmse:2.41495	validation_1-rmse:2.37595
# [21]	validation_0-rmse:2.40085	validation_1-rmse:2.36373
# [22]	validation_0-rmse:2.38863	validation_1-rmse:2.35319
# [23]	validation_0-rmse:2.37475	validation_1-rmse:2.34131
# [24]	validation_0-rmse:2.36418	validation_1-rmse:2.33378
# [25]	validation_0-rmse:2.35514	validation_1-rmse:2.32641
# [26]	validation_0-rmse:2.34538	validation_1-rmse:2.31813
# [27]	validation_0-rmse:2.33861	validation_1-rmse:2.31164
# [28]	validation_0-rmse:2.33235	validation_1-rmse:2.30741
# [29]	validation_0-rmse:2.32557	validation_1-rmse:2.30278
# [30]	validation_0-rmse:2.32046	validation_1-rmse:2.29908
# [31]	validation_0-rmse:2.31656	validation_1-rmse:2.29547
# [32]	validation_0-rmse:2.31288	validation_1-rmse:2.29275
# [33]	validation_0-rmse:2.30878	validation_1-rmse:2.29018
# [34]	validation_0-rmse:2.30549	validation_1-rmse:2.28791
# [35]	validation_0-rmse:2.29966	validation_1-rmse:2.28453
# [36]	validation_0-rmse:2.29707	validation_1-rmse:2.28375
# [37]	validation_0-rmse:2.29317	validation_1-rmse:2.28211
# [38]	validation_0-rmse:2.29047	validation_1-rmse:2.27982
# [39]	validation_0-rmse:2.28731	validation_1-rmse:2.27870
# [40]	validation_0-rmse:2.28467	validation_1-rmse:2.27798
# [41]	validation_0-rmse:2.28300	validation_1-rmse:2.27790
# [42]	validation_0-rmse:2.28110	validation_1-rmse:2.27800
# [43]	validation_0-rmse:2.27924	validation_1-rmse:2.27709
# [44]	validation_0-rmse:2.27758	validation_1-rmse:2.27626
# [45]	validation_0-rmse:2.27634	validation_1-rmse:2.27625
# [46]	validation_0-rmse:2.27419	validation_1-rmse:2.27706
# [47]	validation_0-rmse:2.27298	validation_1-rmse:2.27637
# [48]	validation_0-rmse:2.27027	validation_1-rmse:2.27420
# [49]	validation_0-rmse:2.26906	validation_1-rmse:2.27373
# [50]	validation_0-rmse:2.26789	validation_1-rmse:2.27452
# [51]	validation_0-rmse:2.26545	validation_1-rmse:2.27269
# [52]	validation_0-rmse:2.26537	validation_1-rmse:2.27368
# [53]	validation_0-rmse:2.26520	validation_1-rmse:2.27364
# [54]	validation_0-rmse:2.26440	validation_1-rmse:2.27386
# [55]	validation_0-rmse:2.26260	validation_1-rmse:2.27443
# [0]	validation_0-rmse:4.57922	validation_1-rmse:4.47316
# [1]	validation_0-rmse:4.26267	validation_1-rmse:4.15908
# [2]	validation_0-rmse:3.98312	validation_1-rmse:3.88528
# [3]	validation_0-rmse:3.73789	validation_1-rmse:3.64690
# [4]	validation_0-rmse:3.52555	validation_1-rmse:3.44118
# [5]	validation_0-rmse:3.34146	validation_1-rmse:3.26324
# [6]	validation_0-rmse:3.18381	validation_1-rmse:3.11150
# [7]	validation_0-rmse:3.04654	validation_1-rmse:2.97651
# [8]	validation_0-rmse:2.93068	validation_1-rmse:2.86488
# [9]	validation_0-rmse:2.83195	validation_1-rmse:2.77109
# [10]	validation_0-rmse:2.74872	validation_1-rmse:2.69242
# [11]	validation_0-rmse:2.67693	validation_1-rmse:2.62469
# [12]	validation_0-rmse:2.61618	validation_1-rmse:2.56785
# [13]	validation_0-rmse:2.56550	validation_1-rmse:2.52221
# [14]	validation_0-rmse:2.51764	validation_1-rmse:2.47649
# [15]	validation_0-rmse:2.48177	validation_1-rmse:2.44374
# [16]	validation_0-rmse:2.44989	validation_1-rmse:2.41418
# [17]	validation_0-rmse:2.42212	validation_1-rmse:2.38788
# [18]	validation_0-rmse:2.40057	validation_1-rmse:2.37008
# [19]	validation_0-rmse:2.38325	validation_1-rmse:2.35456
# [20]	validation_0-rmse:2.36692	validation_1-rmse:2.34032
# [21]	validation_0-rmse:2.35376	validation_1-rmse:2.32990
# [22]	validation_0-rmse:2.34247	validation_1-rmse:2.32170
# [23]	validation_0-rmse:2.33188	validation_1-rmse:2.31314
# [24]	validation_0-rmse:2.32314	validation_1-rmse:2.30568
# [25]	validation_0-rmse:2.31613	validation_1-rmse:2.30183
# [26]	validation_0-rmse:2.30994	validation_1-rmse:2.29718
# [27]	validation_0-rmse:2.30468	validation_1-rmse:2.29370
# [28]	validation_0-rmse:2.30007	validation_1-rmse:2.29064
# [29]	validation_0-rmse:2.29647	validation_1-rmse:2.28858
# [30]	validation_0-rmse:2.29295	validation_1-rmse:2.28708
# [31]	validation_0-rmse:2.28979	validation_1-rmse:2.28557
# [32]	validation_0-rmse:2.28774	validation_1-rmse:2.28480
# [33]	validation_0-rmse:2.28510	validation_1-rmse:2.28423
# [34]	validation_0-rmse:2.28254	validation_1-rmse:2.28416
# [35]	validation_0-rmse:2.28086	validation_1-rmse:2.28440
# [36]	validation_0-rmse:2.27885	validation_1-rmse:2.28386
# [37]	validation_0-rmse:2.27659	validation_1-rmse:2.28314
# [38]	validation_0-rmse:2.27543	validation_1-rmse:2.28339
# [39]	validation_0-rmse:2.27380	validation_1-rmse:2.28360
# [40]	validation_0-rmse:2.27179	validation_1-rmse:2.28353
# [41]	validation_0-rmse:2.27056	validation_1-rmse:2.28471
# [0]	validation_0-rmse:4.59467	validation_1-rmse:4.49044
# [1]	validation_0-rmse:4.28505	validation_1-rmse:4.18828
# [2]	validation_0-rmse:4.01254	validation_1-rmse:3.92175
# [3]	validation_0-rmse:3.77434	validation_1-rmse:3.68409
# [4]	validation_0-rmse:3.56555	validation_1-rmse:3.47747
# [5]	validation_0-rmse:3.38670	validation_1-rmse:3.30166
# [6]	validation_0-rmse:3.23074	validation_1-rmse:3.15090
# [7]	validation_0-rmse:3.09327	validation_1-rmse:3.01886
# [8]	validation_0-rmse:2.97634	validation_1-rmse:2.90497
# [9]	validation_0-rmse:2.87583	validation_1-rmse:2.80853
# [10]	validation_0-rmse:2.78861	validation_1-rmse:2.72428
# [11]	validation_0-rmse:2.71663	validation_1-rmse:2.65582
# [12]	validation_0-rmse:2.65510	validation_1-rmse:2.59959
# [13]	validation_0-rmse:2.60186	validation_1-rmse:2.55007
# [14]	validation_0-rmse:2.55614	validation_1-rmse:2.50672
# [15]	validation_0-rmse:2.52073	validation_1-rmse:2.47366
# [16]	validation_0-rmse:2.48826	validation_1-rmse:2.44422
# [17]	validation_0-rmse:2.46218	validation_1-rmse:2.42024
# [18]	validation_0-rmse:2.43982	validation_1-rmse:2.40079
# [19]	validation_0-rmse:2.41927	validation_1-rmse:2.38336
# [20]	validation_0-rmse:2.40159	validation_1-rmse:2.36893
# [21]	validation_0-rmse:2.38760	validation_1-rmse:2.35774
# [22]	validation_0-rmse:2.37465	validation_1-rmse:2.34822
# [23]	validation_0-rmse:2.36232	validation_1-rmse:2.33777
# [24]	validation_0-rmse:2.35299	validation_1-rmse:2.32950
# [25]	validation_0-rmse:2.34444	validation_1-rmse:2.32288
# [26]	validation_0-rmse:2.33605	validation_1-rmse:2.31649
# [27]	validation_0-rmse:2.32809	validation_1-rmse:2.31032
# [28]	validation_0-rmse:2.32237	validation_1-rmse:2.30621
# [29]	validation_0-rmse:2.31678	validation_1-rmse:2.30198
# [30]	validation_0-rmse:2.31284	validation_1-rmse:2.29838
# [31]	validation_0-rmse:2.30809	validation_1-rmse:2.29606
# [32]	validation_0-rmse:2.30299	validation_1-rmse:2.29223
# [33]	validation_0-rmse:2.29988	validation_1-rmse:2.29102
# [34]	validation_0-rmse:2.29742	validation_1-rmse:2.29014
# [35]	validation_0-rmse:2.29496	validation_1-rmse:2.28776
# [36]	validation_0-rmse:2.29299	validation_1-rmse:2.28680
# [37]	validation_0-rmse:2.29081	validation_1-rmse:2.28533
# [38]	validation_0-rmse:2.28771	validation_1-rmse:2.28380
# [39]	validation_0-rmse:2.28494	validation_1-rmse:2.28225
# [40]	validation_0-rmse:2.28384	validation_1-rmse:2.28181
# [41]	validation_0-rmse:2.28202	validation_1-rmse:2.28171
# [42]	validation_0-rmse:2.28013	validation_1-rmse:2.28123
# [43]	validation_0-rmse:2.27921	validation_1-rmse:2.28100
# [44]	validation_0-rmse:2.27838	validation_1-rmse:2.28067
# [45]	validation_0-rmse:2.27758	validation_1-rmse:2.28068
# [46]	validation_0-rmse:2.27582	validation_1-rmse:2.27951
# [47]	validation_0-rmse:2.27478	validation_1-rmse:2.27934
# [48]	validation_0-rmse:2.27258	validation_1-rmse:2.27919
# [49]	validation_0-rmse:2.27109	validation_1-rmse:2.27903
# [50]	validation_0-rmse:2.26876	validation_1-rmse:2.27712
# [51]	validation_0-rmse:2.26843	validation_1-rmse:2.27712
# [52]	validation_0-rmse:2.26592	validation_1-rmse:2.27567
# [53]	validation_0-rmse:2.26466	validation_1-rmse:2.27560
# [54]	validation_0-rmse:2.26352	validation_1-rmse:2.27597
# [55]	validation_0-rmse:2.26206	validation_1-rmse:2.27546
# [56]	validation_0-rmse:2.26030	validation_1-rmse:2.27460
# [57]	validation_0-rmse:2.25982	validation_1-rmse:2.27460
# [58]	validation_0-rmse:2.25756	validation_1-rmse:2.27448
# [59]	validation_0-rmse:2.25581	validation_1-rmse:2.27336
# [60]	validation_0-rmse:2.25468	validation_1-rmse:2.27294
# [61]	validation_0-rmse:2.25423	validation_1-rmse:2.27306
# [62]	validation_0-rmse:2.25257	validation_1-rmse:2.27240
# [63]	validation_0-rmse:2.25169	validation_1-rmse:2.27263
# [64]	validation_0-rmse:2.25039	validation_1-rmse:2.27187
# [65]	validation_0-rmse:2.25000	validation_1-rmse:2.27188
# [66]	validation_0-rmse:2.24943	validation_1-rmse:2.27202
# [67]	validation_0-rmse:2.24782	validation_1-rmse:2.27282
# [68]	validation_0-rmse:2.24668	validation_1-rmse:2.27286
# [0]	validation_0-rmse:4.59440	validation_1-rmse:4.48841
# [1]	validation_0-rmse:4.28724	validation_1-rmse:4.18571
# [2]	validation_0-rmse:4.01475	validation_1-rmse:3.91832
# [3]	validation_0-rmse:3.77937	validation_1-rmse:3.68408
# [4]	validation_0-rmse:3.57107	validation_1-rmse:3.48024
# [5]	validation_0-rmse:3.39285	validation_1-rmse:3.30666
# [6]	validation_0-rmse:3.24529	validation_1-rmse:3.15879
# [7]	validation_0-rmse:3.11005	validation_1-rmse:3.02678
# [8]	validation_0-rmse:2.99308	validation_1-rmse:2.91403
# [9]	validation_0-rmse:2.89988	validation_1-rmse:2.82213
# [10]	validation_0-rmse:2.81915	validation_1-rmse:2.74154
# [11]	validation_0-rmse:2.74409	validation_1-rmse:2.67188
# [12]	validation_0-rmse:2.67960	validation_1-rmse:2.61183
# [13]	validation_0-rmse:2.63008	validation_1-rmse:2.56294
# [14]	validation_0-rmse:2.58331	validation_1-rmse:2.52239
# [15]	validation_0-rmse:2.54753	validation_1-rmse:2.48931
# [16]	validation_0-rmse:2.51212	validation_1-rmse:2.45787
# [17]	validation_0-rmse:2.48193	validation_1-rmse:2.43219
# [18]	validation_0-rmse:2.45872	validation_1-rmse:2.41227
# [19]	validation_0-rmse:2.43630	validation_1-rmse:2.39415
# [20]	validation_0-rmse:2.41937	validation_1-rmse:2.37761
# [21]	validation_0-rmse:2.40334	validation_1-rmse:2.36399
# [22]	validation_0-rmse:2.39053	validation_1-rmse:2.35260
# [23]	validation_0-rmse:2.37613	validation_1-rmse:2.34111
# [24]	validation_0-rmse:2.36513	validation_1-rmse:2.33281
# [25]	validation_0-rmse:2.35608	validation_1-rmse:2.32524
# [26]	validation_0-rmse:2.34914	validation_1-rmse:2.31940
# [27]	validation_0-rmse:2.34106	validation_1-rmse:2.31329
# [28]	validation_0-rmse:2.33149	validation_1-rmse:2.30673
# [29]	validation_0-rmse:2.32586	validation_1-rmse:2.30313
# [30]	validation_0-rmse:2.32095	validation_1-rmse:2.30030
# [31]	validation_0-rmse:2.31607	validation_1-rmse:2.29708
# [32]	validation_0-rmse:2.30969	validation_1-rmse:2.29315
# [33]	validation_0-rmse:2.30617	validation_1-rmse:2.29068
# [34]	validation_0-rmse:2.30277	validation_1-rmse:2.28836
# [35]	validation_0-rmse:2.29994	validation_1-rmse:2.28652
# [36]	validation_0-rmse:2.29624	validation_1-rmse:2.28402
# [37]	validation_0-rmse:2.29380	validation_1-rmse:2.28336
# [38]	validation_0-rmse:2.29053	validation_1-rmse:2.28205
# [39]	validation_0-rmse:2.28837	validation_1-rmse:2.28070
# [40]	validation_0-rmse:2.28579	validation_1-rmse:2.28005
# [41]	validation_0-rmse:2.28291	validation_1-rmse:2.27881
# [42]	validation_0-rmse:2.28131	validation_1-rmse:2.27891
# [43]	validation_0-rmse:2.27937	validation_1-rmse:2.27738
# [44]	validation_0-rmse:2.27766	validation_1-rmse:2.27738
# [45]	validation_0-rmse:2.27622	validation_1-rmse:2.27734
# [46]	validation_0-rmse:2.27356	validation_1-rmse:2.27635
# [47]	validation_0-rmse:2.27263	validation_1-rmse:2.27609
# [48]	validation_0-rmse:2.27105	validation_1-rmse:2.27606
# [49]	validation_0-rmse:2.27064	validation_1-rmse:2.27577
# [50]	validation_0-rmse:2.26844	validation_1-rmse:2.27676
# [51]	validation_0-rmse:2.26707	validation_1-rmse:2.27565
# [52]	validation_0-rmse:2.26524	validation_1-rmse:2.27701
# [53]	validation_0-rmse:2.26501	validation_1-rmse:2.27698
# [54]	validation_0-rmse:2.26382	validation_1-rmse:2.27646
# [55]	validation_0-rmse:2.26309	validation_1-rmse:2.27693
# [56]	validation_0-rmse:2.26190	validation_1-rmse:2.27680
# [0]	validation_0-rmse:4.57883	validation_1-rmse:4.47281
# [1]	validation_0-rmse:4.26193	validation_1-rmse:4.15841
# [2]	validation_0-rmse:3.98202	validation_1-rmse:3.88409
# [3]	validation_0-rmse:3.73656	validation_1-rmse:3.64557
# [4]	validation_0-rmse:3.52414	validation_1-rmse:3.43981
# [5]	validation_0-rmse:3.33988	validation_1-rmse:3.26178
# [6]	validation_0-rmse:3.18219	validation_1-rmse:3.11004
# [7]	validation_0-rmse:3.04495	validation_1-rmse:2.97510
# [8]	validation_0-rmse:2.92915	validation_1-rmse:2.86355
# [9]	validation_0-rmse:2.83095	validation_1-rmse:2.77129
# [10]	validation_0-rmse:2.74718	validation_1-rmse:2.69168
# [11]	validation_0-rmse:2.67510	validation_1-rmse:2.62254
# [12]	validation_0-rmse:2.61431	validation_1-rmse:2.56562
# [13]	validation_0-rmse:2.56405	validation_1-rmse:2.51924
# [14]	validation_0-rmse:2.52077	validation_1-rmse:2.47873
# [15]	validation_0-rmse:2.48114	validation_1-rmse:2.44229
# [16]	validation_0-rmse:2.44985	validation_1-rmse:2.41455
# [17]	validation_0-rmse:2.42519	validation_1-rmse:2.39256
# [18]	validation_0-rmse:2.40380	validation_1-rmse:2.37486
# [19]	validation_0-rmse:2.38355	validation_1-rmse:2.35582
# [20]	validation_0-rmse:2.36558	validation_1-rmse:2.33974
# [21]	validation_0-rmse:2.35186	validation_1-rmse:2.32727
# [22]	validation_0-rmse:2.34023	validation_1-rmse:2.31735
# [23]	validation_0-rmse:2.33015	validation_1-rmse:2.31052
# [24]	validation_0-rmse:2.32152	validation_1-rmse:2.30548
# [25]	validation_0-rmse:2.31431	validation_1-rmse:2.30046
# [26]	validation_0-rmse:2.30745	validation_1-rmse:2.29450
# [27]	validation_0-rmse:2.30154	validation_1-rmse:2.28996
# [28]	validation_0-rmse:2.29634	validation_1-rmse:2.28620
# [29]	validation_0-rmse:2.29261	validation_1-rmse:2.28496
# [30]	validation_0-rmse:2.28908	validation_1-rmse:2.28319
# [31]	validation_0-rmse:2.28607	validation_1-rmse:2.28182
# [32]	validation_0-rmse:2.28291	validation_1-rmse:2.28055
# [33]	validation_0-rmse:2.28103	validation_1-rmse:2.27973
# [34]	validation_0-rmse:2.27847	validation_1-rmse:2.27970
# [35]	validation_0-rmse:2.27615	validation_1-rmse:2.27875
# [36]	validation_0-rmse:2.27349	validation_1-rmse:2.27710
# [37]	validation_0-rmse:2.27219	validation_1-rmse:2.27649
# [38]	validation_0-rmse:2.26997	validation_1-rmse:2.27442
# [39]	validation_0-rmse:2.26777	validation_1-rmse:2.27415
# [40]	validation_0-rmse:2.26663	validation_1-rmse:2.27393
# [41]	validation_0-rmse:2.26455	validation_1-rmse:2.27337
# [42]	validation_0-rmse:2.26281	validation_1-rmse:2.27312
# [43]	validation_0-rmse:2.26135	validation_1-rmse:2.27332
# [44]	validation_0-rmse:2.26017	validation_1-rmse:2.27296
# [45]	validation_0-rmse:2.25904	validation_1-rmse:2.27305
# [46]	validation_0-rmse:2.25909	validation_1-rmse:2.27198
# [47]	validation_0-rmse:2.25768	validation_1-rmse:2.27203
# [48]	validation_0-rmse:2.25621	validation_1-rmse:2.27200
# [49]	validation_0-rmse:2.25445	validation_1-rmse:2.27125
# [50]	validation_0-rmse:2.25354	validation_1-rmse:2.27140
# [51]	validation_0-rmse:2.25125	validation_1-rmse:2.26924
# [52]	validation_0-rmse:2.24856	validation_1-rmse:2.26964
# [53]	validation_0-rmse:2.24677	validation_1-rmse:2.26828
# [54]	validation_0-rmse:2.24595	validation_1-rmse:2.26823
# [55]	validation_0-rmse:2.24420	validation_1-rmse:2.26790
# [56]	validation_0-rmse:2.24354	validation_1-rmse:2.26804
# [57]	validation_0-rmse:2.24260	validation_1-rmse:2.26878
# [58]	validation_0-rmse:2.24040	validation_1-rmse:2.26944
# [59]	validation_0-rmse:2.23943	validation_1-rmse:2.26973
# [0]	validation_0-rmse:4.59515	validation_1-rmse:4.49088
# [1]	validation_0-rmse:4.28598	validation_1-rmse:4.18908
# [2]	validation_0-rmse:4.01383	validation_1-rmse:3.92286
# [3]	validation_0-rmse:3.77577	validation_1-rmse:3.68530
# [4]	validation_0-rmse:3.56730	validation_1-rmse:3.47894
# [5]	validation_0-rmse:3.38852	validation_1-rmse:3.30318
# [6]	validation_0-rmse:3.23257	validation_1-rmse:3.15241
# [7]	validation_0-rmse:3.09528	validation_1-rmse:3.02044
# [8]	validation_0-rmse:2.97834	validation_1-rmse:2.90651
# [9]	validation_0-rmse:2.87786	validation_1-rmse:2.81003
# [10]	validation_0-rmse:2.79049	validation_1-rmse:2.72566
# [11]	validation_0-rmse:2.71842	validation_1-rmse:2.65710
# [12]	validation_0-rmse:2.65683	validation_1-rmse:2.60078
# [13]	validation_0-rmse:2.60347	validation_1-rmse:2.55116
# [14]	validation_0-rmse:2.55732	validation_1-rmse:2.50672
# [15]	validation_0-rmse:2.52210	validation_1-rmse:2.47369
# [16]	validation_0-rmse:2.48982	validation_1-rmse:2.44513
# [17]	validation_0-rmse:2.46254	validation_1-rmse:2.42143
# [18]	validation_0-rmse:2.43944	validation_1-rmse:2.40125
# [19]	validation_0-rmse:2.42024	validation_1-rmse:2.38432
# [20]	validation_0-rmse:2.40349	validation_1-rmse:2.36945
# [21]	validation_0-rmse:2.38864	validation_1-rmse:2.35582
# [22]	validation_0-rmse:2.37408	validation_1-rmse:2.34326
# [23]	validation_0-rmse:2.36321	validation_1-rmse:2.33569
# [24]	validation_0-rmse:2.35192	validation_1-rmse:2.32658
# [25]	validation_0-rmse:2.34296	validation_1-rmse:2.32007
# [26]	validation_0-rmse:2.33597	validation_1-rmse:2.31500
# [27]	validation_0-rmse:2.32946	validation_1-rmse:2.31063
# [28]	validation_0-rmse:2.32407	validation_1-rmse:2.30695
# [29]	validation_0-rmse:2.31938	validation_1-rmse:2.30449
# [30]	validation_0-rmse:2.31401	validation_1-rmse:2.30113
# [31]	validation_0-rmse:2.31009	validation_1-rmse:2.29789
# [32]	validation_0-rmse:2.30627	validation_1-rmse:2.29573
# [33]	validation_0-rmse:2.30245	validation_1-rmse:2.29271
# [34]	validation_0-rmse:2.29806	validation_1-rmse:2.29089
# [35]	validation_0-rmse:2.29498	validation_1-rmse:2.28952
# [36]	validation_0-rmse:2.29179	validation_1-rmse:2.28727
# [37]	validation_0-rmse:2.28990	validation_1-rmse:2.28584
# [38]	validation_0-rmse:2.28681	validation_1-rmse:2.28388
# [39]	validation_0-rmse:2.28520	validation_1-rmse:2.28302
# [40]	validation_0-rmse:2.28258	validation_1-rmse:2.28092
# [41]	validation_0-rmse:2.28115	validation_1-rmse:2.28062
# [42]	validation_0-rmse:2.27939	validation_1-rmse:2.28013
# [43]	validation_0-rmse:2.27816	validation_1-rmse:2.27959
# [44]	validation_0-rmse:2.27729	validation_1-rmse:2.27964
# [45]	validation_0-rmse:2.27653	validation_1-rmse:2.27939
# [46]	validation_0-rmse:2.27560	validation_1-rmse:2.27957
# [47]	validation_0-rmse:2.27513	validation_1-rmse:2.27903
# [48]	validation_0-rmse:2.27374	validation_1-rmse:2.27887
# [49]	validation_0-rmse:2.27131	validation_1-rmse:2.27678
# [50]	validation_0-rmse:2.27050	validation_1-rmse:2.27698
# [51]	validation_0-rmse:2.26929	validation_1-rmse:2.27699
# [52]	validation_0-rmse:2.26707	validation_1-rmse:2.27601
# [53]	validation_0-rmse:2.26665	validation_1-rmse:2.27577
# [54]	validation_0-rmse:2.26486	validation_1-rmse:2.27512
# [55]	validation_0-rmse:2.26285	validation_1-rmse:2.27605
# [56]	validation_0-rmse:2.26195	validation_1-rmse:2.27609
# [57]	validation_0-rmse:2.26091	validation_1-rmse:2.27576
# [58]	validation_0-rmse:2.25954	validation_1-rmse:2.27526
# [0]	validation_0-rmse:4.59501	validation_1-rmse:4.48894
# [1]	validation_0-rmse:4.28820	validation_1-rmse:4.18654
# [2]	validation_0-rmse:4.01621	validation_1-rmse:3.91956
# [3]	validation_0-rmse:3.78102	validation_1-rmse:3.68547
# [4]	validation_0-rmse:3.57306	validation_1-rmse:3.48189
# [5]	validation_0-rmse:3.39535	validation_1-rmse:3.30790
# [6]	validation_0-rmse:3.24822	validation_1-rmse:3.16031
# [7]	validation_0-rmse:3.11294	validation_1-rmse:3.02819
# [8]	validation_0-rmse:2.99603	validation_1-rmse:2.91539
# [9]	validation_0-rmse:2.89777	validation_1-rmse:2.82050
# [10]	validation_0-rmse:2.81117	validation_1-rmse:2.73656
# [11]	validation_0-rmse:2.74322	validation_1-rmse:2.67017
# [12]	validation_0-rmse:2.67961	validation_1-rmse:2.61103
# [13]	validation_0-rmse:2.62453	validation_1-rmse:2.56023
# [14]	validation_0-rmse:2.58130	validation_1-rmse:2.51910
# [15]	validation_0-rmse:2.54073	validation_1-rmse:2.48390
# [16]	validation_0-rmse:2.50701	validation_1-rmse:2.45492
# [17]	validation_0-rmse:2.48102	validation_1-rmse:2.43073
# [18]	validation_0-rmse:2.45613	validation_1-rmse:2.40850
# [19]	validation_0-rmse:2.43376	validation_1-rmse:2.39039
# [20]	validation_0-rmse:2.41497	validation_1-rmse:2.37596
# [21]	validation_0-rmse:2.40087	validation_1-rmse:2.36374
# [22]	validation_0-rmse:2.38865	validation_1-rmse:2.35320
# [23]	validation_0-rmse:2.37477	validation_1-rmse:2.34132
# [24]	validation_0-rmse:2.36419	validation_1-rmse:2.33379
# [25]	validation_0-rmse:2.35516	validation_1-rmse:2.32642
# [26]	validation_0-rmse:2.34540	validation_1-rmse:2.31814
# [27]	validation_0-rmse:2.33862	validation_1-rmse:2.31165
# [28]	validation_0-rmse:2.33236	validation_1-rmse:2.30742
# [29]	validation_0-rmse:2.32559	validation_1-rmse:2.30279
# [30]	validation_0-rmse:2.32048	validation_1-rmse:2.29909
# [31]	validation_0-rmse:2.31657	validation_1-rmse:2.29548
# [32]	validation_0-rmse:2.31290	validation_1-rmse:2.29276
# [33]	validation_0-rmse:2.30880	validation_1-rmse:2.29019
# [34]	validation_0-rmse:2.30551	validation_1-rmse:2.28792
# [35]	validation_0-rmse:2.29968	validation_1-rmse:2.28453
# [36]	validation_0-rmse:2.29709	validation_1-rmse:2.28376
# [37]	validation_0-rmse:2.29319	validation_1-rmse:2.28212
# [38]	validation_0-rmse:2.29048	validation_1-rmse:2.27983
# [39]	validation_0-rmse:2.28733	validation_1-rmse:2.27870
# [40]	validation_0-rmse:2.28469	validation_1-rmse:2.27798
# [41]	validation_0-rmse:2.28302	validation_1-rmse:2.27791
# [42]	validation_0-rmse:2.28112	validation_1-rmse:2.27801
# [43]	validation_0-rmse:2.27926	validation_1-rmse:2.27709
# [44]	validation_0-rmse:2.27760	validation_1-rmse:2.27626
# [45]	validation_0-rmse:2.27636	validation_1-rmse:2.27625
# [46]	validation_0-rmse:2.27421	validation_1-rmse:2.27706
# [47]	validation_0-rmse:2.27301	validation_1-rmse:2.27637
# [48]	validation_0-rmse:2.27030	validation_1-rmse:2.27420
# [49]	validation_0-rmse:2.26909	validation_1-rmse:2.27373
# [50]	validation_0-rmse:2.26792	validation_1-rmse:2.27452
# [51]	validation_0-rmse:2.26547	validation_1-rmse:2.27268
# [52]	validation_0-rmse:2.26540	validation_1-rmse:2.27368
# [53]	validation_0-rmse:2.26522	validation_1-rmse:2.27363
# [54]	validation_0-rmse:2.26443	validation_1-rmse:2.27385
# [55]	validation_0-rmse:2.26263	validation_1-rmse:2.27442
# [56]	validation_0-rmse:2.26084	validation_1-rmse:2.27423
# [0]	validation_0-rmse:4.57922	validation_1-rmse:4.47317
# [1]	validation_0-rmse:4.26268	validation_1-rmse:4.15908
# [2]	validation_0-rmse:3.98313	validation_1-rmse:3.88529
# [3]	validation_0-rmse:3.73790	validation_1-rmse:3.64691
# [4]	validation_0-rmse:3.52556	validation_1-rmse:3.44119
# [5]	validation_0-rmse:3.34147	validation_1-rmse:3.26325
# [6]	validation_0-rmse:3.18382	validation_1-rmse:3.11151
# [7]	validation_0-rmse:3.04656	validation_1-rmse:2.97652
# [8]	validation_0-rmse:2.93069	validation_1-rmse:2.86489
# [9]	validation_0-rmse:2.83196	validation_1-rmse:2.77110
# [10]	validation_0-rmse:2.74874	validation_1-rmse:2.69243
# [11]	validation_0-rmse:2.67694	validation_1-rmse:2.62470
# [12]	validation_0-rmse:2.61620	validation_1-rmse:2.56786
# [13]	validation_0-rmse:2.56551	validation_1-rmse:2.52223
# [14]	validation_0-rmse:2.51766	validation_1-rmse:2.47650
# [15]	validation_0-rmse:2.48178	validation_1-rmse:2.44375
# [16]	validation_0-rmse:2.44990	validation_1-rmse:2.41419
# [17]	validation_0-rmse:2.42213	validation_1-rmse:2.38789
# [18]	validation_0-rmse:2.40058	validation_1-rmse:2.37009
# [19]	validation_0-rmse:2.38326	validation_1-rmse:2.35457
# [20]	validation_0-rmse:2.36693	validation_1-rmse:2.34032
# [21]	validation_0-rmse:2.35377	validation_1-rmse:2.32990
# [22]	validation_0-rmse:2.34248	validation_1-rmse:2.32171
# [23]	validation_0-rmse:2.33189	validation_1-rmse:2.31314
# [24]	validation_0-rmse:2.32315	validation_1-rmse:2.30568
# [25]	validation_0-rmse:2.31613	validation_1-rmse:2.30184
# [26]	validation_0-rmse:2.30995	validation_1-rmse:2.29718
# [27]	validation_0-rmse:2.30469	validation_1-rmse:2.29370
# [28]	validation_0-rmse:2.30008	validation_1-rmse:2.29064
# [29]	validation_0-rmse:2.29648	validation_1-rmse:2.28858
# [30]	validation_0-rmse:2.29296	validation_1-rmse:2.28708
# [31]	validation_0-rmse:2.28980	validation_1-rmse:2.28557
# [32]	validation_0-rmse:2.28774	validation_1-rmse:2.28479
# [33]	validation_0-rmse:2.28511	validation_1-rmse:2.28423
# [34]	validation_0-rmse:2.28255	validation_1-rmse:2.28416
# [35]	validation_0-rmse:2.28086	validation_1-rmse:2.28440
# [36]	validation_0-rmse:2.27886	validation_1-rmse:2.28386
# [37]	validation_0-rmse:2.27660	validation_1-rmse:2.28314
# [38]	validation_0-rmse:2.27544	validation_1-rmse:2.28339
# [39]	validation_0-rmse:2.27381	validation_1-rmse:2.28360
# [40]	validation_0-rmse:2.27181	validation_1-rmse:2.28352
# [41]	validation_0-rmse:2.27057	validation_1-rmse:2.28471
# [42]	validation_0-rmse:2.26912	validation_1-rmse:2.28482
# [0]	validation_0-rmse:4.57664	validation_1-rmse:4.47723
# [1]	validation_0-rmse:4.24378	validation_1-rmse:4.15409
# [2]	validation_0-rmse:3.95391	validation_1-rmse:3.87260
# [3]	validation_0-rmse:3.70252	validation_1-rmse:3.62711
# [4]	validation_0-rmse:3.48101	validation_1-rmse:3.41665
# [5]	validation_0-rmse:3.29438	validation_1-rmse:3.23958
# [6]	validation_0-rmse:3.13109	validation_1-rmse:3.08109
# [7]	validation_0-rmse:2.99185	validation_1-rmse:2.94912
# [8]	validation_0-rmse:2.87160	validation_1-rmse:2.83623
# [9]	validation_0-rmse:2.77173	validation_1-rmse:2.74534
# [10]	validation_0-rmse:2.68355	validation_1-rmse:2.66501
# [11]	validation_0-rmse:2.61070	validation_1-rmse:2.59858
# [12]	validation_0-rmse:2.54827	validation_1-rmse:2.54440
# [13]	validation_0-rmse:2.49475	validation_1-rmse:2.49928
# [14]	validation_0-rmse:2.44606	validation_1-rmse:2.45890
# [15]	validation_0-rmse:2.40809	validation_1-rmse:2.43030
# [16]	validation_0-rmse:2.37481	validation_1-rmse:2.40332
# [17]	validation_0-rmse:2.34535	validation_1-rmse:2.38145
# [18]	validation_0-rmse:2.31943	validation_1-rmse:2.36269
# [19]	validation_0-rmse:2.29910	validation_1-rmse:2.35071
# [20]	validation_0-rmse:2.28282	validation_1-rmse:2.33958
# [21]	validation_0-rmse:2.26564	validation_1-rmse:2.32554
# [22]	validation_0-rmse:2.25145	validation_1-rmse:2.32067
# [23]	validation_0-rmse:2.23944	validation_1-rmse:2.31484
# [24]	validation_0-rmse:2.22813	validation_1-rmse:2.31295
# [25]	validation_0-rmse:2.21824	validation_1-rmse:2.30645
# [26]	validation_0-rmse:2.20895	validation_1-rmse:2.30240
# [27]	validation_0-rmse:2.19990	validation_1-rmse:2.29947
# [28]	validation_0-rmse:2.19024	validation_1-rmse:2.29437
# [29]	validation_0-rmse:2.18335	validation_1-rmse:2.29213
# [30]	validation_0-rmse:2.17721	validation_1-rmse:2.29040
# [31]	validation_0-rmse:2.17004	validation_1-rmse:2.28720
# [32]	validation_0-rmse:2.16396	validation_1-rmse:2.28572
# [33]	validation_0-rmse:2.15773	validation_1-rmse:2.28448
# [34]	validation_0-rmse:2.15280	validation_1-rmse:2.28261
# [35]	validation_0-rmse:2.14691	validation_1-rmse:2.28155
# [36]	validation_0-rmse:2.14535	validation_1-rmse:2.28225
# [37]	validation_0-rmse:2.14411	validation_1-rmse:2.28370
# [38]	validation_0-rmse:2.14122	validation_1-rmse:2.28434
# [39]	validation_0-rmse:2.13821	validation_1-rmse:2.28239
# [40]	validation_0-rmse:2.13442	validation_1-rmse:2.28116
# [41]	validation_0-rmse:2.13129	validation_1-rmse:2.28205
# [42]	validation_0-rmse:2.12815	validation_1-rmse:2.28146
# [43]	validation_0-rmse:2.12505	validation_1-rmse:2.27987
# [44]	validation_0-rmse:2.12130	validation_1-rmse:2.27794
# [45]	validation_0-rmse:2.11831	validation_1-rmse:2.27801
# [46]	validation_0-rmse:2.11624	validation_1-rmse:2.27690
# [47]	validation_0-rmse:2.11526	validation_1-rmse:2.27706
# [48]	validation_0-rmse:2.11386	validation_1-rmse:2.27784
# [49]	validation_0-rmse:2.11093	validation_1-rmse:2.27749
# [50]	validation_0-rmse:2.11054	validation_1-rmse:2.27755
# [51]	validation_0-rmse:2.10798	validation_1-rmse:2.27670
# [52]	validation_0-rmse:2.10739	validation_1-rmse:2.27681
# [53]	validation_0-rmse:2.10362	validation_1-rmse:2.27570
# [54]	validation_0-rmse:2.10293	validation_1-rmse:2.27570
# [55]	validation_0-rmse:2.10162	validation_1-rmse:2.27558
# [56]	validation_0-rmse:2.09934	validation_1-rmse:2.27611
# [57]	validation_0-rmse:2.09942	validation_1-rmse:2.27646
# [58]	validation_0-rmse:2.10355	validation_1-rmse:2.28041
# [59]	validation_0-rmse:2.10247	validation_1-rmse:2.27952
# [60]	validation_0-rmse:2.10014	validation_1-rmse:2.27888
# [0]	validation_0-rmse:4.57448	validation_1-rmse:4.46414
# [1]	validation_0-rmse:4.24699	validation_1-rmse:4.14382
# [2]	validation_0-rmse:3.95831	validation_1-rmse:3.86135
# [3]	validation_0-rmse:3.70860	validation_1-rmse:3.61987
# [4]	validation_0-rmse:3.49268	validation_1-rmse:3.41428
# [5]	validation_0-rmse:3.30615	validation_1-rmse:3.23239
# [6]	validation_0-rmse:3.14196	validation_1-rmse:3.07701
# [7]	validation_0-rmse:3.00259	validation_1-rmse:2.94351
# [8]	validation_0-rmse:2.88289	validation_1-rmse:2.83118
# [9]	validation_0-rmse:2.78146	validation_1-rmse:2.73784
# [10]	validation_0-rmse:2.69298	validation_1-rmse:2.66114
# [11]	validation_0-rmse:2.61759	validation_1-rmse:2.59563
# [12]	validation_0-rmse:2.55287	validation_1-rmse:2.54203
# [13]	validation_0-rmse:2.50442	validation_1-rmse:2.50045
# [14]	validation_0-rmse:2.45936	validation_1-rmse:2.46211
# [15]	validation_0-rmse:2.42616	validation_1-rmse:2.43501
# [16]	validation_0-rmse:2.39614	validation_1-rmse:2.41077
# [17]	validation_0-rmse:2.36507	validation_1-rmse:2.38890
# [18]	validation_0-rmse:2.34422	validation_1-rmse:2.37351
# [19]	validation_0-rmse:2.32224	validation_1-rmse:2.35834
# [20]	validation_0-rmse:2.30499	validation_1-rmse:2.34729
# [21]	validation_0-rmse:2.28691	validation_1-rmse:2.33504
# [22]	validation_0-rmse:2.27274	validation_1-rmse:2.32645
# [23]	validation_0-rmse:2.26083	validation_1-rmse:2.31838
# [24]	validation_0-rmse:2.24930	validation_1-rmse:2.31221
# [25]	validation_0-rmse:2.23794	validation_1-rmse:2.30585
# [26]	validation_0-rmse:2.22945	validation_1-rmse:2.30384
# [27]	validation_0-rmse:2.21887	validation_1-rmse:2.29863
# [28]	validation_0-rmse:2.21080	validation_1-rmse:2.29601
# [29]	validation_0-rmse:2.21203	validation_1-rmse:2.30011
# [30]	validation_0-rmse:2.20686	validation_1-rmse:2.29976
# [31]	validation_0-rmse:2.20088	validation_1-rmse:2.29863
# [32]	validation_0-rmse:2.19503	validation_1-rmse:2.29752
# [33]	validation_0-rmse:2.18899	validation_1-rmse:2.29512
# [34]	validation_0-rmse:2.18335	validation_1-rmse:2.29323
# [35]	validation_0-rmse:2.17766	validation_1-rmse:2.29239
# [36]	validation_0-rmse:2.18429	validation_1-rmse:2.30004
# [37]	validation_0-rmse:2.18839	validation_1-rmse:2.30413
# [38]	validation_0-rmse:2.18306	validation_1-rmse:2.30268
# [39]	validation_0-rmse:2.17848	validation_1-rmse:2.30209
# [40]	validation_0-rmse:2.17413	validation_1-rmse:2.30217
# [0]	validation_0-rmse:4.55925	validation_1-rmse:4.45710
# [1]	validation_0-rmse:4.21847	validation_1-rmse:4.12626
# [2]	validation_0-rmse:3.92344	validation_1-rmse:3.83854
# [3]	validation_0-rmse:3.66025	validation_1-rmse:3.58693
# [4]	validation_0-rmse:3.43655	validation_1-rmse:3.37172
# [5]	validation_0-rmse:3.24097	validation_1-rmse:3.18502
# [6]	validation_0-rmse:3.07465	validation_1-rmse:3.02998
# [7]	validation_0-rmse:2.92887	validation_1-rmse:2.89479
# [8]	validation_0-rmse:2.80220	validation_1-rmse:2.77741
# [9]	validation_0-rmse:2.69704	validation_1-rmse:2.68654
# [10]	validation_0-rmse:2.60624	validation_1-rmse:2.60489
# [11]	validation_0-rmse:2.53097	validation_1-rmse:2.53702
# [12]	validation_0-rmse:2.46750	validation_1-rmse:2.48428
# [13]	validation_0-rmse:2.41235	validation_1-rmse:2.43796
# [14]	validation_0-rmse:2.36789	validation_1-rmse:2.40129
# [15]	validation_0-rmse:2.33028	validation_1-rmse:2.37433
# [16]	validation_0-rmse:2.30167	validation_1-rmse:2.35279
# [17]	validation_0-rmse:2.27668	validation_1-rmse:2.33610
# [18]	validation_0-rmse:2.25624	validation_1-rmse:2.31990
# [19]	validation_0-rmse:2.23844	validation_1-rmse:2.30927
# [20]	validation_0-rmse:2.22201	validation_1-rmse:2.30109
# [21]	validation_0-rmse:2.20820	validation_1-rmse:2.29449
# [22]	validation_0-rmse:2.19861	validation_1-rmse:2.28905
# [23]	validation_0-rmse:2.18701	validation_1-rmse:2.28528
# [24]	validation_0-rmse:2.17948	validation_1-rmse:2.28281
# [25]	validation_0-rmse:2.17103	validation_1-rmse:2.27976
# [26]	validation_0-rmse:2.16418	validation_1-rmse:2.27782
# [27]	validation_0-rmse:2.15617	validation_1-rmse:2.27398
# [28]	validation_0-rmse:2.15259	validation_1-rmse:2.27249
# [29]	validation_0-rmse:2.14782	validation_1-rmse:2.27214
# [30]	validation_0-rmse:2.14345	validation_1-rmse:2.27183
# [31]	validation_0-rmse:2.13761	validation_1-rmse:2.27064
# [32]	validation_0-rmse:2.13585	validation_1-rmse:2.27060
# [33]	validation_0-rmse:2.13120	validation_1-rmse:2.26993
# [34]	validation_0-rmse:2.12820	validation_1-rmse:2.26831
# [35]	validation_0-rmse:2.12362	validation_1-rmse:2.26654
# [36]	validation_0-rmse:2.12237	validation_1-rmse:2.26835
# [37]	validation_0-rmse:2.11894	validation_1-rmse:2.26945
# [38]	validation_0-rmse:2.11696	validation_1-rmse:2.27141
# [39]	validation_0-rmse:2.11381	validation_1-rmse:2.27084
# [40]	validation_0-rmse:2.11238	validation_1-rmse:2.27152
# [0]	validation_0-rmse:4.58516	validation_1-rmse:4.48457
# [1]	validation_0-rmse:4.26068	validation_1-rmse:4.16871
# [2]	validation_0-rmse:3.97068	validation_1-rmse:3.88675
# [3]	validation_0-rmse:3.71692	validation_1-rmse:3.64010
# [4]	validation_0-rmse:3.50030	validation_1-rmse:3.43400
# [5]	validation_0-rmse:3.31220	validation_1-rmse:3.25293
# [6]	validation_0-rmse:3.16238	validation_1-rmse:3.10668
# [7]	validation_0-rmse:3.02775	validation_1-rmse:2.97766
# [8]	validation_0-rmse:2.90785	validation_1-rmse:2.86402
# [9]	validation_0-rmse:2.80880	validation_1-rmse:2.77183
# [10]	validation_0-rmse:2.71988	validation_1-rmse:2.68678
# ...
# [5]	validation_0-rmse:3.22022	validation_1-rmse:3.20386
# [6]	validation_0-rmse:3.04565	validation_1-rmse:3.05297
# [7]	validation_0-rmse:2.89192	validation_1-rmse:2.92334
# [8]	validation_0-rmse:2.75851	validation_1-rmse:2.81712
# [9]	validation_0-rmse:2.64138	validation_1-rmse:2.72335
# [10]	validation_0-rmse:2.54254	validation_1-rmse:2.64325
# [11]	validation_0-rmse:2.45541	validation_1-rmse:2.57859
# [12]	validation_0-rmse:2.38143	validation_1-rmse:2.52921
# [13]	validation_0-rmse:2.31842	validation_1-rmse:2.48833
# [14]	validation_0-rmse:2.26170	validation_1-rmse:2.45498
# [15]	validation_0-rmse:2.21243	validation_1-rmse:2.42717
# [16]	validation_0-rmse:2.17041	validation_1-rmse:2.40381
# [17]	validation_0-rmse:2.13325	validation_1-rmse:2.38585
# [18]	validation_0-rmse:2.10499	validation_1-rmse:2.37079
# [19]	validation_0-rmse:2.07837	validation_1-rmse:2.36028
# [20]	validation_0-rmse:2.05595	validation_1-rmse:2.35125
# [21]	validation_0-rmse:2.03321	validation_1-rmse:2.34110
# [22]	validation_0-rmse:2.01270	validation_1-rmse:2.33620
# [23]	validation_0-rmse:1.99482	validation_1-rmse:2.33078
# [24]	validation_0-rmse:1.98069	validation_1-rmse:2.32901
# [25]	validation_0-rmse:1.96511	validation_1-rmse:2.32477
# [26]	validation_0-rmse:1.95340	validation_1-rmse:2.32146
# [27]	validation_0-rmse:1.94031	validation_1-rmse:2.31843
# [28]	validation_0-rmse:1.92875	validation_1-rmse:2.31701
# [29]	validation_0-rmse:1.91900	validation_1-rmse:2.31572
# [30]	validation_0-rmse:1.90775	validation_1-rmse:2.31283
# [31]	validation_0-rmse:1.89629	validation_1-rmse:2.31195
# [32]	validation_0-rmse:1.88649	validation_1-rmse:2.31099
# [33]	validation_0-rmse:1.87857	validation_1-rmse:2.31182
# [34]	validation_0-rmse:1.87123	validation_1-rmse:2.30944
# [35]	validation_0-rmse:1.86254	validation_1-rmse:2.30859
# [36]	validation_0-rmse:1.85646	validation_1-rmse:2.30914
# [37]	validation_0-rmse:1.84875	validation_1-rmse:2.30754
# [38]	validation_0-rmse:1.84314	validation_1-rmse:2.30693
# [39]	validation_0-rmse:1.83553	validation_1-rmse:2.30503
# [40]	validation_0-rmse:1.82960	validation_1-rmse:2.30427
# [41]	validation_0-rmse:1.82533	validation_1-rmse:2.30398
# [42]	validation_0-rmse:1.81930	validation_1-rmse:2.30436
# [43]	validation_0-rmse:1.81756	validation_1-rmse:2.30557
# [44]	validation_0-rmse:1.81164	validation_1-rmse:2.30547
# [45]	validation_0-rmse:1.80710	validation_1-rmse:2.30439
# [46]	validation_0-rmse:1.80366	validation_1-rmse:2.30478
# [0]	validation_0-rmse:4.53973	validation_1-rmse:4.45000
# [1]	validation_0-rmse:4.18523	validation_1-rmse:4.11881
# [2]	validation_0-rmse:3.87214	validation_1-rmse:3.82961
# [3]	validation_0-rmse:3.59472	validation_1-rmse:3.57680
# [4]	validation_0-rmse:3.35873	validation_1-rmse:3.36529
# [5]	validation_0-rmse:3.14748	validation_1-rmse:3.17947
# [6]	validation_0-rmse:2.96740	validation_1-rmse:3.03032
# [7]	validation_0-rmse:2.81066	validation_1-rmse:2.90428
# [8]	validation_0-rmse:2.67946	validation_1-rmse:2.80027
# [9]	validation_0-rmse:2.56360	validation_1-rmse:2.70853
# [10]	validation_0-rmse:2.46349	validation_1-rmse:2.63015
# [11]	validation_0-rmse:2.37874	validation_1-rmse:2.56945
# [12]	validation_0-rmse:2.30589	validation_1-rmse:2.52017
# [13]	validation_0-rmse:2.24245	validation_1-rmse:2.47746
# [14]	validation_0-rmse:2.18798	validation_1-rmse:2.44798
# [15]	validation_0-rmse:2.14063	validation_1-rmse:2.42251
# [16]	validation_0-rmse:2.10223	validation_1-rmse:2.40081
# [17]	validation_0-rmse:2.06776	validation_1-rmse:2.38586
# [18]	validation_0-rmse:2.03910	validation_1-rmse:2.37468
# [19]	validation_0-rmse:2.01141	validation_1-rmse:2.36333
# [20]	validation_0-rmse:1.99099	validation_1-rmse:2.35572
# [21]	validation_0-rmse:1.97265	validation_1-rmse:2.35087
# [22]	validation_0-rmse:1.95748	validation_1-rmse:2.34446
# [23]	validation_0-rmse:1.94371	validation_1-rmse:2.33932
# [24]	validation_0-rmse:1.93143	validation_1-rmse:2.33773
# [25]	validation_0-rmse:1.91977	validation_1-rmse:2.33814
# [26]	validation_0-rmse:1.91057	validation_1-rmse:2.33774
# [27]	validation_0-rmse:1.90295	validation_1-rmse:2.33979
# [28]	validation_0-rmse:1.89561	validation_1-rmse:2.34120
# [29]	validation_0-rmse:1.88810	validation_1-rmse:2.33930
# [0]	validation_0-rmse:4.57617	validation_1-rmse:4.48420
# [1]	validation_0-rmse:4.24590	validation_1-rmse:4.16952
# [2]	validation_0-rmse:3.95390	validation_1-rmse:3.89683
# [3]	validation_0-rmse:3.71417	validation_1-rmse:3.67577
# [4]	validation_0-rmse:3.48584	validation_1-rmse:3.46538
# [5]	validation_0-rmse:3.28706	validation_1-rmse:3.28978
# [6]	validation_0-rmse:3.11767	validation_1-rmse:3.14730
# [7]	validation_0-rmse:2.97420	validation_1-rmse:3.02525
# [8]	validation_0-rmse:2.84258	validation_1-rmse:2.90955
# [9]	validation_0-rmse:2.73097	validation_1-rmse:2.81525
# [10]	validation_0-rmse:2.63626	validation_1-rmse:2.73821
# [11]	validation_0-rmse:2.55178	validation_1-rmse:2.66937
# [12]	validation_0-rmse:2.47690	validation_1-rmse:2.61343
# [13]	validation_0-rmse:2.41342	validation_1-rmse:2.57024
# [14]	validation_0-rmse:2.36309	validation_1-rmse:2.53317
# [15]	validation_0-rmse:2.31160	validation_1-rmse:2.49881
# [16]	validation_0-rmse:2.26986	validation_1-rmse:2.46916
# [17]	validation_0-rmse:2.23154	validation_1-rmse:2.44513
# [18]	validation_0-rmse:2.19744	validation_1-rmse:2.42588
# [19]	validation_0-rmse:2.16898	validation_1-rmse:2.40886
# [20]	validation_0-rmse:2.14380	validation_1-rmse:2.39410
# [21]	validation_0-rmse:2.12309	validation_1-rmse:2.38382
# [22]	validation_0-rmse:2.10170	validation_1-rmse:2.37831
# [23]	validation_0-rmse:2.07947	validation_1-rmse:2.36866
# [24]	validation_0-rmse:2.06212	validation_1-rmse:2.35974
# [25]	validation_0-rmse:2.04690	validation_1-rmse:2.35389
# [26]	validation_0-rmse:2.03177	validation_1-rmse:2.34800
# [27]	validation_0-rmse:2.01831	validation_1-rmse:2.34214
# [28]	validation_0-rmse:2.00617	validation_1-rmse:2.33708
# [29]	validation_0-rmse:1.99437	validation_1-rmse:2.33477
# [30]	validation_0-rmse:1.98476	validation_1-rmse:2.33397
# [31]	validation_0-rmse:1.97473	validation_1-rmse:2.33002
# [32]	validation_0-rmse:1.96725	validation_1-rmse:2.32831
# [33]	validation_0-rmse:1.95849	validation_1-rmse:2.33076
# [34]	validation_0-rmse:1.95103	validation_1-rmse:2.33020
# [35]	validation_0-rmse:1.94325	validation_1-rmse:2.32793
# [36]	validation_0-rmse:1.93359	validation_1-rmse:2.32495
# [37]	validation_0-rmse:1.92524	validation_1-rmse:2.32217
# [38]	validation_0-rmse:1.91804	validation_1-rmse:2.32059
# [39]	validation_0-rmse:1.91370	validation_1-rmse:2.31997
# [40]	validation_0-rmse:1.90772	validation_1-rmse:2.31890
# [41]	validation_0-rmse:1.90366	validation_1-rmse:2.31873
# [42]	validation_0-rmse:1.89921	validation_1-rmse:2.31706
# [43]	validation_0-rmse:1.89667	validation_1-rmse:2.31677
# [44]	validation_0-rmse:1.89391	validation_1-rmse:2.31696
# [45]	validation_0-rmse:1.89149	validation_1-rmse:2.31674
# [46]	validation_0-rmse:1.88628	validation_1-rmse:2.31537
# [47]	validation_0-rmse:1.88297	validation_1-rmse:2.31378
# [48]	validation_0-rmse:1.88133	validation_1-rmse:2.31433
# [49]	validation_0-rmse:1.87879	validation_1-rmse:2.31481
# [50]	validation_0-rmse:1.87717	validation_1-rmse:2.31567
# [51]	validation_0-rmse:1.87198	validation_1-rmse:2.31530
# [52]	validation_0-rmse:1.86924	validation_1-rmse:2.31570
# [0]	validation_0-rmse:4.56886	validation_1-rmse:4.47027
# [1]	validation_0-rmse:4.23631	validation_1-rmse:4.15181
# [2]	validation_0-rmse:3.95722	validation_1-rmse:3.88025
# [3]	validation_0-rmse:3.70846	validation_1-rmse:3.64335
# [4]	validation_0-rmse:3.48967	validation_1-rmse:3.43331
# [5]	validation_0-rmse:3.29683	validation_1-rmse:3.25599
# [6]	validation_0-rmse:3.12418	validation_1-rmse:3.09978
# [7]	validation_0-rmse:2.97345	validation_1-rmse:2.96807
# [8]	validation_0-rmse:2.84540	validation_1-rmse:2.85471
# [9]	validation_0-rmse:2.73295	validation_1-rmse:2.76867
# [10]	validation_0-rmse:2.63673	validation_1-rmse:2.69493
# [11]	validation_0-rmse:2.55020	validation_1-rmse:2.63043
# [12]	validation_0-rmse:2.47770	validation_1-rmse:2.57593
# [13]	validation_0-rmse:2.41247	validation_1-rmse:2.53463
# [14]	validation_0-rmse:2.35668	validation_1-rmse:2.49548
# [15]	validation_0-rmse:2.30588	validation_1-rmse:2.46486
# [16]	validation_0-rmse:2.26131	validation_1-rmse:2.43845
# [17]	validation_0-rmse:2.22443	validation_1-rmse:2.41483
# [18]	validation_0-rmse:2.19097	validation_1-rmse:2.39614
# [19]	validation_0-rmse:2.16214	validation_1-rmse:2.38057
# [20]	validation_0-rmse:2.13591	validation_1-rmse:2.37040
# [21]	validation_0-rmse:2.11560	validation_1-rmse:2.36034
# [22]	validation_0-rmse:2.09228	validation_1-rmse:2.34857
# [23]	validation_0-rmse:2.07330	validation_1-rmse:2.34268
# [24]	validation_0-rmse:2.05648	validation_1-rmse:2.33701
# [25]	validation_0-rmse:2.04149	validation_1-rmse:2.33197
# [26]	validation_0-rmse:2.02548	validation_1-rmse:2.32705
# [27]	validation_0-rmse:2.01304	validation_1-rmse:2.32259
# [28]	validation_0-rmse:2.00066	validation_1-rmse:2.31958
# [29]	validation_0-rmse:1.99003	validation_1-rmse:2.31817
# [30]	validation_0-rmse:1.98047	validation_1-rmse:2.31708
# [31]	validation_0-rmse:1.97242	validation_1-rmse:2.31544
# [32]	validation_0-rmse:1.96386	validation_1-rmse:2.31339
# [33]	validation_0-rmse:1.95484	validation_1-rmse:2.31193
# [34]	validation_0-rmse:1.94744	validation_1-rmse:2.31041
# [35]	validation_0-rmse:1.94195	validation_1-rmse:2.31046
# [36]	validation_0-rmse:1.93463	validation_1-rmse:2.30886
# [37]	validation_0-rmse:1.93006	validation_1-rmse:2.30820
# [38]	validation_0-rmse:1.92419	validation_1-rmse:2.30810
# [39]	validation_0-rmse:1.91752	validation_1-rmse:2.30564
# [40]	validation_0-rmse:1.91372	validation_1-rmse:2.30530
# [41]	validation_0-rmse:1.91014	validation_1-rmse:2.30555
# [42]	validation_0-rmse:1.90882	validation_1-rmse:2.30663
# [43]	validation_0-rmse:1.90213	validation_1-rmse:2.30386
# [44]	validation_0-rmse:1.89663	validation_1-rmse:2.30344
# [45]	validation_0-rmse:1.88964	validation_1-rmse:2.30405
# [46]	validation_0-rmse:1.88522	validation_1-rmse:2.30380
# [47]	validation_0-rmse:1.88077	validation_1-rmse:2.30559
# [48]	validation_0-rmse:1.87896	validation_1-rmse:2.30493
# [0]	validation_0-rmse:4.55295	validation_1-rmse:4.45500
# [1]	validation_0-rmse:4.20852	validation_1-rmse:4.12563
# [2]	validation_0-rmse:3.90340	validation_1-rmse:3.84175
# [3]	validation_0-rmse:3.63355	validation_1-rmse:3.58903
# [4]	validation_0-rmse:3.39732	validation_1-rmse:3.37133
# [5]	validation_0-rmse:3.19633	validation_1-rmse:3.19655
# [6]	validation_0-rmse:3.02257	validation_1-rmse:3.04696
# [7]	validation_0-rmse:2.86861	validation_1-rmse:2.91535
# [8]	validation_0-rmse:2.73030	validation_1-rmse:2.80381
# [9]	validation_0-rmse:2.61423	validation_1-rmse:2.71599
# [10]	validation_0-rmse:2.51790	validation_1-rmse:2.64202
# [11]	validation_0-rmse:2.43039	validation_1-rmse:2.57946
# [12]	validation_0-rmse:2.35713	validation_1-rmse:2.52963
# [13]	validation_0-rmse:2.29307	validation_1-rmse:2.48385
# [14]	validation_0-rmse:2.23607	validation_1-rmse:2.44937
# [15]	validation_0-rmse:2.18731	validation_1-rmse:2.42126
# [16]	validation_0-rmse:2.14894	validation_1-rmse:2.39961
# [17]	validation_0-rmse:2.11263	validation_1-rmse:2.37752
# [18]	validation_0-rmse:2.07950	validation_1-rmse:2.35991
# [19]	validation_0-rmse:2.05512	validation_1-rmse:2.34939
# [20]	validation_0-rmse:2.03285	validation_1-rmse:2.34260
# [21]	validation_0-rmse:2.01247	validation_1-rmse:2.33536
# [22]	validation_0-rmse:1.99489	validation_1-rmse:2.32940
# [23]	validation_0-rmse:1.98005	validation_1-rmse:2.32545
# [24]	validation_0-rmse:1.96641	validation_1-rmse:2.32513
# [25]	validation_0-rmse:1.95476	validation_1-rmse:2.32188
# [26]	validation_0-rmse:1.94357	validation_1-rmse:2.31852
# [27]	validation_0-rmse:1.93407	validation_1-rmse:2.31744
# [28]	validation_0-rmse:1.92460	validation_1-rmse:2.31634
# [29]	validation_0-rmse:1.91603	validation_1-rmse:2.31636
# [30]	validation_0-rmse:1.90714	validation_1-rmse:2.31376
# [31]	validation_0-rmse:1.90014	validation_1-rmse:2.31217
# [32]	validation_0-rmse:1.89614	validation_1-rmse:2.31300
# [33]	validation_0-rmse:1.88964	validation_1-rmse:2.31204
# [34]	validation_0-rmse:1.88446	validation_1-rmse:2.31223
# [35]	validation_0-rmse:1.87976	validation_1-rmse:2.31460
# [36]	validation_0-rmse:1.87316	validation_1-rmse:2.31573
# [37]	validation_0-rmse:1.86994	validation_1-rmse:2.31732
# [38]	validation_0-rmse:1.86520	validation_1-rmse:2.31675
# [0]	validation_0-rmse:4.58719	validation_1-rmse:4.48196
# [1]	validation_0-rmse:4.27465	validation_1-rmse:4.17594
# [2]	validation_0-rmse:4.00109	validation_1-rmse:3.90964
# [3]	validation_0-rmse:3.76152	validation_1-rmse:3.67359
# [4]	validation_0-rmse:3.55296	validation_1-rmse:3.46909
# [5]	validation_0-rmse:3.36928	validation_1-rmse:3.28655
# [6]	validation_0-rmse:3.21159	validation_1-rmse:3.13332
# [7]	validation_0-rmse:3.07612	validation_1-rmse:3.00224
# [8]	validation_0-rmse:2.95995	validation_1-rmse:2.89224
# [9]	validation_0-rmse:2.86043	validation_1-rmse:2.79739
# [10]	validation_0-rmse:2.77562	validation_1-rmse:2.71597
# [11]	validation_0-rmse:2.70212	validation_1-rmse:2.64600
# [12]	validation_0-rmse:2.64115	validation_1-rmse:2.58777
# [13]	validation_0-rmse:2.58885	validation_1-rmse:2.53925
# [14]	validation_0-rmse:2.54471	validation_1-rmse:2.49827
# [15]	validation_0-rmse:2.50682	validation_1-rmse:2.46420
# [16]	validation_0-rmse:2.47518	validation_1-rmse:2.43565
# [17]	validation_0-rmse:2.44775	validation_1-rmse:2.41089
# [18]	validation_0-rmse:2.42427	validation_1-rmse:2.38900
# [19]	validation_0-rmse:2.40466	validation_1-rmse:2.37210
# [20]	validation_0-rmse:2.38766	validation_1-rmse:2.35726
# [21]	validation_0-rmse:2.37111	validation_1-rmse:2.34212
# [22]	validation_0-rmse:2.35776	validation_1-rmse:2.33165
# [23]	validation_0-rmse:2.34538	validation_1-rmse:2.32044
# [24]	validation_0-rmse:2.33566	validation_1-rmse:2.31353
# [25]	validation_0-rmse:2.32657	validation_1-rmse:2.30595
# [26]	validation_0-rmse:2.31874	validation_1-rmse:2.29943
# [27]	validation_0-rmse:2.31255	validation_1-rmse:2.29514
# [28]	validation_0-rmse:2.30617	validation_1-rmse:2.28984
# [29]	validation_0-rmse:2.30018	validation_1-rmse:2.28536
# [30]	validation_0-rmse:2.29476	validation_1-rmse:2.28169
# [31]	validation_0-rmse:2.29023	validation_1-rmse:2.27963
# [32]	validation_0-rmse:2.28603	validation_1-rmse:2.27686
# [33]	validation_0-rmse:2.28217	validation_1-rmse:2.27492
# [34]	validation_0-rmse:2.27894	validation_1-rmse:2.27358
# [35]	validation_0-rmse:2.27578	validation_1-rmse:2.27215
# [36]	validation_0-rmse:2.27300	validation_1-rmse:2.27098
# [37]	validation_0-rmse:2.27001	validation_1-rmse:2.27066
# [38]	validation_0-rmse:2.26775	validation_1-rmse:2.26957
# [39]	validation_0-rmse:2.26543	validation_1-rmse:2.26937
# [40]	validation_0-rmse:2.26359	validation_1-rmse:2.26937
# [41]	validation_0-rmse:2.26156	validation_1-rmse:2.26873
# [42]	validation_0-rmse:2.25904	validation_1-rmse:2.26713
# [43]	validation_0-rmse:2.25679	validation_1-rmse:2.26638
# [44]	validation_0-rmse:2.25438	validation_1-rmse:2.26544
# [45]	validation_0-rmse:2.25297	validation_1-rmse:2.26508
# [46]	validation_0-rmse:2.25108	validation_1-rmse:2.26470
# [47]	validation_0-rmse:2.24965	validation_1-rmse:2.26375
# [48]	validation_0-rmse:2.24829	validation_1-rmse:2.26369
# [49]	validation_0-rmse:2.24660	validation_1-rmse:2.26468
# [50]	validation_0-rmse:2.24540	validation_1-rmse:2.26488
# [51]	validation_0-rmse:2.24360	validation_1-rmse:2.26329
# [52]	validation_0-rmse:2.24230	validation_1-rmse:2.26404
# [53]	validation_0-rmse:2.24091	validation_1-rmse:2.26351
# [54]	validation_0-rmse:2.23869	validation_1-rmse:2.26197
# [55]	validation_0-rmse:2.23789	validation_1-rmse:2.26203
# [56]	validation_0-rmse:2.23661	validation_1-rmse:2.26333
# [57]	validation_0-rmse:2.23466	validation_1-rmse:2.26228
# [58]	validation_0-rmse:2.23398	validation_1-rmse:2.26218
# [59]	validation_0-rmse:2.23200	validation_1-rmse:2.26051
# [60]	validation_0-rmse:2.23131	validation_1-rmse:2.26082
# [61]	validation_0-rmse:2.23059	validation_1-rmse:2.26113
# [62]	validation_0-rmse:2.22934	validation_1-rmse:2.26157
# [63]	validation_0-rmse:2.22874	validation_1-rmse:2.26173
# [64]	validation_0-rmse:2.22742	validation_1-rmse:2.26063
# Best Hyperparameters:  {'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': 'reg:squarederror', 'reg_alpha': 0.1, 'reg_lambda': 1}
# Best Score:  -5.489427815965247

# %% [markdown]
# **Train an XGboost model**
#
# We will fit all the data in this model using the optimum parameters we found above.

# %%
# Define XGBoost regressor
reg = xgb.XGBRegressor(
    reg_lambda = xgb_grid.best_params_['reg_lambda'],
    reg_alpha = xgb_grid.best_params_['reg_alpha'],
    learning_rate = xgb_grid.best_params_['learning_rate'],
    max_depth = xgb_grid.best_params_['max_depth'],
    n_estimators = 100,
    gamma = xgb_grid.best_params_['gamma'],
    objective = xgb_grid.best_params_['objective'],
    early_stopping_rounds = 5
)

# Train the XGBoost model with feature weights (use validation set on test data)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test,y_test)])
# Out:
# [0]	validation_0-rmse:4.58719	validation_1-rmse:4.48196
# [1]	validation_0-rmse:4.27465	validation_1-rmse:4.17594
# [2]	validation_0-rmse:4.00109	validation_1-rmse:3.90964
# [3]	validation_0-rmse:3.76152	validation_1-rmse:3.67359
# [4]	validation_0-rmse:3.55296	validation_1-rmse:3.46909
# [5]	validation_0-rmse:3.36928	validation_1-rmse:3.28655
# [6]	validation_0-rmse:3.21159	validation_1-rmse:3.13332
# [7]	validation_0-rmse:3.07612	validation_1-rmse:3.00224
# [8]	validation_0-rmse:2.95995	validation_1-rmse:2.89224
# [9]	validation_0-rmse:2.86043	validation_1-rmse:2.79739
# [10]	validation_0-rmse:2.77562	validation_1-rmse:2.71597
# [11]	validation_0-rmse:2.70212	validation_1-rmse:2.64600
# [12]	validation_0-rmse:2.64115	validation_1-rmse:2.58777
# [13]	validation_0-rmse:2.58885	validation_1-rmse:2.53925
# [14]	validation_0-rmse:2.54471	validation_1-rmse:2.49827
# [15]	validation_0-rmse:2.50682	validation_1-rmse:2.46420
# [16]	validation_0-rmse:2.47518	validation_1-rmse:2.43565
# [17]	validation_0-rmse:2.44775	validation_1-rmse:2.41089
# [18]	validation_0-rmse:2.42427	validation_1-rmse:2.38900
# [19]	validation_0-rmse:2.40466	validation_1-rmse:2.37210
# [20]	validation_0-rmse:2.38766	validation_1-rmse:2.35726
# [21]	validation_0-rmse:2.37111	validation_1-rmse:2.34212
# [22]	validation_0-rmse:2.35776	validation_1-rmse:2.33165
# [23]	validation_0-rmse:2.34538	validation_1-rmse:2.32044
# [24]	validation_0-rmse:2.33566	validation_1-rmse:2.31353
# [25]	validation_0-rmse:2.32657	validation_1-rmse:2.30595
# [26]	validation_0-rmse:2.31874	validation_1-rmse:2.29943
# [27]	validation_0-rmse:2.31255	validation_1-rmse:2.29514
# [28]	validation_0-rmse:2.30617	validation_1-rmse:2.28984
# [29]	validation_0-rmse:2.30018	validation_1-rmse:2.28536
# [30]	validation_0-rmse:2.29476	validation_1-rmse:2.28169
# [31]	validation_0-rmse:2.29023	validation_1-rmse:2.27963
# [32]	validation_0-rmse:2.28603	validation_1-rmse:2.27686
# [33]	validation_0-rmse:2.28217	validation_1-rmse:2.27492
# [34]	validation_0-rmse:2.27894	validation_1-rmse:2.27358
# [35]	validation_0-rmse:2.27578	validation_1-rmse:2.27215
# [36]	validation_0-rmse:2.27300	validation_1-rmse:2.27098
# [37]	validation_0-rmse:2.27001	validation_1-rmse:2.27066
# [38]	validation_0-rmse:2.26775	validation_1-rmse:2.26957
# [39]	validation_0-rmse:2.26543	validation_1-rmse:2.26937
# [40]	validation_0-rmse:2.26359	validation_1-rmse:2.26937
# [41]	validation_0-rmse:2.26156	validation_1-rmse:2.26873
# [42]	validation_0-rmse:2.25904	validation_1-rmse:2.26713
# [43]	validation_0-rmse:2.25679	validation_1-rmse:2.26638
# [44]	validation_0-rmse:2.25438	validation_1-rmse:2.26544
# [45]	validation_0-rmse:2.25297	validation_1-rmse:2.26508
# [46]	validation_0-rmse:2.25108	validation_1-rmse:2.26470
# [47]	validation_0-rmse:2.24965	validation_1-rmse:2.26375
# [48]	validation_0-rmse:2.24829	validation_1-rmse:2.26369
# [49]	validation_0-rmse:2.24660	validation_1-rmse:2.26468
# [50]	validation_0-rmse:2.24540	validation_1-rmse:2.26488
# [51]	validation_0-rmse:2.24360	validation_1-rmse:2.26329
# [52]	validation_0-rmse:2.24230	validation_1-rmse:2.26404
# [53]	validation_0-rmse:2.24091	validation_1-rmse:2.26351
# [54]	validation_0-rmse:2.23869	validation_1-rmse:2.26197
# [55]	validation_0-rmse:2.23789	validation_1-rmse:2.26203
# [56]	validation_0-rmse:2.23661	validation_1-rmse:2.26333
# [57]	validation_0-rmse:2.23466	validation_1-rmse:2.26228
# [58]	validation_0-rmse:2.23398	validation_1-rmse:2.26218
# [59]	validation_0-rmse:2.23200	validation_1-rmse:2.26051
# [60]	validation_0-rmse:2.23131	validation_1-rmse:2.26082
# [61]	validation_0-rmse:2.23059	validation_1-rmse:2.26113
# [62]	validation_0-rmse:2.22934	validation_1-rmse:2.26157
# [63]	validation_0-rmse:2.22874	validation_1-rmse:2.26173
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=5,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# Make predictions on the test set

# %%
# Make predictions on the X_test set
y_pred_xgboost = reg.predict(X_test)

# %%
# Calculate the MAE of XGBoost model
mae_xgboost = mean_absolute_error(y_test, y_pred_xgboost)
print("Mae is: ",mae_xgboost)

# Calculate RMSE score of XGBoost model
rmse_xgboost = mean_squared_error(y_test, y_pred_xgboost, squared=False)
print("RMSE score:", rmse_xgboost)
# Out:
# Mae is:  1.3378463940263257
# RMSE score: 2.2605073718967943

# %% [markdown]
# **Train LSTM for time series forecasting**

# %% [markdown]
# Use the same train and test sets as in the XGBoost model. In order to create more accurate predictions, we scale those two sets before giving them as input to the LSTM Recurrent Neural Network model.

# %%
# Scale the data
scaler = MinMaxScaler()
X_tr = scaler.fit_transform(X_train)
X_te = scaler.fit_transform(X_test)

y_tr = scaler.fit_transform(y_train)
y_te = scaler.fit_transform(y_test)

# %%
# Create 3D train set for LSTM
trainX = []
trainY = []

for i in range(len(X_tr)):
    trainX.append(X_tr[i:i+1,:])

for i in range(len(y_tr)):
    trainY.append(y_tr[i:i+1,:])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# Create 3D test set for LSTM
testX = []
testY = []

for i in range(len(X_te)):
    testX.append(X_te[i:i+1,:])

for i in range(len(y_te)):
    testY.append(y_te[i:i+1,:])

testX, testY = np.array(testX), np.array(testY)

# %% [markdown]
# In the LSTM model, we include dense layers to capture more complex non linear patterns and dropout layers to prevent overfitting.

# %%
# Define LSTM model
model = Sequential()
model.add(LSTM(100, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(50, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(25, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(12, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

# Additional Dense layers
model.add(Dense(6, activation='relu'))
model.add(Dense(3, activation='linear'))

# Output layer
model.add(Dense(trainY.shape[1]))

# Add early stopping mechanism
early_stopping = EarlyStopping(patience=5, monitor='val_loss', restore_best_weights=True)
# Out:
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
# Compile LSTM model
model.compile(optimizer='adam', loss='mse')

# %%
# Fit model on training data
history = model.fit(trainX, trainY,
          epochs=50,
          batch_size=len(trainX)//100,
          validation_data=(testX,testY),
          callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 7s 25ms/step - loss: 0.0082 - val_loss: 0.0122
# Epoch 2/50
# 100/100 [==============================] - 1s 9ms/step - loss: 0.0050 - val_loss: 0.0034
# Epoch 3/50
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 4/50
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 5/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 6/50
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 7/50
# 100/100 [==============================] - 5s 54ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 8/50
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 9/50
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 10/50
# 100/100 [==============================] - 3s 27ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 11/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 12/50
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 13/50
# 100/100 [==============================] - 2s 25ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 14/50
# 100/100 [==============================] - 6s 62ms/step - loss: 0.0020 - val_loss: 0.0029
# Epoch 15/50
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0020 - val_loss: 0.0027

# %%
# Evaluate model on test data
loss_lstm = model.evaluate(testX, testY)
print("Test Loss:", loss_lstm)
# Out:
# 429/429 [==============================] - 6s 15ms/step - loss: 0.0027
# Test Loss: 0.0027060627471655607

# %%
# Predict on test data
y_pred_lstm = model.predict(testX)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm.reshape(-1,1))
# Out:
# 429/429 [==============================] - 7s 15ms/step

# %% [markdown]
# Evaluate the LSTM model

# %%
# Calculate the MAE score of LSTM model
mae_lstm = mean_absolute_error(scaler.inverse_transform(testY.reshape(-1,1)),y_pred_lstm)
print("Mae LSTM is: ",mae_lstm)

# Calculate the RMSE score of LSTM model
rmse_lstm = mean_squared_error(scaler.inverse_transform(testY.reshape(-1,1)), y_pred_lstm, squared=False)
print("RMSE LSTM score:", rmse_lstm)
# Out:
# Mae LSTM is:  1.3880633117443453
# RMSE LSTM score: 2.2888721577527673

# %% [markdown]
# Add in the same dataframe the RMSE and MAE scores of each model, in order to compare them

# %%
# Create dataframe with scores (length == 6)
scores = pd.DataFrame(columns=['Model','RMSE Score','MAE Score'])

# Define rows for dataframe
new_row = {'Model': 'XGBoost', 'RMSE Score': rmse_xgboost, 'MAE Score': mae_xgboost}
new_row1 = {'Model': 'LSTM', 'RMSE Score': rmse_lstm, 'MAE Score': mae_lstm}

# Add rows to dataframe
scores = scores.append(new_row, ignore_index=True)
scores = scores.append(new_row1, ignore_index=True)

# %%
scores # length is 6
# Out:
#      Model  RMSE Score  MAE Score
# 0  XGBoost    2.260507   1.337846
# 1     LSTM    2.288872   1.388063

# %%
# Save XGBoost model to a file
reg.save_model('/content/drive/MyDrive/Paper/Models/xgboost_traffic_flow_length-'+str(optimum_lookback)+'.model')

# %%
# Save the model
model.save("/content/drive/MyDrive/Paper/Models/LSTM-length-"+str(optimum_lookback)+".h5")
