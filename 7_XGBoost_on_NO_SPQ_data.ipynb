# %% [markdown]
# <a href="https://colab.research.google.com/github/stratoskar/Path-Based-Traffic-Flow-Prediction/blob/main/7_XGBoost_on_NO_SPQ_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In this section of the code, we use the same machine learning methodology, in order to train an XGBoost model on traffic flow data that have been produced without the use of the SPQ algorithm.**
#
#
# Previously, we generated a distinct traffic flow time series without implementing the SPQ algorithm. In this context, the absence of SPQ rules implies that, for a given path P comprising n edges, we ascertain that a mobile object traverses the designated path within a specific time interval only when it successfully crosses all n edges of the path within the stipulated time frame.

# %%
# Disable warnings
import warnings
warnings.filterwarnings('ignore')

# Standard library imports
import pandas as pd
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Handle timestamp data types
from datetime import datetime, timedelta

# %%
# Access Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define the path with the data that we are interested in
PATH = '/content/drive/MyDrive/Paper/Timeseries/traffic_flow_without_SPQ.csv'
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### **Prepare the dataset**
#
# We use the necessary code to convert our time series dataframe into more usefull one.

# %%
# Read the time series dataset
traffic_flow_no_SPQ = pd.read_csv(PATH)

# This list contains the column names
columns = ["Taxi ID","Traj ID","Path","Length"]

# Generate the columns for the datasets
i =4
while(True):
    if i == 4:
        columns.append(pd.to_datetime('2008-05-17 10:00:04'))
    else:
        columns.append(columns[i-1] + timedelta(seconds=1800))

    if (columns[i]>=pd.to_datetime('2008-06-10 09:30:04')):
        break

    i+=1

# Delete the last timestamp
columns.pop()

# Assign new column names to our dataframe
traffic_flow_no_SPQ.columns = columns

# %%
# Print first 2 rows of dataframe
traffic_flow_no_SPQ.head(2)
# Out:
#    Taxi ID  Traj ID                                               Path  \
# 0      112      479  [204965468, 204965468, 204965468, 204965468, 2...
# 1      378     1123  [930108605, 236348363, 541597678, 202317708, 8...
#
#    Length  2008-05-17 10:00:04  2008-05-17 10:30:04  2008-05-17 11:00:04  \
# 0      11                  220                   90                   99
# 1      18                    1                    1                    0
#
#    2008-05-17 11:30:04  2008-05-17 12:00:04  2008-05-17 12:30:04  ...  \
# 0                   63                   55                   22  ...
# 1                    1                    0                    0  ...
#
#    2008-06-10 04:30:04  2008-06-10 05:00:04  2008-06-10 05:30:04  \
# 0                    8                    0                    0
# 1                    0                    0                    1
#
#    2008-06-10 06:00:04  2008-06-10 06:30:04  2008-06-10 07:00:04  \
# 0                    0                    0                   20
# 1                    0                    0                    0
#
#    2008-06-10 07:30:04  2008-06-10 08:00:04  2008-06-10 08:30:04  \
# 0                   17                    6                   11
# 1                    0                    0                    0
#
#    2008-06-10 09:00:04
# 0                    4
# 1                    1
#
# [2 rows x 1155 columns]

# %%
# Reshape the data from wide format to long format
id_cols = ['Taxi ID','Traj ID', 'Path', 'Length']
time_cols = traffic_flow_no_SPQ.iloc[:,2:].columns
traffic_flow_no_SPQ = traffic_flow_no_SPQ.melt(id_vars=id_cols, value_vars=time_cols, var_name='Time Column', value_name='Traffic Flow')
traffic_flow_no_SPQ['Time Column'] = pd.to_datetime(traffic_flow_no_SPQ['Time Column'])

# Sort rows by 'Path' and 'Time Column'
traffic_flow_no_SPQ.sort_values(by=['Path','Time Column'],inplace=True)

# %% [markdown]
# Convert 'Path' column to numerical

# %%
# Use label encoder
from sklearn.preprocessing import LabelEncoder

# Create an instance of LabelEncoder
label_encoder = LabelEncoder()

# Fit label encoder on the 'Path' column
traffic_flow_no_SPQ['Path'] = label_encoder.fit_transform(traffic_flow_no_SPQ['Path'])

# Sort the data based in Path column
traffic_flow = traffic_flow_no_SPQ.sort_values(by=['Path','Time Column'])

# %%
# Print dataframe
traffic_flow_no_SPQ.head(5)
# Out:
#      Taxi ID  Traj ID  Path  Length         Time Column  Traffic Flow
# 37       385      346     0      16 2008-05-17 10:00:04             3
# 137      385      346     0      16 2008-05-17 10:30:04             3
# 237      385      346     0      16 2008-05-17 11:00:04             5
# 337      385      346     0      16 2008-05-17 11:30:04             4
# 437      385      346     0      16 2008-05-17 12:00:04             2

# %% [markdown]
# **Feature Creation From Time Information**
#
# In this step we define some features based on time series timestamps.
# - Day, day of week, hour and minute features derive directly from the timestamp column of the dataset.
# - Hour_sin and Hour_cos columns transform the hour values into a cyclic representation, where the values range from -1 to 1. This transformation is used in time series analysis to capture the periodic patterns or cyclical nature of time-related data.
# - Use also the 3_hour_interval to describe, in which interval of the day data refer to.

# %%
# Set the timestamps as the index of the dataframe
traffic_flow_no_SPQ.set_index('Time Column', inplace=True)

# %%
# Rename the index for easy understanding of the data
traffic_flow_no_SPQ = traffic_flow_no_SPQ.reset_index()
traffic_flow_no_SPQ.rename(columns={'index': 'Time Column'}, inplace=True)

# %%
### Extract timestamp information to different columns ###

traffic_flow_no_SPQ['hour'] = traffic_flow_no_SPQ['Time Column'].dt.hour
traffic_flow_no_SPQ['dayofweek'] = traffic_flow_no_SPQ['Time Column'].dt.dayofweek
traffic_flow_no_SPQ['day'] = traffic_flow_no_SPQ['Time Column'].dt.day
traffic_flow_no_SPQ['minute'] = traffic_flow_no_SPQ['Time Column'].dt.minute

### Circular Encoding for cyclic time features ###

traffic_flow_no_SPQ['hour_sin'] = np.sin(2 * np.pi * traffic_flow_no_SPQ['hour'] / 24)
traffic_flow_no_SPQ['hour_cos'] = np.cos(2 * np.pi * traffic_flow_no_SPQ['hour'] / 24)

traffic_flow_no_SPQ['day_of_week_sin'] = np.sin(2 * np.pi * traffic_flow_no_SPQ['dayofweek'] / 7)
traffic_flow_no_SPQ['day_of_week_cos'] = np.cos(2 * np.pi * traffic_flow_no_SPQ['dayofweek'] / 7)

traffic_flow_no_SPQ['day_sin'] = np.sin(2 * np.pi * traffic_flow_no_SPQ['day'] / 31)
traffic_flow_no_SPQ['day_cos'] = np.cos(2 * np.pi * traffic_flow_no_SPQ['day'] / 31)

traffic_flow_no_SPQ['minute_sin'] = np.sin(2 * np.pi * traffic_flow_no_SPQ['minute'] / 60)
traffic_flow_no_SPQ['minute_cos'] = np.cos(2 * np.pi * traffic_flow_no_SPQ['minute'] / 60)

# %%
# Define a custom function to determine the three-hour interval, based in timestamp hour information
def get_3hour_interval(hour):
    if hour in [0, 1, 2]:
        return 1
    elif hour in [3, 4, 5]:
        return 2
    elif hour in [6, 7, 8]:
        return 3
    elif hour in [9, 10, 11]:
        return 4
    elif hour in [12, 13, 14]:
        return 5
    elif hour in [15, 16, 17]:
        return 6
    elif hour in [18, 19, 20]:
        return 7
    elif hour in [21, 22, 23]:
        return 8
    else:
        return None

# Apply the custom function on the data to create the '3hour_interval' column
traffic_flow_no_SPQ['3hour_interval'] = traffic_flow_no_SPQ['hour'].apply(get_3hour_interval)

# %%
# Print dataframe
traffic_flow_no_SPQ.head(5)
# Out:
#           Time Column  Taxi ID  Traj ID  Path  Length  Traffic Flow  hour  \
# 0 2008-05-17 10:00:04      385      346     0      16             3    10
# 1 2008-05-17 10:30:04      385      346     0      16             3    10
# 2 2008-05-17 11:00:04      385      346     0      16             5    11
# 3 2008-05-17 11:30:04      385      346     0      16             4    11
# 4 2008-05-17 12:00:04      385      346     0      16             2    12
#
#    dayofweek  day  minute      hour_sin  hour_cos  day_of_week_sin  \
# 0          5   17       0  5.000000e-01 -0.866025        -0.974928
# 1          5   17      30  5.000000e-01 -0.866025        -0.974928
# 2          5   17       0  2.588190e-01 -0.965926        -0.974928
# 3          5   17      30  2.588190e-01 -0.965926        -0.974928
# 4          5   17       0  1.224647e-16 -1.000000        -0.974928
#
#    day_of_week_cos   day_sin   day_cos    minute_sin  minute_cos  \
# 0        -0.222521 -0.299363 -0.954139  0.000000e+00         1.0
# 1        -0.222521 -0.299363 -0.954139  5.665539e-16        -1.0
# 2        -0.222521 -0.299363 -0.954139  0.000000e+00         1.0
# 3        -0.222521 -0.299363 -0.954139  5.665539e-16        -1.0
# 4        -0.222521 -0.299363 -0.954139  0.000000e+00         1.0
#
#    3hour_interval
# 0               4
# 1               4
# 2               4
# 3               4
# 4               5

# %%
# Find highly correlated data in the traffic_flow_no_SPQ dataset
plt.figure(figsize=(10,5))
sns.heatmap(traffic_flow_no_SPQ.corr(), annot=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# Based on the heatmap above, we can see that there is a strong correlation between the:
#
# *  minute_cos and minute
# *  hour_sin and 3hour_interval
# *  hour and 3hour_interval
# *  hour_sin and hour
# *  dayofweek and day_of_week_sin
# *  dayofweek and day_of_week_cos
# *  day and day_sin
# *  minute and minute_sin
# *  minute_cos and minute_sin
#
# So, due to the fact that these features are highly correlated, the information they share is almost the same. So, we can drop the following features, to create a simpler model: **minute, day, 3hour_interval, dayofweek and hour**.

# %%
# Delete high correlated columns
traffic_flow_no_SPQ.drop(['minute', 'day', '3hour_interval', 'dayofweek', 'hour'],axis=1,inplace=True)

# %% [markdown]
# #### **Tune XGBoost model**

# %%
print(f"Earlier timestamp in traffic_flow dataframe is: {traffic_flow_no_SPQ['Time Column'].min()}")
print(f"Latest timestamp in traffic_flow dataframe is: {traffic_flow_no_SPQ['Time Column'].max()}")
# Out:
# Earlier timestamp in traffic_flow dataframe is: 2008-05-17 10:00:04
# Latest timestamp in traffic_flow dataframe is: 2008-06-10 09:00:04

# %% [markdown]
# **Train and Test split of the dataset**
#
# In this step, we split the data into two datasets, train and test.
# - Train dataset contains all the data for each path till 06-06-2008 inclusive.
# - The rest of the data (the most resent ones) are in the test dataset

# %%
# Sort the time series data
traffic_flow_no_SPQ.sort_values(by=['Path','Time Column'], inplace=True)

# %%
# Define train data
train= traffic_flow_no_SPQ.loc[traffic_flow_no_SPQ['Time Column'] < '2008-06-06']

# Define test data
test = traffic_flow_no_SPQ.loc[traffic_flow_no_SPQ['Time Column'] >= '2008-06-06']

# Print the results
print("Traffic flow train set shape: ",train.shape)
print("Traffic flow test set shape: ",test.shape)
# Out:
# Traffic flow train set shape:  (94000, 14)
# Traffic flow test set shape:  (21100, 14)

# %% [markdown]
# **Find the best lookback timesteps for our XGBoost model**
#
# In this step, we define the optimum lookback timestep number for our sliding window. This optimum number will be used by the model for forecasting.

# %%
# Find best lookback timesteps to perform analysis on traffic_flow dataset. Save those scores in a separate dataframe
lookback_scores = pd.DataFrame(columns=['#Timesteps','XGBoost Score'])
lookback_scores['#Timesteps'] = 0
lookback_scores['XGBoost Score'] = 0

# %% [markdown]
# **Create function that converts the data into a supervised problem**
#
# Consider for each path n_in timesteps of observations in the past, in order to predict the n_out timesteps in the future.

# %%
# Create function for generating (X, y) pairs
def series_to_supervised(data, n_in=1, n_out=1):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # Input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('Record %d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # Forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('Record %d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('Record %d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # Put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    return agg

def generate_X_y_pairs(data,n_in=1,n_out=1):
    """
    Convert the training data into a supervised dataset. Create X,y pairs of the traffic column information.
    Then, concatenate the rest of the culumns.
    """
    new_data = pd.DataFrame()
    for item in data['Path'].unique():

        # Call function only for traffic flow columns
        supervised_traffic_flow = series_to_supervised(pd.DataFrame(data[data['Path'] == item]['Traffic Flow']), n_in, n_out)

        # The rest of the columns are concatenated as they were
        supervised_traffic_flow = pd.concat([supervised_traffic_flow, traffic_flow_no_SPQ[traffic_flow_no_SPQ['Path'] == item]], axis=1)

        new_data = pd.concat([new_data,supervised_traffic_flow])

    new_data.dropna(inplace=True)
    return new_data

# %% [markdown]
# Create a loop. In each loop, we are doing the following:
# - 0. Convert train and test sets into supervised problems with lookback timesteps.
# - 1. Define features and labels.
# - 2. Train the XGboost model with defult parameters.
# - 3. Predict on the test set.
# - 4. Save RMSE in a dataframe.

# %%
# Import libraries to use XGBoost model
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
for lookback in [2,3,4,5,6]: # Use different lookback sizes

    # Convert train and test data to supervised
    train_s = generate_X_y_pairs(train,lookback)
    test_s = generate_X_y_pairs(test,lookback)

    print("Lookback = "+str(lookback)+" - To supervised: Completed!")

    # Add rolling mean information
    train_s['rolling_mean'] = 0
    test_s['rolling_mean'] = 0

    train_s['rolling_mean'] = train_s.iloc[:,0:lookback].mean(axis=1)
    test_s['rolling_mean'] = test_s.iloc[:,0:lookback].mean(axis=1)

    # Define features
    features_s = train_s.drop(['Traffic Flow','Record 1(t)', 'Time Column'],axis=1).columns

    # Define label
    labels_s = ['Record 1(t)']

    # Create X_train and y_train datasets
    X_train_s = train_s[features_s]
    y_train_s = train_s[labels_s]

    # Create X_test and y_test datasets
    X_test_s = test_s[features_s]
    y_test_s = test_s[labels_s]

    print("Lookback = "+str(lookback)+" - Train and Test sets: Completed!")

    # Define XGBoost regression model
    reg = xgb.XGBRegressor(objective='reg:squarederror',n_estimators=100,early_stopping_rounds = 5)

    # Train the XGBoost model with feature weights (use validation set on test data)
    reg.fit(X_train_s, y_train_s, eval_set=[(X_train_s, y_train_s), (X_test_s,y_test_s)],verbose=False)

    print("Lookback = "+str(lookback)+" - Trainning: Completed!")

    # Make predictions
    y_pred_s = reg.predict(X_test_s)

    # Calculate RMSE score
    rmse = mean_squared_error(y_test_s, y_pred_s, squared=False)

    # Create a new row as a dictionary
    new_row = {'#Timesteps': lookback, 'XGBoost Score': rmse}

    # Append the new row to the DataFrame
    lookback_scores = lookback_scores.append(new_row, ignore_index=True)

    print("Lookback = "+str(lookback)+" - Saved Results: Completed!")
# Out:
# Lookback = 2 - To supervised: Completed!
# Lookback = 2 - Train and Test sets: Completed!
# Lookback = 2 - Trainning: Completed!
# Lookback = 2 - Saved Results: Completed!
# Lookback = 3 - To supervised: Completed!
# Lookback = 3 - Train and Test sets: Completed!
# Lookback = 3 - Trainning: Completed!
# Lookback = 3 - Saved Results: Completed!
# Lookback = 4 - To supervised: Completed!
# Lookback = 4 - Train and Test sets: Completed!
# Lookback = 4 - Trainning: Completed!
# Lookback = 4 - Saved Results: Completed!
# Lookback = 5 - To supervised: Completed!
# Lookback = 5 - Train and Test sets: Completed!
# Lookback = 5 - Trainning: Completed!
# Lookback = 5 - Saved Results: Completed!
# Lookback = 6 - To supervised: Completed!
# Lookback = 6 - Train and Test sets: Completed!
# Lookback = 6 - Trainning: Completed!
# Lookback = 6 - Saved Results: Completed!

# %%
# Use a plot to show the results
plt.plot(lookback_scores['#Timesteps'], lookback_scores['XGBoost Score'], linestyle='-', marker='o', color='b')

# Set plot title and axis labels
plt.title('Lookback timesteps over RMSE score')
plt.xlabel('Lookback Timesteps of Traffic Flow')
plt.ylabel('RMSE score after XGBoost testing')

# Add gridlines
plt.grid(True)

# Show the plot
plt.show()

# %%
# Find the timesteps corresponding to the minimum RMSE score
optimum_lookback = int(lookback_scores['#Timesteps'].loc[lookback_scores['XGBoost Score'].idxmin()])

# %%
# Convert train and test data to supervised problem based in the optimum lookback step we defined above.
train = generate_X_y_pairs(train, optimum_lookback)
test = generate_X_y_pairs(test, optimum_lookback)

# %% [markdown]
# **Extract features about trend of time series**
#
# In this step we define the rolling mean and rolling variance of a window. Since we are trying to forecast the last value of each window, only the first optimum_lookback values in the window are used to compute rolling features. The last value (that we are trying to forecast) is not included.

# %%
# Add rolling mean information
train['rolling_mean'] = 0
test['rolling_mean'] = 0

# Add rolling var information
train['rolling_var'] = 0
test['rolling_var'] = 0

# Calculate rolling mean of window
train['rolling_mean'] = train.iloc[:,0:optimum_lookback].mean(axis=1)
test['rolling_mean'] = test.iloc[:,0:optimum_lookback].mean(axis=1)

# Calculate rolling variance of window
train['rolling_var'] = train.iloc[:, 0:optimum_lookback].var(axis=1)
test['rolling_var'] = test.iloc[:, 0:optimum_lookback].var(axis=1)

# %% [markdown]
# **Define labels and features**
#
# - Features will help the XGboost algorithm to predict the output value (the label). We will use all the traffic flow information at previous timesteps (t-n,t-n+1...,t-2,t-1), as well as the rest of the features (time and trend information) as features.
#
# - Label will be out target value, the Traffic Flow at timestep t.

# %%
# Define features
features = train.drop(['Time Column','Record 1(t)','Traffic Flow'],axis=1).columns

# Define labels
labels = ['Record 1(t)']

# Create X_train and y_train data sets
X_train = train[features]
y_train = train[labels]

# Create X_test and y_test data sets
X_test = test[features]
y_test = test[labels]

# %%
# Show shape information about X and y training and testing sets
print("Shape of X_train is: ",X_train.shape)
print("Shape of y_train is: ",y_train.shape)
print("Shape of X_test is: ",X_test.shape)
print("Shape of y_test is: ",y_test.shape)
# Out:
# Shape of X_train is:  (93400, 20)
# Shape of y_train is:  (93400, 1)
# Shape of X_test is:  (20500, 20)
# Shape of y_test is:  (20500, 1)

# %% [markdown]
# **Apply GridSearchCV**
#
# Use a 3-fold K-fold cross-validation was used for learning the optimum hyperparameters for the XGBoost algorithm.

# %%
# Import Grid Search library
from sklearn.model_selection import GridSearchCV

# %%
# Tune hyperparameters using XGboost
xgb_params = {
    "n_estimators": [100],
    "learning_rate": [0.1,0.01],
    "max_depth": [3,9],
    "gamma":[0.2,0]
}

# Define GridSearchCV object
xgb_grid = GridSearchCV(xgb.XGBRegressor(),
                        xgb_params,cv=3,
                        verbose=1,
                        scoring= "neg_mean_squared_error")

# Train on train data using 3 fold Cross Validation
xgb_grid.fit(X_train,y_train,
             early_stopping_rounds=5,
             eval_set=[(X_train, y_train), (X_test,y_test)],
             eval_metric='rmse')

# print the best hyperparameters and corresponding score
print("Best Hyperparameters: ", xgb_grid.best_params_)
print("Best Score: ", xgb_grid.best_score_)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [0]	validation_0-rmse:44.40574	validation_1-rmse:43.07046
# [1]	validation_0-rmse:40.97377	validation_1-rmse:39.75548
# [2]	validation_0-rmse:38.30604	validation_1-rmse:37.09043
# [3]	validation_0-rmse:35.76430	validation_1-rmse:34.55590
# [4]	validation_0-rmse:33.43841	validation_1-rmse:32.14610
# [5]	validation_0-rmse:31.39463	validation_1-rmse:30.14779
# [6]	validation_0-rmse:29.63916	validation_1-rmse:28.38466
# [7]	validation_0-rmse:28.07766	validation_1-rmse:26.88561
# [8]	validation_0-rmse:26.85537	validation_1-rmse:25.73769
# [9]	validation_0-rmse:25.82833	validation_1-rmse:24.72542
# [10]	validation_0-rmse:24.85139	validation_1-rmse:23.73483
# [11]	validation_0-rmse:24.03989	validation_1-rmse:22.89006
# [12]	validation_0-rmse:23.40330	validation_1-rmse:22.27312
# [13]	validation_0-rmse:22.75189	validation_1-rmse:21.66621
# [14]	validation_0-rmse:22.24721	validation_1-rmse:21.13642
# [15]	validation_0-rmse:21.77860	validation_1-rmse:20.69754
# [16]	validation_0-rmse:21.40522	validation_1-rmse:20.32926
# [17]	validation_0-rmse:21.09832	validation_1-rmse:20.03353
# [18]	validation_0-rmse:20.84358	validation_1-rmse:19.79608
# [19]	validation_0-rmse:20.59676	validation_1-rmse:19.57181
# [20]	validation_0-rmse:20.39344	validation_1-rmse:19.38948
# [21]	validation_0-rmse:20.20787	validation_1-rmse:19.17357
# [22]	validation_0-rmse:20.04218	validation_1-rmse:19.01899
# [23]	validation_0-rmse:19.95155	validation_1-rmse:18.93325
# [24]	validation_0-rmse:19.82111	validation_1-rmse:18.80733
# [25]	validation_0-rmse:19.76139	validation_1-rmse:18.75562
# [26]	validation_0-rmse:19.70584	validation_1-rmse:18.70667
# [27]	validation_0-rmse:19.65593	validation_1-rmse:18.66904
# [28]	validation_0-rmse:19.58047	validation_1-rmse:18.58716
# [29]	validation_0-rmse:19.54302	validation_1-rmse:18.55378
# [30]	validation_0-rmse:19.51909	validation_1-rmse:18.53795
# [31]	validation_0-rmse:19.49553	validation_1-rmse:18.48219
# [32]	validation_0-rmse:19.43607	validation_1-rmse:18.43824
# [33]	validation_0-rmse:19.41097	validation_1-rmse:18.41154
# [34]	validation_0-rmse:19.38906	validation_1-rmse:18.39394
# [35]	validation_0-rmse:19.35716	validation_1-rmse:18.36595
# [36]	validation_0-rmse:19.33629	validation_1-rmse:18.35273
# [37]	validation_0-rmse:19.32929	validation_1-rmse:18.34720
# [38]	validation_0-rmse:19.31218	validation_1-rmse:18.33779
# [39]	validation_0-rmse:19.29323	validation_1-rmse:18.32245
# [40]	validation_0-rmse:19.28849	validation_1-rmse:18.32391
# [41]	validation_0-rmse:19.27688	validation_1-rmse:18.31805
# [42]	validation_0-rmse:19.25321	validation_1-rmse:18.29959
# [43]	validation_0-rmse:19.24704	validation_1-rmse:18.29706
# [44]	validation_0-rmse:19.22319	validation_1-rmse:18.26982
# [45]	validation_0-rmse:19.21974	validation_1-rmse:18.26862
# [46]	validation_0-rmse:19.21494	validation_1-rmse:18.26478
# [47]	validation_0-rmse:19.21274	validation_1-rmse:18.26441
# [48]	validation_0-rmse:19.18984	validation_1-rmse:18.24813
# [49]	validation_0-rmse:19.18839	validation_1-rmse:18.24796
# [50]	validation_0-rmse:19.16968	validation_1-rmse:18.24206
# [51]	validation_0-rmse:19.17388	validation_1-rmse:18.23537
# [52]	validation_0-rmse:19.18024	validation_1-rmse:18.23151
# [53]	validation_0-rmse:19.17000	validation_1-rmse:18.22784
# [54]	validation_0-rmse:19.16852	validation_1-rmse:18.22764
# [55]	validation_0-rmse:19.15794	validation_1-rmse:18.22214
# [56]	validation_0-rmse:19.15696	validation_1-rmse:18.22214
# [57]	validation_0-rmse:19.16789	validation_1-rmse:18.21850
# [58]	validation_0-rmse:19.15742	validation_1-rmse:18.21236
# [59]	validation_0-rmse:19.14435	validation_1-rmse:18.20401
# [60]	validation_0-rmse:19.14347	validation_1-rmse:18.20401
# [61]	validation_0-rmse:19.14268	validation_1-rmse:18.20401
# [62]	validation_0-rmse:19.12687	validation_1-rmse:18.19034
# [63]	validation_0-rmse:19.11596	validation_1-rmse:18.17839
# [64]	validation_0-rmse:19.11758	validation_1-rmse:18.17806
# [65]	validation_0-rmse:19.15440	validation_1-rmse:18.18345
# [66]	validation_0-rmse:19.13214	validation_1-rmse:18.16904
# [67]	validation_0-rmse:19.12478	validation_1-rmse:18.16424
# [68]	validation_0-rmse:19.12590	validation_1-rmse:18.16342
# [69]	validation_0-rmse:19.15107	validation_1-rmse:18.17066
# [70]	validation_0-rmse:19.15047	validation_1-rmse:18.17067
# [71]	validation_0-rmse:19.15009	validation_1-rmse:18.16591
# [72]	validation_0-rmse:19.14335	validation_1-rmse:18.16025
# [73]	validation_0-rmse:19.15527	validation_1-rmse:18.16940
# [74]	validation_0-rmse:19.15472	validation_1-rmse:18.16940
# [75]	validation_0-rmse:19.16418	validation_1-rmse:18.17658
# [76]	validation_0-rmse:19.16466	validation_1-rmse:18.17596
# [77]	validation_0-rmse:19.15848	validation_1-rmse:18.17350
# [0]	validation_0-rmse:44.29081	validation_1-rmse:43.18568
# [1]	validation_0-rmse:40.88285	validation_1-rmse:39.86262
# [2]	validation_0-rmse:37.88170	validation_1-rmse:36.94291
# [3]	validation_0-rmse:35.23470	validation_1-rmse:34.34488
# [4]	validation_0-rmse:32.91248	validation_1-rmse:32.08865
# [5]	validation_0-rmse:30.88947	validation_1-rmse:30.10482
# [6]	validation_0-rmse:29.13047	validation_1-rmse:28.38006
# [7]	validation_0-rmse:27.60388	validation_1-rmse:26.87425
# [8]	validation_0-rmse:26.27636	validation_1-rmse:25.60399
# [9]	validation_0-rmse:25.14192	validation_1-rmse:24.48189
# [10]	validation_0-rmse:24.15702	validation_1-rmse:23.51604
# [11]	validation_0-rmse:23.31855	validation_1-rmse:22.69400
# [12]	validation_0-rmse:22.61215	validation_1-rmse:21.99500
# [13]	validation_0-rmse:22.00762	validation_1-rmse:21.41768
# [14]	validation_0-rmse:21.49772	validation_1-rmse:20.88959
# [15]	validation_0-rmse:21.07131	validation_1-rmse:20.45025
# [16]	validation_0-rmse:20.70866	validation_1-rmse:20.10819
# [17]	validation_0-rmse:20.40089	validation_1-rmse:19.81270
# [18]	validation_0-rmse:20.14392	validation_1-rmse:19.54476
# [19]	validation_0-rmse:19.90377	validation_1-rmse:19.30349
# [20]	validation_0-rmse:19.72024	validation_1-rmse:19.12286
# [21]	validation_0-rmse:19.55864	validation_1-rmse:18.97738
# [22]	validation_0-rmse:19.43094	validation_1-rmse:18.85928
# [23]	validation_0-rmse:19.30998	validation_1-rmse:18.73619
# [24]	validation_0-rmse:19.21311	validation_1-rmse:18.65041
# [25]	validation_0-rmse:19.13321	validation_1-rmse:18.57861
# [26]	validation_0-rmse:19.04573	validation_1-rmse:18.48855
# [27]	validation_0-rmse:18.96822	validation_1-rmse:18.41672
# [28]	validation_0-rmse:18.90788	validation_1-rmse:18.37015
# [29]	validation_0-rmse:18.85530	validation_1-rmse:18.32353
# [30]	validation_0-rmse:18.80602	validation_1-rmse:18.28710
# [31]	validation_0-rmse:18.76075	validation_1-rmse:18.26119
# [32]	validation_0-rmse:18.72735	validation_1-rmse:18.24236
# [33]	validation_0-rmse:18.69691	validation_1-rmse:18.22046
# [34]	validation_0-rmse:18.65929	validation_1-rmse:18.18978
# [35]	validation_0-rmse:18.63363	validation_1-rmse:18.17089
# [36]	validation_0-rmse:18.61568	validation_1-rmse:18.16004
# [37]	validation_0-rmse:18.59355	validation_1-rmse:18.13547
# [38]	validation_0-rmse:18.56828	validation_1-rmse:18.11525
# [39]	validation_0-rmse:18.55009	validation_1-rmse:18.10372
# [40]	validation_0-rmse:18.52372	validation_1-rmse:18.07870
# [41]	validation_0-rmse:18.51378	validation_1-rmse:18.07543
# [42]	validation_0-rmse:18.48813	validation_1-rmse:18.05784
# [43]	validation_0-rmse:18.46465	validation_1-rmse:18.04120
# [44]	validation_0-rmse:18.44711	validation_1-rmse:18.03226
# [45]	validation_0-rmse:18.42746	validation_1-rmse:18.01742
# [46]	validation_0-rmse:18.40852	validation_1-rmse:17.99230
# [47]	validation_0-rmse:18.39572	validation_1-rmse:17.98352
# [48]	validation_0-rmse:18.37833	validation_1-rmse:17.97321
# [49]	validation_0-rmse:18.36160	validation_1-rmse:17.96638
# [50]	validation_0-rmse:18.33966	validation_1-rmse:17.95097
# [51]	validation_0-rmse:18.32593	validation_1-rmse:17.93621
# [52]	validation_0-rmse:18.30621	validation_1-rmse:17.92422
# [53]	validation_0-rmse:18.28575	validation_1-rmse:17.91844
# [54]	validation_0-rmse:18.26294	validation_1-rmse:17.91192
# [55]	validation_0-rmse:18.22775	validation_1-rmse:17.88341
# [56]	validation_0-rmse:18.20545	validation_1-rmse:17.86651
# [57]	validation_0-rmse:18.20035	validation_1-rmse:17.87517
# [58]	validation_0-rmse:18.19271	validation_1-rmse:17.87075
# [59]	validation_0-rmse:18.19248	validation_1-rmse:17.87229
# [60]	validation_0-rmse:18.18612	validation_1-rmse:17.86767
# [0]	validation_0-rmse:44.36237	validation_1-rmse:43.19461
# [1]	validation_0-rmse:41.10351	validation_1-rmse:40.02622
# [2]	validation_0-rmse:38.21649	validation_1-rmse:37.21691
# [3]	validation_0-rmse:35.68626	validation_1-rmse:34.75953
# [4]	validation_0-rmse:33.47904	validation_1-rmse:32.60905
# [5]	validation_0-rmse:31.53752	validation_1-rmse:30.72068
# [6]	validation_0-rmse:29.83212	validation_1-rmse:29.05721
# [7]	validation_0-rmse:28.33441	validation_1-rmse:27.59912
# [8]	validation_0-rmse:27.03399	validation_1-rmse:26.33318
# [9]	validation_0-rmse:25.90580	validation_1-rmse:25.23416
# [10]	validation_0-rmse:24.95025	validation_1-rmse:24.31083
# [11]	validation_0-rmse:24.11441	validation_1-rmse:23.50474
# [12]	validation_0-rmse:23.44343	validation_1-rmse:22.88793
# [13]	validation_0-rmse:22.82322	validation_1-rmse:22.27829
# [14]	validation_0-rmse:22.29382	validation_1-rmse:21.76794
# [15]	validation_0-rmse:21.85988	validation_1-rmse:21.33112
# [16]	validation_0-rmse:21.47632	validation_1-rmse:20.96328
# [17]	validation_0-rmse:21.15682	validation_1-rmse:20.66394
# [18]	validation_0-rmse:20.92251	validation_1-rmse:20.45873
# [19]	validation_0-rmse:20.67192	validation_1-rmse:20.21293
# [20]	validation_0-rmse:20.49336	validation_1-rmse:20.04180
# [21]	validation_0-rmse:20.32287	validation_1-rmse:19.89706
# [22]	validation_0-rmse:20.15816	validation_1-rmse:19.73779
# [23]	validation_0-rmse:20.03354	validation_1-rmse:19.61412
# [24]	validation_0-rmse:19.94674	validation_1-rmse:19.54273
# [25]	validation_0-rmse:19.85598	validation_1-rmse:19.46682
# [26]	validation_0-rmse:19.76728	validation_1-rmse:19.38622
# [27]	validation_0-rmse:19.68695	validation_1-rmse:19.31568
# [28]	validation_0-rmse:19.63839	validation_1-rmse:19.28726
# [29]	validation_0-rmse:19.60023	validation_1-rmse:19.25568
# [30]	validation_0-rmse:19.53351	validation_1-rmse:19.20668
# [31]	validation_0-rmse:19.46436	validation_1-rmse:19.15746
# [32]	validation_0-rmse:19.42904	validation_1-rmse:19.13224
# [33]	validation_0-rmse:19.41306	validation_1-rmse:19.14587
# [34]	validation_0-rmse:19.37139	validation_1-rmse:19.11097
# [35]	validation_0-rmse:19.35000	validation_1-rmse:19.10107
# [36]	validation_0-rmse:19.33133	validation_1-rmse:19.09565
# [37]	validation_0-rmse:19.30655	validation_1-rmse:19.07958
# [38]	validation_0-rmse:19.27327	validation_1-rmse:19.05414
# [39]	validation_0-rmse:19.25615	validation_1-rmse:19.05404
# [40]	validation_0-rmse:19.24049	validation_1-rmse:19.05510
# [41]	validation_0-rmse:19.22301	validation_1-rmse:19.05359
# [42]	validation_0-rmse:19.20945	validation_1-rmse:19.05353
# [43]	validation_0-rmse:19.18702	validation_1-rmse:19.05085
# [44]	validation_0-rmse:19.17041	validation_1-rmse:19.05487
# [45]	validation_0-rmse:19.15447	validation_1-rmse:19.04674
# [46]	validation_0-rmse:19.13149	validation_1-rmse:19.03161
# [47]	validation_0-rmse:19.12445	validation_1-rmse:19.04405
# [48]	validation_0-rmse:19.10830	validation_1-rmse:19.03192
# [49]	validation_0-rmse:19.08838	validation_1-rmse:19.01603
# [50]	validation_0-rmse:19.08535	validation_1-rmse:19.02359
# [51]	validation_0-rmse:19.06562	validation_1-rmse:19.01369
# [52]	validation_0-rmse:19.06717	validation_1-rmse:19.02147
# [53]	validation_0-rmse:19.04002	validation_1-rmse:19.01283
# [54]	validation_0-rmse:19.01476	validation_1-rmse:18.98898
# [55]	validation_0-rmse:19.03298	validation_1-rmse:19.02384
# [56]	validation_0-rmse:19.03209	validation_1-rmse:19.03310
# [57]	validation_0-rmse:19.02641	validation_1-rmse:19.04312
# [58]	validation_0-rmse:19.02858	validation_1-rmse:19.05044
# [59]	validation_0-rmse:19.01529	validation_1-rmse:19.03740
# [0]	validation_0-rmse:44.62307	validation_1-rmse:43.40741
# [1]	validation_0-rmse:41.41405	validation_1-rmse:40.27580
# [2]	validation_0-rmse:38.56793	validation_1-rmse:37.77374
# [3]	validation_0-rmse:36.07489	validation_1-rmse:35.42048
# [4]	validation_0-rmse:33.82273	validation_1-rmse:33.41847
# [5]	validation_0-rmse:31.86719	validation_1-rmse:31.59441
# [6]	validation_0-rmse:30.15609	validation_1-rmse:29.85570
# [7]	validation_0-rmse:28.69360	validation_1-rmse:28.37215
# [8]	validation_0-rmse:27.41058	validation_1-rmse:27.09782
# [9]	validation_0-rmse:26.39348	validation_1-rmse:26.08236
# [10]	validation_0-rmse:25.48374	validation_1-rmse:25.20536
# [11]	validation_0-rmse:24.68225	validation_1-rmse:24.49020
# [12]	validation_0-rmse:24.03512	validation_1-rmse:23.85615
# [13]	validation_0-rmse:23.43526	validation_1-rmse:23.33133
# [14]	validation_0-rmse:22.97513	validation_1-rmse:22.91626
# [15]	validation_0-rmse:22.50890	validation_1-rmse:22.51863
# [16]	validation_0-rmse:22.13218	validation_1-rmse:22.17932
# [17]	validation_0-rmse:21.79339	validation_1-rmse:21.92844
# [18]	validation_0-rmse:21.50956	validation_1-rmse:21.73383
# [19]	validation_0-rmse:21.29187	validation_1-rmse:21.59463
# [20]	validation_0-rmse:21.10035	validation_1-rmse:21.49464
# [21]	validation_0-rmse:20.93555	validation_1-rmse:21.42039
# [22]	validation_0-rmse:20.77801	validation_1-rmse:21.37348
# [23]	validation_0-rmse:20.63467	validation_1-rmse:21.33740
# [24]	validation_0-rmse:20.51259	validation_1-rmse:21.31377
# [25]	validation_0-rmse:20.38969	validation_1-rmse:21.25601
# [26]	validation_0-rmse:20.28828	validation_1-rmse:21.20101
# [27]	validation_0-rmse:20.22982	validation_1-rmse:21.20400
# [28]	validation_0-rmse:20.16418	validation_1-rmse:21.20569
# [29]	validation_0-rmse:20.09299	validation_1-rmse:21.18452
# [30]	validation_0-rmse:20.03279	validation_1-rmse:21.17287
# [31]	validation_0-rmse:19.98554	validation_1-rmse:21.14714
# [32]	validation_0-rmse:19.94773	validation_1-rmse:21.15794
# [33]	validation_0-rmse:19.91152	validation_1-rmse:21.15947
# [34]	validation_0-rmse:19.86846	validation_1-rmse:21.15682
# [35]	validation_0-rmse:19.85340	validation_1-rmse:21.15364
# [36]	validation_0-rmse:19.83662	validation_1-rmse:21.12655
# [37]	validation_0-rmse:19.80463	validation_1-rmse:21.15192
# [38]	validation_0-rmse:19.78129	validation_1-rmse:21.16117
# [39]	validation_0-rmse:19.76505	validation_1-rmse:21.16898
# [40]	validation_0-rmse:19.75122	validation_1-rmse:21.19100
# [41]	validation_0-rmse:19.74796	validation_1-rmse:21.22167
# [0]	validation_0-rmse:44.04110	validation_1-rmse:42.98455
# [1]	validation_0-rmse:40.38149	validation_1-rmse:39.58837
# [2]	validation_0-rmse:37.13949	validation_1-rmse:36.53420
# [3]	validation_0-rmse:34.25682	validation_1-rmse:33.84047
# [4]	validation_0-rmse:31.69706	validation_1-rmse:31.42528
# [5]	validation_0-rmse:29.43152	validation_1-rmse:29.48680
# [6]	validation_0-rmse:27.43230	validation_1-rmse:27.68962
# [7]	validation_0-rmse:25.64890	validation_1-rmse:26.11539
# [8]	validation_0-rmse:24.09076	validation_1-rmse:24.84816
# [9]	validation_0-rmse:22.72324	validation_1-rmse:23.74836
# [10]	validation_0-rmse:21.50866	validation_1-rmse:22.79376
# [11]	validation_0-rmse:20.45109	validation_1-rmse:21.98106
# [12]	validation_0-rmse:19.52926	validation_1-rmse:21.30959
# [13]	validation_0-rmse:18.72675	validation_1-rmse:20.71397
# [14]	validation_0-rmse:18.00843	validation_1-rmse:20.19342
# [15]	validation_0-rmse:17.39167	validation_1-rmse:19.77728
# [16]	validation_0-rmse:16.84546	validation_1-rmse:19.46335
# [17]	validation_0-rmse:16.37079	validation_1-rmse:19.15409
# [18]	validation_0-rmse:15.94662	validation_1-rmse:18.93379
# [19]	validation_0-rmse:15.58034	validation_1-rmse:18.74944
# [20]	validation_0-rmse:15.26979	validation_1-rmse:18.58538
# [21]	validation_0-rmse:14.99094	validation_1-rmse:18.43673
# [22]	validation_0-rmse:14.73982	validation_1-rmse:18.31454
# [23]	validation_0-rmse:14.52760	validation_1-rmse:18.20666
# [24]	validation_0-rmse:14.32351	validation_1-rmse:18.08628
# [25]	validation_0-rmse:14.11162	validation_1-rmse:17.99130
# [26]	validation_0-rmse:13.94421	validation_1-rmse:17.93006
# [27]	validation_0-rmse:13.78231	validation_1-rmse:17.85793
# [28]	validation_0-rmse:13.63531	validation_1-rmse:17.81145
# [29]	validation_0-rmse:13.50820	validation_1-rmse:17.76421
# [30]	validation_0-rmse:13.39801	validation_1-rmse:17.74468
# [31]	validation_0-rmse:13.28077	validation_1-rmse:17.71617
# [32]	validation_0-rmse:13.15238	validation_1-rmse:17.68970
# [33]	validation_0-rmse:13.04056	validation_1-rmse:17.66162
# [34]	validation_0-rmse:12.94155	validation_1-rmse:17.65158
# [35]	validation_0-rmse:12.84276	validation_1-rmse:17.62477
# [36]	validation_0-rmse:12.77621	validation_1-rmse:17.60950
# [37]	validation_0-rmse:12.68470	validation_1-rmse:17.60002
# [38]	validation_0-rmse:12.60654	validation_1-rmse:17.58933
# [39]	validation_0-rmse:12.52073	validation_1-rmse:17.56947
# [40]	validation_0-rmse:12.44781	validation_1-rmse:17.57006
# [41]	validation_0-rmse:12.37873	validation_1-rmse:17.56270
# [42]	validation_0-rmse:12.32037	validation_1-rmse:17.56680
# [43]	validation_0-rmse:12.25051	validation_1-rmse:17.54901
# [44]	validation_0-rmse:12.19544	validation_1-rmse:17.54428
# [45]	validation_0-rmse:12.11651	validation_1-rmse:17.52623
# [46]	validation_0-rmse:12.06405	validation_1-rmse:17.51619
# [47]	validation_0-rmse:12.00467	validation_1-rmse:17.50770
# [48]	validation_0-rmse:11.95664	validation_1-rmse:17.49372
# [49]	validation_0-rmse:11.89991	validation_1-rmse:17.48034
# [50]	validation_0-rmse:11.85164	validation_1-rmse:17.46978
# [51]	validation_0-rmse:11.81310	validation_1-rmse:17.47324
# [52]	validation_0-rmse:11.76158	validation_1-rmse:17.46010
# [53]	validation_0-rmse:11.73654	validation_1-rmse:17.45862
# [54]	validation_0-rmse:11.68641	validation_1-rmse:17.45318
# [55]	validation_0-rmse:11.64601	validation_1-rmse:17.44904
# [56]	validation_0-rmse:11.60223	validation_1-rmse:17.44839
# [57]	validation_0-rmse:11.57978	validation_1-rmse:17.45064
# [58]	validation_0-rmse:11.53891	validation_1-rmse:17.45178
# [59]	validation_0-rmse:11.50576	validation_1-rmse:17.45409
# [60]	validation_0-rmse:11.46964	validation_1-rmse:17.45243
# [61]	validation_0-rmse:11.43789	validation_1-rmse:17.44685
# [62]	validation_0-rmse:11.39340	validation_1-rmse:17.44151
# [63]	validation_0-rmse:11.37146	validation_1-rmse:17.43087
# [64]	validation_0-rmse:11.35098	validation_1-rmse:17.43102
# [65]	validation_0-rmse:11.33629	validation_1-rmse:17.42856
# [66]	validation_0-rmse:11.30604	validation_1-rmse:17.42595
# [67]	validation_0-rmse:11.29409	validation_1-rmse:17.43031
# [68]	validation_0-rmse:11.28007	validation_1-rmse:17.43083
# [69]	validation_0-rmse:11.26013	validation_1-rmse:17.42961
# [70]	validation_0-rmse:11.23154	validation_1-rmse:17.42277
# [71]	validation_0-rmse:11.20658	validation_1-rmse:17.41713
# [72]	validation_0-rmse:11.18691	validation_1-rmse:17.41820
# [73]	validation_0-rmse:11.16717	validation_1-rmse:17.40406
# [74]	validation_0-rmse:11.12747	validation_1-rmse:17.39821
# [75]	validation_0-rmse:11.10762	validation_1-rmse:17.39977
# [76]	validation_0-rmse:11.09103	validation_1-rmse:17.40147
# [77]	validation_0-rmse:11.06798	validation_1-rmse:17.40604
# [78]	validation_0-rmse:11.02018	validation_1-rmse:17.40395
# [79]	validation_0-rmse:10.98000	validation_1-rmse:17.40027
# [0]	validation_0-rmse:44.24899	validation_1-rmse:43.23181
# [1]	validation_0-rmse:40.98140	validation_1-rmse:40.30495
# [2]	validation_0-rmse:38.07476	validation_1-rmse:37.63665
# [3]	validation_0-rmse:35.48476	validation_1-rmse:35.39400
# [4]	validation_0-rmse:33.21913	validation_1-rmse:33.48778
# [5]	validation_0-rmse:31.12237	validation_1-rmse:31.51889
# [6]	validation_0-rmse:29.44264	validation_1-rmse:30.15030
# [7]	validation_0-rmse:27.96280	validation_1-rmse:28.89642
# [8]	validation_0-rmse:26.63694	validation_1-rmse:27.87468
# [9]	validation_0-rmse:25.54215	validation_1-rmse:26.97155
# [10]	validation_0-rmse:24.58266	validation_1-rmse:26.21996
# [11]	validation_0-rmse:23.67118	validation_1-rmse:25.40074
# [12]	validation_0-rmse:22.83374	validation_1-rmse:24.62538
# [13]	validation_0-rmse:22.11410	validation_1-rmse:24.03752
# [14]	validation_0-rmse:21.49643	validation_1-rmse:23.51444
# [15]	validation_0-rmse:20.97650	validation_1-rmse:23.17317
# [16]	validation_0-rmse:20.47891	validation_1-rmse:22.83975
# [17]	validation_0-rmse:20.01941	validation_1-rmse:22.54845
# [18]	validation_0-rmse:19.65896	validation_1-rmse:22.32923
# [19]	validation_0-rmse:19.36008	validation_1-rmse:22.14827
# [20]	validation_0-rmse:19.10229	validation_1-rmse:22.01227
# [21]	validation_0-rmse:18.82646	validation_1-rmse:21.84475
# [22]	validation_0-rmse:18.58707	validation_1-rmse:21.69445
# [23]	validation_0-rmse:18.38328	validation_1-rmse:21.58447
# [24]	validation_0-rmse:18.19467	validation_1-rmse:21.45257
# [25]	validation_0-rmse:18.01385	validation_1-rmse:21.31853
# [26]	validation_0-rmse:17.83553	validation_1-rmse:21.19747
# [27]	validation_0-rmse:17.67850	validation_1-rmse:21.08048
# [28]	validation_0-rmse:17.54291	validation_1-rmse:20.98590
# [29]	validation_0-rmse:17.40933	validation_1-rmse:20.91484
# [30]	validation_0-rmse:17.30123	validation_1-rmse:20.87048
# [31]	validation_0-rmse:17.21173	validation_1-rmse:20.82306
# [32]	validation_0-rmse:17.13209	validation_1-rmse:20.78011
# [33]	validation_0-rmse:17.05013	validation_1-rmse:20.73262
# [34]	validation_0-rmse:16.99872	validation_1-rmse:20.69499
# [35]	validation_0-rmse:16.90710	validation_1-rmse:20.64634
# [36]	validation_0-rmse:16.83848	validation_1-rmse:20.64392
# [37]	validation_0-rmse:16.77216	validation_1-rmse:20.59850
# [38]	validation_0-rmse:16.72159	validation_1-rmse:20.58248
# [39]	validation_0-rmse:16.65985	validation_1-rmse:20.54281
# [40]	validation_0-rmse:16.60754	validation_1-rmse:20.54343
# [41]	validation_0-rmse:16.55121	validation_1-rmse:20.53381
# [42]	validation_0-rmse:16.49882	validation_1-rmse:20.51467
# [43]	validation_0-rmse:16.46286	validation_1-rmse:20.52557
# [44]	validation_0-rmse:16.42029	validation_1-rmse:20.50755
# [45]	validation_0-rmse:16.38059	validation_1-rmse:20.49096
# [46]	validation_0-rmse:16.37991	validation_1-rmse:20.51966
# [47]	validation_0-rmse:16.36024	validation_1-rmse:20.51804
# [48]	validation_0-rmse:16.32120	validation_1-rmse:20.50803
# [49]	validation_0-rmse:16.30995	validation_1-rmse:20.50134
# [0]	validation_0-rmse:47.81586	validation_1-rmse:46.36263
# [1]	validation_0-rmse:47.43717	validation_1-rmse:45.99709
# [2]	validation_0-rmse:47.06302	validation_1-rmse:45.63593
# [3]	validation_0-rmse:46.69345	validation_1-rmse:45.27911
# [4]	validation_0-rmse:46.32764	validation_1-rmse:44.92484
# [5]	validation_0-rmse:45.96700	validation_1-rmse:44.57667
# [6]	validation_0-rmse:45.60134	validation_1-rmse:44.22349
# [7]	validation_0-rmse:45.25057	validation_1-rmse:43.87380
# [8]	validation_0-rmse:44.89406	validation_1-rmse:43.53050
# [9]	validation_0-rmse:44.54141	validation_1-rmse:43.19004
# [10]	validation_0-rmse:44.20009	validation_1-rmse:42.85902
# [11]	validation_0-rmse:43.85576	validation_1-rmse:42.52652
# [12]	validation_0-rmse:43.52709	validation_1-rmse:42.19981
# [13]	validation_0-rmse:43.19085	validation_1-rmse:41.87508
# [14]	validation_0-rmse:42.86939	validation_1-rmse:41.55547
# [15]	validation_0-rmse:42.55322	validation_1-rmse:41.24900
# [16]	validation_0-rmse:42.23755	validation_1-rmse:40.94340
# [17]	validation_0-rmse:41.91698	validation_1-rmse:40.63372
# [18]	validation_0-rmse:41.63695	validation_1-rmse:40.35428
# [19]	validation_0-rmse:41.33134	validation_1-rmse:40.04995
# [20]	validation_0-rmse:41.03166	validation_1-rmse:39.75170
# [21]	validation_0-rmse:40.74483	validation_1-rmse:39.46475
# [22]	validation_0-rmse:40.47491	validation_1-rmse:39.20376
# [23]	validation_0-rmse:40.18443	validation_1-rmse:38.92303
# [24]	validation_0-rmse:39.89775	validation_1-rmse:38.64624
# [25]	validation_0-rmse:39.61481	validation_1-rmse:38.36414
# [26]	validation_0-rmse:39.33709	validation_1-rmse:38.09635
# [27]	validation_0-rmse:39.08104	validation_1-rmse:37.84158
# [28]	validation_0-rmse:38.80748	validation_1-rmse:37.57724
# [29]	validation_0-rmse:38.53658	validation_1-rmse:37.30552
# [30]	validation_0-rmse:38.27164	validation_1-rmse:37.05014
# [31]	validation_0-rmse:37.99677	validation_1-rmse:36.78311
# [32]	validation_0-rmse:37.73371	validation_1-rmse:36.51806
# [33]	validation_0-rmse:37.47888	validation_1-rmse:36.25593
# [34]	validation_0-rmse:37.22438	validation_1-rmse:36.00089
# [35]	validation_0-rmse:36.97191	validation_1-rmse:35.74771
# [36]	validation_0-rmse:36.72752	validation_1-rmse:35.51247
# [37]	validation_0-rmse:36.50174	validation_1-rmse:35.28774
# [38]	validation_0-rmse:36.26243	validation_1-rmse:35.04138
# [39]	validation_0-rmse:36.01958	validation_1-rmse:34.80480
# [40]	validation_0-rmse:35.77953	validation_1-rmse:34.56242
# [41]	validation_0-rmse:35.55009	validation_1-rmse:34.32633
# [42]	validation_0-rmse:35.31403	validation_1-rmse:34.09557
# [43]	validation_0-rmse:35.08300	validation_1-rmse:33.87055
# [44]	validation_0-rmse:34.87222	validation_1-rmse:33.65478
# [45]	validation_0-rmse:34.66171	validation_1-rmse:33.45237
# [46]	validation_0-rmse:34.43828	validation_1-rmse:33.22602
# [47]	validation_0-rmse:34.22459	validation_1-rmse:33.00633
# [48]	validation_0-rmse:34.00724	validation_1-rmse:32.79460
# [49]	validation_0-rmse:33.79120	validation_1-rmse:32.58329
# [50]	validation_0-rmse:33.59087	validation_1-rmse:32.38334
# [51]	validation_0-rmse:33.38214	validation_1-rmse:32.17207
# [52]	validation_0-rmse:33.17736	validation_1-rmse:31.97304
# [53]	validation_0-rmse:32.98707	validation_1-rmse:31.79022
# [54]	validation_0-rmse:32.80573	validation_1-rmse:31.60903
# [55]	validation_0-rmse:32.60721	validation_1-rmse:31.41653
# [56]	validation_0-rmse:32.42650	validation_1-rmse:31.23168
# [57]	validation_0-rmse:32.23137	validation_1-rmse:31.04075
# [58]	validation_0-rmse:32.05930	validation_1-rmse:30.86869
# [59]	validation_0-rmse:31.86916	validation_1-rmse:30.68280
# [60]	validation_0-rmse:31.68513	validation_1-rmse:30.49725
# [61]	validation_0-rmse:31.51763	validation_1-rmse:30.33614
# [62]	validation_0-rmse:31.33564	validation_1-rmse:30.15157
# [63]	validation_0-rmse:31.17210	validation_1-rmse:29.99343
# [64]	validation_0-rmse:30.99645	validation_1-rmse:29.81555
# [65]	validation_0-rmse:30.82209	validation_1-rmse:29.64534
# [66]	validation_0-rmse:30.65372	validation_1-rmse:29.47192
# [67]	validation_0-rmse:30.49485	validation_1-rmse:29.31987
# [68]	validation_0-rmse:30.34309	validation_1-rmse:29.16966
# [69]	validation_0-rmse:30.17788	validation_1-rmse:29.00210
# [70]	validation_0-rmse:30.02587	validation_1-rmse:28.85569
# [71]	validation_0-rmse:29.86812	validation_1-rmse:28.69349
# [72]	validation_0-rmse:29.70544	validation_1-rmse:28.53635
# [73]	validation_0-rmse:29.54722	validation_1-rmse:28.38143
# [74]	validation_0-rmse:29.39906	validation_1-rmse:28.23349
# [75]	validation_0-rmse:29.25686	validation_1-rmse:28.09662
# [76]	validation_0-rmse:29.11820	validation_1-rmse:27.95524
# [77]	validation_0-rmse:28.96787	validation_1-rmse:27.80824
# [78]	validation_0-rmse:28.82461	validation_1-rmse:27.66112
# [79]	validation_0-rmse:28.67675	validation_1-rmse:27.51882
# [80]	validation_0-rmse:28.54844	validation_1-rmse:27.39082
# [81]	validation_0-rmse:28.40684	validation_1-rmse:27.25177
# [82]	validation_0-rmse:28.27089	validation_1-rmse:27.11140
# [83]	validation_0-rmse:28.14810	validation_1-rmse:26.98906
# [84]	validation_0-rmse:28.01645	validation_1-rmse:26.85414
# [85]	validation_0-rmse:27.88317	validation_1-rmse:26.72416
# [86]	validation_0-rmse:27.76289	validation_1-rmse:26.60211
# [87]	validation_0-rmse:27.64659	validation_1-rmse:26.48723
# [88]	validation_0-rmse:27.51592	validation_1-rmse:26.36242
# [89]	validation_0-rmse:27.38960	validation_1-rmse:26.23949
# [90]	validation_0-rmse:27.27851	validation_1-rmse:26.12833
# [91]	validation_0-rmse:27.16138	validation_1-rmse:26.01103
# [92]	validation_0-rmse:27.03929	validation_1-rmse:25.89015
# [93]	validation_0-rmse:26.91945	validation_1-rmse:25.76670
# [94]	validation_0-rmse:26.81471	validation_1-rmse:25.66263
# [95]	validation_0-rmse:26.71190	validation_1-rmse:25.55963
# [96]	validation_0-rmse:26.59715	validation_1-rmse:25.44790
# [97]	validation_0-rmse:26.49408	validation_1-rmse:25.34353
# [98]	validation_0-rmse:26.39473	validation_1-rmse:25.24574
# [99]	validation_0-rmse:26.28454	validation_1-rmse:25.13571
# [0]	validation_0-rmse:47.75328	validation_1-rmse:46.56670
# [1]	validation_0-rmse:47.36872	validation_1-rmse:46.19111
# [2]	validation_0-rmse:46.98882	validation_1-rmse:45.82110
# [3]	validation_0-rmse:46.61329	validation_1-rmse:45.45510
# [4]	validation_0-rmse:46.24242	validation_1-rmse:45.09395
# [5]	validation_0-rmse:45.87562	validation_1-rmse:44.73651
# [6]	validation_0-rmse:45.51330	validation_1-rmse:44.38172
# [7]	validation_0-rmse:45.15496	validation_1-rmse:44.03144
# [8]	validation_0-rmse:44.80121	validation_1-rmse:43.68626
# [9]	validation_0-rmse:44.45114	validation_1-rmse:43.34407
# [10]	validation_0-rmse:44.10544	validation_1-rmse:43.00564
# [11]	validation_0-rmse:43.76367	validation_1-rmse:42.67157
# [12]	validation_0-rmse:43.42610	validation_1-rmse:42.34031
# [13]	validation_0-rmse:43.09254	validation_1-rmse:42.01421
# [14]	validation_0-rmse:42.76315	validation_1-rmse:41.69423
# [15]	validation_0-rmse:42.43749	validation_1-rmse:41.37618
# [16]	validation_0-rmse:42.11609	validation_1-rmse:41.06292
# [17]	validation_0-rmse:41.79807	validation_1-rmse:40.74918
# [18]	validation_0-rmse:41.48339	validation_1-rmse:40.44137
# [19]	validation_0-rmse:41.17248	validation_1-rmse:40.13982
# [20]	validation_0-rmse:40.86513	validation_1-rmse:39.83898
# [21]	validation_0-rmse:40.56167	validation_1-rmse:39.54354
# [22]	validation_0-rmse:40.26187	validation_1-rmse:39.24987
# [23]	validation_0-rmse:39.96555	validation_1-rmse:38.96111
# [24]	validation_0-rmse:39.67232	validation_1-rmse:38.67626
# [25]	validation_0-rmse:39.38326	validation_1-rmse:38.39375
# [26]	validation_0-rmse:39.09754	validation_1-rmse:38.11539
# [27]	validation_0-rmse:38.81543	validation_1-rmse:37.83931
# [28]	validation_0-rmse:38.53686	validation_1-rmse:37.56720
# [29]	validation_0-rmse:38.26125	validation_1-rmse:37.29715
# [30]	validation_0-rmse:37.98879	validation_1-rmse:37.03275
# [31]	validation_0-rmse:37.71944	validation_1-rmse:36.76965
# [32]	validation_0-rmse:37.45298	validation_1-rmse:36.50796
# [33]	validation_0-rmse:37.18955	validation_1-rmse:36.24942
# [34]	validation_0-rmse:36.92970	validation_1-rmse:35.99463
# [35]	validation_0-rmse:36.67255	validation_1-rmse:35.74255
# [36]	validation_0-rmse:36.41877	validation_1-rmse:35.49345
# [37]	validation_0-rmse:36.16834	validation_1-rmse:35.24838
# [38]	validation_0-rmse:35.92086	validation_1-rmse:35.00529
# [39]	validation_0-rmse:35.67639	validation_1-rmse:34.76513
# [40]	validation_0-rmse:35.43480	validation_1-rmse:34.52853
# [41]	validation_0-rmse:35.19753	validation_1-rmse:34.29710
# [42]	validation_0-rmse:34.96186	validation_1-rmse:34.06727
# [43]	validation_0-rmse:34.73003	validation_1-rmse:33.84038
# [44]	validation_0-rmse:34.50042	validation_1-rmse:33.61479
# [45]	validation_0-rmse:34.27356	validation_1-rmse:33.39369
# [46]	validation_0-rmse:34.04963	validation_1-rmse:33.17380
# [47]	validation_0-rmse:33.82880	validation_1-rmse:32.95829
# [48]	validation_0-rmse:33.61059	validation_1-rmse:32.74527
# [49]	validation_0-rmse:33.39512	validation_1-rmse:32.53413
# [50]	validation_0-rmse:33.18287	validation_1-rmse:32.32697
# [51]	validation_0-rmse:32.97349	validation_1-rmse:32.12340
# [52]	validation_0-rmse:32.76638	validation_1-rmse:31.92183
# [53]	validation_0-rmse:32.56182	validation_1-rmse:31.72359
# [54]	validation_0-rmse:32.35935	validation_1-rmse:31.52474
# [55]	validation_0-rmse:32.16019	validation_1-rmse:31.33101
# [56]	validation_0-rmse:31.96385	validation_1-rmse:31.13822
# [57]	validation_0-rmse:31.77009	validation_1-rmse:30.95005
# [58]	validation_0-rmse:31.57853	validation_1-rmse:30.76489
# [59]	validation_0-rmse:31.38877	validation_1-rmse:30.57903
# [60]	validation_0-rmse:31.20226	validation_1-rmse:30.39562
# [61]	validation_0-rmse:31.01832	validation_1-rmse:30.21781
# [62]	validation_0-rmse:30.83612	validation_1-rmse:30.03894
# [63]	validation_0-rmse:30.65712	validation_1-rmse:29.86372
# [64]	validation_0-rmse:30.48035	validation_1-rmse:29.68979
# [65]	validation_0-rmse:30.30610	validation_1-rmse:29.52113
# [66]	validation_0-rmse:30.13417	validation_1-rmse:29.35191
# [67]	validation_0-rmse:29.96273	validation_1-rmse:29.18516
# [68]	validation_0-rmse:29.79527	validation_1-rmse:29.02150
# [69]	validation_0-rmse:29.62958	validation_1-rmse:28.85956
# [70]	validation_0-rmse:29.46606	validation_1-rmse:28.69847
# [71]	validation_0-rmse:29.30534	validation_1-rmse:28.54114
# [72]	validation_0-rmse:29.14635	validation_1-rmse:28.38456
# [73]	validation_0-rmse:28.99009	validation_1-rmse:28.23209
# [74]	validation_0-rmse:28.83522	validation_1-rmse:28.07897
# [75]	validation_0-rmse:28.68284	validation_1-rmse:27.93019
# [76]	validation_0-rmse:28.53305	validation_1-rmse:27.78358
# [77]	validation_0-rmse:28.38439	validation_1-rmse:27.63687
# [78]	validation_0-rmse:28.23794	validation_1-rmse:27.49203
# [79]	validation_0-rmse:28.09408	validation_1-rmse:27.35119
# [80]	validation_0-rmse:27.95168	validation_1-rmse:27.21095
# [81]	validation_0-rmse:27.81175	validation_1-rmse:27.07325
# [82]	validation_0-rmse:27.67246	validation_1-rmse:26.93789
# [83]	validation_0-rmse:27.53597	validation_1-rmse:26.80230
# [84]	validation_0-rmse:27.40132	validation_1-rmse:26.66983
# [85]	validation_0-rmse:27.26943	validation_1-rmse:26.54081
# [86]	validation_0-rmse:27.13786	validation_1-rmse:26.41292
# [87]	validation_0-rmse:27.00893	validation_1-rmse:26.28550
# [88]	validation_0-rmse:26.88228	validation_1-rmse:26.16061
# [89]	validation_0-rmse:26.75633	validation_1-rmse:26.03814
# [90]	validation_0-rmse:26.63293	validation_1-rmse:25.91644
# [91]	validation_0-rmse:26.51203	validation_1-rmse:25.79817
# [92]	validation_0-rmse:26.39195	validation_1-rmse:25.67923
# [93]	validation_0-rmse:26.27292	validation_1-rmse:25.56209
# [94]	validation_0-rmse:26.15696	validation_1-rmse:25.44872
# [95]	validation_0-rmse:26.04219	validation_1-rmse:25.33540
# [96]	validation_0-rmse:25.92832	validation_1-rmse:25.22463
# [97]	validation_0-rmse:25.81649	validation_1-rmse:25.11423
# [98]	validation_0-rmse:25.70680	validation_1-rmse:25.00608
# [99]	validation_0-rmse:25.59716	validation_1-rmse:24.89916
# [0]	validation_0-rmse:47.66242	validation_1-rmse:46.38140
# [1]	validation_0-rmse:47.29615	validation_1-rmse:46.02775
# [2]	validation_0-rmse:46.93209	validation_1-rmse:45.67467
# [3]	validation_0-rmse:46.57435	validation_1-rmse:45.32954
# [4]	validation_0-rmse:46.21883	validation_1-rmse:44.98498
# [5]	validation_0-rmse:45.86930	validation_1-rmse:44.64840
# [6]	validation_0-rmse:45.52205	validation_1-rmse:44.31056
# [7]	validation_0-rmse:45.18080	validation_1-rmse:43.98194
# [8]	validation_0-rmse:44.84176	validation_1-rmse:43.65348
# [9]	validation_0-rmse:44.50666	validation_1-rmse:43.32731
# [10]	validation_0-rmse:44.17747	validation_1-rmse:43.01016
# [11]	validation_0-rmse:43.85034	validation_1-rmse:42.69214
# [12]	validation_0-rmse:43.52807	validation_1-rmse:42.38091
# [13]	validation_0-rmse:43.20875	validation_1-rmse:42.07130
# [14]	validation_0-rmse:42.89533	validation_1-rmse:41.76808
# [15]	validation_0-rmse:42.58274	validation_1-rmse:41.46459
# [16]	validation_0-rmse:42.27686	validation_1-rmse:41.16860
# [17]	validation_0-rmse:41.97256	validation_1-rmse:40.87235
# [18]	validation_0-rmse:41.67059	validation_1-rmse:40.57894
# [19]	validation_0-rmse:41.37459	validation_1-rmse:40.29179
# [20]	validation_0-rmse:41.07986	validation_1-rmse:40.00506
# [21]	validation_0-rmse:40.79038	validation_1-rmse:39.72479
# [22]	validation_0-rmse:40.50310	validation_1-rmse:39.44478
# [23]	validation_0-rmse:40.21866	validation_1-rmse:39.16841
# [24]	validation_0-rmse:39.93988	validation_1-rmse:38.89849
# [25]	validation_0-rmse:39.66258	validation_1-rmse:38.62976
# [26]	validation_0-rmse:39.38828	validation_1-rmse:38.36317
# [27]	validation_0-rmse:39.11838	validation_1-rmse:38.10086
# [28]	validation_0-rmse:38.85113	validation_1-rmse:37.84146
# [29]	validation_0-rmse:38.58759	validation_1-rmse:37.58520
# [30]	validation_0-rmse:38.32658	validation_1-rmse:37.33182
# [31]	validation_0-rmse:38.06918	validation_1-rmse:37.08226
# [32]	validation_0-rmse:37.81541	validation_1-rmse:36.83576
# [33]	validation_0-rmse:37.56345	validation_1-rmse:36.59028
# [34]	validation_0-rmse:37.31564	validation_1-rmse:36.34862
# [35]	validation_0-rmse:37.06959	validation_1-rmse:36.10781
# [36]	validation_0-rmse:36.82728	validation_1-rmse:35.87117
# [37]	validation_0-rmse:36.58788	validation_1-rmse:35.63860
# [38]	validation_0-rmse:36.35151	validation_1-rmse:35.40777
# [39]	validation_0-rmse:36.11919	validation_1-rmse:35.18254
# [40]	validation_0-rmse:35.88901	validation_1-rmse:34.95856
# [41]	validation_0-rmse:35.66030	validation_1-rmse:34.73500
# [42]	validation_0-rmse:35.43550	validation_1-rmse:34.51566
# [43]	validation_0-rmse:35.21258	validation_1-rmse:34.30038
# [44]	validation_0-rmse:34.99392	validation_1-rmse:34.08849
# [45]	validation_0-rmse:34.77879	validation_1-rmse:33.87999
# [46]	validation_0-rmse:34.56489	validation_1-rmse:33.67105
# [47]	validation_0-rmse:34.35262	validation_1-rmse:33.46631
# [48]	validation_0-rmse:34.14278	validation_1-rmse:33.26281
# [49]	validation_0-rmse:33.93638	validation_1-rmse:33.06355
# [50]	validation_0-rmse:33.73296	validation_1-rmse:32.86475
# [51]	validation_0-rmse:33.53053	validation_1-rmse:32.66840
# [52]	validation_0-rmse:33.33170	validation_1-rmse:32.47623
# [53]	validation_0-rmse:33.13554	validation_1-rmse:32.28516
# [54]	validation_0-rmse:32.94085	validation_1-rmse:32.09627
# [55]	validation_0-rmse:32.74851	validation_1-rmse:31.90991
# [56]	validation_0-rmse:32.55912	validation_1-rmse:31.72730
# [57]	validation_0-rmse:32.37325	validation_1-rmse:31.54569
# [58]	validation_0-rmse:32.18873	validation_1-rmse:31.36709
# [59]	validation_0-rmse:32.00836	validation_1-rmse:31.19292
# [60]	validation_0-rmse:31.82928	validation_1-rmse:31.01860
# [61]	validation_0-rmse:31.65205	validation_1-rmse:30.84564
# [62]	validation_0-rmse:31.47629	validation_1-rmse:30.67509
# [63]	validation_0-rmse:31.30347	validation_1-rmse:30.50734
# [64]	validation_0-rmse:31.13211	validation_1-rmse:30.34070
# [65]	validation_0-rmse:30.96386	validation_1-rmse:30.17735
# [66]	validation_0-rmse:30.79974	validation_1-rmse:30.01731
# [67]	validation_0-rmse:30.63568	validation_1-rmse:29.85800
# [68]	validation_0-rmse:30.47329	validation_1-rmse:29.70001
# [69]	validation_0-rmse:30.31358	validation_1-rmse:29.54516
# [70]	validation_0-rmse:30.15492	validation_1-rmse:29.39083
# [71]	validation_0-rmse:29.99837	validation_1-rmse:29.23931
# [72]	validation_0-rmse:29.84403	validation_1-rmse:29.08895
# [73]	validation_0-rmse:29.69126	validation_1-rmse:28.94004
# [74]	validation_0-rmse:29.54190	validation_1-rmse:28.79519
# [75]	validation_0-rmse:29.39419	validation_1-rmse:28.65204
# [76]	validation_0-rmse:29.24770	validation_1-rmse:28.50883
# [77]	validation_0-rmse:29.10385	validation_1-rmse:28.36875
# [78]	validation_0-rmse:28.96148	validation_1-rmse:28.22979
# [79]	validation_0-rmse:28.82087	validation_1-rmse:28.09263
# [80]	validation_0-rmse:28.68316	validation_1-rmse:27.95909
# [81]	validation_0-rmse:28.54636	validation_1-rmse:27.82547
# [82]	validation_0-rmse:28.41152	validation_1-rmse:27.69381
# [83]	validation_0-rmse:28.27930	validation_1-rmse:27.56551
# [84]	validation_0-rmse:28.16294	validation_1-rmse:27.46069
# [85]	validation_0-rmse:28.03328	validation_1-rmse:27.33381
# [86]	validation_0-rmse:27.90578	validation_1-rmse:27.20956
# [87]	validation_0-rmse:27.78003	validation_1-rmse:27.08860
# [88]	validation_0-rmse:27.65516	validation_1-rmse:26.96637
# [89]	validation_0-rmse:27.53247	validation_1-rmse:26.84689
# [90]	validation_0-rmse:27.41152	validation_1-rmse:26.72870
# [91]	validation_0-rmse:27.29301	validation_1-rmse:26.61391
# [92]	validation_0-rmse:27.17585	validation_1-rmse:26.50009
# [93]	validation_0-rmse:27.05976	validation_1-rmse:26.38709
# [94]	validation_0-rmse:26.94330	validation_1-rmse:26.27302
# [95]	validation_0-rmse:26.83100	validation_1-rmse:26.16452
# [96]	validation_0-rmse:26.71974	validation_1-rmse:26.05587
# [97]	validation_0-rmse:26.61046	validation_1-rmse:25.94968
# [98]	validation_0-rmse:26.50289	validation_1-rmse:25.84583
# [99]	validation_0-rmse:26.39712	validation_1-rmse:25.74276
# [0]	validation_0-rmse:47.83766	validation_1-rmse:46.39612
# [1]	validation_0-rmse:47.48103	validation_1-rmse:46.05156
# [2]	validation_0-rmse:47.12612	validation_1-rmse:45.71514
# [3]	validation_0-rmse:46.77678	validation_1-rmse:45.38217
# [4]	validation_0-rmse:46.43076	validation_1-rmse:45.04190
# [5]	validation_0-rmse:46.09008	validation_1-rmse:44.72200
# [6]	validation_0-rmse:45.75448	validation_1-rmse:44.40210
# [7]	validation_0-rmse:45.41728	validation_1-rmse:44.08069
# [8]	validation_0-rmse:45.08479	validation_1-rmse:43.76932
# [9]	validation_0-rmse:44.75388	validation_1-rmse:43.46286
# [10]	validation_0-rmse:44.42751	validation_1-rmse:43.16433
# [11]	validation_0-rmse:44.10552	validation_1-rmse:42.86003
# [12]	validation_0-rmse:43.78917	validation_1-rmse:42.57888
# [13]	validation_0-rmse:43.47372	validation_1-rmse:42.28748
# [14]	validation_0-rmse:43.16212	validation_1-rmse:41.99453
# [15]	validation_0-rmse:42.85782	validation_1-rmse:41.71549
# [16]	validation_0-rmse:42.55201	validation_1-rmse:41.44202
# [17]	validation_0-rmse:42.25546	validation_1-rmse:41.16203
# [18]	validation_0-rmse:41.95096	validation_1-rmse:40.89021
# [19]	validation_0-rmse:41.65227	validation_1-rmse:40.61897
# [20]	validation_0-rmse:41.35681	validation_1-rmse:40.33790
# [21]	validation_0-rmse:41.06400	validation_1-rmse:40.06286
# [22]	validation_0-rmse:40.77706	validation_1-rmse:39.79447
# [23]	validation_0-rmse:40.48838	validation_1-rmse:39.51558
# [24]	validation_0-rmse:40.20788	validation_1-rmse:39.26315
# [25]	validation_0-rmse:39.92902	validation_1-rmse:39.01305
# [26]	validation_0-rmse:39.66226	validation_1-rmse:38.75036
# [27]	validation_0-rmse:39.39597	validation_1-rmse:38.50957
# [28]	validation_0-rmse:39.12896	validation_1-rmse:38.26886
# [29]	validation_0-rmse:38.86196	validation_1-rmse:38.00829
# [30]	validation_0-rmse:38.60163	validation_1-rmse:37.76900
# [31]	validation_0-rmse:38.34733	validation_1-rmse:37.53273
# [32]	validation_0-rmse:38.08890	validation_1-rmse:37.28868
# [33]	validation_0-rmse:37.84945	validation_1-rmse:37.06820
# [34]	validation_0-rmse:37.60380	validation_1-rmse:36.84287
# [35]	validation_0-rmse:37.35512	validation_1-rmse:36.59845
# [36]	validation_0-rmse:37.11565	validation_1-rmse:36.37664
# [37]	validation_0-rmse:36.87657	validation_1-rmse:36.15568
# [38]	validation_0-rmse:36.64263	validation_1-rmse:35.93467
# [39]	validation_0-rmse:36.41436	validation_1-rmse:35.71973
# [40]	validation_0-rmse:36.18162	validation_1-rmse:35.50220
# [41]	validation_0-rmse:35.96074	validation_1-rmse:35.28546
# [42]	validation_0-rmse:35.74172	validation_1-rmse:35.09262
# [43]	validation_0-rmse:35.51359	validation_1-rmse:34.87360
# [44]	validation_0-rmse:35.29184	validation_1-rmse:34.67732
# [45]	validation_0-rmse:35.08315	validation_1-rmse:34.48052
# [46]	validation_0-rmse:34.86653	validation_1-rmse:34.26687
# [47]	validation_0-rmse:34.64991	validation_1-rmse:34.07793
# [48]	validation_0-rmse:34.43863	validation_1-rmse:33.89233
# [49]	validation_0-rmse:34.23193	validation_1-rmse:33.69913
# [50]	validation_0-rmse:34.03045	validation_1-rmse:33.49527
# [51]	validation_0-rmse:33.83145	validation_1-rmse:33.29901
# [52]	validation_0-rmse:33.63732	validation_1-rmse:33.11888
# [53]	validation_0-rmse:33.44384	validation_1-rmse:32.94280
# [54]	validation_0-rmse:33.25075	validation_1-rmse:32.75538
# [55]	validation_0-rmse:33.05851	validation_1-rmse:32.56680
# [56]	validation_0-rmse:32.87172	validation_1-rmse:32.39415
# [57]	validation_0-rmse:32.68688	validation_1-rmse:32.21748
# [58]	validation_0-rmse:32.50489	validation_1-rmse:32.03625
# [59]	validation_0-rmse:32.32992	validation_1-rmse:31.86454
# [60]	validation_0-rmse:32.14657	validation_1-rmse:31.69668
# [61]	validation_0-rmse:31.97055	validation_1-rmse:31.52836
# [62]	validation_0-rmse:31.79275	validation_1-rmse:31.35517
# [63]	validation_0-rmse:31.62424	validation_1-rmse:31.19527
# [64]	validation_0-rmse:31.45835	validation_1-rmse:31.03231
# [65]	validation_0-rmse:31.29391	validation_1-rmse:30.87065
# [66]	validation_0-rmse:31.12701	validation_1-rmse:30.70019
# [67]	validation_0-rmse:30.96990	validation_1-rmse:30.54482
# [68]	validation_0-rmse:30.81007	validation_1-rmse:30.38794
# [69]	validation_0-rmse:30.65287	validation_1-rmse:30.23281
# [70]	validation_0-rmse:30.49353	validation_1-rmse:30.07252
# [71]	validation_0-rmse:30.34087	validation_1-rmse:29.91705
# [72]	validation_0-rmse:30.18740	validation_1-rmse:29.76050
# [73]	validation_0-rmse:30.03846	validation_1-rmse:29.63328
# [74]	validation_0-rmse:29.88975	validation_1-rmse:29.48295
# [75]	validation_0-rmse:29.74379	validation_1-rmse:29.33287
# [76]	validation_0-rmse:29.59989	validation_1-rmse:29.20950
# [77]	validation_0-rmse:29.45736	validation_1-rmse:29.06730
# [78]	validation_0-rmse:29.31560	validation_1-rmse:28.93336
# [79]	validation_0-rmse:29.17952	validation_1-rmse:28.81945
# [80]	validation_0-rmse:29.04296	validation_1-rmse:28.68573
# [81]	validation_0-rmse:28.91141	validation_1-rmse:28.55541
# [82]	validation_0-rmse:28.77572	validation_1-rmse:28.44620
# [83]	validation_0-rmse:28.64720	validation_1-rmse:28.32176
# [84]	validation_0-rmse:28.52353	validation_1-rmse:28.19981
# [85]	validation_0-rmse:28.39838	validation_1-rmse:28.08061
# [86]	validation_0-rmse:28.27705	validation_1-rmse:27.97838
# [87]	validation_0-rmse:28.15977	validation_1-rmse:27.86033
# [88]	validation_0-rmse:28.04277	validation_1-rmse:27.74724
# [89]	validation_0-rmse:27.92629	validation_1-rmse:27.63680
# [90]	validation_0-rmse:27.81611	validation_1-rmse:27.52242
# [91]	validation_0-rmse:27.70146	validation_1-rmse:27.41183
# [92]	validation_0-rmse:27.58695	validation_1-rmse:27.29459
# [93]	validation_0-rmse:27.47420	validation_1-rmse:27.17940
# [94]	validation_0-rmse:27.35836	validation_1-rmse:27.06510
# [95]	validation_0-rmse:27.24904	validation_1-rmse:26.95806
# [96]	validation_0-rmse:27.14164	validation_1-rmse:26.85127
# [97]	validation_0-rmse:27.03409	validation_1-rmse:26.74616
# [98]	validation_0-rmse:26.92742	validation_1-rmse:26.64002
# [99]	validation_0-rmse:26.82298	validation_1-rmse:26.53865
# [0]	validation_0-rmse:47.72929	validation_1-rmse:46.54704
# [1]	validation_0-rmse:47.32084	validation_1-rmse:46.15816
# [2]	validation_0-rmse:46.91677	validation_1-rmse:45.76871
# [3]	validation_0-rmse:46.51722	validation_1-rmse:45.39262
# [4]	validation_0-rmse:46.12182	validation_1-rmse:45.01434
# [5]	validation_0-rmse:45.73138	validation_1-rmse:44.64496
# [6]	validation_0-rmse:45.34481	validation_1-rmse:44.27962
# [7]	validation_0-rmse:44.96301	validation_1-rmse:43.92219
# [8]	validation_0-rmse:44.58436	validation_1-rmse:43.55799
# [9]	validation_0-rmse:44.21012	validation_1-rmse:43.20441
# [10]	validation_0-rmse:43.84089	validation_1-rmse:42.85825
# [11]	validation_0-rmse:43.47466	validation_1-rmse:42.50969
# [12]	validation_0-rmse:43.11356	validation_1-rmse:42.16592
# [13]	validation_0-rmse:42.75559	validation_1-rmse:41.82571
# [14]	validation_0-rmse:42.40122	validation_1-rmse:41.49293
# [15]	validation_0-rmse:42.05237	validation_1-rmse:41.16930
# [16]	validation_0-rmse:41.70584	validation_1-rmse:40.84757
# [17]	validation_0-rmse:41.36319	validation_1-rmse:40.52936
# [18]	validation_0-rmse:41.02496	validation_1-rmse:40.21637
# [19]	validation_0-rmse:40.69001	validation_1-rmse:39.90728
# [20]	validation_0-rmse:40.35936	validation_1-rmse:39.60282
# [21]	validation_0-rmse:40.03284	validation_1-rmse:39.29191
# [22]	validation_0-rmse:39.70929	validation_1-rmse:38.99486
# [23]	validation_0-rmse:39.38963	validation_1-rmse:38.68923
# [24]	validation_0-rmse:39.07388	validation_1-rmse:38.38599
# [25]	validation_0-rmse:38.76141	validation_1-rmse:38.09816
# [26]	validation_0-rmse:38.45212	validation_1-rmse:37.80527
# [27]	validation_0-rmse:38.14689	validation_1-rmse:37.51474
# [28]	validation_0-rmse:37.84361	validation_1-rmse:37.24027
# [29]	validation_0-rmse:37.54413	validation_1-rmse:36.95930
# [30]	validation_0-rmse:37.24880	validation_1-rmse:36.68009
# [31]	validation_0-rmse:36.95587	validation_1-rmse:36.41547
# [32]	validation_0-rmse:36.66651	validation_1-rmse:36.14204
# [33]	validation_0-rmse:36.38042	validation_1-rmse:35.88539
# [34]	validation_0-rmse:36.09758	validation_1-rmse:35.61670
# [35]	validation_0-rmse:35.81845	validation_1-rmse:35.36710
# [36]	validation_0-rmse:35.54250	validation_1-rmse:35.11099
# [37]	validation_0-rmse:35.26915	validation_1-rmse:34.85600
# [38]	validation_0-rmse:34.99940	validation_1-rmse:34.61773
# [39]	validation_0-rmse:34.73317	validation_1-rmse:34.36668
# [40]	validation_0-rmse:34.46923	validation_1-rmse:34.12912
# [41]	validation_0-rmse:34.20846	validation_1-rmse:33.88603
# [42]	validation_0-rmse:33.95078	validation_1-rmse:33.64918
# ...
# [31]	validation_0-rmse:36.95587	validation_1-rmse:36.41547
# [32]	validation_0-rmse:36.66651	validation_1-rmse:36.14204
# [33]	validation_0-rmse:36.38042	validation_1-rmse:35.88539
# [34]	validation_0-rmse:36.09758	validation_1-rmse:35.61670
# [35]	validation_0-rmse:35.81845	validation_1-rmse:35.36710
# [36]	validation_0-rmse:35.54250	validation_1-rmse:35.11099
# [37]	validation_0-rmse:35.26915	validation_1-rmse:34.85600
# [38]	validation_0-rmse:34.99940	validation_1-rmse:34.61773
# [39]	validation_0-rmse:34.73317	validation_1-rmse:34.36668
# [40]	validation_0-rmse:34.46923	validation_1-rmse:34.12912
# [41]	validation_0-rmse:34.20846	validation_1-rmse:33.88603
# [42]	validation_0-rmse:33.95078	validation_1-rmse:33.64918
# [43]	validation_0-rmse:33.69631	validation_1-rmse:33.41152
# [44]	validation_0-rmse:33.44418	validation_1-rmse:33.18038
# [45]	validation_0-rmse:33.19476	validation_1-rmse:32.95155
# [46]	validation_0-rmse:32.94849	validation_1-rmse:32.72036
# [47]	validation_0-rmse:32.70418	validation_1-rmse:32.49658
# [48]	validation_0-rmse:32.46370	validation_1-rmse:32.27513
# [49]	validation_0-rmse:32.22489	validation_1-rmse:32.05635
# [50]	validation_0-rmse:31.99028	validation_1-rmse:31.84113
# [51]	validation_0-rmse:31.75817	validation_1-rmse:31.63044
# [52]	validation_0-rmse:31.52754	validation_1-rmse:31.42532
# [53]	validation_0-rmse:31.30009	validation_1-rmse:31.21523
# [54]	validation_0-rmse:31.07626	validation_1-rmse:31.01587
# [55]	validation_0-rmse:30.85445	validation_1-rmse:30.81189
# [56]	validation_0-rmse:30.63523	validation_1-rmse:30.62059
# [57]	validation_0-rmse:30.41753	validation_1-rmse:30.42133
# [58]	validation_0-rmse:30.20350	validation_1-rmse:30.23360
# [59]	validation_0-rmse:29.99133	validation_1-rmse:30.04752
# [60]	validation_0-rmse:29.78084	validation_1-rmse:29.85445
# [61]	validation_0-rmse:29.57439	validation_1-rmse:29.66799
# [62]	validation_0-rmse:29.36990	validation_1-rmse:29.48825
# [63]	validation_0-rmse:29.16699	validation_1-rmse:29.31214
# [64]	validation_0-rmse:28.96781	validation_1-rmse:29.13865
# [65]	validation_0-rmse:28.76955	validation_1-rmse:28.96983
# [66]	validation_0-rmse:28.57499	validation_1-rmse:28.79735
# [67]	validation_0-rmse:28.38204	validation_1-rmse:28.63052
# [68]	validation_0-rmse:28.19052	validation_1-rmse:28.45575
# [69]	validation_0-rmse:28.00289	validation_1-rmse:28.29503
# [70]	validation_0-rmse:27.81591	validation_1-rmse:28.13534
# [71]	validation_0-rmse:27.63155	validation_1-rmse:27.97405
# [72]	validation_0-rmse:27.44733	validation_1-rmse:27.80451
# [73]	validation_0-rmse:27.26773	validation_1-rmse:27.65526
# [74]	validation_0-rmse:27.08905	validation_1-rmse:27.49339
# [75]	validation_0-rmse:26.91190	validation_1-rmse:27.33587
# [76]	validation_0-rmse:26.73802	validation_1-rmse:27.19118
# [77]	validation_0-rmse:26.56456	validation_1-rmse:27.03360
# [78]	validation_0-rmse:26.39443	validation_1-rmse:26.88118
# [79]	validation_0-rmse:26.22772	validation_1-rmse:26.74552
# [80]	validation_0-rmse:26.06114	validation_1-rmse:26.59500
# [81]	validation_0-rmse:25.89676	validation_1-rmse:26.44868
# [82]	validation_0-rmse:25.73544	validation_1-rmse:26.31782
# [83]	validation_0-rmse:25.57614	validation_1-rmse:26.18941
# [84]	validation_0-rmse:25.41812	validation_1-rmse:26.05560
# [85]	validation_0-rmse:25.26317	validation_1-rmse:25.92688
# [86]	validation_0-rmse:25.10767	validation_1-rmse:25.79905
# [87]	validation_0-rmse:24.95621	validation_1-rmse:25.67724
# [88]	validation_0-rmse:24.80531	validation_1-rmse:25.54691
# [89]	validation_0-rmse:24.65589	validation_1-rmse:25.41734
# [90]	validation_0-rmse:24.50960	validation_1-rmse:25.29923
# [91]	validation_0-rmse:24.36456	validation_1-rmse:25.18063
# [92]	validation_0-rmse:24.22227	validation_1-rmse:25.06296
# [93]	validation_0-rmse:24.07954	validation_1-rmse:24.94230
# [94]	validation_0-rmse:23.93863	validation_1-rmse:24.82474
# [95]	validation_0-rmse:23.80215	validation_1-rmse:24.71356
# [96]	validation_0-rmse:23.66655	validation_1-rmse:24.60608
# [97]	validation_0-rmse:23.53308	validation_1-rmse:24.49623
# [98]	validation_0-rmse:23.40070	validation_1-rmse:24.38920
# [99]	validation_0-rmse:23.26978	validation_1-rmse:24.28031
# [0]	validation_0-rmse:47.65173	validation_1-rmse:46.38524
# [1]	validation_0-rmse:47.28620	validation_1-rmse:46.05958
# [2]	validation_0-rmse:46.92361	validation_1-rmse:45.73751
# [3]	validation_0-rmse:46.56914	validation_1-rmse:45.42218
# [4]	validation_0-rmse:46.20394	validation_1-rmse:45.08621
# [5]	validation_0-rmse:45.85406	validation_1-rmse:44.77652
# [6]	validation_0-rmse:45.51624	validation_1-rmse:44.48526
# [7]	validation_0-rmse:45.16908	validation_1-rmse:44.16683
# [8]	validation_0-rmse:44.83903	validation_1-rmse:43.88222
# [9]	validation_0-rmse:44.49970	validation_1-rmse:43.57076
# [10]	validation_0-rmse:44.16877	validation_1-rmse:43.27213
# [11]	validation_0-rmse:43.83787	validation_1-rmse:42.96856
# [12]	validation_0-rmse:43.51498	validation_1-rmse:42.68190
# [13]	validation_0-rmse:43.19220	validation_1-rmse:42.38376
# [14]	validation_0-rmse:42.88654	validation_1-rmse:42.12187
# [15]	validation_0-rmse:42.57061	validation_1-rmse:41.83375
# [16]	validation_0-rmse:42.26273	validation_1-rmse:41.55872
# [17]	validation_0-rmse:41.95611	validation_1-rmse:41.27853
# [18]	validation_0-rmse:41.65210	validation_1-rmse:41.00009
# [19]	validation_0-rmse:41.35553	validation_1-rmse:40.73815
# [20]	validation_0-rmse:41.06185	validation_1-rmse:40.46941
# [21]	validation_0-rmse:40.76662	validation_1-rmse:40.20448
# [22]	validation_0-rmse:40.47255	validation_1-rmse:39.92837
# [23]	validation_0-rmse:40.19207	validation_1-rmse:39.68555
# [24]	validation_0-rmse:39.90522	validation_1-rmse:39.42141
# [25]	validation_0-rmse:39.62880	validation_1-rmse:39.18369
# [26]	validation_0-rmse:39.35098	validation_1-rmse:38.92451
# [27]	validation_0-rmse:39.07343	validation_1-rmse:38.67472
# [28]	validation_0-rmse:38.80478	validation_1-rmse:38.44266
# [29]	validation_0-rmse:38.54202	validation_1-rmse:38.21722
# [30]	validation_0-rmse:38.27448	validation_1-rmse:37.97847
# [31]	validation_0-rmse:38.01651	validation_1-rmse:37.75679
# [32]	validation_0-rmse:37.75199	validation_1-rmse:37.51480
# [33]	validation_0-rmse:37.49659	validation_1-rmse:37.29734
# [34]	validation_0-rmse:37.24063	validation_1-rmse:37.06452
# [35]	validation_0-rmse:36.99312	validation_1-rmse:36.85446
# [36]	validation_0-rmse:36.74600	validation_1-rmse:36.64129
# [37]	validation_0-rmse:36.50089	validation_1-rmse:36.42880
# [38]	validation_0-rmse:36.25978	validation_1-rmse:36.21964
# [39]	validation_0-rmse:36.02711	validation_1-rmse:36.02520
# [40]	validation_0-rmse:35.78989	validation_1-rmse:35.80968
# [41]	validation_0-rmse:35.55374	validation_1-rmse:35.60428
# [42]	validation_0-rmse:35.32530	validation_1-rmse:35.40726
# [43]	validation_0-rmse:35.09758	validation_1-rmse:35.21327
# [44]	validation_0-rmse:34.87769	validation_1-rmse:35.03462
# [45]	validation_0-rmse:34.64994	validation_1-rmse:34.82816
# [46]	validation_0-rmse:34.43829	validation_1-rmse:34.64795
# [47]	validation_0-rmse:34.21725	validation_1-rmse:34.44359
# [48]	validation_0-rmse:34.00806	validation_1-rmse:34.27350
# [49]	validation_0-rmse:33.80435	validation_1-rmse:34.10548
# [50]	validation_0-rmse:33.60065	validation_1-rmse:33.93997
# [51]	validation_0-rmse:33.40003	validation_1-rmse:33.77014
# [52]	validation_0-rmse:33.20100	validation_1-rmse:33.60928
# [53]	validation_0-rmse:33.00630	validation_1-rmse:33.44814
# [54]	validation_0-rmse:32.81328	validation_1-rmse:33.29327
# [55]	validation_0-rmse:32.61942	validation_1-rmse:33.12356
# [56]	validation_0-rmse:32.43282	validation_1-rmse:32.97296
# [57]	validation_0-rmse:32.25100	validation_1-rmse:32.82540
# [58]	validation_0-rmse:32.06942	validation_1-rmse:32.67892
# [59]	validation_0-rmse:31.88766	validation_1-rmse:32.52962
# [60]	validation_0-rmse:31.71747	validation_1-rmse:32.39407
# [61]	validation_0-rmse:31.54529	validation_1-rmse:32.24718
# [62]	validation_0-rmse:31.36545	validation_1-rmse:32.09815
# [63]	validation_0-rmse:31.19315	validation_1-rmse:31.95551
# [64]	validation_0-rmse:31.01634	validation_1-rmse:31.80460
# [65]	validation_0-rmse:30.84357	validation_1-rmse:31.65560
# [66]	validation_0-rmse:30.67346	validation_1-rmse:31.51401
# [67]	validation_0-rmse:30.51039	validation_1-rmse:31.37534
# [68]	validation_0-rmse:30.35306	validation_1-rmse:31.24570
# [69]	validation_0-rmse:30.19374	validation_1-rmse:31.11361
# [70]	validation_0-rmse:30.04062	validation_1-rmse:30.98784
# [71]	validation_0-rmse:29.88750	validation_1-rmse:30.85989
# [72]	validation_0-rmse:29.73649	validation_1-rmse:30.73543
# [73]	validation_0-rmse:29.58759	validation_1-rmse:30.61405
# [74]	validation_0-rmse:29.43921	validation_1-rmse:30.48819
# [75]	validation_0-rmse:29.29655	validation_1-rmse:30.36848
# [76]	validation_0-rmse:29.15218	validation_1-rmse:30.25166
# [77]	validation_0-rmse:29.01117	validation_1-rmse:30.13414
# [78]	validation_0-rmse:28.86607	validation_1-rmse:30.01511
# [79]	validation_0-rmse:28.72591	validation_1-rmse:29.89591
# [80]	validation_0-rmse:28.59038	validation_1-rmse:29.78324
# [81]	validation_0-rmse:28.45711	validation_1-rmse:29.67423
# [82]	validation_0-rmse:28.32360	validation_1-rmse:29.56440
# [83]	validation_0-rmse:28.19467	validation_1-rmse:29.45963
# [84]	validation_0-rmse:28.06222	validation_1-rmse:29.35206
# [85]	validation_0-rmse:27.93519	validation_1-rmse:29.25137
# [86]	validation_0-rmse:27.80557	validation_1-rmse:29.14413
# [87]	validation_0-rmse:27.68350	validation_1-rmse:29.04685
# [88]	validation_0-rmse:27.56041	validation_1-rmse:28.94873
# [89]	validation_0-rmse:27.43994	validation_1-rmse:28.85299
# [90]	validation_0-rmse:27.32166	validation_1-rmse:28.75726
# [91]	validation_0-rmse:27.20473	validation_1-rmse:28.66413
# [92]	validation_0-rmse:27.08931	validation_1-rmse:28.56994
# [93]	validation_0-rmse:26.96307	validation_1-rmse:28.44970
# [94]	validation_0-rmse:26.83855	validation_1-rmse:28.33110
# [95]	validation_0-rmse:26.72578	validation_1-rmse:28.23976
# [96]	validation_0-rmse:26.60391	validation_1-rmse:28.12406
# [97]	validation_0-rmse:26.49240	validation_1-rmse:28.03229
# [98]	validation_0-rmse:26.38056	validation_1-rmse:27.93835
# [99]	validation_0-rmse:26.26346	validation_1-rmse:27.82685
# [0]	validation_0-rmse:44.24238	validation_1-rmse:43.03200
# [1]	validation_0-rmse:40.89410	validation_1-rmse:39.78381
# [2]	validation_0-rmse:37.94545	validation_1-rmse:36.93239
# [3]	validation_0-rmse:35.33216	validation_1-rmse:34.38525
# [4]	validation_0-rmse:33.04414	validation_1-rmse:32.17000
# [5]	validation_0-rmse:31.04285	validation_1-rmse:30.23493
# [6]	validation_0-rmse:29.29028	validation_1-rmse:28.52163
# [7]	validation_0-rmse:27.77176	validation_1-rmse:27.01949
# [8]	validation_0-rmse:26.46626	validation_1-rmse:25.74555
# [9]	validation_0-rmse:25.33574	validation_1-rmse:24.65163
# [10]	validation_0-rmse:24.36162	validation_1-rmse:23.69465
# [11]	validation_0-rmse:23.52730	validation_1-rmse:22.87336
# [12]	validation_0-rmse:22.82413	validation_1-rmse:22.17268
# [13]	validation_0-rmse:22.22369	validation_1-rmse:21.58253
# [14]	validation_0-rmse:21.72013	validation_1-rmse:21.08775
# [15]	validation_0-rmse:21.29584	validation_1-rmse:20.66917
# [16]	validation_0-rmse:20.93260	validation_1-rmse:20.31559
# [17]	validation_0-rmse:20.62459	validation_1-rmse:20.02557
# [18]	validation_0-rmse:20.36289	validation_1-rmse:19.75107
# [19]	validation_0-rmse:20.14511	validation_1-rmse:19.52403
# [20]	validation_0-rmse:19.95902	validation_1-rmse:19.33870
# [21]	validation_0-rmse:19.80164	validation_1-rmse:19.20354
# [22]	validation_0-rmse:19.65332	validation_1-rmse:19.04939
# [23]	validation_0-rmse:19.52975	validation_1-rmse:18.91902
# [24]	validation_0-rmse:19.42443	validation_1-rmse:18.81678
# [25]	validation_0-rmse:19.33813	validation_1-rmse:18.73787
# [26]	validation_0-rmse:19.25748	validation_1-rmse:18.65479
# [27]	validation_0-rmse:19.18174	validation_1-rmse:18.58424
# [28]	validation_0-rmse:19.10095	validation_1-rmse:18.49571
# [29]	validation_0-rmse:19.04957	validation_1-rmse:18.45220
# [30]	validation_0-rmse:19.00350	validation_1-rmse:18.41552
# [31]	validation_0-rmse:18.95259	validation_1-rmse:18.37032
# [32]	validation_0-rmse:18.89996	validation_1-rmse:18.31792
# [33]	validation_0-rmse:18.86408	validation_1-rmse:18.28918
# [34]	validation_0-rmse:18.83411	validation_1-rmse:18.27035
# [35]	validation_0-rmse:18.80601	validation_1-rmse:18.25682
# [36]	validation_0-rmse:18.77084	validation_1-rmse:18.22011
# [37]	validation_0-rmse:18.74243	validation_1-rmse:18.19535
# [38]	validation_0-rmse:18.71618	validation_1-rmse:18.16631
# [39]	validation_0-rmse:18.69509	validation_1-rmse:18.15850
# [40]	validation_0-rmse:18.66866	validation_1-rmse:18.12547
# [41]	validation_0-rmse:18.64724	validation_1-rmse:18.11061
# [42]	validation_0-rmse:18.62214	validation_1-rmse:18.09507
# [43]	validation_0-rmse:18.60087	validation_1-rmse:18.07735
# [44]	validation_0-rmse:18.57190	validation_1-rmse:18.06473
# [45]	validation_0-rmse:18.55108	validation_1-rmse:18.04624
# [46]	validation_0-rmse:18.53389	validation_1-rmse:18.03333
# [47]	validation_0-rmse:18.50478	validation_1-rmse:18.00525
# [48]	validation_0-rmse:18.48664	validation_1-rmse:18.00181
# [49]	validation_0-rmse:18.45964	validation_1-rmse:17.98098
# [50]	validation_0-rmse:18.44503	validation_1-rmse:17.97422
# [51]	validation_0-rmse:18.42514	validation_1-rmse:17.96222
# [52]	validation_0-rmse:18.40473	validation_1-rmse:17.95107
# [53]	validation_0-rmse:18.38716	validation_1-rmse:17.94036
# [54]	validation_0-rmse:18.37433	validation_1-rmse:17.93240
# [55]	validation_0-rmse:18.35730	validation_1-rmse:17.92417
# [56]	validation_0-rmse:18.33749	validation_1-rmse:17.90938
# [57]	validation_0-rmse:18.32622	validation_1-rmse:17.90807
# [58]	validation_0-rmse:18.30168	validation_1-rmse:17.89987
# [59]	validation_0-rmse:18.29981	validation_1-rmse:17.89972
# [60]	validation_0-rmse:18.29528	validation_1-rmse:17.89715
# [61]	validation_0-rmse:18.29046	validation_1-rmse:17.89186
# [62]	validation_0-rmse:18.28886	validation_1-rmse:17.89167
# [63]	validation_0-rmse:18.28061	validation_1-rmse:17.88982
# [64]	validation_0-rmse:18.27914	validation_1-rmse:17.88931
# [65]	validation_0-rmse:18.27199	validation_1-rmse:17.88485
# [66]	validation_0-rmse:18.24717	validation_1-rmse:17.85991
# [67]	validation_0-rmse:18.22987	validation_1-rmse:17.83700
# [68]	validation_0-rmse:18.22853	validation_1-rmse:17.83700
# [69]	validation_0-rmse:18.21902	validation_1-rmse:17.82901
# [70]	validation_0-rmse:18.21781	validation_1-rmse:17.82901
# [71]	validation_0-rmse:18.20217	validation_1-rmse:17.80747
# [72]	validation_0-rmse:18.19835	validation_1-rmse:17.80625
# [73]	validation_0-rmse:18.19734	validation_1-rmse:17.80592
# [74]	validation_0-rmse:18.19162	validation_1-rmse:17.80367
# [75]	validation_0-rmse:18.17298	validation_1-rmse:17.78327
# [76]	validation_0-rmse:18.16192	validation_1-rmse:17.77129
# [77]	validation_0-rmse:18.15054	validation_1-rmse:17.76434
# [78]	validation_0-rmse:18.13340	validation_1-rmse:17.74919
# [79]	validation_0-rmse:18.11274	validation_1-rmse:17.73095
# [80]	validation_0-rmse:18.10908	validation_1-rmse:17.72896
# [81]	validation_0-rmse:18.10821	validation_1-rmse:17.72812
# [82]	validation_0-rmse:18.10215	validation_1-rmse:17.72497
# [83]	validation_0-rmse:18.10084	validation_1-rmse:17.72523
# [84]	validation_0-rmse:18.09472	validation_1-rmse:17.71836
# [85]	validation_0-rmse:18.08479	validation_1-rmse:17.71615
# [86]	validation_0-rmse:18.05753	validation_1-rmse:17.70203
# [87]	validation_0-rmse:18.04889	validation_1-rmse:17.70363
# [88]	validation_0-rmse:18.03777	validation_1-rmse:17.70311
# [89]	validation_0-rmse:18.03428	validation_1-rmse:17.70212
# [90]	validation_0-rmse:18.03155	validation_1-rmse:17.69794
# [91]	validation_0-rmse:18.03083	validation_1-rmse:17.69724
# [92]	validation_0-rmse:18.02632	validation_1-rmse:17.69771
# [93]	validation_0-rmse:18.02562	validation_1-rmse:17.69697
# [94]	validation_0-rmse:18.01908	validation_1-rmse:17.69239
# [95]	validation_0-rmse:18.01261	validation_1-rmse:17.68863
# [96]	validation_0-rmse:18.00586	validation_1-rmse:17.68565
# [97]	validation_0-rmse:17.98412	validation_1-rmse:17.67259
# [98]	validation_0-rmse:17.98168	validation_1-rmse:17.67297
# [99]	validation_0-rmse:17.96908	validation_1-rmse:17.67161
# Best Hyperparameters:  {'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Best Score:  -417.07266475488524

# %% [markdown]
# #### **Train an XGboost model**
#
# We will fit all the data in this model using the optimum parameters we found above.

# %%
# Create dataframe to save actual values and model predictions
total_predictions = pd.DataFrame(index=pd.to_datetime(test['Time Column']))
total_predictions['Actual'] = y_test['Record 1(t)'].values
total_predictions['Path'] = X_test['Path'].values

# %%
# Define XGBoost regressor
reg = xgb.XGBRegressor(
    learning_rate = xgb_grid.best_params_['learning_rate'],
    max_depth = xgb_grid.best_params_['max_depth'],
    n_estimators = 500,
    gamma = xgb_grid.best_params_['gamma']
)

# Train the XGBoost model with feature weights (use validation set on test data)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test,y_test)],
        verbose=True)
# Out:
# [0]	validation_0-rmse:44.24238	validation_1-rmse:43.03200
# [1]	validation_0-rmse:40.89410	validation_1-rmse:39.78381
# [2]	validation_0-rmse:37.94545	validation_1-rmse:36.93239
# [3]	validation_0-rmse:35.33216	validation_1-rmse:34.38525
# [4]	validation_0-rmse:33.04414	validation_1-rmse:32.17000
# [5]	validation_0-rmse:31.04285	validation_1-rmse:30.23493
# [6]	validation_0-rmse:29.29028	validation_1-rmse:28.52163
# [7]	validation_0-rmse:27.77176	validation_1-rmse:27.01949
# [8]	validation_0-rmse:26.46626	validation_1-rmse:25.74555
# [9]	validation_0-rmse:25.33574	validation_1-rmse:24.65163
# [10]	validation_0-rmse:24.36162	validation_1-rmse:23.69465
# [11]	validation_0-rmse:23.52730	validation_1-rmse:22.87336
# [12]	validation_0-rmse:22.82413	validation_1-rmse:22.17268
# [13]	validation_0-rmse:22.22369	validation_1-rmse:21.58253
# [14]	validation_0-rmse:21.72013	validation_1-rmse:21.08775
# [15]	validation_0-rmse:21.29584	validation_1-rmse:20.66917
# [16]	validation_0-rmse:20.93260	validation_1-rmse:20.31559
# [17]	validation_0-rmse:20.62459	validation_1-rmse:20.02557
# [18]	validation_0-rmse:20.36289	validation_1-rmse:19.75107
# [19]	validation_0-rmse:20.14511	validation_1-rmse:19.52403
# [20]	validation_0-rmse:19.95902	validation_1-rmse:19.33870
# [21]	validation_0-rmse:19.80164	validation_1-rmse:19.20354
# [22]	validation_0-rmse:19.65332	validation_1-rmse:19.04939
# [23]	validation_0-rmse:19.52975	validation_1-rmse:18.91902
# [24]	validation_0-rmse:19.42443	validation_1-rmse:18.81678
# [25]	validation_0-rmse:19.33813	validation_1-rmse:18.73787
# [26]	validation_0-rmse:19.25748	validation_1-rmse:18.65479
# [27]	validation_0-rmse:19.18174	validation_1-rmse:18.58424
# [28]	validation_0-rmse:19.10095	validation_1-rmse:18.49571
# [29]	validation_0-rmse:19.04957	validation_1-rmse:18.45220
# [30]	validation_0-rmse:19.00350	validation_1-rmse:18.41552
# [31]	validation_0-rmse:18.95259	validation_1-rmse:18.37032
# [32]	validation_0-rmse:18.89996	validation_1-rmse:18.31792
# [33]	validation_0-rmse:18.86408	validation_1-rmse:18.28918
# [34]	validation_0-rmse:18.83411	validation_1-rmse:18.27035
# [35]	validation_0-rmse:18.80601	validation_1-rmse:18.25682
# [36]	validation_0-rmse:18.77084	validation_1-rmse:18.22011
# [37]	validation_0-rmse:18.74243	validation_1-rmse:18.19535
# [38]	validation_0-rmse:18.71618	validation_1-rmse:18.16631
# [39]	validation_0-rmse:18.69509	validation_1-rmse:18.15850
# [40]	validation_0-rmse:18.66866	validation_1-rmse:18.12547
# [41]	validation_0-rmse:18.64724	validation_1-rmse:18.11061
# [42]	validation_0-rmse:18.62214	validation_1-rmse:18.09507
# [43]	validation_0-rmse:18.60087	validation_1-rmse:18.07735
# [44]	validation_0-rmse:18.57190	validation_1-rmse:18.06473
# [45]	validation_0-rmse:18.55108	validation_1-rmse:18.04624
# [46]	validation_0-rmse:18.53389	validation_1-rmse:18.03333
# [47]	validation_0-rmse:18.50478	validation_1-rmse:18.00525
# [48]	validation_0-rmse:18.48664	validation_1-rmse:18.00181
# [49]	validation_0-rmse:18.45964	validation_1-rmse:17.98098
# [50]	validation_0-rmse:18.44503	validation_1-rmse:17.97422
# [51]	validation_0-rmse:18.42514	validation_1-rmse:17.96222
# [52]	validation_0-rmse:18.40473	validation_1-rmse:17.95107
# [53]	validation_0-rmse:18.38716	validation_1-rmse:17.94036
# [54]	validation_0-rmse:18.37433	validation_1-rmse:17.93240
# [55]	validation_0-rmse:18.35730	validation_1-rmse:17.92417
# [56]	validation_0-rmse:18.33749	validation_1-rmse:17.90938
# [57]	validation_0-rmse:18.32622	validation_1-rmse:17.90807
# [58]	validation_0-rmse:18.30168	validation_1-rmse:17.89987
# [59]	validation_0-rmse:18.29981	validation_1-rmse:17.89972
# [60]	validation_0-rmse:18.29528	validation_1-rmse:17.89715
# [61]	validation_0-rmse:18.29046	validation_1-rmse:17.89186
# [62]	validation_0-rmse:18.28886	validation_1-rmse:17.89167
# [63]	validation_0-rmse:18.28061	validation_1-rmse:17.88982
# [64]	validation_0-rmse:18.27914	validation_1-rmse:17.88931
# [65]	validation_0-rmse:18.27199	validation_1-rmse:17.88485
# [66]	validation_0-rmse:18.24717	validation_1-rmse:17.85991
# [67]	validation_0-rmse:18.22987	validation_1-rmse:17.83700
# [68]	validation_0-rmse:18.22853	validation_1-rmse:17.83700
# [69]	validation_0-rmse:18.21902	validation_1-rmse:17.82901
# [70]	validation_0-rmse:18.21781	validation_1-rmse:17.82901
# [71]	validation_0-rmse:18.20217	validation_1-rmse:17.80747
# [72]	validation_0-rmse:18.19835	validation_1-rmse:17.80625
# [73]	validation_0-rmse:18.19734	validation_1-rmse:17.80592
# [74]	validation_0-rmse:18.19162	validation_1-rmse:17.80367
# [75]	validation_0-rmse:18.17298	validation_1-rmse:17.78327
# [76]	validation_0-rmse:18.16192	validation_1-rmse:17.77129
# [77]	validation_0-rmse:18.15054	validation_1-rmse:17.76434
# [78]	validation_0-rmse:18.13340	validation_1-rmse:17.74919
# [79]	validation_0-rmse:18.11274	validation_1-rmse:17.73095
# [80]	validation_0-rmse:18.10908	validation_1-rmse:17.72896
# [81]	validation_0-rmse:18.10821	validation_1-rmse:17.72812
# [82]	validation_0-rmse:18.10215	validation_1-rmse:17.72497
# [83]	validation_0-rmse:18.10084	validation_1-rmse:17.72523
# [84]	validation_0-rmse:18.09472	validation_1-rmse:17.71836
# [85]	validation_0-rmse:18.08479	validation_1-rmse:17.71615
# [86]	validation_0-rmse:18.05753	validation_1-rmse:17.70203
# [87]	validation_0-rmse:18.04889	validation_1-rmse:17.70363
# [88]	validation_0-rmse:18.03777	validation_1-rmse:17.70311
# [89]	validation_0-rmse:18.03428	validation_1-rmse:17.70212
# [90]	validation_0-rmse:18.03155	validation_1-rmse:17.69794
# [91]	validation_0-rmse:18.03083	validation_1-rmse:17.69724
# [92]	validation_0-rmse:18.02632	validation_1-rmse:17.69771
# [93]	validation_0-rmse:18.02562	validation_1-rmse:17.69697
# [94]	validation_0-rmse:18.01908	validation_1-rmse:17.69239
# [95]	validation_0-rmse:18.01261	validation_1-rmse:17.68863
# [96]	validation_0-rmse:18.00586	validation_1-rmse:17.68565
# [97]	validation_0-rmse:17.98412	validation_1-rmse:17.67259
# [98]	validation_0-rmse:17.98168	validation_1-rmse:17.67297
# [99]	validation_0-rmse:17.96908	validation_1-rmse:17.67161
# [100]	validation_0-rmse:17.96011	validation_1-rmse:17.67257
# [101]	validation_0-rmse:17.95619	validation_1-rmse:17.67307
# [102]	validation_0-rmse:17.94254	validation_1-rmse:17.65286
# [103]	validation_0-rmse:17.94000	validation_1-rmse:17.65223
# [104]	validation_0-rmse:17.92742	validation_1-rmse:17.64594
# [105]	validation_0-rmse:17.91435	validation_1-rmse:17.64030
# [106]	validation_0-rmse:17.90309	validation_1-rmse:17.62994
# [107]	validation_0-rmse:17.89515	validation_1-rmse:17.62153
# [108]	validation_0-rmse:17.89330	validation_1-rmse:17.62117
# [109]	validation_0-rmse:17.88569	validation_1-rmse:17.61904
# [110]	validation_0-rmse:17.87648	validation_1-rmse:17.62266
# [111]	validation_0-rmse:17.86785	validation_1-rmse:17.61561
# [112]	validation_0-rmse:17.86608	validation_1-rmse:17.61339
# [113]	validation_0-rmse:17.84571	validation_1-rmse:17.60123
# [114]	validation_0-rmse:17.83453	validation_1-rmse:17.59599
# [115]	validation_0-rmse:17.82339	validation_1-rmse:17.58886
# [116]	validation_0-rmse:17.81396	validation_1-rmse:17.58094
# [117]	validation_0-rmse:17.80753	validation_1-rmse:17.57342
# [118]	validation_0-rmse:17.79566	validation_1-rmse:17.57288
# [119]	validation_0-rmse:17.77976	validation_1-rmse:17.56000
# [120]	validation_0-rmse:17.77160	validation_1-rmse:17.56451
# [121]	validation_0-rmse:17.76372	validation_1-rmse:17.55850
# [122]	validation_0-rmse:17.75222	validation_1-rmse:17.54692
# [123]	validation_0-rmse:17.74732	validation_1-rmse:17.54365
# [124]	validation_0-rmse:17.74075	validation_1-rmse:17.54460
# [125]	validation_0-rmse:17.73109	validation_1-rmse:17.53682
# [126]	validation_0-rmse:17.72968	validation_1-rmse:17.53585
# [127]	validation_0-rmse:17.72043	validation_1-rmse:17.53096
# [128]	validation_0-rmse:17.71318	validation_1-rmse:17.52849
# [129]	validation_0-rmse:17.70333	validation_1-rmse:17.51883
# [130]	validation_0-rmse:17.69070	validation_1-rmse:17.51077
# [131]	validation_0-rmse:17.68191	validation_1-rmse:17.51114
# [132]	validation_0-rmse:17.68140	validation_1-rmse:17.51104
# [133]	validation_0-rmse:17.67939	validation_1-rmse:17.51080
# [134]	validation_0-rmse:17.67001	validation_1-rmse:17.50162
# [135]	validation_0-rmse:17.66859	validation_1-rmse:17.50146
# [136]	validation_0-rmse:17.66086	validation_1-rmse:17.49613
# [137]	validation_0-rmse:17.65233	validation_1-rmse:17.48903
# [138]	validation_0-rmse:17.64298	validation_1-rmse:17.48393
# [139]	validation_0-rmse:17.63192	validation_1-rmse:17.48862
# [140]	validation_0-rmse:17.63007	validation_1-rmse:17.48915
# [141]	validation_0-rmse:17.62208	validation_1-rmse:17.49123
# [142]	validation_0-rmse:17.61382	validation_1-rmse:17.49195
# [143]	validation_0-rmse:17.60757	validation_1-rmse:17.49475
# [144]	validation_0-rmse:17.60002	validation_1-rmse:17.49630
# [145]	validation_0-rmse:17.59330	validation_1-rmse:17.50011
# [146]	validation_0-rmse:17.59192	validation_1-rmse:17.50439
# [147]	validation_0-rmse:17.58747	validation_1-rmse:17.50203
# [148]	validation_0-rmse:17.58583	validation_1-rmse:17.50190
# [149]	validation_0-rmse:17.57859	validation_1-rmse:17.49646
# [150]	validation_0-rmse:17.57262	validation_1-rmse:17.49607
# [151]	validation_0-rmse:17.56198	validation_1-rmse:17.48179
# [152]	validation_0-rmse:17.55453	validation_1-rmse:17.47947
# [153]	validation_0-rmse:17.54779	validation_1-rmse:17.48037
# [154]	validation_0-rmse:17.53751	validation_1-rmse:17.47861
# [155]	validation_0-rmse:17.51746	validation_1-rmse:17.47225
# [156]	validation_0-rmse:17.51105	validation_1-rmse:17.47529
# [157]	validation_0-rmse:17.50417	validation_1-rmse:17.47225
# [158]	validation_0-rmse:17.49724	validation_1-rmse:17.46701
# [159]	validation_0-rmse:17.48851	validation_1-rmse:17.46322
# [160]	validation_0-rmse:17.48009	validation_1-rmse:17.46808
# [161]	validation_0-rmse:17.47296	validation_1-rmse:17.46071
# [162]	validation_0-rmse:17.46284	validation_1-rmse:17.45526
# [163]	validation_0-rmse:17.45655	validation_1-rmse:17.45160
# [164]	validation_0-rmse:17.44826	validation_1-rmse:17.44748
# [165]	validation_0-rmse:17.44313	validation_1-rmse:17.44664
# [166]	validation_0-rmse:17.43607	validation_1-rmse:17.44119
# [167]	validation_0-rmse:17.42768	validation_1-rmse:17.43448
# [168]	validation_0-rmse:17.42651	validation_1-rmse:17.43850
# [169]	validation_0-rmse:17.41912	validation_1-rmse:17.42947
# [170]	validation_0-rmse:17.40588	validation_1-rmse:17.42096
# [171]	validation_0-rmse:17.39835	validation_1-rmse:17.41179
# [172]	validation_0-rmse:17.39043	validation_1-rmse:17.40964
# [173]	validation_0-rmse:17.38659	validation_1-rmse:17.40450
# [174]	validation_0-rmse:17.38023	validation_1-rmse:17.40256
# [175]	validation_0-rmse:17.37337	validation_1-rmse:17.40483
# [176]	validation_0-rmse:17.36566	validation_1-rmse:17.39519
# [177]	validation_0-rmse:17.36048	validation_1-rmse:17.38964
# [178]	validation_0-rmse:17.35414	validation_1-rmse:17.38834
# [179]	validation_0-rmse:17.34830	validation_1-rmse:17.38210
# [180]	validation_0-rmse:17.34227	validation_1-rmse:17.38386
# [181]	validation_0-rmse:17.32857	validation_1-rmse:17.37758
# [182]	validation_0-rmse:17.32318	validation_1-rmse:17.38532
# [183]	validation_0-rmse:17.31322	validation_1-rmse:17.38357
# [184]	validation_0-rmse:17.30686	validation_1-rmse:17.37979
# [185]	validation_0-rmse:17.30085	validation_1-rmse:17.38092
# [186]	validation_0-rmse:17.29285	validation_1-rmse:17.37460
# [187]	validation_0-rmse:17.28725	validation_1-rmse:17.37586
# [188]	validation_0-rmse:17.28400	validation_1-rmse:17.37636
# [189]	validation_0-rmse:17.27819	validation_1-rmse:17.37020
# [190]	validation_0-rmse:17.26999	validation_1-rmse:17.36579
# [191]	validation_0-rmse:17.26281	validation_1-rmse:17.36468
# [192]	validation_0-rmse:17.25691	validation_1-rmse:17.35920
# [193]	validation_0-rmse:17.24509	validation_1-rmse:17.34818
# [194]	validation_0-rmse:17.23991	validation_1-rmse:17.34756
# [195]	validation_0-rmse:17.23127	validation_1-rmse:17.34486
# [196]	validation_0-rmse:17.22622	validation_1-rmse:17.34395
# [197]	validation_0-rmse:17.22249	validation_1-rmse:17.34194
# [198]	validation_0-rmse:17.21486	validation_1-rmse:17.33962
# [199]	validation_0-rmse:17.20178	validation_1-rmse:17.33716
# [200]	validation_0-rmse:17.19793	validation_1-rmse:17.33802
# [201]	validation_0-rmse:17.19237	validation_1-rmse:17.33387
# [202]	validation_0-rmse:17.18650	validation_1-rmse:17.32840
# [203]	validation_0-rmse:17.17926	validation_1-rmse:17.32818
# [204]	validation_0-rmse:17.17510	validation_1-rmse:17.32633
# [205]	validation_0-rmse:17.17090	validation_1-rmse:17.32768
# [206]	validation_0-rmse:17.16625	validation_1-rmse:17.32648
# [207]	validation_0-rmse:17.16035	validation_1-rmse:17.32466
# [208]	validation_0-rmse:17.15945	validation_1-rmse:17.32684
# [209]	validation_0-rmse:17.15333	validation_1-rmse:17.32282
# [210]	validation_0-rmse:17.14706	validation_1-rmse:17.32295
# [211]	validation_0-rmse:17.14063	validation_1-rmse:17.31897
# [212]	validation_0-rmse:17.13553	validation_1-rmse:17.31861
# [213]	validation_0-rmse:17.12944	validation_1-rmse:17.31682
# [214]	validation_0-rmse:17.12294	validation_1-rmse:17.30896
# [215]	validation_0-rmse:17.11936	validation_1-rmse:17.30803
# [216]	validation_0-rmse:17.11322	validation_1-rmse:17.30877
# [217]	validation_0-rmse:17.10914	validation_1-rmse:17.30799
# [218]	validation_0-rmse:17.10135	validation_1-rmse:17.30467
# [219]	validation_0-rmse:17.09629	validation_1-rmse:17.30080
# [220]	validation_0-rmse:17.09093	validation_1-rmse:17.29901
# [221]	validation_0-rmse:17.08863	validation_1-rmse:17.29793
# [222]	validation_0-rmse:17.08603	validation_1-rmse:17.29792
# [223]	validation_0-rmse:17.08067	validation_1-rmse:17.29755
# [224]	validation_0-rmse:17.07719	validation_1-rmse:17.30030
# [225]	validation_0-rmse:17.07158	validation_1-rmse:17.29907
# [226]	validation_0-rmse:17.06633	validation_1-rmse:17.29917
# [227]	validation_0-rmse:17.06542	validation_1-rmse:17.30247
# [228]	validation_0-rmse:17.05908	validation_1-rmse:17.29985
# [229]	validation_0-rmse:17.05443	validation_1-rmse:17.29710
# [230]	validation_0-rmse:17.04851	validation_1-rmse:17.29388
# [231]	validation_0-rmse:17.04406	validation_1-rmse:17.29349
# [232]	validation_0-rmse:17.04076	validation_1-rmse:17.29452
# [233]	validation_0-rmse:17.03281	validation_1-rmse:17.28806
# [234]	validation_0-rmse:17.02605	validation_1-rmse:17.28677
# [235]	validation_0-rmse:17.02113	validation_1-rmse:17.28542
# [236]	validation_0-rmse:17.01773	validation_1-rmse:17.28201
# [237]	validation_0-rmse:17.01269	validation_1-rmse:17.27609
# [238]	validation_0-rmse:17.00832	validation_1-rmse:17.27698
# [239]	validation_0-rmse:17.00387	validation_1-rmse:17.27446
# [240]	validation_0-rmse:16.99957	validation_1-rmse:17.27723
# [241]	validation_0-rmse:16.99360	validation_1-rmse:17.27473
# [242]	validation_0-rmse:16.98654	validation_1-rmse:17.26998
# [243]	validation_0-rmse:16.98328	validation_1-rmse:17.26950
# [244]	validation_0-rmse:16.97822	validation_1-rmse:17.26758
# [245]	validation_0-rmse:16.97425	validation_1-rmse:17.26568
# [246]	validation_0-rmse:16.97056	validation_1-rmse:17.26371
# [247]	validation_0-rmse:16.96772	validation_1-rmse:17.26347
# [248]	validation_0-rmse:16.96178	validation_1-rmse:17.25871
# [249]	validation_0-rmse:16.95172	validation_1-rmse:17.24956
# [250]	validation_0-rmse:16.94683	validation_1-rmse:17.25045
# [251]	validation_0-rmse:16.93989	validation_1-rmse:17.24635
# [252]	validation_0-rmse:16.93570	validation_1-rmse:17.24537
# [253]	validation_0-rmse:16.93023	validation_1-rmse:17.24205
# [254]	validation_0-rmse:16.92401	validation_1-rmse:17.24415
# [255]	validation_0-rmse:16.92109	validation_1-rmse:17.24976
# [256]	validation_0-rmse:16.91859	validation_1-rmse:17.24914
# [257]	validation_0-rmse:16.91402	validation_1-rmse:17.24474
# [258]	validation_0-rmse:16.91284	validation_1-rmse:17.24470
# [259]	validation_0-rmse:16.90866	validation_1-rmse:17.24228
# [260]	validation_0-rmse:16.90366	validation_1-rmse:17.23936
# [261]	validation_0-rmse:16.90054	validation_1-rmse:17.23798
# [262]	validation_0-rmse:16.89730	validation_1-rmse:17.23738
# [263]	validation_0-rmse:16.89505	validation_1-rmse:17.23556
# [264]	validation_0-rmse:16.87629	validation_1-rmse:17.22503
# [265]	validation_0-rmse:16.87483	validation_1-rmse:17.22576
# [266]	validation_0-rmse:16.87196	validation_1-rmse:17.22516
# [267]	validation_0-rmse:16.86778	validation_1-rmse:17.22086
# [268]	validation_0-rmse:16.86297	validation_1-rmse:17.21888
# [269]	validation_0-rmse:16.85920	validation_1-rmse:17.22307
# [270]	validation_0-rmse:16.85612	validation_1-rmse:17.22263
# [271]	validation_0-rmse:16.85341	validation_1-rmse:17.22271
# [272]	validation_0-rmse:16.85005	validation_1-rmse:17.22043
# [273]	validation_0-rmse:16.84934	validation_1-rmse:17.22188
# [274]	validation_0-rmse:16.84771	validation_1-rmse:17.22092
# [275]	validation_0-rmse:16.84423	validation_1-rmse:17.22108
# [276]	validation_0-rmse:16.83867	validation_1-rmse:17.21932
# [277]	validation_0-rmse:16.83509	validation_1-rmse:17.21813
# [278]	validation_0-rmse:16.82904	validation_1-rmse:17.22315
# [279]	validation_0-rmse:16.82524	validation_1-rmse:17.21937
# [280]	validation_0-rmse:16.82205	validation_1-rmse:17.22046
# [281]	validation_0-rmse:16.81708	validation_1-rmse:17.22031
# [282]	validation_0-rmse:16.81169	validation_1-rmse:17.21760
# [283]	validation_0-rmse:16.80866	validation_1-rmse:17.21680
# [284]	validation_0-rmse:16.80106	validation_1-rmse:17.20889
# [285]	validation_0-rmse:16.79778	validation_1-rmse:17.20787
# [286]	validation_0-rmse:16.79406	validation_1-rmse:17.20939
# [287]	validation_0-rmse:16.78844	validation_1-rmse:17.20695
# [288]	validation_0-rmse:16.78316	validation_1-rmse:17.20667
# [289]	validation_0-rmse:16.77693	validation_1-rmse:17.20321
# [290]	validation_0-rmse:16.77063	validation_1-rmse:17.20141
# [291]	validation_0-rmse:16.76697	validation_1-rmse:17.20001
# [292]	validation_0-rmse:16.76485	validation_1-rmse:17.20031
# [293]	validation_0-rmse:16.76008	validation_1-rmse:17.19628
# [294]	validation_0-rmse:16.75216	validation_1-rmse:17.18837
# [295]	validation_0-rmse:16.74806	validation_1-rmse:17.18448
# [296]	validation_0-rmse:16.74439	validation_1-rmse:17.18603
# [297]	validation_0-rmse:16.73570	validation_1-rmse:17.17695
# [298]	validation_0-rmse:16.73296	validation_1-rmse:17.17594
# [299]	validation_0-rmse:16.72732	validation_1-rmse:17.17549
# [300]	validation_0-rmse:16.72266	validation_1-rmse:17.17319
# [301]	validation_0-rmse:16.72099	validation_1-rmse:17.17258
# [302]	validation_0-rmse:16.71638	validation_1-rmse:17.17504
# [303]	validation_0-rmse:16.71286	validation_1-rmse:17.17152
# [304]	validation_0-rmse:16.70861	validation_1-rmse:17.17108
# [305]	validation_0-rmse:16.70520	validation_1-rmse:17.17041
# [306]	validation_0-rmse:16.70127	validation_1-rmse:17.16788
# [307]	validation_0-rmse:16.69757	validation_1-rmse:17.16690
# [308]	validation_0-rmse:16.69313	validation_1-rmse:17.16547
# [309]	validation_0-rmse:16.68769	validation_1-rmse:17.16128
# [310]	validation_0-rmse:16.68159	validation_1-rmse:17.15869
# [311]	validation_0-rmse:16.67678	validation_1-rmse:17.15611
# [312]	validation_0-rmse:16.67306	validation_1-rmse:17.15853
# [313]	validation_0-rmse:16.66940	validation_1-rmse:17.15735
# [314]	validation_0-rmse:16.66402	validation_1-rmse:17.15439
# [315]	validation_0-rmse:16.66134	validation_1-rmse:17.15422
# [316]	validation_0-rmse:16.65504	validation_1-rmse:17.14916
# [317]	validation_0-rmse:16.65144	validation_1-rmse:17.14671
# [318]	validation_0-rmse:16.64899	validation_1-rmse:17.14658
# [319]	validation_0-rmse:16.64678	validation_1-rmse:17.14617
# [320]	validation_0-rmse:16.64212	validation_1-rmse:17.14570
# [321]	validation_0-rmse:16.63832	validation_1-rmse:17.14600
# [322]	validation_0-rmse:16.63553	validation_1-rmse:17.14565
# [323]	validation_0-rmse:16.62973	validation_1-rmse:17.14151
# [324]	validation_0-rmse:16.62736	validation_1-rmse:17.14305
# [325]	validation_0-rmse:16.62445	validation_1-rmse:17.14328
# [326]	validation_0-rmse:16.61747	validation_1-rmse:17.14197
# [327]	validation_0-rmse:16.61296	validation_1-rmse:17.14208
# [328]	validation_0-rmse:16.60803	validation_1-rmse:17.14186
# [329]	validation_0-rmse:16.60323	validation_1-rmse:17.13942
# [330]	validation_0-rmse:16.59900	validation_1-rmse:17.13962
# [331]	validation_0-rmse:16.59436	validation_1-rmse:17.13785
# [332]	validation_0-rmse:16.59118	validation_1-rmse:17.13750
# [333]	validation_0-rmse:16.58747	validation_1-rmse:17.13795
# [334]	validation_0-rmse:16.58356	validation_1-rmse:17.13591
# [335]	validation_0-rmse:16.57860	validation_1-rmse:17.13681
# [336]	validation_0-rmse:16.57323	validation_1-rmse:17.13578
# [337]	validation_0-rmse:16.57060	validation_1-rmse:17.13460
# [338]	validation_0-rmse:16.56641	validation_1-rmse:17.13476
# [339]	validation_0-rmse:16.56356	validation_1-rmse:17.13589
# [340]	validation_0-rmse:16.56072	validation_1-rmse:17.13699
# [341]	validation_0-rmse:16.55775	validation_1-rmse:17.13570
# [342]	validation_0-rmse:16.55534	validation_1-rmse:17.13467
# [343]	validation_0-rmse:16.54962	validation_1-rmse:17.14074
# [344]	validation_0-rmse:16.54550	validation_1-rmse:17.14279
# [345]	validation_0-rmse:16.53990	validation_1-rmse:17.14142
# [346]	validation_0-rmse:16.53697	validation_1-rmse:17.14415
# [347]	validation_0-rmse:16.53023	validation_1-rmse:17.14619
# [348]	validation_0-rmse:16.52583	validation_1-rmse:17.14497
# [349]	validation_0-rmse:16.52369	validation_1-rmse:17.14803
# [350]	validation_0-rmse:16.52107	validation_1-rmse:17.14700
# [351]	validation_0-rmse:16.51783	validation_1-rmse:17.14559
# [352]	validation_0-rmse:16.51306	validation_1-rmse:17.14999
# [353]	validation_0-rmse:16.50869	validation_1-rmse:17.14710
# [354]	validation_0-rmse:16.50638	validation_1-rmse:17.14700
# [355]	validation_0-rmse:16.50418	validation_1-rmse:17.14697
# [356]	validation_0-rmse:16.50097	validation_1-rmse:17.14695
# [357]	validation_0-rmse:16.49742	validation_1-rmse:17.14842
# [358]	validation_0-rmse:16.49264	validation_1-rmse:17.15216
# [359]	validation_0-rmse:16.48739	validation_1-rmse:17.15212
# [360]	validation_0-rmse:16.48350	validation_1-rmse:17.14826
# [361]	validation_0-rmse:16.48140	validation_1-rmse:17.14803
# [362]	validation_0-rmse:16.47850	validation_1-rmse:17.14981
# [363]	validation_0-rmse:16.47517	validation_1-rmse:17.14820
# [364]	validation_0-rmse:16.47143	validation_1-rmse:17.14647
# [365]	validation_0-rmse:16.46847	validation_1-rmse:17.14665
# [366]	validation_0-rmse:16.46394	validation_1-rmse:17.14153
# [367]	validation_0-rmse:16.46231	validation_1-rmse:17.14097
# [368]	validation_0-rmse:16.45984	validation_1-rmse:17.14155
# [369]	validation_0-rmse:16.45657	validation_1-rmse:17.13955
# [370]	validation_0-rmse:16.45353	validation_1-rmse:17.13879
# [371]	validation_0-rmse:16.45066	validation_1-rmse:17.13680
# [372]	validation_0-rmse:16.44892	validation_1-rmse:17.13568
# [373]	validation_0-rmse:16.44625	validation_1-rmse:17.13399
# [374]	validation_0-rmse:16.44251	validation_1-rmse:17.13176
# [375]	validation_0-rmse:16.44070	validation_1-rmse:17.13179
# [376]	validation_0-rmse:16.43730	validation_1-rmse:17.14040
# [377]	validation_0-rmse:16.43557	validation_1-rmse:17.14099
# [378]	validation_0-rmse:16.43287	validation_1-rmse:17.14116
# [379]	validation_0-rmse:16.42743	validation_1-rmse:17.14256
# [380]	validation_0-rmse:16.42077	validation_1-rmse:17.13961
# [381]	validation_0-rmse:16.41709	validation_1-rmse:17.14038
# [382]	validation_0-rmse:16.41355	validation_1-rmse:17.14127
# [383]	validation_0-rmse:16.41134	validation_1-rmse:17.14372
# [384]	validation_0-rmse:16.40551	validation_1-rmse:17.14044
# [385]	validation_0-rmse:16.40296	validation_1-rmse:17.13874
# [386]	validation_0-rmse:16.40187	validation_1-rmse:17.13836
# [387]	validation_0-rmse:16.39693	validation_1-rmse:17.13757
# [388]	validation_0-rmse:16.39499	validation_1-rmse:17.13684
# [389]	validation_0-rmse:16.38973	validation_1-rmse:17.13021
# [390]	validation_0-rmse:16.38625	validation_1-rmse:17.12544
# [391]	validation_0-rmse:16.38249	validation_1-rmse:17.12723
# [392]	validation_0-rmse:16.37851	validation_1-rmse:17.12512
# [393]	validation_0-rmse:16.37493	validation_1-rmse:17.12554
# [394]	validation_0-rmse:16.37413	validation_1-rmse:17.12507
# [395]	validation_0-rmse:16.37183	validation_1-rmse:17.12394
# [396]	validation_0-rmse:16.36859	validation_1-rmse:17.12481
# [397]	validation_0-rmse:16.36752	validation_1-rmse:17.12538
# [398]	validation_0-rmse:16.36447	validation_1-rmse:17.12514
# [399]	validation_0-rmse:16.36126	validation_1-rmse:17.12515
# [400]	validation_0-rmse:16.35932	validation_1-rmse:17.12688
# [401]	validation_0-rmse:16.35645	validation_1-rmse:17.12778
# [402]	validation_0-rmse:16.35600	validation_1-rmse:17.12769
# [403]	validation_0-rmse:16.35280	validation_1-rmse:17.12428
# [404]	validation_0-rmse:16.35131	validation_1-rmse:17.12436
# [405]	validation_0-rmse:16.34888	validation_1-rmse:17.12315
# [406]	validation_0-rmse:16.34103	validation_1-rmse:17.11487
# [407]	validation_0-rmse:16.33793	validation_1-rmse:17.11920
# [408]	validation_0-rmse:16.33424	validation_1-rmse:17.11891
# [409]	validation_0-rmse:16.33030	validation_1-rmse:17.11885
# [410]	validation_0-rmse:16.32686	validation_1-rmse:17.11905
# [411]	validation_0-rmse:16.32031	validation_1-rmse:17.12401
# [412]	validation_0-rmse:16.31385	validation_1-rmse:17.12936
# [413]	validation_0-rmse:16.31011	validation_1-rmse:17.12846
# [414]	validation_0-rmse:16.30574	validation_1-rmse:17.12839
# [415]	validation_0-rmse:16.30376	validation_1-rmse:17.12917
# [416]	validation_0-rmse:16.30144	validation_1-rmse:17.12919
# [417]	validation_0-rmse:16.29918	validation_1-rmse:17.12845
# [418]	validation_0-rmse:16.29567	validation_1-rmse:17.12450
# [419]	validation_0-rmse:16.29288	validation_1-rmse:17.12218
# [420]	validation_0-rmse:16.28916	validation_1-rmse:17.12215
# [421]	validation_0-rmse:16.28580	validation_1-rmse:17.12334
# [422]	validation_0-rmse:16.28273	validation_1-rmse:17.12379
# [423]	validation_0-rmse:16.28171	validation_1-rmse:17.12315
# [424]	validation_0-rmse:16.27674	validation_1-rmse:17.11943
# [425]	validation_0-rmse:16.27534	validation_1-rmse:17.11918
# [426]	validation_0-rmse:16.27253	validation_1-rmse:17.12000
# [427]	validation_0-rmse:16.26869	validation_1-rmse:17.11820
# [428]	validation_0-rmse:16.26605	validation_1-rmse:17.11803
# [429]	validation_0-rmse:16.26544	validation_1-rmse:17.11650
# [430]	validation_0-rmse:16.25869	validation_1-rmse:17.11022
# [431]	validation_0-rmse:16.25345	validation_1-rmse:17.10235
# [432]	validation_0-rmse:16.25054	validation_1-rmse:17.10384
# [433]	validation_0-rmse:16.24490	validation_1-rmse:17.09880
# [434]	validation_0-rmse:16.24427	validation_1-rmse:17.10153
# [435]	validation_0-rmse:16.24198	validation_1-rmse:17.09960
# [436]	validation_0-rmse:16.23484	validation_1-rmse:17.09973
# [437]	validation_0-rmse:16.23155	validation_1-rmse:17.09905
# [438]	validation_0-rmse:16.22866	validation_1-rmse:17.09819
# [439]	validation_0-rmse:16.22503	validation_1-rmse:17.09821
# [440]	validation_0-rmse:16.22034	validation_1-rmse:17.10123
# [441]	validation_0-rmse:16.21971	validation_1-rmse:17.10099
# [442]	validation_0-rmse:16.21684	validation_1-rmse:17.10093
# [443]	validation_0-rmse:16.21632	validation_1-rmse:17.10097
# [444]	validation_0-rmse:16.21573	validation_1-rmse:17.10109
# [445]	validation_0-rmse:16.21396	validation_1-rmse:17.09997
# [446]	validation_0-rmse:16.21281	validation_1-rmse:17.09982
# [447]	validation_0-rmse:16.20974	validation_1-rmse:17.09706
# [448]	validation_0-rmse:16.20810	validation_1-rmse:17.09577
# [449]	validation_0-rmse:16.19807	validation_1-rmse:17.09054
# [450]	validation_0-rmse:16.19235	validation_1-rmse:17.09421
# [451]	validation_0-rmse:16.19134	validation_1-rmse:17.09477
# [452]	validation_0-rmse:16.19076	validation_1-rmse:17.09484
# [453]	validation_0-rmse:16.18751	validation_1-rmse:17.09604
# [454]	validation_0-rmse:16.18379	validation_1-rmse:17.09181
# [455]	validation_0-rmse:16.18021	validation_1-rmse:17.09770
# [456]	validation_0-rmse:16.17877	validation_1-rmse:17.09771
# [457]	validation_0-rmse:16.17059	validation_1-rmse:17.09342
# [458]	validation_0-rmse:16.16783	validation_1-rmse:17.09339
# [459]	validation_0-rmse:16.16335	validation_1-rmse:17.09761
# [460]	validation_0-rmse:16.15909	validation_1-rmse:17.09597
# [461]	validation_0-rmse:16.15509	validation_1-rmse:17.09394
# [462]	validation_0-rmse:16.15443	validation_1-rmse:17.09392
# [463]	validation_0-rmse:16.15267	validation_1-rmse:17.09328
# [464]	validation_0-rmse:16.14992	validation_1-rmse:17.09291
# [465]	validation_0-rmse:16.14904	validation_1-rmse:17.09257
# [466]	validation_0-rmse:16.14618	validation_1-rmse:17.09303
# [467]	validation_0-rmse:16.14449	validation_1-rmse:17.09360
# [468]	validation_0-rmse:16.14248	validation_1-rmse:17.09383
# [469]	validation_0-rmse:16.13971	validation_1-rmse:17.09257
# [470]	validation_0-rmse:16.13374	validation_1-rmse:17.09344
# [471]	validation_0-rmse:16.12913	validation_1-rmse:17.09601
# [472]	validation_0-rmse:16.12436	validation_1-rmse:17.09602
# [473]	validation_0-rmse:16.11914	validation_1-rmse:17.10057
# [474]	validation_0-rmse:16.11690	validation_1-rmse:17.09977
# [475]	validation_0-rmse:16.11381	validation_1-rmse:17.09840
# [476]	validation_0-rmse:16.11045	validation_1-rmse:17.09312
# [477]	validation_0-rmse:16.10740	validation_1-rmse:17.09715
# [478]	validation_0-rmse:16.10310	validation_1-rmse:17.09965
# [479]	validation_0-rmse:16.10061	validation_1-rmse:17.09955
# [480]	validation_0-rmse:16.09886	validation_1-rmse:17.10084
# [481]	validation_0-rmse:16.09379	validation_1-rmse:17.09966
# [482]	validation_0-rmse:16.09177	validation_1-rmse:17.09777
# [483]	validation_0-rmse:16.08730	validation_1-rmse:17.09786
# [484]	validation_0-rmse:16.08333	validation_1-rmse:17.09447
# [485]	validation_0-rmse:16.08025	validation_1-rmse:17.09354
# [486]	validation_0-rmse:16.07502	validation_1-rmse:17.09274
# [487]	validation_0-rmse:16.07109	validation_1-rmse:17.09444
# [488]	validation_0-rmse:16.06870	validation_1-rmse:17.09727
# [489]	validation_0-rmse:16.06452	validation_1-rmse:17.09750
# [490]	validation_0-rmse:16.06164	validation_1-rmse:17.09483
# [491]	validation_0-rmse:16.05731	validation_1-rmse:17.09260
# [492]	validation_0-rmse:16.05267	validation_1-rmse:17.09532
# [493]	validation_0-rmse:16.05076	validation_1-rmse:17.09378
# [494]	validation_0-rmse:16.04919	validation_1-rmse:17.09345
# [495]	validation_0-rmse:16.04537	validation_1-rmse:17.08925
# [496]	validation_0-rmse:16.04269	validation_1-rmse:17.08826
# [497]	validation_0-rmse:16.04065	validation_1-rmse:17.08846
# [498]	validation_0-rmse:16.03890	validation_1-rmse:17.08788
# [499]	validation_0-rmse:16.03697	validation_1-rmse:17.08809
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.2, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=500, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Show how much each of the features was used in our regression analysis
plt.figure(figsize=(15,5))
fi = pd.DataFrame(data=reg.feature_importances_,index=reg.feature_names_in_,columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.xlabel('Feature Importance')
plt.ylabel('Feature Name')
plt.show()

# %% [markdown]
# Plot train and validation errors of XGBoost model in the same graph

# %%
# Acquire the values of train and validation errors
results = reg.evals_result()
train_errors = results['validation_0']['rmse']
validation_errors = results['validation_1']['rmse']

# Plot the validation and training errors
plt.figure(figsize=(10, 6))
plt.plot(train_errors, label='Train Error (Train Set)')
plt.plot(validation_errors, label='Validation Error (Test Set)')
plt.xlabel('Number of Iterations')
plt.ylabel('RMSE score of XGBoost')
plt.title('XGBoost Model Training and Validation Errors')
plt.legend()
plt.show()

# %% [markdown]
# Make predictions on the test set

# %%
# Predict on the X_test, estimate the y_test values
y_pred_xgboost = reg.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# calculate the MAE of XGBoost model
mae_xgboost = mean_absolute_error(y_test, y_pred_xgboost)
print("Mae is: ",mae_xgboost)

# calculate RMSE score of XGBoost model
rmse_xgboost = mean_squared_error(y_test, y_pred_xgboost, squared=False)
print("RMSE score:", rmse_xgboost)
# Out:
# Mae is:  8.01153742687076
# RMSE score: 17.08808875689585

# %% [markdown]
# Show example of how well the model learned the trainning data.
#
#
# Use a random path to visualize the results

# %%
# Predict on the trainning set
y_pred_train = reg.predict(X_train)

# Add information in the trainning set
train_predictions = pd.DataFrame(index=pd.to_datetime(train['Time Column']))
train_predictions.insert(0,'Train Actual',y_train['Record 1(t)'].values)
train_predictions.insert(1,'Train Predicted',y_pred_train)
train_predictions.insert(2,'Path',X_train['Path'].values)

# Plot an example of the train-predictions at path 6 of the datase
plt.figure(figsize=(15,5))
plt.plot(train_predictions[train_predictions['Path']==6]['Train Actual'],".-",label='Actual Values')
plt.plot(train_predictions[train_predictions['Path']==6]['Train Predicted'],".-",label='Predictions on train set using XGboost')
plt.xlabel('Time')
plt.ylabel('Traffic Flow at path 6')
plt.title('Forecast on train set using XGBoost model')
plt.legend()
plt.show()

# %% [markdown]
# As we can see, the model has learned the trend and (almost) the seasonality of the data.
#
# Despite the non-linearity of Traffic Flow, XGBoost performs quite well!

# %%
# Store predictions of XGBoost model to a dataframe
total_predictions['Predicted XGBoost'] = y_pred_xgboost

# %%
# Print dataframe with predictions
total_predictions
# Out:
#                      Actual  Path  Predicted XGBoost
# Time Column
# 2008-06-06 03:00:04     7.0     0           3.476144
# 2008-06-06 03:30:04    11.0     0           6.013399
# 2008-06-06 04:00:04     6.0     0           8.511186
# 2008-06-06 04:30:04     3.0     0           7.730863
# 2008-06-06 05:00:04     4.0     0           5.149044
# ...                     ...   ...                ...
# 2008-06-10 07:00:04     0.0    99          -0.410955
# 2008-06-10 07:30:04     0.0    99          -0.705220
# 2008-06-10 08:00:04     0.0    99          -0.705220
# 2008-06-10 08:30:04     0.0    99          -0.705220
# 2008-06-10 09:00:04     0.0    99          -0.562332
#
# [20500 rows x 3 columns]

# %%
# Plot predictions for path 8
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==8]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==8]['Predicted XGBoost'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 8 using XGBoost model')
plt.legend()
plt.plot()
# Out:
# []

# %%
# Plot predictions for path 56
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==56]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==56]['Predicted XGBoost'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 56 using XGBoost model')
plt.legend()
plt.plot()
# Out:
# []

# %%
# Plot predictions for path 78
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==78]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==78]['Predicted XGBoost'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 78 using XGBoost model')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# Add in the same dataframe the RMSE and MAE scores of each model, in order to compare them

# %%
# Create dataframe with scores
scores = pd.DataFrame(columns=['Model','RMSE Score','MAE Score'])

# Define rows for dataframe
new_row = {'Model': 'XGBoost', 'RMSE Score': rmse_xgboost, 'MAE Score': mae_xgboost}

# Add rows to dataframe
scores = scores.append(new_row, ignore_index=True)

# Print dataframe with all model scores
scores
# Out:
#      Model  RMSE Score  MAE Score
# 0  XGBoost   17.088089   8.011537

# %% [markdown]
# Data that have been collected without the SPQ rules tend to introduce noice. By this way, the best model that we defined before, strugles to understand the data and find patterns in them.
